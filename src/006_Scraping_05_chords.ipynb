# %% [markdown]
# ## Lets extract chords from a song

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
from functools import reduce
import time
import random
import jl_io as io
import os
import uuid

# %%
url = 'https://tabs.ultimate-guitar.com/tab/mariah-carey/all-i-want-for-christmas-is-you-chords-903566'

# %%
class ChordExtractor:

    def __init__(self, raw_html_output_directory):
        self.raw_html_output_directory = raw_html_output_directory
        self.driver = self.create_chrome_driver()
        self.first_time = True
        
        if not os.path.isdir(self.raw_html_output_directory):
            os.mkdir(self.raw_html_output_directory)
            
    def extract_song_data(self,url):
        chords_spans = self.get_chord_spans(url)
        
        chords = [span.decode_contents() for span in chords_spans]
        
        song_uuid = str(uuid.uuid4())
        with open(f"{self.raw_html_output_directory}/{song_uuid}.html", "w") as file: # De los datos,como del cerdo, se guarda todo.
            file.write(self.driver.page_source )
    
        info = {
            "url":url,
            "chords":chords,
            "uuid":song_uuid
        }
        
        return info
    
    def get_chord_spans(self,url):
        self.driver.get(url)
        
        if self.driver.page_source == '<html><head></head><body></body></html>':
            raise Exception('Denegation error')

        if self.first_time:
            self.click_on_accept_cookies()
            self.first_time = False

        soup = BeautifulSoup(self.driver.page_source, 'lxml')

        article = soup.findAll('article')[3];
        
        return article.findAll('span', {"style":"color: rgb(0, 0, 0);"})
    
    def click_on_accept_cookies(self):
        try:
            button = self.driver.find_element_by_xpath('//button[contains(text(), "thanks")]')

            button.click()
        except:
            print('cookies banner not found. Ignored')
            
    
    def create_chrome_driver(self):
        options = webdriver.ChromeOptions()
        options.add_argument('--ignore-certificate-errors')
        options.add_argument('--incognito')
        options.add_argument('--headless')
        
        driver = webdriver.Chrome("./chromedriver", options=options)
        return driver

# %%
extractor = ChordExtractor('../data/pages/')

# %%
data = extractor.extract_song_data(url)
data
# Out:
# {'url': 'https://tabs.ultimate-guitar.com/tab/mariah-carey/all-i-want-for-christmas-is-you-chords-903566',
#  'chords': ['G',
#   'Em',
#   'C',
#   'D',
#   'G',
#   'G/B',
#   'C',
#   'Cm/Eb',
#   'G/B',
#   'B7',
#   'Em',
#   'Cm/Eb',
#   'G/D',
#   'E7',
#   'Am7',
#   'Cm6/D',
#   'G',
#   'Em',
#   'C',
#   'D',
#   'G',
#   'C',
#   'Eb6',
#   'G',
#   'G',
#   'C',
#   'Eb6',
#   'G',
#   'B7',
#   'Em',
#   'Eb6',
#   'G/D',
#   'E7',
#   'Am7',
#   'Cm6/D',
#   'G',
#   'Em',
#   'C',
#   'D',
#   'G',
#   'G',
#   'C',
#   'Eb6',
#   'G',
#   'C',
#   'Eb6',
#   'G',
#   'B7',
#   'Em',
#   'Eb6',
#   'G/D',
#   'E7',
#   'Am7',
#   'Cm6/Eb',
#   'G',
#   'Em',
#   'C',
#   'D',
#   'B7',
#   'Em',
#   'B7',
#   'Em',
#   'Eb6',
#   'G/D',
#   'E7',
#   'Am7',
#   'D',
#   'G',
#   'C',
#   'Eb6',
#   'G',
#   'B7',
#   'Em',
#   'Eb6',
#   'G/D',
#   'E7',
#   'Am7',
#   'Cm6/D',
#   'G',
#   'Em',
#   'C',
#   'D',
#   'G',
#   'Em',
#   'C',
#   'D',
#   'G',
#   'Em',
#   'C',
#   'D'],
#  'uuid': 'be739ac3-2f50-4475-a977-82760d472688'}

# %%
! ls ../data/pages/

# %% [markdown]
# ## Let's prepare a place to save our data

# %%
import pandas as pd
import os.path

class SongData:
    SEPARATOR = '^'
    
    def __init__(self, initial_data_path=None):
        self.df = pd.DataFrame(data=[], columns=['url','name','genre','decade','chords','uuid'])
        
        if initial_data_path is not None and os.path.isfile(initial_data_path):
            self.df = pd.read_csv(initial_data_path, sep=self.SEPARATOR)
            
    def add_basic_data(self,basic_data):
        self.df = self.df.append(basic_data,ignore_index=True)

    def add_details(self,details):
        self.df.loc[self.df['url'] == details["url"], ["chords"]] = str(details["chords"])
        self.df.loc[self.df['url'] == details["url"], ["uuid"]] = details["uuid"]
        
    def has_basic_data(self,url):
        return (self.df['url'] == url).any()
    
    def has_chords(self,url):
        return ((self.df['url'] == url) & (self.df['chords'].notnull())).any()
        
    def get_chords(self,url):
        return eval( self.df[self.df['url'] == url]['chords'][0])
    
    def has_genre_and_decade(self, genre, decade):
        return ((self.df['genre'] == genre) & (self.df['decade'] == decade)).any()
    
    def save(self, path):
        self.df.to_csv(path,index=False,sep=self.SEPARATOR)

# %%
data = SongData()
data.df

# %%
data.has_basic_data('http.://www.help.com')

# %%
data.has_chords('http.://www.help.com')

# %%
data.has_genre_and_decade('pop','1980s')

# %%
data.add_basic_data({
    "name":"Help",
    "url":"http.://www.help.com",
    "genre": "pop",
    "decade": "1980s",
})

# %%
data.df

# %%
data.has_basic_data('http.://www.help.com')

# %%
data.has_chords('http.://www.help.com')

# %%
data.has_genre_and_decade('pop','1980s')

# %%
data.add_details({
    "url":"http.://www.help.com",
    "chords": ["E", "F", "G"],
    'uuid': "7656-i87-gj"
})

# %%
data.df

# %%
data.has_basic_data('http.://www.help.com')

# %%
data.has_chords('http.://www.help.com')

# %%
data.get_chords('http.://www.help.com')[0]

# %%
data.save('borrare.csv')

# %%
data = SongData('borrare.csv')

# %%
data.get_chords('http.://www.help.com')[0]

# %%
! rm borrare.csv

# %% [markdown]
# ## Link extractor (adapted from previous notebooks)

# %% [markdown]
# Find song links for a genre and decade

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
from functools import reduce

class LinkExtractor:
    BASE_URL = "https://www.ultimate-guitar.com/explore?&type[]=Chords";
    
    def __init__(self):
        self.driver = self.create_chrome_driver()
        self.first_time = True
    
    def get_all_songs(self, genre, decade, first_page, last_page):
        links = self.get_all_filter_song_links(genre['pattern'],decade['pattern'], first_page, last_page)
        result = [ self.link_to_song_dict(link,genre,decade) for link in links]
        
        return result
    
    def link_to_song_dict(self,link, genre, decade):
        return {
            "name": link.contents[0],
            "url": link['href'],
            "genre": genre["name"],
            "decade": decade["name"]
        }
    
    def get_all_filter_song_links(self,genreFilter,decadeFilter, first_page, last_page):
        list_of_list = [self.get_links_single_page(genreFilter, decadeFilter, f'&page={page}')
                  for page in range(first_page,last_page + 1)]
        
        return reduce(lambda list1, list2: [*list1, *list2], list_of_list)
    
    def get_links_single_page(self,genreFilter,decadeFilter, pageFilter):
        self.driver.get(f'{self.BASE_URL}{genreFilter}{decadeFilter}{pageFilter}')
        
        if self.driver.page_source == '<html><head></head><body></body></html>':
            raise Exception('Denegation error')

        if self.first_time:
            self.click_on_accept_cookies()
            self.first_time = False

        soup = BeautifulSoup(self.driver.page_source, 'lxml')

        return soup.findAll('a', {"class":"_2KJtL _1mes3 kWOod"})
    
    def click_on_accept_cookies(self):
        try:
            button = self.driver.find_element_by_xpath('//button[contains(text(), "thanks")]')

            button.click()
        except:
            print('cookies banner not found. Ignored')
            
    
    def create_chrome_driver(self):
        options = webdriver.ChromeOptions()
        options.add_argument('--ignore-certificate-errors')
        options.add_argument('--incognito')
        options.add_argument('--headless')
        
        driver = webdriver.Chrome("./chromedriver", options=options)
        return driver

# %% [markdown]
# ## Simplified extractor (adapted from previous notebooks)

# %% [markdown]
# We are going to iterate through genres and decades (we will forget about styles)

# %%
import jl_io as io
genres = io.from_file('../data/genres')
decades = io.from_file('../data/decades')

# %% [markdown]
# Let's extract only the first page per genre and decade

# %%
potential_number_of_songs = len(genres) * len(decades) * 20
potential_number_of_songs
# Out:
# 2940

# %%
import jl_io as io

class SimplifiedCombinationsSongExtractor:
    def __init__(self, linkExtractor, chordExtractor, genres, decades, song_data):
        self.linkExtractor = linkExtractor
        self.chordExtractor = chordExtractor
        self.genres = genres
        self.decades = decades
        self.song_data = song_data
        
        self.combinations = []

        for decade in self.decades:
            for genre in self.genres:
                    self.combinations.append( {"decade": decade, "genre": genre})
        
    def extract(self, first_page, last_page):      
        startIndex = 1
        
        return self.extract_from(startIndex, first_page, last_page)
            
    def extract_from(self, startIndexBase1,first_page, last_page):    
        for index, combination in enumerate(self.combinations[startIndexBase1 - 1:]):
            new_extracted_songs = []
            genre = combination["genre"]
            decade = combination["decade"]
            
            if song_data.has_genre_and_decade(genre["name"], decade["name"]):
                print(f'{genre["name"]},{decade["name"]} already extracted')
                continue
            
            song_basic_data_array = []          
            try:
                song_basic_data_array = self.linkExtractor.get_all_songs(genre,decade, first_page, last_page)
                      
                for basic_data in song_basic_data_array:
                    self.song_data.add_basic_data(basic_data)
                      
                new_extracted_songs = [self.extract_song_data(index,song) for index,song in enumerate(new_extracted_songs)]
            except Exception as e: 
                print(f'Error in ({genre["name"]},{decade["name"]})')
                print(e)
                return
            
            for index,song in enumerate(song_basic_data_array):
                try:
                    self.extract_song_data(index,song)
                except Exception as e: 
                    print(f'Error in "{song["name"]}"')
                    print(e)
                    return
            
            number_of_songs = len(self.song_data.df)
            print(f'Extracted {index+startIndexBase1} of {len(self.combinations)} ({genre["name"]},{decade["name"]}). {number_of_songs} in total')  
        
    def extract_song_data(self,index,song): 
        if self.song_data.has_chords(song["url"]):
            print(f'Song {index}. "{song["name"]}" already extracted')  
            return
      
        song_details = self.chordExtractor.extract_song_data(song["url"])           
        self.song_data.add_details(song_details)
        print(f'Extracted data from song {index}. "{song["name"]}"')

# %% [markdown]
# ## Let's use it!

# %%
linkExtractor = LinkExtractor()

# %%
raw_html_output = '../data/raw_html'

# %%
chordExtractor = ChordExtractor(raw_html_output)

# %%
song_data = SongData()

# %%
extractor = SimplifiedCombinationsSongExtractor(linkExtractor,chordExtractor,genres,decades,song_data )

# %%
extractor.extract(first_page=1, last_page=1)
# Out:
# Extracted data from song 0. "All I Want"
# Extracted data from song 1. "Take Me To Church (ver 2)"
# Extracted data from song 2. "Radioactive"
# Extracted data from song 3. "Say Something (ver 3)"
# Extracted data from song 4. "Cigarette Daydreams"
# Extracted data from song 5. "Believer (ver 2)"
# Extracted data from song 6. "Million Reasons"
# Extracted data from song 7. "Counting Stars"
# Extracted data from song 8. "Sign Of The Times"
# Extracted data from song 9. "Demons"
# Extracted data from song 10. "Little Talks"
# Extracted data from song 11. "Take Me To Church"
# Extracted data from song 12. "High Hopes (ver 2)"
# Extracted data from song 13. "Demons (ver 2)"
# Extracted data from song 14. "Everglow"
# Extracted data from song 15. "High Hopes"
# Extracted data from song 16. "Say Something (ver 2)"
# Extracted data from song 17. "Another Love"
# Extracted data from song 18. "Pompeii (ver 3)"
# Extracted data from song 19. "Breezeblocks (ver 2)"
# Extracted data from song 20. "Sweet Creature"
# Extracted data from song 21. "Somebody Else"
# Extracted data from song 22. "Little Black Submarines (ver 2)"
# Extracted data from song 23. "Tonight You Belong To Me"
# Extracted data from song 24. "Youngblood"
# Extracted data from song 25. "We Are Young (ver 2)"
# Extracted data from song 26. "Shake Up Christmas"
# Extracted data from song 27. "Bad Liar"
# Extracted data from song 28. "The Less I Know The Better (ver 2)"
# Extracted data from song 29. "Colder Weather"
# Extracted data from song 30. "Youth"
# Extracted data from song 31. "A Sky Full Of Stars (ver 2)"
# Extracted data from song 32. "Chlorine"
# Extracted data from song 33. "Death Of A Bachelor"
# Extracted data from song 34. "All I Want (ver 6)"
# Extracted data from song 35. "Still Into You (ver 5)"
# Extracted data from song 36. "Renegades (ver 2)"
# Extracted data from song 37. "I Wanna Be Yours"
# Extracted data from song 38. "Unsteady"
# Extracted data from song 39. "Pumped Up Kicks"
# Extracted data from song 40. "Exs And Ohs"
# Extracted data from song 41. "Dirty Paws"
# Extracted data from song 42. "Rose Tattoo"
# Extracted data from song 43. "The Suburbs"
# Extracted data from song 44. "One More Light (ver 2)"
# Extracted data from song 45. "Two Ghosts"
# Extracted data from song 46. "Amnesia"
# Extracted data from song 47. "Talk Is Cheap"
# Extracted data from song 48. "From The Dining Table"
# Extracted data from song 49. "Paradise"
# Extracted 50 of 147 (Rock,2010s). 50 in total
# Extracted data from song 0. "Perfect"
# Extracted data from song 1. "Let Her Go"
# Extracted data from song 2. "Riptide (ver 2)"
# Extracted data from song 3. "Photograph"
# Extracted data from song 4. "Thinking Out Loud"
# Extracted data from song 5. "Let It Go (ver 2)"
# Extracted data from song 6. "Riptide"
# Extracted data from song 7. "The Night We Met"
# Extracted data from song 8. "Shape Of You (ver 2)"
# Extracted data from song 9. "Happier"
# Extracted data from song 10. "Supermarket Flowers"
# Extracted data from song 11. "Castle On The Hill"
# Extracted data from song 12. "Photograph (ver 2)"
# Extracted data from song 13. "Jar Of Hearts"
# Extracted data from song 14. "Ophelia (ver 4)"
# Extracted data from song 15. "Ophelia"
# Extracted data from song 16. "Ho Hey"
# Extracted data from song 17. "Galway Girl"
# Extracted data from song 18. "Stolen Dance"
# Extracted data from song 19. "I Wont Give Up"
# Extracted data from song 20. "Let Her Go (ver 2)"
# Song 21. "Another Love" already extracted
# Extracted data from song 22. "Shape Of You"
# Extracted data from song 23. "The A Team (ver 10)"
# Extracted data from song 24. "All Too Well"
# Extracted data from song 25. "Give Me Love (ver 5)"
# Extracted data from song 26. "Ho Hey (ver 2)"
# Extracted data from song 27. "Lego House"
# Extracted data from song 28. "The A Team (ver 4)"
# Extracted data from song 29. "Thinking Out Loud (ver 3)"
# Extracted data from song 30. "Cover Me Up (ver 2)"
# Extracted data from song 31. "Stubborn Love (ver 2)"
# Extracted data from song 32. "Rivers And Roads"
# Extracted data from song 33. "Stolen Dance (ver 3)"
# Extracted data from song 34. "Everything Has Changed"
# Extracted data from song 35. "Great Are You Lord"
# Song 36. "Tonight You Belong To Me" already extracted
# Extracted data from song 37. "Big Jet Plane"
# Extracted data from song 38. "Dive (ver 2)"
# Extracted data from song 39. "Budapest (ver 3)"
# Extracted data from song 40. "I Knew You Were Trouble"
# Extracted data from song 41. "Castle On The Hill (ver 3)"
# Extracted data from song 42. "Perfect (ver 5)"
# Extracted data from song 43. "Sleep On The Floor"
# Extracted data from song 44. "Thinking Out Loud (ver 2)"
# Extracted data from song 45. "I Took A Pill In Ibiza (ver 2)"
# Extracted data from song 46. "Tenerife Sea (ver 4)"
# Extracted data from song 47. "Kiss Me"
# Extracted data from song 48. "Hold Back The River (ver 4)"
# Extracted data from song 49. "Cold Little Heart"
# Extracted 50 of 147 (Folk,2010s). 100 in total
# Extracted data from song 0. "Someone Like You"
# Song 1. "Photograph" already extracted
# Song 2. "Thinking Out Loud" already extracted
# Extracted data from song 3. "When I Was Your Man"
# Extracted data from song 4. "Love Yourself"
# Extracted data from song 5. "Say You Wont Let Go (ver 4)"
# Extracted data from song 6. "Mistletoe (ver 5)"
# Extracted data from song 7. "Stay"
# Extracted data from song 8. "Rolling In The Deep (ver 4)"
# Extracted data from song 9. "Skinny Love (ver 4)"
# Extracted data from song 10. "Someone Like You (ver 2)"
# Extracted data from song 11. "Somebody That I Used To Know (ver 2)"
# Extracted data from song 12. "Stitches"
# Song 13. "Photograph (ver 2)" already extracted
# Extracted data from song 14. "Just The Way You Are"
# Song 15. "Jar Of Hearts" already extracted
# Extracted data from song 16. "Talking To The Moon"
# Extracted data from song 17. "Grenade"
# Extracted data from song 18. "Summertime Sadness"
# Extracted data from song 19. "Stone Cold"
# Extracted data from song 20. "Video Games"
# Extracted data from song 21. "Girls Like You"
# Extracted data from song 22. "Treat You Better (ver 3)"
# Extracted data from song 23. "Set Fire To The Rain (ver 2)"
# Song 24. "I Wont Give Up" already extracted
# Extracted data from song 25. "Mistletoe (ver 2)"
# Extracted data from song 26. "Mercy"
# Extracted data from song 27. "Count On Me (ver 3)"
# Extracted data from song 28. "Need You Now"
# Extracted data from song 29. "The Lazy Song (ver 9)"
# Extracted data from song 30. "Little Things (ver 4)"
# Extracted data from song 31. "Diamonds"
# Extracted data from song 32. "Just Give Me A Reason"
# Song 33. "All Too Well" already extracted
# Song 34. "Breezeblocks (ver 2)" already extracted
# Extracted data from song 35. "Turning Tables"
# Extracted data from song 36. "Back To December"
# Song 37. "Thinking Out Loud (ver 3)" already extracted
# Extracted data from song 38. "Night Changes"
# Extracted data from song 39. "Price Tag"
# Extracted data from song 40. "Little Do You Know"
# Extracted data from song 41. "Blue Jeans"
# Extracted data from song 42. "Liability (ver 2)"
# Song 43. "Everything Has Changed" already extracted
# Extracted data from song 44. "Rolling In The Deep"
# Extracted data from song 45. "Royals"
# Extracted data from song 46. "Imagination"
# Extracted data from song 47. "Born To Die (ver 2)"
# Extracted data from song 48. "Wrecking Ball"
# Extracted data from song 49. "Be My Mistake"
# Extracted 50 of 147 (Pop,2010s). 150 in total
# Extracted data from song 0. "Tennessee Whiskey"
# Extracted data from song 1. "Wagon Wheel"
# Song 2. "Ho Hey" already extracted
# Song 3. "Need You Now" already extracted
# Song 4. "Ho Hey (ver 2)" already extracted
# Extracted data from song 5. "Tennessee Whiskey (ver 3)"
# Extracted data from song 6. "Broken Halos"
# Song 7. "Back To December" already extracted
# Song 8. "Cover Me Up (ver 2)" already extracted
# Song 9. "Stubborn Love (ver 2)" already extracted
# Song 10. "Rivers And Roads" already extracted
# Song 11. "Colder Weather" already extracted
# Extracted data from song 12. "If I Die Young"
# Extracted data from song 13. "Back To December (ver 2)"
# Extracted data from song 14. "Fire Away"
# Extracted data from song 15. "Blue Aint Your Color"
# Extracted data from song 16. "Whiskey And You"
# Extracted data from song 17. "Christmas Makes Me Cry"
# Extracted data from song 18. "Stubborn Love"
# Extracted data from song 19. "Tin Man (ver 2)"
# Extracted data from song 20. "No Hard Feelings"
# Extracted data from song 21. "Drink A Beer"
# Extracted data from song 22. "Speak Now"
# Extracted data from song 23. "Dear John (ver 4)"
# Extracted data from song 24. "Mine (ver 2)"
# Extracted data from song 25. "My Church"
# Extracted data from song 26. "Enchanted"
# Extracted data from song 27. "Flowers In Your Hair"
# Extracted data from song 28. "Head Over Boots"
# Extracted data from song 29. "Mean (ver 6)"
# Extracted data from song 30. "Aint No Grave"
# Extracted data from song 31. "Sparks Fly"
# Extracted data from song 32. "Ours"
# Extracted data from song 33. "Parachute"
# Extracted data from song 34. "Holy"
# Extracted data from song 35. "Humble And Kind (ver 2)"
# Extracted data from song 36. "Slow It Down"
# Extracted data from song 37. "Kansas City"
# Extracted data from song 38. "Enchanted (ver 3)"
# Extracted data from song 39. "Never Grow Up"
# Extracted data from song 40. "Either Way"
# Extracted data from song 41. "Lost In My Mind"
# Extracted data from song 42. "Last Kiss"
# Extracted data from song 43. "If I Die Young (ver 2)"
# Extracted data from song 44. "Need You Now (ver 2)"
# Extracted data from song 45. "Broken Halos (ver 2)"
# Extracted data from song 46. "I Wish I Was"
# Extracted data from song 47. "Play It Again (ver 2)"
# Extracted data from song 48. "God Gave Me You (ver 2)"
# Extracted data from song 49. "Mean"
# Extracted 50 of 147 (Country,2010s). 200 in total
# Extracted data from song 0. "When The Partys Over"
# Extracted data from song 1. "I Love You"
# Extracted data from song 2. "Wake Me Up (ver 2)"
# Extracted data from song 3. "Bad Guy"
# Extracted data from song 4. "Xanny"
# Extracted data from song 5. "Chandelier (ver 3)"
# Extracted data from song 6. "All The Good Girls Go To Hell"
# Extracted data from song 7. "Listen Before I Go"
# Extracted data from song 8. "Oceans Where Feet May Fail (ver 7)"
# Extracted data from song 9. "Wake Me Up"
# Song 10. "Girls Like You" already extracted
# Extracted data from song 11. "Oceans Where Feet May Fail"
# Song 12. "High Hopes" already extracted
# Song 13. "Pompeii (ver 3)" already extracted
# Extracted data from song 14. "When The Partys Over (ver 2)"
# Extracted data from song 15. "Blank Space"
# Extracted data from song 16. "House Of Gold"
# Extracted data from song 17. "Bury A Friend"
# Song 18. "Liability (ver 2)" already extracted
# Song 19. "Somebody Else" already extracted
# Extracted data from song 20. "Elastic Heart"
# Extracted data from song 21. "Stressed Out"
# Extracted data from song 22. "Wildest Dreams"
# Extracted data from song 23. "Hey Brother (ver 4)"
# Song 24. "Youngblood" already extracted
# Extracted data from song 25. "Something Just Like This (ver 3)"
# Extracted data from song 26. "I Love You (ver 3)"
# Song 27. "Royals" already extracted
# Song 28. "Bad Liar" already extracted
# Song 29. "The Less I Know The Better (ver 2)" already extracted
# Song 30. "A Sky Full Of Stars (ver 2)" already extracted
# Extracted data from song 31. "Sorry (ver 2)"
# Extracted data from song 32. "Wish You Were Gay"
# Extracted data from song 33. "Ride (ver 3)"
# Song 34. "One More Light (ver 2)" already extracted
# Extracted data from song 35. "Shake It Off"
# Extracted data from song 36. "Fight Song"
# Extracted data from song 37. "Hey Brother"
# Extracted data from song 38. "Somewhere Only We Know (ver 2)"
# Extracted data from song 39. "8"
# Extracted data from song 40. "Scars To Your Beautiful"
# Extracted data from song 41. "Bad Guy (ver 2)"
# Extracted data from song 42. "Ilomilo"
# Extracted data from song 43. "Piece By Piece"
# Extracted data from song 44. "Ghost Of You"
# Extracted data from song 45. "Cheap Thrills (ver 2)"
# Extracted data from song 46. "Lie To Me"
# Extracted data from song 47. "Love Me Like You Do (ver 3)"
# Extracted data from song 48. "Waiting For Love"
# Extracted data from song 49. "Blank Space (ver 2)"
# Extracted 50 of 147 (Electronic,2010s). 250 in total
# Extracted data from song 0. "All Of Me"
# Song 1. "Someone Like You" already extracted
# Song 2. "Take Me To Church (ver 2)" already extracted
# Extracted data from song 3. "When We Were Young"
# Extracted data from song 4. "Stay With Me"
# Song 5. "Rolling In The Deep (ver 4)" already extracted
# Extracted data from song 6. "Im Not The Only One"
# Song 7. "Someone Like You (ver 2)" already extracted
# Song 8. "Stitches" already extracted
# Extracted data from song 9. "All Of Me (ver 3)"
# Extracted data from song 10. "All I Ask"
# Extracted data from song 11. "7 Years (ver 2)"
# Extracted data from song 12. "Hello"
# Song 13. "Take Me To Church" already extracted
# Song 14. "Set Fire To The Rain (ver 2)" already extracted
# Extracted data from song 15. "Rise Up"
# Extracted data from song 16. "Stay With Me (ver 2)"
# Extracted data from song 17. "One Call Away"
# Song 18. "Turning Tables" already extracted
# Extracted data from song 19. "Hello (ver 2)"
# Extracted data from song 20. "We Dont Talk Anymore"
# Song 21. "Rolling In The Deep" already extracted
# Song 22. "Imagination" already extracted
# Extracted data from song 23. "Redbone"
# Extracted data from song 24. "Self Control"
# Extracted data from song 25. "Happy (ver 4)"
# Song 26. "Exs And Ohs" already extracted
# Extracted data from song 27. "Im Not The Only One (ver 2)"
# Song 28. "Cold Little Heart" already extracted
# Extracted data from song 29. "Ivy"
# Extracted data from song 30. "Never Be Alone"
# Extracted data from song 31. "Stitches (ver 2)"
# Extracted data from song 32. "Million Years Ago"
# Extracted data from song 33. "Uptown Funk"
# Extracted data from song 34. "One And Only"
# Extracted data from song 35. "Work Song"
# Extracted data from song 36. "Lay Me Down"
# Extracted data from song 37. "Set Fire To The Rain"
# Extracted data from song 38. "From Eden"
# Extracted data from song 39. "Life Of The Party (ver 3)"
# Extracted data from song 40. "All Time Low"
# Extracted data from song 41. "Someone New"
# Extracted data from song 42. "Dont You Remember (ver 6)"
# Extracted data from song 43. "Love And Hate"
# Extracted data from song 44. "Too Close"
# Extracted data from song 45. "When We Were Young (ver 5)"
# Extracted data from song 46. "Forget You"
# Extracted data from song 47. "Rolling In The Deep (ver 2)"
# Extracted data from song 48. "7 Years"
# Extracted data from song 49. "Jackie And Wilson"
# Extracted 50 of 147 (Rhythm And Blues,2010s). 300 in total
# Extracted data from song 0. "The Sound Of Silence"
# Extracted data from song 1. "So Far Away"
# Extracted data from song 2. "Drown (ver 4)"
# Extracted data from song 3. "The Sound Of Silence (ver 3)"
# Extracted data from song 4. "Drown"
# Extracted data from song 5. "Song 3"
# Extracted data from song 6. "He Is"
# Extracted data from song 7. "A Reason To Fight (ver 2)"
# Extracted data from song 8. "For Evigt"
# Extracted data from song 9. "Wrong Side Of Heaven (ver 2)"
# Extracted data from song 10. "Alone In A Room"
# Extracted data from song 11. "Ashes Of Eden"
# Extracted data from song 12. "Something To Remind You"
# Extracted data from song 13. "Geboren Um Zu Leben (ver 2)"
# Extracted data from song 14. "Diamant"
# Extracted data from song 15. "Cirice"
# Extracted data from song 16. "Stabbing In The Dark"
# Extracted data from song 17. "So Far Away (ver 6)"
# Extracted data from song 18. "Buried Alive"
# Extracted data from song 19. "Sleepwalking"
# Extracted data from song 20. "Hail To The King"
# Extracted data from song 21. "Lonesome Rider (ver 2)"
# Extracted data from song 22. "Fucked With An Anchor"
# Extracted data from song 23. "A Reason To Fight"
# Extracted data from song 24. "Ausländer"
# Extracted data from song 25. "Nightmare"
# Extracted data from song 26. "Lola Montez"
# Extracted data from song 27. "Sextape"
# Extracted data from song 28. "Imperfect"
# Extracted data from song 29. "Hesitate"
# Extracted data from song 30. "Remember Everything"
# Extracted data from song 31. "The Crow The Owl And The Dove (ver 2)"
# Extracted data from song 32. "Tonight The World Dies"
# Extracted data from song 33. "The Last Stand"
# Extracted data from song 34. "Taciturn"
# Extracted data from song 35. "Roman Sky"
# Extracted data from song 36. "The Lines (ver 2)"
# Extracted data from song 37. "The Devil In I"
# Extracted data from song 38. "St Marie"
# Extracted data from song 39. "Not Strong Enough (ver 2)"
# Extracted data from song 40. "Voices"
# Extracted data from song 41. "Vultures (ver 2)"
# Extracted data from song 42. "Whore"
# Extracted data from song 43. "The Morticians Daughter (ver 2)"
# Extracted data from song 44. "He Is (ver 2)"
# Extracted data from song 45. "Angels Fall"
# Extracted data from song 46. "Dont Need You (ver 2)"
# Extracted data from song 47. "Danger Line"
# Extracted data from song 48. "The Call Of The Mountains"
# Extracted data from song 49. "Fallen"
# Extracted 50 of 147 (Metal,2010s). 350 in total
# Song 0. "Love Yourself" already extracted
# Song 1. "When The Partys Over" already extracted
# Song 2. "I Love You" already extracted
# Song 3. "Stay" already extracted
# Song 4. "Bad Guy" already extracted
# Song 5. "Xanny" already extracted
# Song 6. "All The Good Girls Go To Hell" already extracted
# Song 7. "Listen Before I Go" already extracted
# Song 8. "Girls Like You" already extracted
# Extracted data from song 9. "Love On The Brain"
# Song 10. "Diamonds" already extracted
# Song 11. "When The Partys Over (ver 2)" already extracted
# Song 12. "Bury A Friend" already extracted
# Song 13. "I Love You (ver 3)" already extracted
# Song 14. "Wrecking Ball" already extracted
# Extracted data from song 15. "Feeling Whitney (ver 2)"
# Song 16. "Self Control" already extracted
# Song 17. "Happy (ver 4)" already extracted
# Song 18. "Wish You Were Gay" already extracted
# Extracted data from song 19. "I Hate U I Love U (ver 2)"
# Song 20. "Ivy" already extracted
# Extracted data from song 21. "Dangerous Woman"
# Extracted data from song 22. "Girl On Fire"
# Song 23. "Talk Is Cheap" already extracted
# Song 24. "8" already extracted
# Song 25. "Scars To Your Beautiful" already extracted
# Song 26. "Bad Guy (ver 2)" already extracted
# Song 27. "Ilomilo" already extracted
# Extracted data from song 28. "Secret Love Song"
# Extracted data from song 29. "Almost Is Never Enough (ver 5)"
# Extracted data from song 30. "Love Yourself (ver 2)"
# Extracted data from song 31. "Sorry"
# Extracted data from song 32. "Almost Is Never Enough (ver 4)"
# Extracted data from song 33. "Diamonds (ver 5)"
# Extracted data from song 34. "Wrecking Ball (ver 7)"
# Extracted data from song 35. "Go Flex"
# Extracted data from song 36. "Stay (ver 4)"
# Extracted data from song 37. "My Strange Addiction (ver 2)"
# Extracted data from song 38. "You Should See Me In A Crown"
# Extracted data from song 39. "I Was Made For Loving You"
# Extracted data from song 40. "As Long As You Love Me"
# Extracted data from song 41. "One Last Time (ver 2)"
# Extracted data from song 42. "We Cant Stop (ver 3)"
# Extracted data from song 43. "I Love You (ver 2)"
# Extracted data from song 44. "Congratulations"
# Extracted data from song 45. "Love Yourself (ver 4)"
# Extracted data from song 46. "Adore You"
# Extracted data from song 47. "Mirrors (ver 6)"
# Extracted data from song 48. "Feeling Whitney"
# Extracted data from song 49. "One Last Time"
# Extracted 50 of 147 (Contemporary R&b,2010s). 400 in total
# Song 0. "Oceans Where Feet May Fail (ver 7)" already extracted
# Song 1. "Oceans Where Feet May Fail" already extracted
# Song 2. "Great Are You Lord" already extracted
# Extracted data from song 3. "Revelation Song"
# Extracted data from song 4. "Trust In You"
# Extracted data from song 5. "Forever"
# Extracted data from song 6. "Great Are You Lord (ver 4)"
# Extracted data from song 7. "Oceans Where Feet May Fail (ver 3)"
# Extracted data from song 8. "Scandal Of Grace"
# Extracted data from song 9. "God With Us"
# Extracted data from song 10. "Sinking Deep (ver 2)"
# Extracted data from song 11. "Let It Rain"
# Extracted data from song 12. "How Can It Be"
# Extracted data from song 13. "I Am Not Alone"
# Extracted data from song 14. "Love Came Down"
# Extracted data from song 15. "Oceans Where Feet May Fail (ver 2)"
# Extracted data from song 16. "Build Your Kingdom Here"
# Extracted data from song 17. "Touch The Sky"
# Extracted data from song 18. "Salt And Light"
# Extracted data from song 19. "Your Great Name (ver 4)"
# Extracted data from song 20. "Miracles"
# Extracted data from song 21. "Once And For All"
# Extracted data from song 22. "Heres My Heart"
# Extracted data from song 23. "Great Are You Lord (ver 2)"
# Extracted data from song 24. "We Believe"
# Extracted data from song 25. "Holy Spirit"
# Extracted data from song 26. "Rooftops (ver 3)"
# Extracted data from song 27. "Your Glory Nothing But The Blood"
# Extracted data from song 28. "I Am Not Alone (ver 5)"
# Extracted data from song 29. "Captain"
# Extracted data from song 30. "In The River"
# Extracted data from song 31. "Alive"
# Extracted data from song 32. "Prince Of Peace"
# Extracted data from song 33. "Joy Of The Lord"
# Extracted data from song 34. "Rooftops"
# Extracted data from song 35. "Let It Rain (ver 2)"
# Extracted data from song 36. "Wake"
# Extracted data from song 37. "Gracious Tempest"
# Extracted data from song 38. "Sinking Deep (ver 5)"
# Extracted data from song 39. "All The Poor And Powerless (ver 2)"
# Extracted data from song 40. "God With Us"
# Extracted data from song 41. "Freedom Reigns"
# Extracted data from song 42. "Say The Word"
# Extracted data from song 43. "We Are"
# Extracted data from song 44. "First"
# Extracted data from song 45. "First (ver 2)"
# Extracted data from song 46. "Sinking Deep"
# Extracted data from song 47. "Steady My Heart (ver 2)"
# Extracted data from song 48. "Love Goes On"
# Extracted data from song 49. "Loyal"
# Extracted 50 of 147 (Religious Music,2010s). 450 in total
# Song 0. "House Of Gold" already extracted
# Song 1. "Stressed Out" already extracted
# Song 2. "Chlorine" already extracted
# Song 3. "Feeling Whitney (ver 2)" already extracted
# Song 4. "Ride (ver 3)" already extracted
# Extracted data from song 5. "Love The Way You Lie"
# Song 6. "All Time Low" already extracted
# Extracted data from song 7. "Truce"
# Song 8. "Go Flex" already extracted
# Extracted data from song 9. "We Dont Believe Whats On Tv (ver 3)"
# Extracted data from song 10. "Ride"
# Extracted data from song 11. "The Judge (ver 2)"
# Extracted data from song 12. "Rehab"
# Song 13. "Congratulations" already extracted
# Song 14. "Feeling Whitney" already extracted
# Extracted data from song 15. "Beneath Your Beautiful"
# Extracted data from song 16. "Tear In My Heart"
# Extracted data from song 17. "Car Radio"
# Extracted data from song 18. "Stereo Hearts (ver 2)"
# Extracted data from song 19. "Runaway (ver 2)"
# Extracted data from song 20. "Hold On Were Going Home (ver 4)"
# Extracted data from song 21. "Airplanes (ver 3)"
# Extracted data from song 22. "Centuries (ver 2)"
# Extracted data from song 23. "Smithereens"
# Extracted data from song 24. "Cant Hold Us"
# Extracted data from song 25. "Trees (ver 3)"
# Extracted data from song 26. "Goner (ver 3)"
# Extracted data from song 27. "Same Love"
# Extracted data from song 28. "River"
# Extracted data from song 29. "We Dont Believe Whats On Tv"
# Extracted data from song 30. "Migraine"
# Extracted data from song 31. "How To Love"
# Extracted data from song 32. "The Judge"
# Extracted data from song 33. "Beneath Your Beautiful (ver 2)"
# Extracted data from song 34. "My Blood (ver 2)"
# Extracted data from song 35. "Stressed Out (ver 3)"
# Extracted data from song 36. "Tear In My Heart (ver 2)"
# Extracted data from song 37. "Whistle (ver 2)"
# Extracted data from song 38. "The Monster"
# Extracted data from song 39. "Jumpsuit"
# Extracted data from song 40. "Guillotine"
# Extracted data from song 41. "Just A Dream (ver 2)"
# Extracted data from song 42. "Grand Piano"
# Extracted data from song 43. "Bandito"
# Extracted data from song 44. "The Hype"
# Extracted data from song 45. "Immortals"
# Extracted data from song 46. "Go Flex (ver 4)"
# Extracted data from song 47. "Starships (ver 2)"
# Extracted data from song 48. "Holy Grail"
# Extracted data from song 49. "House Of Gold (ver 3)"
# Extracted 50 of 147 (Hip Hop,2010s). 500 in total
# Extracted data from song 0. "Rude (ver 2)"
# Extracted data from song 1. "Rude (ver 7)"
# Extracted data from song 2. "Locked Away (ver 2)"
# Extracted data from song 3. "Lean On (ver 4)"
# Extracted data from song 4. "Rude"
# Extracted data from song 5. "Sunshine"
# Extracted data from song 6. "Powerful (ver 2)"
# Extracted data from song 7. "Lean On (ver 3)"
# Extracted data from song 8. "Take It Or Leave It"
# Extracted data from song 9. "Rude (ver 5)"
# Extracted data from song 10. "Dont Forget Your Roots (ver 2)"
# Extracted data from song 11. "Lean On (ver 2)"
# Extracted data from song 12. "Live Like A Warrior (ver 3)"
# Extracted data from song 13. "Green Bottles"
# Extracted data from song 14. "You Better Listen"
# Extracted data from song 15. "Sunshine (ver 3)"
# Extracted data from song 16. "Fade Away"
# Extracted data from song 17. "Let Your Hair Down"
# Extracted data from song 18. "Let Your Hair Down (ver 3)"
# Extracted data from song 19. "Love Comes And Goes (ver 2)"
# Extracted data from song 20. "Rude (ver 8)"
# Extracted data from song 21. "My Sweet Summer (ver 2)"
# Extracted data from song 22. "Finest Wine"
# Extracted data from song 23. "Still Young"
# Extracted data from song 24. "Breeze"
# Extracted data from song 25. "Molly Town"
# Extracted data from song 26. "Locked Away"
# Extracted data from song 27. "Augenbling"
# Extracted data from song 28. "Soften The Blow"
# Extracted data from song 29. "Get Free"
# Extracted data from song 30. "Rude (ver 3)"
# Extracted data from song 31. "Clean The House"
# Extracted data from song 32. "Sound Of Change"
# Extracted data from song 33. "Dont Forget Your Roots"
# Extracted data from song 34. "Only To Be"
# Extracted data from song 35. "Roots Reggae Music"
# Extracted data from song 36. "Sunshine (ver 2)"
# Extracted data from song 37. "Broken Car"
# Extracted data from song 38. "Lay My Claim"
# Extracted data from song 39. "Those Days"
# Extracted data from song 40. "Count Me In"
# Extracted data from song 41. "Panic (ver 2)"
# Extracted data from song 42. "Pch"
# Extracted data from song 43. "Same Old Situation"
# Extracted data from song 44. "Spun"
# Extracted data from song 45. "Lovelee"
# Extracted data from song 46. "Wonderful Life"
# Extracted data from song 47. "Steal The Light"
# Extracted data from song 48. "Sleep Wont Sleep"
# Extracted data from song 49. "All Night Loud (ver 2)"
# Extracted 50 of 147 (Reggae,2010s). 550 in total
# Extracted data from song 0. "Your Heart Is As Black As Night"
# Extracted data from song 1. "My Valentine"
# Extracted data from song 2. "Go Gentle (ver 2)"
# Extracted data from song 3. "Baby Im A Fool (ver 2)"
# Extracted data from song 4. "Your Heart Is As Black As Night (ver 2)"
# Extracted data from song 5. "Baby Im A Fool"
# Extracted data from song 6. "Carry On"
# Extracted data from song 7. "Go Gentle"
# Extracted data from song 8. "Im Gonna Sit Right Down And Write Myself A Letter"
# Extracted data from song 9. "My Valentine (ver 3)"
# Extracted data from song 10. "Our Love Is Easy"
# Extracted data from song 11. "Carry On (ver 2)"
# Extracted data from song 12. "Shine My Shoes"
# Extracted data from song 13. "Morning Sun"
# Extracted data from song 14. "Bad News"
# Extracted data from song 15. "Once I Was Loved"
# Extracted data from song 16. "My Valentine (ver 2)"
# Extracted data from song 17. "My Valentine (ver 5)"
# Extracted data from song 18. "Desperado"
# Extracted data from song 19. "Animal Spirits"
# Extracted data from song 20. "Animal Spirits (ver 2)"
# Extracted data from song 21. "Conscious Club"
# Extracted data from song 22. "Aunt Leslie"
# Extracted data from song 23. "Aunt Leslie (ver 2)"
# Extracted data from song 24. "Get Yourself Another Fool"
# Extracted data from song 25. "Flipside"
# Extracted data from song 26. "If I Tell You I Love You"
# Extracted data from song 27. "If I Take You Home Tonight"
# Extracted data from song 28. "Go Gentle (ver 3)"
# Extracted data from song 29. "Go Gentle (ver 4)"
# Extracted data from song 30. "Go Gentle (ver 5)"
# Extracted data from song 31. "Baby Im A Fool (ver 3)"
# Extracted data from song 32. "16 Tons"
# Extracted data from song 33. "Preacherman"
# Extracted data from song 34. "My Valentine (ver 4)"
# Extracted data from song 35. "California Dreamin"
# Extracted data from song 36. "Superstar"
# Extracted data from song 37. "Wallflower"
# Extracted data from song 38. "Feels Like Home"
# Extracted data from song 39. "Feels Like Home (ver 2)"
# Extracted data from song 40. "Feels Like Home (ver 3)"
# Extracted data from song 41. "Since I Fell For You"
# Extracted data from song 42. "Bye Bye Blackbird"
# Extracted data from song 43. "If The Stars Were Mine"
# Extracted data from song 44. "Les Etoiles"
# Extracted data from song 45. "The Rain"
# Extracted data from song 46. "My One And Only Thrill"
# Extracted data from song 47. "Tragedy"
# Extracted data from song 48. "Day Breaks"
# Extracted data from song 49. "State Of Mind"
# Extracted 50 of 147 (Jazz,2010s). 600 in total
# Extracted data from song 0. "Driving Towards The Daylight"
# Extracted data from song 1. "Floating Bridge"
# Extracted data from song 2. "Ride Em On Down"
# Extracted data from song 3. "Driving Towards The Daylight (ver 2)"
# Extracted data from song 4. "Catch The Blues"
# Extracted data from song 5. "Take My Love With You"
# Extracted data from song 6. "All Of Your Love"
# Extracted data from song 7. "I Cant Quit You Baby"
# Extracted data from song 8. "Slow Train"
# Extracted data from song 9. "Cant Let You Do It"
# Extracted data from song 10. "Spiral"
# Extracted data from song 11. "Little Man Youve Had A Busy Day"
# Extracted data from song 12. "I Dreamed I Saw St Augustine"
# Extracted data from song 13. "Hate To See You Go"
# Extracted data from song 14. "Hell To Pay"
# Extracted data from song 15. "Treasures"
# Extracted data from song 16. "You Cant Fail Me Now (ver 2)"
# Extracted data from song 17. "Not Cause I Wanted To"
# Extracted data from song 18. "Kiss Of Fire"
# Extracted data from song 19. "The Weed Smokers Dream"
# Extracted data from song 20. "I Will Be There"
# Extracted data from song 21. "I Will Be There (ver 2)"
# Extracted data from song 22. "Alabama Woman Blues"
# Extracted data from song 23. "Lucky Acoustic"
# Extracted data from song 24. "Cruel"
# Extracted data from song 25. "Yes Man"
# Extracted data from song 26. "Emily"
# Extracted data from song 27. "Emily (ver 2)"
# Extracted data from song 28. "Our Big Mistake"
# Extracted data from song 29. "Let Me Do It Over"
# Extracted data from song 30. "The Worst Is Yet To Come"
# Extracted data from song 31. "If It Wasnt For Bad"
# Extracted data from song 32. "Somebodys Knockin"
# Extracted data from song 33. "Eight Hundred Dollar Shoes"
# Extracted data from song 34. "Hey Ahab"
# Extracted data from song 35. "Gone To Shiloh"
# Extracted data from song 36. "When Love Is Dying"
# Extracted data from song 37. "Its A Long Long Way"
# Extracted data from song 38. "Alone"
# Extracted data from song 39. "Wait For Me"
# Extracted data from song 40. "In The Garden"
# Extracted data from song 41. "Love Aint A Love Song"
# Extracted data from song 42. "Used To Rule The World"
# Extracted data from song 43. "You Cant Fail Me Now"
# Extracted data from song 44. "Not Cause I Wanted To (ver 2)"
# Extracted data from song 45. "Standing In The Doorway"
# Extracted data from song 46. "Junkers Blues"
# Extracted data from song 47. "Kiss Of Fire (ver 2)"
# Extracted data from song 48. "Just Another Rider"
# Extracted data from song 49. "Just Your Fool"
# Extracted 50 of 147 (Blues,2010s). 650 in total
# Extracted data from song 0. "Vivir Mi Vida"
# Extracted data from song 1. "Darte Un Beso"
# Extracted data from song 2. "Lagrimas Negras"
# Extracted data from song 3. "Propuesta Indecente"
# Extracted data from song 4. "Cancioncitas De Amor"
# Extracted data from song 5. "Challa (ver 3)"
# Extracted data from song 6. "Mi Santa"
# Extracted data from song 7. "Lagrimas Negras (ver 2)"
# Extracted data from song 8. "Promise"
# Extracted data from song 9. "Odio"
# Extracted data from song 10. "Challa"
# Extracted data from song 11. "Incondicional"
# Extracted data from song 12. "Las Cosas Pequeñas"
# Extracted data from song 13. "Cancioncitas De Amor (ver 2)"
# Extracted data from song 14. "Eres Tú"
# Extracted data from song 15. "Hecha Para Mí"
# Extracted data from song 16. "Dulce"
# Extracted data from song 17. "Dulce (ver 2)"
# Extracted data from song 18. "Te Me Vas"
# Extracted data from song 19. "Te Me Vas (ver 2)"
# Extracted data from song 20. "You"
# Extracted data from song 21. "Magia Negra"
# Extracted data from song 22. "Soberbio"
# Extracted data from song 23. "Llévame Contigo"
# Extracted data from song 24. "La Bella Y La Bestia"
# Extracted data from song 25. "Soy El Mismo"
# Extracted data from song 26. "Soy El Mismo (ver 2)"
# Extracted data from song 27. "Te Robaré"
# Extracted data from song 28. "You Are Fire Intro"
# Extracted data from song 29. "You Are Fire"
# Extracted data from song 30. "Me Encanta"
# Extracted data from song 31. "Tu Príncipe"
# Extracted data from song 32. "Invisible"
# Extracted data from song 33. "Nada"
# Extracted data from song 34. "Flor Pálida"
# Extracted data from song 35. "Hipocresía"
# Extracted data from song 36. "Cautivo De Este Amor"
# Extracted data from song 37. "Necio"
# Extracted data from song 38. "Eres Mia"
# Extracted data from song 39. "Odio (ver 2)"
# Extracted data from song 40. "Odio (ver 3)"
# Extracted data from song 41. "Hilito"
# Extracted data from song 42. "Yo Tambien"
# Extracted data from song 43. "Rival"
# Extracted data from song 44. "Rival (ver 2)"
# Extracted data from song 45. "Challa (ver 2)"
# Extracted 46 of 147 (World Music,2010s). 696 in total
# Extracted data from song 0. "Get Lucky (ver 2)"
# Extracted data from song 1. "Instant Crush"
# Extracted data from song 2. "Get Lucky"
# Extracted data from song 3. "Lose Yourself To Dance"
# Extracted data from song 4. "Get Lucky (ver 4)"
# Extracted data from song 5. "Touch"
# Extracted data from song 6. "Instant Crush (ver 2)"
# Extracted data from song 7. "Give Life Back To Music"
# Extracted data from song 8. "Fragments Of Time"
# Extracted data from song 9. "Get Lucky (ver 3)"
# Extracted data from song 10. "Get Lucky (ver 5)"
# Extracted data from song 11. "Lose Yourself To Dance (ver 2)"
# Extracted data from song 12. "Doin It Right"
# Extracted data from song 13. "Within"
# Extracted data from song 14. "Within (ver 2)"
# Extracted data from song 15. "Cloud 9"
# Extracted data from song 16. "Lose Yourself To Dance (ver 3)"
# Extracted data from song 17. "Pocket Full Of Dreams"
# Extracted data from song 18. "Pocket Full Of Dreams (ver 2)"
# Extracted data from song 19. "Fragments Of Time (ver 2)"
# Extracted data from song 20. "Whole New Way"
# Extracted data from song 21. "Fire With Fire"
# Extracted data from song 22. "Fire With Fire (ver 2)"
# Extracted data from song 23. "Fire With Fire (ver 3)"
# Extracted data from song 24. "Skin Tight"
# Extracted data from song 25. "Touch (ver 2)"
# Extracted data from song 26. "Touch (ver 3)"
# Extracted data from song 27. "Doin It Right (ver 2)"
# Extracted data from song 28. "Shake It On"
# Extracted data from song 29. "Automaton"
# Extracted data from song 30. "Superfresh"
# Extracted data from song 31. "Hot Property"
# Extracted data from song 32. "Something About You"
# Extracted data from song 33. "Summer Girl"
# Extracted data from song 34. "Nights Out In The Jungle"
# Extracted data from song 35. "Dr Buzz"
# Extracted data from song 36. "We Can Do It"
# Extracted data from song 37. "Vitamin"
# Extracted data from song 38. "Vitamin (ver 2)"
# Extracted data from song 39. "Anything"
# Extracted data from song 40. "Anything (ver 2)"
# Extracted data from song 41. "Anything (ver 3)"
# Extracted data from song 42. "Crazy For You"
# Extracted data from song 43. "Crazy For You (ver 2)"
# Extracted data from song 44. "Headphones"
# Extracted data from song 45. "Heaven In Our Headlights"
# Extracted data from song 46. "Dreamings For Sleeping"
# Extracted data from song 47. "Wild Life"
# Extracted data from song 48. "Got Love"
# Extracted data from song 49. "All The Way"
# Extracted 50 of 147 (Disco,2010s). 746 in total
# Extracted data from song 0. "Foil"
# Extracted data from song 1. "Cnr"
# Extracted data from song 2. "Tmz"
# Extracted data from song 3. "Skipper Dan"
# Extracted data from song 4. "Skipper Dan (ver 2)"
# Extracted data from song 5. "Party In The Cia"
# Extracted data from song 6. "If That Isnt Love"
# Extracted data from song 7. "Stop Forwarding That Crap To Me"
# Extracted data from song 8. "Foil (ver 2)"
# Extracted data from song 9. "Word Crimes"
# Extracted data from song 10. "Mission Statement"
# Extracted data from song 11. "Jackson Park Express"
# Extracted 12 of 147 (Comedy,2010s). 758 in total
# Extracted data from song 0. "Kawaii"
# Extracted 1 of 147 (New Age,2010s). 759 in total
# Extracted data from song 0. "Amsterdam"
# Extracted data from song 1. "Saint Valentine"
# Extracted data from song 2. "Living Proof"
# Extracted data from song 3. "Liars"
# Extracted data from song 4. "Song Of The Lonely Mountain"
# Extracted data from song 5. "Apple Carts"
# Extracted data from song 6. "Apple Carts (ver 2)"
# Extracted 7 of 147 (Classical,2010s). 766 in total
# Extracted data from song 0. "Sober-Delic Acid Only"
# Extracted 1 of 147 (Experimental,2010s). 767 in total
# Extracted data from song 0. "World Princess Part Ii"
# Extracted data from song 1. "Girls Girls Girls"
# Extracted data from song 2. "Fight Like A Girl"
# Extracted data from song 3. "One Foot In Front Of The Other"
# Extracted 4 of 147 (Darkwave,2010s). 771 in total
# Extracted data from song 0. "Signals (ver 2)"
# Extracted data from song 1. "The Flame In The Flood"
# Extracted data from song 2. "We All Become"
# Extracted data from song 3. "What We Leave Behind"
# Extracted data from song 4. "The Flame In The Flood (ver 2)"
# Extracted data from song 5. "The Spine"
# Extracted data from song 6. "The Spine (ver 2)"
# Extracted data from song 7. "In Circles"
# Extracted data from song 8. "Signals"
# Extracted data from song 9. "Paper Boats"
# Extracted data from song 10. "Gathering Wood"
# Extracted data from song 11. "Cover Me Gently"
# Extracted 12 of 147 (Soundtrack,2010s). 783 in total
# Extracted data from song 0. "Im Yours (ver 8)"
# Extracted data from song 1. "Boulevard Of Broken Dreams (ver 3)"
# Extracted data from song 2. "Hey There Delilah (ver 3)"
# Extracted data from song 3. "Viva La Vida"
# Extracted data from song 4. "Yellow (ver 2)"
# Extracted data from song 5. "Fix You (ver 17)"
# Extracted data from song 6. "The Scientist (ver 5)"
# Extracted data from song 7. "Somewhere Only We Know"
# Extracted data from song 8. "Chasing Cars"
# Extracted data from song 9. "I Will Follow You Into The Dark (ver 3)"
# Extracted data from song 10. "The Scientist"
# Extracted data from song 11. "Love Story"
# Extracted data from song 12. "Yellow (ver 3)"
# Extracted data from song 13. "Hey Soul Sister (ver 2)"
# Extracted data from song 14. "Wake Me Up When September Ends (ver 4)"
# Extracted data from song 15. "The Scientist (ver 2)"
# Extracted data from song 16. "Numb"
# Extracted data from song 17. "The Only Exception"
# Extracted data from song 18. "She Will Be Loved (ver 3)"
# Extracted data from song 19. "Mr Brightside"
# Extracted data from song 20. "Im Yours"
# Extracted data from song 21. "Youre Beautiful (ver 2)"
# Extracted data from song 22. "Drops Of Jupiter"
# Extracted data from song 23. "Seven Nation Army"
# Extracted data from song 24. "Hey There Delilah (ver 4)"
# Extracted data from song 25. "Gravity"
# Extracted data from song 26. "You Belong With Me (ver 2)"
# Extracted data from song 27. "I Dont Want To Miss A Thing"
# Extracted data from song 28. "Fix You (ver 2)"
# Extracted data from song 29. "21 Guns"
# Extracted data from song 30. "Mad World"
# Extracted data from song 31. "Slow Dancing In A Burning Room (ver 2)"
# Extracted data from song 32. "Yellow"
# Extracted data from song 33. "Clocks"
# Extracted data from song 34. "Hero Of War (ver 3)"
# Extracted data from song 35. "Somewhere Only We Know (ver 8)"
# Extracted data from song 36. "This Love (ver 4)"
# Extracted data from song 37. "Apologize"
# Extracted data from song 38. "Here Without You (ver 3)"
# Extracted data from song 39. "I Dont Love You"
# Extracted data from song 40. "Youre Beautiful"
# Extracted data from song 41. "This Is The Life (ver 3)"
# Extracted data from song 42. "Mardy Bum"
# Extracted data from song 43. "Welcome To The Black Parade"
# Extracted data from song 44. "You And Me (ver 3)"
# Extracted data from song 45. "Lucky (ver 2)"
# Extracted data from song 46. "Holiday"
# Extracted data from song 47. "Snow Hey Oh"
# Extracted data from song 48. "Behind Blue Eyes"
# Extracted data from song 49. "I Am The Highway"
# Extracted 50 of 147 (Rock,2000s). 833 in total
# Song 0. "Im Yours (ver 8)" already extracted
# Song 1. "Im Yours" already extracted
# Song 2. "Youre Beautiful (ver 2)" already extracted
# Extracted data from song 3. "First Day Of My Life"
# Song 4. "Gravity" already extracted
# Extracted data from song 5. "Society"
# Extracted data from song 6. "Skinny Love (ver 2)"
# Extracted data from song 7. "Banana Pancakes"
# Song 8. "Mad World" already extracted
# Song 9. "Slow Dancing In A Burning Room (ver 2)" already extracted
# Extracted data from song 10. "Little Lion Man"
# Extracted data from song 11. "Better Together"
# Extracted data from song 12. "Falling Slowly"
# Song 13. "Youre Beautiful" already extracted
# Song 14. "This Is The Life (ver 3)" already extracted
# Extracted data from song 15. "Put Your Records On (ver 3)"
# Song 16. "Lucky (ver 2)" already extracted
# Extracted data from song 17. "The Blowers Daughter"
# Extracted data from song 18. "I Kissed A Girl"
# Extracted data from song 19. "Candy"
# Extracted data from song 20. "Lua"
# Extracted data from song 21. "Bubbly (ver 4)"
# Extracted data from song 22. "Mad World (ver 6)"
# Extracted data from song 23. "Hard Sun"
# Extracted data from song 24. "Home"
# Extracted data from song 25. "Last Request"
# Extracted data from song 26. "The Cave"
# Extracted data from song 27. "The Stable Song"
# Extracted data from song 28. "The Girl"
# Extracted data from song 29. "Re Stacks"
# Extracted data from song 30. "Daughters"
# Extracted data from song 31. "Upside Down"
# Extracted data from song 32. "You And I"
# Extracted data from song 33. "9 Crimes (ver 2)"
# Extracted data from song 34. "Jolene (ver 2)"
# Extracted data from song 35. "The Story (ver 2)"
# Extracted data from song 36. "Flume (ver 3)"
# Extracted data from song 37. "Love Song"
# Extracted data from song 38. "Lucky"
# Extracted data from song 39. "Stop This Train (ver 2)"
# Extracted data from song 40. "The Funeral"
# Extracted data from song 41. "Goodbye My Lover (ver 2)"
# Extracted data from song 42. "This Year (ver 4)"
# Extracted data from song 43. "Flightless Bird American Mouth"
# Extracted data from song 44. "Sitting Waiting Wishing (ver 2)"
# Extracted data from song 45. "Who Says (ver 3)"
# Extracted data from song 46. "White Winter Hymnal (ver 2)"
# Extracted data from song 47. "Anyone Else But You"
# Extracted data from song 48. "Waiting On The World To Change"
# Extracted data from song 49. "Delicate"
# Extracted 50 of 147 (Folk,2000s). 883 in total
# Song 0. "Im Yours (ver 8)" already extracted
# Extracted data from song 1. "Make You Feel My Love"
# Song 2. "Viva La Vida" already extracted
# Song 3. "Im Yours" already extracted
# Song 4. "Youre Beautiful (ver 2)" already extracted
# Extracted data from song 5. "You Raise Me Up (ver 3)"
# Song 6. "Youre Beautiful" already extracted
# Song 7. "Lucky (ver 2)" already extracted
# Extracted data from song 8. "Hero (ver 2)"
# Song 9. "I Kissed A Girl" already extracted
# Extracted data from song 10. "Umbrella"
# Extracted data from song 11. "Dont Know Why"
# Song 12. "Bubbly (ver 4)" already extracted
# Extracted data from song 13. "Chasing Pavements (ver 9)"
# Extracted data from song 14. "Hurt"
# Extracted data from song 15. "Paparazzi (ver 2)"
# Extracted data from song 16. "Youve Got The Love (ver 2)"
# Extracted data from song 17. "Dont Know Why (ver 2)"
# Extracted data from song 18. "Hallelujah (ver 2)"
# Extracted data from song 19. "Beautiful (ver 3)"
# Extracted data from song 20. "Feel Good Inc (ver 3)"
# Extracted data from song 21. "You Raise Me Up (ver 4)"
# Extracted data from song 22. "Dog Days Are Over (ver 3)"
# Extracted data from song 23. "Cry Me A River"
# Song 24. "Love Song" already extracted
# Song 25. "Lucky" already extracted
# Extracted data from song 26. "Sunrise (ver 4)"
# Song 27. "Goodbye My Lover (ver 2)" already extracted
# Extracted data from song 28. "White Flag (ver 4)"
# Extracted data from song 29. "Viva La Vida (ver 4)"
# Extracted data from song 30. "Broken Strings (ver 2)"
# Extracted data from song 31. "Make You Feel My Love (ver 7)"
# Extracted data from song 32. "Big Girls Dont Cry (ver 5)"
# Extracted data from song 33. "Chasing Pavements (ver 6)"
# Extracted data from song 34. "Come Away With Me"
# Extracted data from song 35. "Make You Feel My Love (ver 5)"
# Extracted data from song 36. "Dont Know Why (ver 4)"
# Extracted data from song 37. "Gravity (ver 2)"
# Extracted data from song 38. "Feel Good Inc (ver 4)"
# Extracted data from song 39. "Hometown Glory (ver 3)"
# Extracted data from song 40. "Dear Mr President (ver 4)"
# Extracted data from song 41. "Gravity"
# Extracted data from song 42. "Breathe Me"
# Extracted data from song 43. "A Thousand Miles (ver 2)"
# Extracted data from song 44. "Casimir Pulaski Day"
# Extracted data from song 45. "Prayer"
# Extracted data from song 46. "You Raise Me Up (ver 2)"
# Extracted data from song 47. "Northern Downpour"
# Extracted data from song 48. "Chasing Pavements"
# Extracted data from song 49. "With You (ver 7)"
# Extracted 50 of 147 (Pop,2000s). 933 in total
# Extracted data from song 0. "Hurt"
# Song 1. "Love Story" already extracted
# Song 2. "You Belong With Me (ver 2)" already extracted
# Extracted data from song 3. "Wagon Wheel"
# Extracted data from song 4. "Teardrops On My Guitar"
# Extracted data from song 5. "Your Man"
# Extracted data from song 6. "Hurt (ver 3)"
# Extracted data from song 7. "Picture"
# Extracted data from song 8. "Bless The Broken Road"
# Extracted data from song 9. "Wayfaring Stranger"
# Extracted data from song 10. "In Color"
# Extracted data from song 11. "Landslide"
# Extracted data from song 12. "Chicken Fried (ver 5)"
# Extracted data from song 13. "Whiskey Lullaby (ver 2)"
# Extracted data from song 14. "One"
# Song 15. "Flightless Bird American Mouth" already extracted
# Extracted data from song 16. "Follow Me"
# Extracted data from song 17. "The Old Rugged Cross"
# Extracted data from song 18. "Our Song"
# Extracted data from song 19. "Chicken Fried"
# Extracted data from song 20. "Chicken Fried (ver 6)"
# Extracted data from song 21. "Gods Gonna Cut You Down (ver 4)"
# Extracted data from song 22. "Personal Jesus"
# Extracted data from song 23. "Stay"
# Extracted data from song 24. "White Horse (ver 2)"
# Extracted data from song 25. "Old Number 7"
# Extracted data from song 26. "Turn Your Eyes Upon Jesus"
# Extracted data from song 27. "What Hurts The Most"
# Extracted data from song 28. "Whiskey Lullaby"
# Extracted data from song 29. "Fifteen"
# Extracted data from song 30. "Toes"
# Extracted data from song 31. "Before He Cheats (ver 2)"
# Extracted data from song 32. "Solitary Man"
# Extracted data from song 33. "Wagon Wheel (ver 2)"
# Extracted data from song 34. "Your Man (ver 3)"
# Extracted data from song 35. "You Belong With Me"
# Extracted data from song 36. "Oh My Sweet Carolina"
# Extracted data from song 37. "Personal Jesus (ver 2)"
# Extracted data from song 38. "Let It Be Christmas (ver 4)"
# Extracted data from song 39. "I Wont Back Down"
# Extracted data from song 40. "Long Black Train"
# Extracted data from song 41. "Fearless (ver 2)"
# Extracted data from song 42. "Red Dirt Road"
# Extracted data from song 43. "Three Wooden Crosses"
# Extracted data from song 44. "Hurt (ver 5)"
# Extracted data from song 45. "Big Black Car (ver 3)"
# Extracted data from song 46. "Youll Think Of Me (ver 2)"
# Extracted data from song 47. "Love Story (ver 2)"
# Extracted data from song 48. "I Hung My Head"
# Extracted data from song 49. "Further On Up The Road (ver 2)"
# Extracted 50 of 147 (Country,2000s). 983 in total
# Song 0. "Numb" already extracted
# Extracted data from song 1. "How He Loves"
# Song 2. "Paparazzi (ver 2)" already extracted
# Extracted data from song 3. "To Build A Home"
# Extracted data from song 4. "Crawling (ver 3)"
# Song 5. "Feel Good Inc (ver 3)" already extracted
# ...
# Extracted data from song 39. "Baby I Love Your Way (ver 2)"
# Extracted data from song 40. "Sunday Morning (ver 2)"
# Extracted data from song 41. "Spiderwebs"
# Extracted data from song 42. "Pawn Shop"
# Extracted data from song 43. "Here In Your Bedroom"
# Extracted data from song 44. "All I Want Is More"
# Extracted data from song 45. "Burritos"
# Extracted data from song 46. "Give You All The Love"
# Extracted data from song 47. "The Climb"
# Extracted data from song 48. "Dont Speak (ver 7)"
# Extracted data from song 49. "Ñapa Es"
# Extracted 50 of 147 (Reggae,1990s). 2163 in total
# Extracted data from song 0. "Fields Of Gold (ver 2)"
# Song 1. "I Try" already extracted
# Extracted data from song 2. "Autumn Leaves"
# Song 3. "Songbird (ver 2)" already extracted
# Extracted data from song 4. "Chan Chan"
# Extracted data from song 5. "Wade In The Water"
# Song 6. "I Try (ver 3)" already extracted
# Extracted data from song 7. "Dos Gardenias (ver 2)"
# Extracted data from song 8. "Over The Rainbow (ver 4)"
# Extracted data from song 9. "I Know You By Heart"
# Extracted data from song 10. "El Cuarto De Tula"
# Extracted data from song 11. "Veinte Años"
# Extracted data from song 12. "Falling"
# Extracted data from song 13. "Fields Of Gold (ver 4)"
# Extracted data from song 14. "What A Wonderful World"
# Extracted data from song 15. "Over The Rainbow"
# Extracted data from song 16. "Over The Rainbow (ver 5)"
# Extracted data from song 17. "Candela"
# Extracted data from song 18. "Bridge Over Troubled Water Live"
# Extracted data from song 19. "The Nearness Of You"
# Extracted data from song 20. "Chan Chan (ver 3)"
# Extracted data from song 21. "Fields Of Gold"
# Extracted data from song 22. "Autumn Leaves (ver 3)"
# Extracted data from song 23. "Chan Chan (ver 2)"
# Extracted data from song 24. "Dos Gardenias"
# Extracted data from song 25. "El Cuarto De Tula (ver 2)"
# Extracted data from song 26. "Veinte Años (ver 2)"
# Extracted data from song 27. "A Nightingale Sang In Berkeley Square"
# Extracted data from song 28. "A Foggy Day"
# Extracted data from song 29. "Candela (ver 2)"
# Extracted data from song 30. "Amor De Loca Juventud"
# Extracted data from song 31. "Buena Vista Social Club"
# Extracted data from song 32. "Brother Can You Spare A Dime"
# Extracted data from song 33. "Blue Skies"
# Extracted data from song 34. "Wayfaring Stranger"
# Extracted data from song 35. "Autumn Leaves (ver 2)"
# Extracted data from song 36. "Autumn Leaves (ver 5)"
# Extracted data from song 37. "What A Wonderful World (ver 2)"
# Extracted data from song 38. "Songbird"
# Extracted data from song 39. "Over The Rainbow (ver 6)"
# Extracted data from song 40. "Lets Fall In Love"
# Extracted data from song 41. "Sycamore Trees"
# Extracted data from song 42. "Dos Gardenias (ver 3)"
# Extracted data from song 43. "Walkin After Midnight"
# Extracted data from song 44. "Always A Use"
# Extracted data from song 45. "A Prayer"
# Extracted data from song 46. "Was I Drunk"
# Extracted data from song 47. "Dreamland"
# Extracted data from song 48. "Lovesick Blues"
# Extracted data from song 49. "Say Goodbye"
# Extracted 50 of 147 (Jazz,1990s). 2213 in total
# Extracted data from song 0. "Still Got The Blues"
# Extracted data from song 1. "Still Got The Blues (ver 3)"
# Extracted data from song 2. "Midnight Blues"
# Extracted data from song 3. "Walking By Myself"
# Extracted data from song 4. "It Hurts Me Too"
# Extracted data from song 5. "It Hurt So Bad"
# Extracted data from song 6. "Someday After A While (ver 2)"
# Extracted data from song 7. "Feels Like Rain"
# Extracted data from song 8. "Feels Like Rain (ver 2)"
# Extracted data from song 9. "Damn Right Ive Got The Blues"
# Extracted data from song 10. "She Just Wants To Dance"
# Extracted data from song 11. "Never Make Your Move Too Soon"
# Extracted data from song 12. "Mannish Boy"
# Extracted data from song 13. "Im Tore Down"
# Extracted data from song 14. "Motherless Child"
# Extracted data from song 15. "Motherless Child (ver 2)"
# Extracted data from song 16. "Walking By Myself (ver 2)"
# Extracted data from song 17. "Story Of The Blues"
# Extracted data from song 18. "Julia"
# Extracted data from song 19. "Julia (ver 2)"
# Extracted data from song 20. "Blood In My Eyes"
# Extracted data from song 21. "A Better Man"
# Extracted data from song 22. "Walking Away (ver 2)"
# Extracted data from song 23. "City Boy"
# Extracted data from song 24. "When You Got A Good Friend"
# Extracted data from song 25. "Blues Before Sunrise"
# Extracted data from song 26. "Sinners Prayer"
# Extracted data from song 27. "Someday After A While"
# Extracted data from song 28. "Too Long In Exile"
# Extracted data from song 29. "Who Let In The Rain (ver 2)"
# Extracted data from song 30. "Still Got The Blues (ver 2)"
# Extracted data from song 31. "Tanqueray"
# Extracted data from song 32. "Rock Me Right"
# Extracted data from song 33. "Little By Little"
# Extracted data from song 34. "More Than One Way Home (ver 2)"
# Extracted data from song 35. "Further On Up The Road"
# Extracted data from song 36. "Blood In My Eyes (ver 2)"
# Extracted data from song 37. "All Your Love"
# Extracted data from song 38. "Walking Away"
# Extracted data from song 39. "Leaving To Stay"
# Extracted data from song 40. "How Long Blues"
# Extracted data from song 41. "World Gone Wrong"
# Extracted data from song 42. "World Gone Wrong (ver 2)"
# Extracted data from song 43. "World Gone Wrong (ver 3)"
# Extracted data from song 44. "The New Hula Blues"
# Extracted data from song 45. "Tell Everybody I Know"
# Extracted data from song 46. "Strut"
# Extracted data from song 47. "Moving On"
# Extracted data from song 48. "True Love"
# Extracted data from song 49. "Betty N Dupree"
# Extracted 50 of 147 (Blues,1990s). 2263 in total
# Song 0. "Chan Chan" already extracted
# Extracted data from song 1. "Historia De Un Amor"
# Extracted data from song 2. "Como La Flor"
# Song 3. "Dos Gardenias (ver 2)" already extracted
# Song 4. "El Cuarto De Tula" already extracted
# Extracted data from song 5. "Amor Prohibido"
# Extracted data from song 6. "Dreaming Of You (ver 4)"
# Song 7. "Veinte Años" already extracted
# Extracted data from song 8. "No Volveré"
# Extracted data from song 9. "No Me Queda Más"
# Extracted data from song 10. "Love Is The Answer"
# Song 11. "Candela" already extracted
# Extracted data from song 12. "La Media Vuelta (ver 2)"
# Extracted data from song 13. "I Could Fall In Love"
# Extracted data from song 14. "Sozinho (ver 2)"
# Song 15. "Chan Chan (ver 3)" already extracted
# Extracted data from song 16. "Dream Goes On Forever"
# Extracted data from song 17. "Que Creías"
# Extracted data from song 18. "Baila Me"
# Song 19. "Chan Chan (ver 2)" already extracted
# Song 20. "Dos Gardenias" already extracted
# Song 21. "El Cuarto De Tula (ver 2)" already extracted
# Song 22. "Veinte Años (ver 2)" already extracted
# Extracted data from song 23. "Habla Me"
# Extracted data from song 24. "Siempre Hace Frio"
# Extracted data from song 25. "Solamente Una Vez"
# Extracted data from song 26. "Como Yo Te Amé"
# Extracted data from song 27. "Mujer"
# Song 28. "Candela (ver 2)" already extracted
# Song 29. "Amor De Loca Juventud" already extracted
# Song 30. "Buena Vista Social Club" already extracted
# Extracted data from song 31. "Como La Flor (ver 2)"
# Extracted data from song 32. "Como La Flor (ver 3)"
# Extracted data from song 33. "Amor Prohibido (ver 2)"
# Extracted data from song 34. "Dreaming Of You"
# Extracted data from song 35. "Dreaming Of You (ver 3)"
# Extracted data from song 36. "Bidi Bidi Bom Bom"
# Extracted data from song 37. "La Media Vuelta"
# Extracted data from song 38. "La Media Vuelta (ver 3)"
# Extracted data from song 39. "Sozinho"
# Song 40. "Dos Gardenias (ver 3)" already extracted
# Extracted data from song 41. "Si La Quieres"
# Extracted data from song 42. "Siempre Estoy Pensando En Tí"
# Extracted data from song 43. "Sin Ella"
# Extracted data from song 44. "Mi Vida"
# Extracted data from song 45. "El Mauro"
# Extracted data from song 46. "No Debes Jugar"
# Extracted data from song 47. "La Llamada"
# Extracted data from song 48. "Somos Novios"
# Extracted data from song 49. "Sin Tí"
# Extracted 50 of 147 (World Music,1990s). 2313 in total
# Extracted data from song 0. "Romeo"
# Extracted 1 of 147 (Disco,1990s). 2314 in total
# Extracted data from song 0. "You Dont Love Me Anymore"
# Extracted data from song 1. "Jerry Springer"
# Extracted data from song 2. "Jurassic Park"
# Extracted data from song 3. "Everything You Know Is Wrong (ver 2)"
# Extracted data from song 4. "Albuquerque"
# Extracted data from song 5. "Frank's 2000 Inch Tv"
# Extracted data from song 6. "The Night Santa Went Crazy"
# Extracted data from song 7. "The Night Santa Went Crazy (ver 2)"
# Extracted data from song 8. "Trigger Happy"
# Extracted data from song 9. "Carrot Juice Is Murder"
# Extracted data from song 10. "The Last Saskatchewan Pirate (ver 2)"
# Extracted data from song 11. "Everything You Know Is Wrong"
# Extracted data from song 12. "My Babys In Love With Eddie Vedder"
# Extracted data from song 13. "Your Horoscope For Today"
# Extracted data from song 14. "Your Horoscope For Today (ver 2)"
# Extracted data from song 15. "Truck Drivin' Song"
# Extracted data from song 16. "Grapefruit Diet"
# Extracted data from song 17. "Achy Breaky Song"
# Extracted data from song 18. "Traffic Jam"
# Extracted data from song 19. "You Dont Love Me Anymore (ver 2)"
# Extracted data from song 20. "You Dont Love Me Anymore (ver 3)"
# Extracted data from song 21. "Amish Paradise"
# Extracted data from song 22. "Amish Paradise (ver 2)"
# Extracted data from song 23. "Callin In Sick"
# Extracted data from song 24. "Since You've Been Gone"
# Extracted data from song 25. "Gump"
# Extracted data from song 26. "Phony Calls"
# Extracted data from song 27. "Jesus Brother Bob"
# Extracted data from song 28. "Canadas Really Big"
# Extracted data from song 29. "The Last Saskatchewan Pirate"
# Extracted 30 of 147 (Comedy,1990s). 2344 in total
# Extracted data from song 0. "Caribbean Blue"
# Extracted data from song 1. "Moonshine"
# Extracted data from song 2. "Anywhere Is"
# Extracted data from song 3. "Lothlorien"
# Extracted data from song 4. "Smaointe"
# Extracted data from song 5. "Dreams Are More Precious"
# Extracted data from song 6. "The Memory Of Trees"
# Extracted data from song 7. "Athair Ar Neamh"
# Extracted data from song 8. "Hope Has A Place"
# Extracted data from song 9. "Once You Had Gold"
# Extracted data from song 10. "La Sonadora"
# Extracted data from song 11. "On My Way Home"
# Extracted data from song 12. "In The Beginning"
# Extracted data from song 13. "Valentine"
# Extracted data from song 14. "Angeles"
# Extracted data from song 15. "Once In A Lifetime"
# Extracted data from song 16. "The Second Element Ii"
# Extracted data from song 17. "Book Of Days"
# Extracted data from song 18. "Book Of Days (ver 2)"
# Extracted data from song 19. "China Roses"
# Extracted data from song 20. "Evacuee"
# Extracted data from song 21. "How Can I Keep From Singing"
# Extracted data from song 22. "How Can I Keep From Singing (ver 2)"
# Extracted 23 of 147 (New Age,1990s). 2367 in total
# Song 0. "Time To Say Goodbye Con Te Partirò" already extracted
# Extracted data from song 1. "Ave Maria Gulio Caccini"
# Extracted data from song 2. "Monochrome"
# Extracted data from song 3. "Who Do You Think You Are"
# Extracted data from song 4. "Taking My Life In Your Hands"
# Extracted 5 of 147 (Classical,1990s). 2372 in total
# Extracted data from song 0. "Tomorrow (ver 2)"
# Extracted data from song 1. "Farmer In The City (ver 2)"
# Extracted data from song 2. "Say Something"
# Extracted data from song 3. "Tilt"
# Extracted data from song 4. "Farmer In The City"
# Extracted data from song 5. "Lights Of Cincinnati"
# Extracted data from song 6. "Lights Of Cincinnati (ver 2)"
# Extracted data from song 7. "Tomorrow"
# Extracted data from song 8. "Tomorrow (ver 3)"
# Extracted data from song 9. "Tomorrow (ver 4)"
# Extracted data from song 10. "Rosary"
# Extracted 11 of 147 (Experimental,1990s). 2383 in total
# Extracted 62 of 147 (Darkwave,1990s). 2383 in total
# Extracted data from song 0. "Eyes On Me"
# Extracted 1 of 147 (Soundtrack,1990s). 2384 in total
# Extracted data from song 0. "Fairytale Of New York (ver 2)"
# Extracted data from song 1. "Wicked Game"
# Extracted data from song 2. "Sweet Child O Mine"
# Extracted data from song 3. "Africa"
# Extracted data from song 4. "Fairytale Of New York (ver 4)"
# Extracted data from song 5. "Landslide"
# Extracted data from song 6. "With Or Without You"
# Extracted data from song 7. "Where Is My Mind"
# Extracted data from song 8. "Take On Me"
# Extracted data from song 9. "Every Breath You Take (ver 5)"
# Extracted data from song 10. "Free Fallin"
# Extracted data from song 11. "Fast Car (ver 3)"
# Extracted data from song 12. "Summer Of 69"
# Extracted data from song 13. "Patience (ver 2)"
# Extracted data from song 14. "Heaven"
# Extracted data from song 15. "Dont Dream Its Over"
# Extracted data from song 16. "Dont Stop Believin (ver 13)"
# Extracted data from song 17. "I Still Havent Found What Im Looking For"
# Extracted data from song 18. "Every Rose Has Its Thorn"
# Extracted data from song 19. "Dancing In The Dark (ver 5)"
# Extracted data from song 20. "Im Still Standing"
# Extracted data from song 21. "There Is A Light That Never Goes Out"
# Extracted data from song 22. "Fast Car (ver 2)"
# Extracted data from song 23. "I Want To Break Free"
# Extracted data from song 24. "Mad World (ver 2)"
# Extracted data from song 25. "Every Breath You Take (ver 2)"
# Extracted data from song 26. "I Wont Back Down"
# Extracted data from song 27. "The River"
# Extracted data from song 28. "Back In Black"
# Extracted data from song 29. "Total Eclipse Of The Heart (ver 4)"
# Extracted data from song 30. "Im On Fire (ver 3)"
# Extracted data from song 31. "Time After Time"
# Extracted data from song 32. "Englishman In New York"
# Extracted data from song 33. "Still Loving You (ver 4)"
# Extracted data from song 34. "Cant Fight This Feeling (ver 2)"
# Extracted data from song 35. "Livin On A Prayer (ver 2)"
# Extracted data from song 36. "Eye Of The Tiger (ver 2)"
# Extracted data from song 37. "Sweet Dreams Are Made Of This (ver 3)"
# Extracted data from song 38. "Free Fallin (ver 4)"
# Extracted data from song 39. "Under Pressure"
# Extracted data from song 40. "Free Fallin (ver 2)"
# Extracted data from song 41. "Scarborough Fair"
# Extracted data from song 42. "Wanted Dead Or Alive (ver 3)"
# Extracted data from song 43. "Africa (ver 7)"
# Extracted data from song 44. "Just Like Heaven"
# Extracted data from song 45. "With Or Without You (ver 4)"
# Extracted data from song 46. "Man In The Mirror"
# Extracted data from song 47. "In The Air Tonight"
# Extracted data from song 48. "Landslide (ver 5)"
# Extracted data from song 49. "Time After Time (ver 3)"
# Extracted 50 of 147 (Rock,1980s). 2434 in total
# Extracted data from song 0. "Hallelujah"
# Song 1. "Fast Car (ver 3)" already extracted
# Song 2. "Fast Car (ver 2)" already extracted
# Song 3. "The River" already extracted
# Song 4. "Englishman In New York" already extracted
# Song 5. "Scarborough Fair" already extracted
# Extracted data from song 6. "Im Gonna Be 500 Miles"
# Extracted data from song 7. "Hallelujah (ver 4)"
# Extracted data from song 8. "9 To 5 (ver 3)"
# Extracted data from song 9. "Tougher Than The Rest (ver 2)"
# Extracted data from song 10. "Atlantic City"
# Extracted data from song 11. "Hallelujah (ver 2)"
# Extracted data from song 12. "Englishman In New York (ver 2)"
# Extracted data from song 13. "Baby Can I Hold You"
# Extracted data from song 14. "Fast Car"
# Extracted data from song 15. "Dance Me To The End Of Love"
# Extracted data from song 16. "Copperhead Road"
# Extracted data from song 17. "Scarborough Fair (ver 4)"
# Extracted data from song 18. "Caledonia"
# Extracted data from song 19. "Talkin Bout A Revolution (ver 5)"
# Extracted data from song 20. "Dont Let It Bring You Down"
# Extracted data from song 21. "Same Old Lang Syne"
# Extracted data from song 22. "Luka (ver 2)"
# Extracted data from song 23. "Downtown Train (ver 2)"
# Extracted data from song 24. "Dont Let It Bring You Down (ver 2)"
# Extracted data from song 25. "Ride On"
# Extracted data from song 26. "Fragile"
# Extracted data from song 27. "Closer To Fine (ver 2)"
# Error in "True Love Will Find You In The End"
# Denegation error

# %%
song_data.df
# Out:
#                                                     url  \
# 0     https://tabs.ultimate-guitar.com/tab/kodaline/...
# 1     https://tabs.ultimate-guitar.com/tab/hozier/ta...
# 2     https://tabs.ultimate-guitar.com/tab/imagine-d...
# 3     https://tabs.ultimate-guitar.com/tab/a_great_b...
# 4     https://tabs.ultimate-guitar.com/tab/cage-the-...
# ...                                                 ...
# 2479  https://tabs.ultimate-guitar.com/tab/warren_ze...
# 2480  https://tabs.ultimate-guitar.com/tab/billy_bra...
# 2481  https://tabs.ultimate-guitar.com/tab/renaud/de...
# 2482  https://tabs.ultimate-guitar.com/tab/hannes-wa...
# 2483  https://tabs.ultimate-guitar.com/tab/leonard-c...
#
#                                 name genre decade  \
# 0                         All I Want  Rock  2010s
# 1          Take Me To Church (ver 2)  Rock  2010s
# 2                        Radioactive  Rock  2010s
# 3              Say Something (ver 3)  Rock  2010s
# 4                Cigarette Daydreams  Rock  2010s
# ...                              ...   ...    ...
# 2479  Lawyers Guns And Money (ver 2)  Folk  1980s
# 2480           A New England (ver 2)  Folk  1980s
# 2481       Des Que Le Vent Soufflera  Folk  1980s
# 2482      Es Ist An Der Zeit (ver 2)  Folk  1980s
# 2483         First We Take Manhattan  Folk  1980s
#
#                                                  chords  \
# 0     ['C', 'F', 'C', 'G/B', 'Am', 'F', 'C', 'F', 'C...
# 1     ['F#', 'Em', 'Am', 'Em', 'Am', 'G', 'Am', 'Em'...
# 2     ['G6sus2', 'Am', 'C', 'G6', 'G6sus2', 'Am', 'C...
# 3     ['Am', 'F', 'C', 'Gsus4', 'Am', 'F', 'C', 'Gsu...
# 4     ['D', 'Dmaj7', 'Em', 'G', 'A', 'D', 'Dmaj7', '...
# ...                                                 ...
# 2479                                                NaN
# 2480                                                NaN
# 2481                                                NaN
# 2482                                                NaN
# 2483                                                NaN
#
#                                       uuid
# 0     62d4ec07-9d59-4e00-a312-e98ce4f3b2fd
# 1     30af0a56-524d-49b7-ac65-be4caddbe097
# 2     672a1a12-3de2-4b68-bb17-55df130ce0e0
# 3     9edbfa0f-6d6d-44a4-b3d7-189d33010e15
# 4     eab426dd-9c57-4fad-b1b1-2b94601ff6ac
# ...                                    ...
# 2479                                   NaN
# 2480                                   NaN
# 2481                                   NaN
# 2482                                   NaN
# 2483                                   NaN
#
# [2484 rows x 6 columns]

# %%
song_data

# %%
song_data.save("../data/chords.csv")

# %%
! ls -alt ../data/chords.csv
# Out:
# -rw-r--r--  1 juanluisgarcialopez  staff  1500476 Dec  8 19:14 ../data/chords.csv

# %%
song_data.df["decade"].unique()
# Out:
# array(['2010s', '2000s', '1990s', '1980s'], dtype=object)

# %%
len(song_data.df.groupby('url'))
# Out:
# 2252

# %%
len(song_data.df.groupby(['url', 'name']))
# Out:
# 2252

# %%
len(song_data.df.groupby(['url', 'name', 'decade']))
# Out:
# 2252

# %%
grouped = song_data.df.groupby(['url', 'name', 'decade'])

# %%
grouped.count()["chords"].unique()
# Out:
# array([1, 0])

# %%
grouped.count()["genre"].unique()
# Out:
# array([2, 1, 3])

# %% [markdown]
# ## Segunda extracción

# %%
dataset_path = '../data/chords.csv'

# %%
new_song_data = SongData(dataset_path)

# %%
new_song_data.df
# Out:
#                                                     url  \
# 0     https://tabs.ultimate-guitar.com/tab/kodaline/...
# 1     https://tabs.ultimate-guitar.com/tab/hozier/ta...
# 2     https://tabs.ultimate-guitar.com/tab/imagine-d...
# 3     https://tabs.ultimate-guitar.com/tab/a_great_b...
# 4     https://tabs.ultimate-guitar.com/tab/cage-the-...
# ...                                                 ...
# 2479  https://tabs.ultimate-guitar.com/tab/warren_ze...
# 2480  https://tabs.ultimate-guitar.com/tab/billy_bra...
# 2481  https://tabs.ultimate-guitar.com/tab/renaud/de...
# 2482  https://tabs.ultimate-guitar.com/tab/hannes-wa...
# 2483  https://tabs.ultimate-guitar.com/tab/leonard-c...
#
#                                 name genre decade  \
# 0                         All I Want  Rock  2010s
# 1          Take Me To Church (ver 2)  Rock  2010s
# 2                        Radioactive  Rock  2010s
# 3              Say Something (ver 3)  Rock  2010s
# 4                Cigarette Daydreams  Rock  2010s
# ...                              ...   ...    ...
# 2479  Lawyers Guns And Money (ver 2)  Folk  1980s
# 2480           A New England (ver 2)  Folk  1980s
# 2481       Des Que Le Vent Soufflera  Folk  1980s
# 2482      Es Ist An Der Zeit (ver 2)  Folk  1980s
# 2483         First We Take Manhattan  Folk  1980s
#
#                                                  chords  \
# 0     ['C', 'F', 'C', 'G/B', 'Am', 'F', 'C', 'F', 'C...
# 1     ['F#', 'Em', 'Am', 'Em', 'Am', 'G', 'Am', 'Em'...
# 2     ['G6sus2', 'Am', 'C', 'G6', 'G6sus2', 'Am', 'C...
# 3     ['Am', 'F', 'C', 'Gsus4', 'Am', 'F', 'C', 'Gsu...
# 4     ['D', 'Dmaj7', 'Em', 'G', 'A', 'D', 'Dmaj7', '...
# ...                                                 ...
# 2479                                                NaN
# 2480                                                NaN
# 2481                                                NaN
# 2482                                                NaN
# 2483                                                NaN
#
#                                       uuid
# 0     62d4ec07-9d59-4e00-a312-e98ce4f3b2fd
# 1     30af0a56-524d-49b7-ac65-be4caddbe097
# 2     672a1a12-3de2-4b68-bb17-55df130ce0e0
# 3     9edbfa0f-6d6d-44a4-b3d7-189d33010e15
# 4     eab426dd-9c57-4fad-b1b1-2b94601ff6ac
# ...                                    ...
# 2479                                   NaN
# 2480                                   NaN
# 2481                                   NaN
# 2482                                   NaN
# 2483                                   NaN
#
# [2484 rows x 6 columns]

# %%
def extract(songData, first_page, last_page):
    linkExtractor = LinkExtractor()
    raw_html_output = '../data/raw_html'
    chordExtractor = ChordExtractor(raw_html_output)
    extractor = SimplifiedCombinationsSongExtractor(linkExtractor,chordExtractor,genres,decades,songData)
    extractor.extract(first_page, last_page)

# %%
extract(new_song_data, 1,1)
# Out:
# Rock,2010s already extracted
# Folk,2010s already extracted
# Pop,2010s already extracted
# Country,2010s already extracted
# Electronic,2010s already extracted
# Rhythm And Blues,2010s already extracted
# Metal,2010s already extracted
# Contemporary R&b,2010s already extracted
# Religious Music,2010s already extracted
# Hip Hop,2010s already extracted
# Reggae,2010s already extracted
# Jazz,2010s already extracted
# Blues,2010s already extracted
# World Music,2010s already extracted
# Disco,2010s already extracted
# Comedy,2010s already extracted
# New Age,2010s already extracted
# Classical,2010s already extracted
# Experimental,2010s already extracted
# Darkwave,2010s already extracted
# Soundtrack,2010s already extracted
# Rock,2000s already extracted
# Folk,2000s already extracted
# Pop,2000s already extracted
# Country,2000s already extracted
# Electronic,2000s already extracted
# Rhythm And Blues,2000s already extracted
# Metal,2000s already extracted
# Contemporary R&b,2000s already extracted
# Religious Music,2000s already extracted
# Hip Hop,2000s already extracted
# Reggae,2000s already extracted
# Jazz,2000s already extracted
# Blues,2000s already extracted
# World Music,2000s already extracted
# Disco,2000s already extracted
# Comedy,2000s already extracted
# New Age,2000s already extracted
# Classical,2000s already extracted
# cookies banner not found. Ignored
# Extracted 40 of 147 (Experimental,2000s). 2534 in total
# Darkwave,2000s already extracted
# Soundtrack,2000s already extracted
# Rock,1990s already extracted
# Folk,1990s already extracted
# Pop,1990s already extracted
# Country,1990s already extracted
# Electronic,1990s already extracted
# Rhythm And Blues,1990s already extracted
# Metal,1990s already extracted
# Contemporary R&b,1990s already extracted
# Religious Music,1990s already extracted
# Hip Hop,1990s already extracted
# Reggae,1990s already extracted
# Jazz,1990s already extracted
# Blues,1990s already extracted
# World Music,1990s already extracted
# Disco,1990s already extracted
# Comedy,1990s already extracted
# New Age,1990s already extracted
# Classical,1990s already extracted
# Experimental,1990s already extracted
# Extracted 62 of 147 (Darkwave,1990s). 2534 in total
# Soundtrack,1990s already extracted
# Rock,1980s already extracted
# Folk,1980s already extracted
# Extracted data from song 0. "Last Christmas"
# Song 1. "Hallelujah" already extracted
# Extracted data from song 2. "Last Christmas (ver 4)"
# Song 3. "Take On Me" already extracted
# Extracted data from song 4. "Last Christmas (ver 2)"
# Song 5. "Im Still Standing" already extracted
# Song 6. "Mad World (ver 2)" already extracted
# Song 7. "Time After Time" already extracted
# Extracted data from song 8. "The Winner Takes It All"
# Song 9. "Englishman In New York" already extracted
# Extracted data from song 10. "Last Christmas (ver 3)"
# Song 11. "Man In The Mirror" already extracted
# Song 12. "Time After Time (ver 3)" already extracted
# Extracted data from song 13. "Slipping Through My Fingers"
# Song 14. "Hallelujah (ver 4)" already extracted
# Extracted data from song 15. "Billie Jean (ver 2)"
# Extracted data from song 16. "Im Still Standing (ver 3)"
# Extracted data from song 17. "I Just Called To Say I Love You (ver 4)"
# Extracted data from song 18. "Billie Jean (ver 3)"
# Extracted data from song 19. "Take On Me (ver 4)"
# Extracted data from song 20. "I Guess Thats Why They Call It The Blues (ver 2)"
# Extracted data from song 21. "Beat It"
# Extracted data from song 22. "True Colors (ver 2)"
# Extracted data from song 23. "Girls Just Want To Have Fun"
# Song 24. "Hallelujah (ver 2)" already extracted
# Extracted data from song 25. "Hello (ver 5)"
# Extracted data from song 26. "Last Christmas (ver 5)"
# Extracted data from song 27. "Islands In The Stream"
# Extracted data from song 28. "Billie Jean"
# Song 29. "Englishman In New York (ver 2)" already extracted
# Extracted data from song 30. "Proud Mary"
# Extracted data from song 31. "Eternal Flame (ver 2)"
# Song 32. "Dance Me To The End Of Love" already extracted
# Extracted data from song 33. "Wake Me Up Before You Go-Go"
# Extracted data from song 34. "The Way You Make Me Feel (ver 2)"
# Extracted data from song 35. "Faith (ver 2)"
# Extracted data from song 36. "Stuck On You (ver 4)"
# Extracted data from song 37. "True Colors"
# Extracted data from song 38. "Eye In The Sky"
# Extracted data from song 39. "Smooth Criminal"
# Extracted data from song 40. "Faith (ver 3)"
# Extracted data from song 41. "Like A Prayer"
# Extracted data from song 42. "All Out Of Love (ver 2)"
# Extracted data from song 43. "Wonderful Life"
# Extracted data from song 44. "Listen To Your Heart"
# Extracted data from song 45. "Its Still Rock And Roll To Me"
# Extracted data from song 46. "Only The Good Die Young (ver 2)"
# Extracted data from song 47. "Faith"
# Extracted data from song 48. "Human Nature"
# Extracted data from song 49. "Andante Andante"
# Extracted 50 of 147 (Pop,1980s). 2584 in total
# Song 0. "Wicked Game" already extracted
# Extracted data from song 1. "Amarillo By Morning"
# Extracted data from song 2. "The Dance"
# Extracted data from song 3. "Wicked Game (ver 6)"
# Song 4. "9 To 5 (ver 3)" already extracted
# Extracted data from song 5. "Will The Circle Be Unbroken"
# Extracted data from song 6. "If Tomorrow Never Comes"
# Extracted data from song 7. "Christmas In Dixie"
# Song 8. "Atlantic City" already extracted
# Extracted data from song 9. "Forever And Ever Amen"
# Song 10. "Hello (ver 5)" already extracted
# Song 11. "Islands In The Stream" already extracted
# Extracted data from song 12. "On The Road Again"
# Extracted data from song 13. "Dixieland Delight (ver 2)"
# Song 14. "Stuck On You (ver 4)" already extracted
# Song 15. "Copperhead Road" already extracted
# Extracted data from song 16. "A Country Boy Can Survive"
# Extracted data from song 17. "Dont Close Your Eyes"
# Extracted data from song 18. "On The Road Again (ver 5)"
# Extracted data from song 19. "Luckenbach Texas (ver 2)"
# Extracted data from song 20. "All Night Long"
# Extracted data from song 21. "The Dance (ver 5)"
# Extracted data from song 22. "When You Say Nothing At All"
# Extracted data from song 23. "Althea"
# Extracted data from song 24. "He Stopped Loving Her Today"
# Extracted data from song 25. "Hello"
# Extracted data from song 26. "Endless Love"
# Extracted data from song 27. "9 To 5 (ver 2)"
# Extracted data from song 28. "City Of New Orleans"
# Extracted data from song 29. "Loser"
# Extracted data from song 30. "I Told You So"
# Extracted data from song 31. "Theres A New Kid In Town"
# Extracted data from song 32. "Angel Flying Too Close To The Ground"
# Extracted data from song 33. "The Chair (ver 2)"
# Extracted data from song 34. "Wildflowers"
# Extracted data from song 35. "Wicked Game (ver 3)"
# Extracted data from song 36. "Fishin In The Dark"
# Extracted data from song 37. "On The Road Again (ver 4)"
# Extracted data from song 38. "Touch Of Grey (ver 4)"
# Extracted data from song 39. "Diggin Up Bones"
# Extracted data from song 40. "Chasin That Neon Rainbow (ver 2)"
# Extracted data from song 41. "All My Rowdy Friends Have Settled Down"
# Extracted data from song 42. "Storms Never Last"
# Extracted data from song 43. "Deeper Than The Holler (ver 3)"
# Extracted data from song 44. "Cassidy (ver 2)"
# Extracted data from song 45. "Hello (ver 2)"
# Extracted data from song 46. "Wicked Game (ver 2)"
# Extracted data from song 47. "Dinosaur"
# Extracted data from song 48. "God Bless The Usa (ver 3)"
# Extracted data from song 49. "Amarillo By Morning (ver 5)"
# Extracted 50 of 147 (Country,1980s). 2634 in total
# Song 0. "Take On Me" already extracted
# Extracted data from song 1. "Forever Young"
# Song 2. "Mad World (ver 2)" already extracted
# Song 3. "Sweet Dreams Are Made Of This (ver 3)" already extracted
# Extracted data from song 4. "Forever Young (ver 4)"
# Song 5. "Take On Me (ver 4)" already extracted
# Extracted data from song 6. "Holding Out For A Hero"
# Extracted data from song 7. "99 Luftballons (ver 2)"
# Extracted data from song 8. "Only You (ver 2)"
# Extracted data from song 9. "Tainted Love (ver 2)"
# Extracted data from song 10. "A Little Respect"
# Extracted data from song 11. "Personal Jesus"
# Extracted data from song 12. "Here Comes The Rain Again"
# Extracted data from song 13. "Dont You Want Me (ver 2)"
# Extracted data from song 14. "Head Over Heels"
# Extracted data from song 15. "Like A Virgin"
# Extracted data from song 16. "Everybody Wants To Rule The World (ver 2)"
# Extracted data from song 17. "Its Raining Men (ver 2)"
# Extracted data from song 18. "Shout (ver 2)"
# Extracted data from song 19. "Irgendwie Irgendwo Irgendwann"
# Extracted data from song 20. "Take My Breath Away"
# Extracted data from song 21. "Hungry Like The Wolf"
# Extracted data from song 22. "Tainted Love (ver 5)"
# Extracted data from song 23. "Sweet Dreams Are Made Of This"
# Extracted data from song 24. "I Ran"
# Extracted data from song 25. "Blue Monday"
# Extracted data from song 26. "Take My Breath Away (ver 3)"
# Extracted data from song 27. "Sunglasses At Night"
# Extracted data from song 28. "Ella Elle La"
# Extracted data from song 29. "Save A Prayer"
# Extracted data from song 30. "The Riddle"
# Extracted data from song 31. "True Faith"
# Extracted data from song 32. "Never Let Me Down Again"
# Extracted data from song 33. "Its Raining Men"
# Extracted data from song 34. "Shake The Disease"
# Extracted data from song 35. "Just Cant Get Enough (ver 2)"
# Extracted data from song 36. "Rio (ver 4)"
# Extracted data from song 37. "Take On Me (ver 2)"
# Extracted data from song 38. "Hunting High And Low"
# Extracted data from song 39. "Dancing With Tears In My Eyes"
# Extracted data from song 40. "Save A Prayer (ver 2)"
# Extracted data from song 41. "Borderline"
# Extracted data from song 42. "Its A Sin"
# Extracted data from song 43. "Nobodys Diary (ver 2)"
# Extracted data from song 44. "Dont You Want Me (ver 3)"
# Extracted data from song 45. "Somebody"
# Extracted data from song 46. "Der Kommissar"
# Extracted data from song 47. "Mad World"
# Extracted data from song 48. "The Sun Always Shines On Tv"
# Extracted data from song 49. "The Chauffeur (ver 2)"
# Extracted 50 of 147 (Electronic,1980s). 2684 in total
# Song 0. "I Just Called To Say I Love You (ver 4)" already extracted
# Song 1. "Hello (ver 5)" already extracted
# Extracted data from song 2. "Everybody Needs Somebody To Love"
# Song 3. "Proud Mary" already extracted
# Song 4. "Wake Me Up Before You Go-Go" already extracted
# Song 5. "Stuck On You (ver 4)" already extracted
# Extracted data from song 6. "Unchain My Heart"
# Extracted data from song 7. "Nothings Gonna Change My Love For You (ver 4)"
# Song 8. "All Night Long" already extracted
# Extracted data from song 9. "Whats Love Got To Do With It (ver 2)"
# Extracted data from song 10. "Sweet Home Chicago (ver 2)"
# Extracted data from song 11. "Holding Back The Years"
# Song 12. "Hello" already extracted
# Extracted data from song 13. "Smooth Operator"
# Extracted data from song 14. "Maneater"
# Extracted data from song 15. "Out Of Touch (ver 2)"
# Extracted data from song 16. "Im So Excited (ver 2)"
# Extracted data from song 17. "Every Time You Go Away (ver 2)"
# Extracted data from song 18. "You Make My Dreams (ver 4)"
# Extracted data from song 19. "That Spirit Of Christmas"
# Extracted data from song 20. "I Cant Go For That No Can Do"
# Extracted data from song 21. "Overjoyed (ver 5)"
# Extracted data from song 22. "Je Te Promets"
# Extracted data from song 23. "Minnie The Moocher"
# Extracted data from song 24. "Maneater (ver 3)"
# Extracted data from song 25. "Sexual Healing (ver 2)"
# Extracted data from song 26. "You Make My Dreams (ver 2)"
# Song 27. "Hello (ver 2)" already extracted
# Extracted data from song 28. "Up Where We Belong (ver 3)"
# Extracted data from song 29. "If You Dont Know Me By Now (ver 2)"
# Extracted data from song 30. "Quelque Chose De Tennessee (ver 2)"
# Extracted data from song 31. "1999"
# Extracted data from song 32. "On The Wings Of Love"
# Extracted data from song 33. "Sweet Home Chicago"
# Extracted data from song 34. "I Just Called To Say I Love You (ver 2)"
# Extracted data from song 35. "Overjoyed"
# Extracted data from song 36. "Part-Time Lover"
# Extracted data from song 37. "Every Time You Go Away (ver 4)"
# Extracted data from song 38. "Little Red Corvette (ver 2)"
# Extracted data from song 39. "Nothings Gonna Change My Love For You (ver 3)"
# Extracted data from song 40. "Happy Birthday"
# Extracted data from song 41. "Private Dancer"
# Extracted data from song 42. "Lenvie"
# Extracted data from song 43. "When You Were Mine (ver 2)"
# Extracted data from song 44. "Kiss On My List (ver 2)"
# Extracted data from song 45. "Give It Up"
# Extracted data from song 46. "You Can Leave Your Hat On"
# Extracted data from song 47. "Lets Groove"
# Extracted data from song 48. "Stuck On You"
# Extracted data from song 49. "Freedom"
# Extracted 50 of 147 (Rhythm And Blues,1980s). 2734 in total
# Song 0. "Every Rose Has Its Thorn" already extracted
# Song 1. "Still Loving You (ver 4)" already extracted
# Extracted data from song 2. "I Remember You (ver 2)"
# Extracted data from song 3. "Fade To Black"
# Extracted data from song 4. "Crazy Train (ver 3)"
# Extracted data from song 5. "Still Loving You (ver 2)"
# Extracted data from song 6. "Rock You Like A Hurricane"
# Extracted data from song 7. "One"
# Extracted data from song 8. "Were Not Gonna Take It"
# Extracted data from song 9. "Every Rose Has Its Thorn (ver 3)"
# Extracted data from song 10. "Master Of Puppets"
# Extracted data from song 11. "When The Children Cry (ver 4)"
# Extracted data from song 12. "Heaven"
# Extracted data from song 13. "No One Like You"
# Extracted data from song 14. "Still Loving You"
# Extracted data from song 15. "Talk Dirty To Me"
# Extracted data from song 16. "Wasted Years"
# Extracted data from song 17. "Run To The Hills"
# Extracted data from song 18. "Crazy Train"
# Extracted data from song 19. "Still Loving You (ver 5)"
# Extracted data from song 20. "Mother"
# Extracted data from song 21. "18 And Life"
# Extracted data from song 22. "Holy Diver"
# Extracted data from song 23. "Youve Got Another Thing Comin (ver 2)"
# Extracted data from song 24. "Breaking The Law"
# Extracted data from song 25. "Breaking The Law (ver 2)"
# Extracted data from song 26. "Every Rose Has Its Thorn (ver 2)"
# Extracted data from song 27. "When The Smoke Is Going Down"
# Extracted data from song 28. "Bringin On The Heartbreak"
# Extracted data from song 29. "The Ballad Of Jayne (ver 2)"
# Extracted data from song 30. "Cum On Feel The Noize (ver 3)"
# Extracted data from song 31. "Fallen Angel"
# Extracted data from song 32. "Heaven (ver 3)"
# Extracted data from song 33. "Mr Crowley"
# Extracted data from song 34. "Dont Know What You Got Till Its Gone"
# Extracted data from song 35. "Still Loving You (ver 3)"
# Extracted data from song 36. "Close My Eyes Forever"
# Extracted data from song 37. "Goodbye To Romance (ver 2)"
# Extracted data from song 38. "For Whom The Bell Tolls (ver 2)"
# Extracted data from song 39. "The Trooper"
# Extracted data from song 40. "Epic"
# Extracted data from song 41. "Rainbow In The Dark"
# Extracted data from song 42. "Heart Of Steel"
# Extracted data from song 43. "Crazy Crazy Nights"
# Extracted data from song 44. "Close My Eyes Forever (ver 2)"
# Extracted data from song 45. "Heaven And Hell"
# Extracted data from song 46. "Nothin But A Good Time"
# Extracted data from song 47. "For Whom The Bell Tolls"
# Extracted data from song 48. "2 Minutes To Midnight"
# Extracted data from song 49. "18 And Life (ver 3)"
# Extracted 50 of 147 (Metal,1980s). 2784 in total
# Song 0. "Man In The Mirror" already extracted
# Song 1. "Billie Jean (ver 2)" already extracted
# Song 2. "Billie Jean (ver 3)" already extracted
# Song 3. "Beat It" already extracted
# Song 4. "Billie Jean" already extracted
# Song 5. "The Way You Make Me Feel (ver 2)" already extracted
# Song 6. "Human Nature" already extracted
# Extracted data from song 7. "Thriller"
# Extracted data from song 8. "Bad"
# Song 9. "Overjoyed (ver 5)" already extracted
# Extracted data from song 10. "Greatest Love Of All"
# Extracted data from song 11. "Man In The Mirror (ver 4)"
# Extracted data from song 12. "Saving All My Love For You"
# Extracted data from song 13. "Man In The Mirror (ver 2)"
# Song 14. "On The Wings Of Love" already extracted
# Extracted data from song 15. "Pyt Pretty Young Thing (ver 3)"
# Song 16. "Overjoyed" already extracted
# Song 17. "Part-Time Lover" already extracted
# Extracted data from song 18. "How Will I Know (ver 4)"
# Extracted data from song 19. "Human Nature (ver 2)"
# Extracted data from song 20. "Saving All My Love For You (ver 2)"
# Extracted data from song 21. "Part-Time Lover (ver 2)"
# Extracted data from song 22. "If We Hold On Together"
# Extracted data from song 23. "Bad Album"
# Extracted data from song 24. "Beat It (ver 2)"
# Extracted data from song 25. "Greatest Love Of All (ver 3)"
# Extracted data from song 26. "I Just Cant Stop Loving You (ver 2)"
# Extracted data from song 27. "Suddenly"
# Extracted data from song 28. "Free (ver 2)"
# Extracted data from song 29. "The Girl Is Mine"
# Extracted data from song 30. "The Beautiful Ones"
# Extracted data from song 31. "I Just Cant Stop Loving You"
# Extracted data from song 32. "The Lady In My Life"
# Extracted data from song 33. "Through The Fire"
# Extracted data from song 34. "Starfish And Coffee"
# Extracted data from song 35. "Super Freak"
# Extracted data from song 36. "The Way You Make Me Feel"
# Extracted data from song 37. "Billie Jean (ver 8)"
# Extracted data from song 38. "Overjoyed (ver 2)"
# Extracted data from song 39. "Give It To Me Baby"
# Extracted data from song 40. "Through The Fire (ver 2)"
# Extracted data from song 41. "I Just Cant Stop Loving You (ver 6)"
# Extracted data from song 42. "The Way You Make Me Feel (ver 4)"
# Extracted data from song 43. "Pyt Pretty Young Thing"
# Extracted data from song 44. "Thriller Album"
# Extracted data from song 45. "Do Me Baby (ver 2)"
# Extracted data from song 46. "Adore"
# Extracted data from song 47. "You Give Good Love (ver 2)"
# Extracted data from song 48. "Greatest Love Of All (ver 2)"
# Extracted data from song 49. "Dare Me (ver 2)"
# Extracted 50 of 147 (Contemporary R&b,1980s). 2834 in total
# Extracted data from song 0. "Oh Lord Youre Beautiful"
# Extracted data from song 1. "Tennessee Christmas"
# Extracted data from song 2. "Thy Word (ver 3)"
# Extracted data from song 3. "I Will Be Here (ver 5)"
# Extracted data from song 4. "There Is A Redeemer"
# Extracted data from song 5. "Great Is The Lord"
# Extracted data from song 6. "We Bow Down"
# Extracted data from song 7. "Friends All In The Family Of God"
# Extracted data from song 8. "I Will Call Upon The Lord"
# Extracted data from song 9. "Thy Word (ver 2)"
# Extracted data from song 10. "Friends"
# Extracted data from song 11. "There Is A Redeemer (ver 2)"
# Extracted data from song 12. "There Is A Redeemer (ver 3)"
# Extracted data from song 13. "Oh Lord Youre Beautiful (ver 2)"
# Extracted data from song 14. "Lead Me On"
# Extracted data from song 15. "The Warrior Is A Child"
# Extracted data from song 16. "Take Me In"
# Extracted data from song 17. "Emmanuel"
# Extracted data from song 18. "Emmanuel (ver 2)"
# Extracted data from song 19. "The Love Of God"
# Extracted data from song 20. "Thy Word (ver 4)"
# Extracted data from song 21. "I Will Be Here"
# Extracted data from song 22. "I Will Be Here (ver 2)"
# Extracted data from song 23. "There Is A Redeemer (ver 4)"
# Extracted data from song 24. "Romans Vii"
# Extracted data from song 25. "Oh Lord Youre Beautiful (ver 3)"
# Extracted data from song 26. "Oh Lord Youre Beautiful (ver 4)"
# Extracted data from song 27. "Oh Lord Youre Beautiful (ver 5)"
# Extracted data from song 28. "Oh Lord Youre Beautiful (ver 6)"
# Extracted data from song 29. "Oh Lord Youre Beautiful (ver 7)"
# Extracted data from song 30. "Oh Lord Youre Beautiful (ver 8)"
# Extracted data from song 31. "Oh Lord Youre Beautiful (ver 9)"
# Extracted data from song 32. "Verge Of A Miracle"
# Extracted data from song 33. "Be With You"
# Extracted data from song 34. "Screen Door"
# Extracted data from song 35. "What Trouble Are Giants"
# Extracted data from song 36. "We Bow Down (ver 2)"
# Extracted data from song 37. "The Battle Belongs To The Lord"
# Extracted data from song 38. "Hallowed Be Thy Name"
# Extracted data from song 39. "Hallowed Be Thy Name (ver 2)"
# Extracted data from song 40. "Until That Final Day"
# Extracted data from song 41. "Hope To Carry On"
# Extracted data from song 42. "First Family"
# Extracted data from song 43. "Bound To Come Some Trouble"
# Extracted data from song 44. "Somewhere"
# Extracted data from song 45. "Lean On Me"
# Extracted data from song 46. "Too Late"
# Extracted data from song 47. "The Now And The Not Yet"
# Extracted data from song 48. "Thy Word"
# Extracted data from song 49. "Grace By Which I Stand"
# Extracted 50 of 147 (Religious Music,1980s). 2884 in total
# Extracted data from song 0. "Just A Friend"
# Extracted data from song 1. "Rappers Delight"
# Extracted data from song 2. "Ice Ice Baby"
# Extracted data from song 3. "Its Tricky"
# Extracted 4 of 147 (Hip Hop,1980s). 2888 in total
# Extracted data from song 0. "Redemption Song (ver 2)"
# Extracted data from song 1. "Redemption Song"
# Extracted data from song 2. "Redemption Song (ver 3)"
# Extracted data from song 3. "Red Red Wine"
# Extracted data from song 4. "Could You Be Loved"
# Extracted data from song 5. "Natural Mystic"
# Extracted data from song 6. "Kingston Town"
# Extracted data from song 7. "It Must Be Love (ver 5)"
# Extracted data from song 8. "Kingston Town (ver 2)"
# Extracted data from song 9. "Red Red Wine (ver 3)"
# Extracted data from song 10. "Our House (ver 3)"
# Extracted data from song 11. "Lively Up Yourself"
# Extracted data from song 12. "Your House"
# Extracted data from song 13. "Soul Rebel"
# Extracted data from song 14. "Sinds 1 Dag Of 2 32 Jaar"
# Extracted data from song 15. "Ghost Town"
# Extracted data from song 16. "I Got You Babe"
# Extracted data from song 17. "Gimme Hope Joanna"
# Extracted data from song 18. "Bad Boys (ver 2)"
# Extracted data from song 19. "It Must Be Love (ver 2)"
# Extracted data from song 20. "Redemption Song (ver 6)"
# Extracted data from song 21. "Redemption Song (ver 8)"
# Extracted data from song 22. "Homely Girl"
# Extracted data from song 23. "Many Rivers To Cross"
# Extracted data from song 24. "Kaya"
# Extracted data from song 25. "Natural Mystic (ver 2)"
# Extracted data from song 26. "Bad Boys"
# Extracted data from song 27. "Food For Thought"
# Extracted data from song 28. "Forever Loving Jah"
# Extracted data from song 29. "Zion Train"
# Extracted data from song 30. "Kingston Town (ver 4)"
# Extracted data from song 31. "Red Red Wine (ver 4)"
# Extracted data from song 32. "Dont Break My Heart"
# Extracted data from song 33. "Electric Avenue"
# Extracted data from song 34. "House Of Fun"
# Extracted data from song 35. "Roller Skates"
# Extracted data from song 36. "Smoorverliefd"
# Extracted data from song 37. "Pimpers Paradise"
# Extracted data from song 38. "Reggae Fever"
# Extracted data from song 39. "Coming In From The Cold"
# Extracted data from song 40. "Coming In From The Cold (ver 2)"
# Extracted data from song 41. "Keep On Moving"
# Extracted data from song 42. "Johnny B Goode"
# Extracted data from song 43. "Rally Round"
# Extracted data from song 44. "Your House (ver 2)"
# Extracted data from song 45. "Do You Feel My Love"
# Extracted data from song 46. "Cherry Oh Baby"
# Extracted data from song 47. "Rat In Mi Kitchen"
# Extracted data from song 48. "Im Hurting Inside"
# Extracted data from song 49. "Real Situation"
# Extracted 50 of 147 (Reggae,1980s). 2938 in total
# Extracted data from song 0. "Dont Worry Be Happy (ver 3)"
# Song 1. "Nothings Gonna Change My Love For You (ver 4)" already extracted
# Extracted data from song 2. "Dont Worry Be Happy (ver 2)"
# Song 3. "Nothings Gonna Change My Love For You (ver 3)" already extracted
# Extracted data from song 4. "It Had To Be You (ver 2)"
# Extracted data from song 5. "Dont Worry Be Happy (ver 4)"
# Extracted data from song 6. "Nothings Gonna Change My Love For You"
# Extracted data from song 7. "Give Me The Night"
# Extracted data from song 8. "Dont Worry Be Happy"
# Extracted data from song 9. "Nothings Gonna Change My Love For You (ver 2)"
# Extracted data from song 10. "Broken Bicycles"
# Extracted data from song 11. "I Beg Your Pardon Dear"
# Extracted data from song 12. "Dont Worry Be Happy (ver 8)"
# Extracted data from song 13. "Nothings Gonna Change My Love For You (ver 5)"
# Extracted data from song 14. "Smiles And Smiles To Go"
# Extracted data from song 15. "Dont Worry Be Happy (ver 5)"
# Extracted data from song 16. "54 Duncan Terrace"
# Extracted data from song 17. "Take Me Home"
# Extracted data from song 18. "In Your Eyes (ver 2)"
# Extracted data from song 19. "It Had To Be You"
# Extracted data from song 20. "It Had To Be You (ver 3)"
# Extracted data from song 21. "Oh No"
# Extracted data from song 22. "Dont Worry Be Happy (ver 7)"
# Extracted data from song 23. "Love Games"
# Extracted data from song 24. "Looking Glass"
# Extracted data from song 25. "Drifting And Dreaming"
# Extracted data from song 26. "Stinkfoot"
# Extracted data from song 27. "Broken Bicycles (ver 2)"
# Extracted data from song 28. "Little Boy Blue"
# Extracted data from song 29. "You Are The Love Of My Life"
# Extracted data from song 30. "Out Of Sight Out Of Mind"
# Extracted data from song 31. "The Chant Has Begun"
# Extracted data from song 32. "La Is My Lady"
# Extracted data from song 33. "In Your Eyes"
# Extracted data from song 34. "It Had To Be You (ver 4)"
# Extracted data from song 35. "Breezin"
# Extracted data from song 36. "Tenderly"
# Extracted data from song 37. "Three Views Of A Secret"
# Extracted data from song 38. "Dont Worry Be Happy (ver 6)"
# Extracted 39 of 147 (Jazz,1980s). 2977 in total
# Extracted data from song 0. "Josephine"
# Extracted data from song 1. "On The Beach"
# Extracted data from song 2. "Damn Your Eyes"
# Extracted data from song 3. "I Can Hear Your Heartbeat (ver 2)"
# Extracted data from song 4. "On The Beach (ver 2)"
# Extracted data from song 5. "I Just Wanna Make Love To You"
# Extracted data from song 6. "Stainsby Girls"
# Extracted data from song 7. "Josephine (ver 2)"
# Extracted data from song 8. "Lets Dance"
# Extracted data from song 9. "On The Beach (ver 3)"
# Extracted data from song 10. "Champagne And Reefer"
# Extracted data from song 11. "Damn Your Eyes (ver 2)"
# Extracted data from song 12. "Room To Move"
# Extracted data from song 13. "Jumping At Shadows"
# Extracted data from song 14. "I Just Wanna Make Love To You (ver 2)"
# Extracted data from song 15. "Josephine (ver 4)"
# Extracted data from song 16. "She Bop"
# Extracted data from song 17. "I Can Hear Your Heartbeat"
# Extracted data from song 18. "The Sky Is Crying"
# Extracted data from song 19. "Change Of Heart"
# Extracted data from song 20. "Change Of Heart (ver 2)"
# Extracted data from song 21. "Baby Baby Baby"
# Extracted data from song 22. "Hey Baby Right Away"
# Extracted data from song 23. "Trouble Ive Had All My Days"
# Extracted data from song 24. "Jumping At Shadows (ver 2)"
# Extracted data from song 25. "Jumping At Shadows (ver 3)"
# Extracted data from song 26. "Jumping At Shadows (ver 4)"
# Extracted data from song 27. "Josephine (ver 3)"
# Extracted data from song 28. "I Guess I Showed Her"
# Extracted data from song 29. "Foul Play"
# Extracted data from song 30. "Smoking Gun"
# Extracted 31 of 147 (Blues,1980s). 3008 in total
# Extracted data from song 0. "Lambada"
# Extracted data from song 1. "Un Amor"
# Extracted data from song 2. "No Touch"
# Extracted data from song 3. "Un Amor (ver 2)"
# Extracted data from song 4. "Djobi Djoba (ver 2)"
# Extracted data from song 5. "La Dona"
# Extracted data from song 6. "Por Un Amor"
# Extracted data from song 7. "Voce E Linda"
# Extracted data from song 8. "Kahit Na Anong Mangyari"
# Extracted data from song 9. "Calaverada"
# Extracted data from song 10. "Ruptura"
# Extracted data from song 11. "Princessa"
# Extracted data from song 12. "Ciento"
# Extracted data from song 13. "Solituda"
# Extracted data from song 14. "Papa No Pega La Mama"
# Extracted data from song 15. "Rogaciano El Huapanguero"
# Extracted data from song 16. "El Sol Que Tú Eres"
# Extracted data from song 17. "Vaca Profana"
# Extracted data from song 18. "O Quereres"
# Extracted data from song 19. "Dom De Iludir"
# Extracted data from song 20. "Los Laureles"
# Extracted data from song 21. "Panahon"
# Extracted data from song 22. "Inday"
# Extracted data from song 23. "Queixa"
# Extracted data from song 24. "Trem Das Cores"
# Extracted data from song 25. "Meu Bem, Meu Mal"
# Extracted data from song 26. "Djobi Djoba"
# Extracted data from song 27. "Valsa De Uma Cidade"
# Extracted 28 of 147 (World Music,1980s). 3036 in total
# Extracted data from song 0. "Lay All Your Love On Me"
# Song 1. "Im So Excited (ver 2)" already extracted
# Extracted data from song 2. "Youre My Heart Youre My Soul (ver 2)"
# Song 3. "Give It Up" already extracted
# Extracted data from song 4. "Funkytown"
# Extracted data from song 5. "Lay All Your Love On Me (ver 2)"
# Extracted data from song 6. "Upside Down (ver 2)"
# Extracted data from song 7. "Cheri Cheri Lady"
# Extracted data from song 8. "Brother Louie"
# Extracted data from song 9. "Im Coming Out"
# Extracted data from song 10. "I Am What I Am"
# Extracted data from song 11. "She Works Hard For The Money"
# Extracted data from song 12. "Upside Down"
# Extracted data from song 13. "Geronimos Cadillac"
# Extracted data from song 14. "Youre My Heart Youre My Soul"
# Extracted data from song 15. "You Can Win If You Want"
# Extracted data from song 16. "Funkytown (ver 2)"
# Extracted data from song 17. "Do You Wanna"
# Extracted data from song 18. "This Time I Know Its For Real"
# Extracted data from song 19. "Brother Louie (ver 2)"
# Extracted data from song 20. "Im So Excited"
# Extracted data from song 21. "Who Will Save The World"
# Extracted data from song 22. "Me And I"
# Extracted data from song 23. "Designer Music"
# Extracted data from song 24. "My Old Piano"
# Extracted data from song 25. "Heaven Will Know"
# Extracted data from song 26. "Im Coming Out (ver 2)"
# Extracted data from song 27. "Upside Down (ver 3)"
# Extracted data from song 28. "The Night Is Yours The Night Is Mine"
# Extracted data from song 29. "Love At First Sight"
# Extracted data from song 30. "Love At First Sight (ver 2)"
# Extracted data from song 31. "Diamonds Never Made A Lady"
# Extracted data from song 32. "Theres Too Much Blue In Missing You"
# Extracted data from song 33. "Breakaway"
# Extracted data from song 34. "Cheri Cheri Lady (ver 2)"
# Extracted data from song 35. "One In A Million"
# Extracted data from song 36. "Bells Of Paris"
# Extracted data from song 37. "Lucky Guy"
# Extracted data from song 38. "Dont Worry"
# Extracted data from song 39. "Im So Excited (ver 3)"
# Extracted 40 of 147 (Disco,1980s). 3076 in total
# Extracted data from song 0. "Yoda"
# Extracted data from song 1. "Melanie"
# Extracted data from song 2. "I Love Rocky Road"
# Extracted data from song 3. "Christmas At Ground Zero"
# Extracted data from song 4. "One More Minute (ver 3)"
# Extracted data from song 5. "Good Enough For Now"
# Extracted data from song 6. "Stop Draggin My Car Around"
# Extracted data from song 7. "I Think Im A Clone Now"
# Extracted data from song 8. "My Bologna"
# Extracted data from song 9. "Another One Rides The Bus"
# Extracted data from song 10. "Ricky"
# Extracted data from song 11. "Midnight Star"
# Extracted data from song 12. "This Is The Life"
# Extracted data from song 13. "Living With A Hernia"
# Extracted data from song 14. "You Make Me"
# Extracted data from song 15. "The Biggest Ball Of Twine In Minnesota"
# Extracted data from song 16. "Generic Blues"
# Extracted data from song 17. "Eat It"
# Extracted data from song 18. "One More Minute"
# Extracted data from song 19. "One More Minute (ver 2)"
# Extracted data from song 20. "Dare To Be Stupid"
# Extracted data from song 21. "I Lost On Jeopardy"
# Extracted data from song 22. "Nature Trail To Hell"
# Extracted data from song 23. "Nature Trail To Hell (ver 2)"
# Extracted data from song 24. "Nature Trail To Hell (ver 3)"
# Extracted data from song 25. "Happy Birthday"
# Extracted data from song 26. "Gotta Boogie"
# Extracted data from song 27. "Mr. Frump In The Iron Lung"
# Extracted data from song 28. "Dont Wear Those Shoes"
# Extracted data from song 29. "Spam"
# Extracted data from song 30. "Buckingham Blues"
# Extracted data from song 31. "The Checks In The Mail"
# Extracted 32 of 147 (Comedy,1980s). 3108 in total
# Extracted data from song 0. "Orinoco Flow"
# Extracted data from song 1. "Evening Falls"
# Extracted data from song 2. "Exile"
# Extracted data from song 3. "Exile (ver 2)"
# Extracted data from song 4. "Na Laetha Geal Moige"
# Extracted data from song 5. "Na Laetha Geal Moige (ver 2)"
# Extracted data from song 6. "Cursum Perficio"
# Extracted data from song 7. "On Your Shore"
# Extracted data from song 8. "On Your Shore (ver 2)"
# Extracted data from song 9. "Storms In Africa"
# Extracted data from song 10. "Storms In Africa (ver 2)"
# Extracted data from song 11. "River"
# Extracted 12 of 147 (New Age,1980s). 3120 in total
# Song 0. "Oh No" already extracted
# Extracted 1 of 147 (Classical,1980s). 3121 in total
# Extracted data from song 0. "Eternal Legs"
# Extracted 1 of 147 (Experimental,1980s). 3122 in total
# Extracted data from song 0. "The Honour Of Silence"
# Extracted data from song 1. "The Honour Of Silence (ver 2)"
# Extracted data from song 2. "Leper Lord"
# Extracted data from song 3. "She Said Destroy"
# Extracted data from song 4. "She Said Destroy (ver 2)"
# Extracted 5 of 147 (Darkwave,1980s). 3127 in total
# Extracted 84 of 147 (Soundtrack,1980s). 3127 in total
# Extracted data from song 0. "Hotel California"
# Extracted data from song 1. "Wish You Were Here"
# Extracted data from song 2. "Imagine"
# Extracted data from song 3. "Let It Be (ver 2)"
# Extracted data from song 4. "Your Song"
# Extracted data from song 5. "Knockin On Heavens Door (ver 2)"
# Extracted data from song 6. "Bohemian Rhapsody (ver 5)"
# Extracted data from song 7. "Have You Ever Seen The Rain"
# Extracted data from song 8. "Love Of My Life"
# Extracted data from song 9. "Let It Be"
# Extracted data from song 10. "Father And Son"
# Extracted data from song 11. "Sweet Caroline"
# Extracted data from song 12. "Dont Stop Me Now (ver 3)"
# Extracted data from song 13. "Heart Of Gold"
# Extracted data from song 14. "Piano Man (ver 5)"
# Extracted data from song 15. "Please Come Home For Christmas"
# Extracted data from song 16. "Rocket Man"
# Extracted data from song 17. "Bohemian Rhapsody"
# Extracted data from song 18. "Wonderful Tonight (ver 2)"
# Extracted data from song 19. "A Horse With No Name"
# Extracted data from song 20. "Stairway To Heaven (ver 5)"
# Extracted data from song 21. "Take It Easy (ver 2)"
# Extracted data from song 22. "Crazy Little Thing Called Love"
# Extracted data from song 23. "Hotel California (ver 4)"
# Extracted data from song 24. "Somebody To Love"
# Extracted data from song 25. "Dust In The Wind (ver 2)"
# Extracted data from song 26. "How Deep Is Your Love (ver 8)"
# Extracted data from song 27. "Across The Universe"
# Extracted data from song 28. "Sweet Home Alabama"
# Extracted data from song 29. "Simple Man (ver 3)"
# Extracted data from song 30. "Starman (ver 2)"
# Extracted data from song 31. "Wish You Were Here (ver 2)"
# Extracted data from song 32. "Wild World"
# Extracted data from song 33. "Sultans Of Swing (ver 2)"
# Extracted data from song 34. "Highway To Hell"
# Extracted data from song 35. "Tiny Dancer (ver 2)"
# Extracted data from song 36. "My Sweet Lord"
# Extracted data from song 37. "Comfortably Numb"
# Extracted data from song 38. "Goodbye Yellow Brick Road"
# Extracted data from song 39. "The Long And Winding Road"
# Extracted data from song 40. "Me And Bobby Mcgee"
# Extracted data from song 41. "Wild Horses"
# Extracted data from song 42. "Fire And Rain (ver 3)"
# Extracted data from song 43. "Imagine (ver 4)"
# Extracted data from song 44. "Bridge Over Troubled Water (ver 2)"
# Extracted data from song 45. "Heroes (ver 3)"
# Extracted data from song 46. "Desperado"
# Extracted data from song 47. "Roxanne (ver 3)"
# Extracted data from song 48. "The Chain (ver 2)"
# Extracted data from song 49. "Lyin Eyes"
# Extracted 50 of 147 (Rock,1970s). 3177 in total
# Extracted data from song 0. "Take Me Home Country Roads (ver 10)"
# Song 1. "Imagine" already extracted
# Extracted data from song 2. "Take Me Home Country Roads"
# Song 3. "Your Song" already extracted
# Song 4. "Knockin On Heavens Door (ver 2)" already extracted
# Extracted data from song 5. "Jolene (ver 2)"
# Song 6. "Father And Son" already extracted
# Song 7. "Sweet Caroline" already extracted
# Extracted data from song 8. "American Pie"
# Song 9. "Heart Of Gold" already extracted
# Song 10. "Piano Man (ver 5)" already extracted
# Song 11. "Rocket Man" already extracted
# Extracted data from song 12. "River (ver 4)"
# Song 13. "Wild World" already extracted
# Song 14. "My Sweet Lord" already extracted
# Song 15. "Goodbye Yellow Brick Road" already extracted
# Song 16. "Fire And Rain (ver 3)" already extracted
# Song 17. "Imagine (ver 4)" already extracted
# Song 18. "Bridge Over Troubled Water (ver 2)" already extracted
# Extracted data from song 19. "Youve Got A Friend"
# Extracted data from song 20. "Your Song (ver 7)"
# Extracted data from song 21. "Old Man (ver 10)"
# Extracted data from song 22. "Rocket Man (ver 4)"
# Extracted data from song 23. "Take Me Home Country Roads (ver 2)"
# Extracted data from song 24. "Jealous Guy"
# Extracted data from song 25. "Knockin On Heavens Door (ver 5)"
# Extracted data from song 26. "Morning Has Broken"
# Extracted data from song 27. "Wild World (ver 2)"
# Extracted data from song 28. "Sweet Caroline (ver 4)"
# Extracted data from song 29. "Maybe Im Amazed"
# Extracted data from song 30. "Angel From Montgomery (ver 2)"
# Extracted data from song 31. "Into The Mystic (ver 2)"
# Extracted data from song 32. "Working Class Hero"
# Extracted data from song 33. "Cats In The Cradle"
# Extracted data from song 34. "Pancho And Lefty (ver 2)"
# Extracted data from song 35. "Big Yellow Taxi"
# Extracted data from song 36. "Sundown"
# Extracted data from song 37. "A Spaceman Came Travelling"
# Extracted data from song 38. "Time In A Bottle"
# Extracted data from song 39. "Tangled Up In Blue"
# Extracted data from song 40. "Chelsea Hotel No 2 (ver 2)"
# Extracted data from song 41. "If You Could Read My Mind"
# Extracted data from song 42. "Your Song (ver 3)"
# Extracted data from song 43. "Take Me Home Country Roads (ver 3)"
# Extracted data from song 44. "New York State Of Mind"
# Extracted data from song 45. "Hurricane"
# Extracted data from song 46. "Heart Of Gold (ver 4)"
# Extracted data from song 47. "Old Man (ver 4)"
# Extracted data from song 48. "Imagine (ver 6)"
# Extracted data from song 49. "Youre So Vain (ver 3)"
# Extracted 50 of 147 (Folk,1970s). 3227 in total
# Song 0. "Sweet Caroline" already extracted
# Song 1. "How Deep Is Your Love (ver 8)" already extracted
# Extracted data from song 2. "I Will Survive (ver 2)"
# Extracted data from song 3. "Mamma Mia"
# Extracted data from song 4. "The Gambler (ver 2)"
# Extracted data from song 5. "Give A Little Bit (ver 2)"
# Extracted data from song 6. "Mr Blue Sky"
# Song 7. "Sweet Caroline (ver 4)" already extracted
# Song 8. "Angel From Montgomery (ver 2)" already extracted
# Extracted data from song 9. "Über Den Wolken"
# Song 10. "A Spaceman Came Travelling" already extracted
# Extracted data from song 11. "Superstition"
# Song 12. "New York State Of Mind" already extracted
# Extracted data from song 13. "How Deep Is Your Love"
# Extracted data from song 14. "I Will Survive"
# Song 15. "Youre So Vain (ver 3)" already extracted
# Extracted data from song 16. "Solsbury Hill (ver 2)"
# Extracted data from song 17. "Dont Let The Sun Go Down On Me (ver 2)"
# Extracted data from song 18. "Je Laime A Mourir (ver 3)"
# Extracted data from song 19. "Burning Love"
# Extracted data from song 20. "I Have A Dream"
# Extracted data from song 21. "Top Of The World"
# Extracted data from song 22. "Stayin Alive (ver 2)"
# Extracted data from song 23. "Thank You For The Music (ver 2)"
# Extracted data from song 24. "Youve Got A Friend (ver 2)"
# Extracted data from song 25. "Merry Christmas Darling"
# Extracted data from song 26. "Telephone Line"
# Extracted data from song 27. "Sos"
# Extracted data from song 28. "Sir Duke"
# Extracted data from song 29. "How Deep Is Your Love (ver 3)"
# Extracted data from song 30. "I Wont Last A Day Without You (ver 3)"
# Extracted data from song 31. "Its Too Late (ver 3)"
# Extracted data from song 32. "You Are So Beautiful"
# Extracted data from song 33. "Chiquitita (ver 2)"
# Extracted data from song 34. "How Deep Is Your Love (ver 4)"
# Extracted data from song 35. "Mr Blue Sky (ver 2)"
# Extracted data from song 36. "Mamma Mia (ver 2)"
# Extracted data from song 37. "Im Not In Love"
# Extracted data from song 38. "Dancing Queen"
# Extracted data from song 39. "Rock With You (ver 2)"
# Extracted data from song 40. "I Have A Dream (ver 2)"
# Extracted data from song 41. "Year Of The Cat"
# Extracted data from song 42. "Superstition (ver 4)"
# Extracted data from song 43. "Solsbury Hill"
# Extracted data from song 44. "The Gambler (ver 3)"
# Extracted data from song 45. "Rhinestone Cowboy (ver 2)"
# Extracted data from song 46. "Dancing Queen (ver 4)"
# Extracted data from song 47. "Cracklin Rosie"
# Extracted data from song 48. "Escape The Pina Colada Song"
# Extracted data from song 49. "Sailing"
# Extracted 50 of 147 (Pop,1970s). 3277 in total
# Song 0. "Take Me Home Country Roads (ver 10)" already extracted
# Song 1. "Take Me Home Country Roads" already extracted
# Song 2. "Knockin On Heavens Door (ver 2)" already extracted
# Song 3. "Jolene (ver 2)" already extracted
# Song 4. "The Gambler (ver 2)" already extracted
# Song 5. "Take Me Home Country Roads (ver 2)" already extracted
# Extracted data from song 6. "Always On My Mind"
# Song 7. "Knockin On Heavens Door (ver 5)" already extracted
# Extracted data from song 8. "Sunday Morning Coming Down (ver 5)"
# Song 9. "Pancho And Lefty (ver 2)" already extracted
# Extracted data from song 10. "Ghost Riders In The Sky (ver 7)"
# Song 11. "Take Me Home Country Roads (ver 3)" already extracted
# Extracted data from song 12. "Listen To The Music (ver 4)"
# Extracted data from song 13. "Rocky Mountain High"
# Extracted data from song 14. "Help Me Make It Through The Night (ver 2)"
# Extracted data from song 15. "Friend Of The Devil (ver 2)"
# Extracted data from song 16. "I Will Always Love You (ver 4)"
# Extracted data from song 17. "Blue Eyes Crying In The Rain"
# Extracted data from song 18. "Angel From Montgomery (ver 2)"
# Extracted data from song 19. "Margaritaville (ver 2)"
# Extracted data from song 20. "Knockin On Heavens Door"
# Extracted data from song 21. "Long Train Runnin (ver 2)"
# Extracted data from song 22. "Beautiful Star Of Bethlehem"
# Extracted data from song 23. "Take Me Home Country Roads (ver 8)"
# Extracted data from song 24. "Coat Of Many Colors (ver 2)"
# Extracted data from song 25. "Sunday Morning Coming Down (ver 3)"
# Extracted data from song 26. "If We Make It Through December"
# Extracted data from song 27. "Why Me Lord"
# Extracted data from song 28. "Thank God Im A Country Boy (ver 3)"
# Extracted data from song 29. "Scarlet Begonias"
# Extracted data from song 30. "Long Train Runnin (ver 3)"
# Extracted data from song 31. "Family Tradition"
# Extracted data from song 32. "Man In Black"
# Song 33. "The Gambler (ver 3)" already extracted
# Song 34. "Rhinestone Cowboy (ver 2)" already extracted
# Extracted data from song 35. "Mr Bojangles (ver 3)"
# Extracted data from song 36. "Jolene"
# Extracted data from song 37. "Me And Bobby Mcgee"
# Extracted data from song 38. "Listen To The Music"
# Extracted data from song 39. "Eyes Of The World (ver 2)"
# Extracted data from song 40. "Shady Grove"
# Extracted data from song 41. "For The Good Times"
# Extracted data from song 42. "Pancho And Lefty (ver 3)"
# Extracted data from song 43. "The Devil Went Down To Georgia"
# Extracted data from song 44. "Christmas For Cowboys"
# Extracted data from song 45. "Whiskey Bent And Hell Bound"
# Extracted data from song 46. "Sunshine On My Shoulders"
# Extracted data from song 47. "Here You Come Again"
# Extracted data from song 48. "Blue Eyes Crying In The Rain (ver 2)"
# Extracted data from song 49. "Sam Stone (ver 3)"
# Extracted 50 of 147 (Country,1970s). 3327 in total
# Extracted data from song 0. "Video Killed The Radio Star (ver 2)"
# Extracted data from song 1. "Video Killed The Radio Star (ver 4)"
# Extracted data from song 2. "Mr Soul"
# Extracted data from song 3. "Me"
# Extracted data from song 4. "Autobahn"
# Extracted data from song 5. "Video Killed The Radio Star"
# Extracted data from song 6. "Mr Soul (ver 4)"
# Extracted data from song 7. "Mr Soul (ver 5)"
# Extracted data from song 8. "Someone Somewhere In Summertime"
# Extracted data from song 9. "Being Boiled"
# Extracted data from song 10. "Metal"
# Extracted data from song 11. "Blind Youth"
# Extracted data from song 12. "Video Killed The Radio Star (ver 3)"
# Extracted data from song 13. "Kid Dynamo"
# Extracted data from song 14. "Mr Soul (ver 2)"
# Extracted data from song 15. "Mr Soul (ver 3)"
# Extracted data from song 16. "Tracks"
# Extracted data from song 17. "Airlane"
# Extracted data from song 18. "Engineers"
# Extracted data from song 19. "Complex"
# Extracted data from song 20. "Conversation"
# Extracted data from song 21. "Kometenmelodie 2"
# Extracted data from song 22. "Cars"
# Extracted data from song 23. "Films"
# Extracted 24 of 147 (Electronic,1970s). 3351 in total
# Extracted data from song 0. "Aint No Sunshine"
# Extracted data from song 1. "Lean On Me"
# Extracted data from song 2. "September"
# Song 3. "Into The Mystic (ver 2)" already extracted
# Extracted data from song 4. "Killing Me Softly With His Song"
# Song 5. "Superstition" already extracted
# Extracted data from song 6. "Aint No Mountain High Enough"
# Extracted data from song 7. "Easy (ver 2)"
# Extracted data from song 8. "Lets Stay Together"
# Extracted data from song 9. "Moondance"
# Extracted data from song 10. "Rich Girl (ver 3)"
# Extracted data from song 11. "Easy (ver 4)"
# Song 12. "Sir Duke" already extracted
# Song 13. "You Are So Beautiful" already extracted
# Song 14. "Superstition (ver 4)" already extracted
# Extracted data from song 15. "Lovely Day (ver 5)"
# Extracted data from song 16. "I Wish"
# Extracted data from song 17. "Easy"
# Extracted data from song 18. "Aint No Mountain High Enough (ver 2)"
# Extracted data from song 19. "People Get Ready (ver 2)"
# Extracted data from song 20. "You Are So Beautiful (ver 4)"
# Extracted data from song 21. "Higher Ground (ver 2)"
# Extracted data from song 22. "You Are The Sunshine Of My Life"
# Extracted data from song 23. "Play That Funky Music"
# Error in "The Wonder Of You (ver 5)"
# Denegation error

# %%
new_song_data.df
# Out:
#                                                     url  \
# 0     https://tabs.ultimate-guitar.com/tab/kodaline/...
# 1     https://tabs.ultimate-guitar.com/tab/hozier/ta...
# 2     https://tabs.ultimate-guitar.com/tab/imagine-d...
# 3     https://tabs.ultimate-guitar.com/tab/a_great_b...
# 4     https://tabs.ultimate-guitar.com/tab/cage-the-...
# ...                                                 ...
# 3396  https://tabs.ultimate-guitar.com/tab/van_morri...
# 3397  https://tabs.ultimate-guitar.com/tab/hall-oate...
# 3398  https://tabs.ultimate-guitar.com/tab/hall-oate...
# 3399  https://tabs.ultimate-guitar.com/tab/marvin-ga...
# 3400  https://tabs.ultimate-guitar.com/tab/curtis-ma...
#
#                            name             genre decade  \
# 0                    All I Want              Rock  2010s
# 1     Take Me To Church (ver 2)              Rock  2010s
# 2                   Radioactive              Rock  2010s
# 3         Say Something (ver 3)              Rock  2010s
# 4           Cigarette Daydreams              Rock  2010s
# ...                         ...               ...    ...
# 3396          Moondance (ver 4)  Rhythm And Blues  1970s
# 3397                  Rich Girl  Rhythm And Blues  1970s
# 3398                 Sara Smile  Rhythm And Blues  1970s
# 3399             Lets Get It On  Rhythm And Blues  1970s
# 3400                 Move On Up  Rhythm And Blues  1970s
#
#                                                  chords  \
# 0     ['C', 'F', 'C', 'G/B', 'Am', 'F', 'C', 'F', 'C...
# 1     ['F#', 'Em', 'Am', 'Em', 'Am', 'G', 'Am', 'Em'...
# 2     ['G6sus2', 'Am', 'C', 'G6', 'G6sus2', 'Am', 'C...
# 3     ['Am', 'F', 'C', 'Gsus4', 'Am', 'F', 'C', 'Gsu...
# 4     ['D', 'Dmaj7', 'Em', 'G', 'A', 'D', 'Dmaj7', '...
# ...                                                 ...
# 3396                                                NaN
# 3397                                                NaN
# 3398                                                NaN
# 3399                                                NaN
# 3400                                                NaN
#
#                                       uuid
# 0     62d4ec07-9d59-4e00-a312-e98ce4f3b2fd
# 1     30af0a56-524d-49b7-ac65-be4caddbe097
# 2     672a1a12-3de2-4b68-bb17-55df130ce0e0
# 3     9edbfa0f-6d6d-44a4-b3d7-189d33010e15
# 4     eab426dd-9c57-4fad-b1b1-2b94601ff6ac
# ...                                    ...
# 3396                                   NaN
# 3397                                   NaN
# 3398                                   NaN
# 3399                                   NaN
# 3400                                   NaN
#
# [3401 rows x 6 columns]

# %%
new_song_data.save(dataset_path)

# %% [markdown]
# ## Tercera extracción

# %%
song_data_3 = SongData(dataset_path)

# %%
song_data_3.df
# Out:
#                                                     url  \
# 0     https://tabs.ultimate-guitar.com/tab/kodaline/...
# 1     https://tabs.ultimate-guitar.com/tab/hozier/ta...
# 2     https://tabs.ultimate-guitar.com/tab/imagine-d...
# 3     https://tabs.ultimate-guitar.com/tab/a_great_b...
# 4     https://tabs.ultimate-guitar.com/tab/cage-the-...
# ...                                                 ...
# 3396  https://tabs.ultimate-guitar.com/tab/van_morri...
# 3397  https://tabs.ultimate-guitar.com/tab/hall-oate...
# 3398  https://tabs.ultimate-guitar.com/tab/hall-oate...
# 3399  https://tabs.ultimate-guitar.com/tab/marvin-ga...
# 3400  https://tabs.ultimate-guitar.com/tab/curtis-ma...
#
#                            name             genre decade  \
# 0                    All I Want              Rock  2010s
# 1     Take Me To Church (ver 2)              Rock  2010s
# 2                   Radioactive              Rock  2010s
# 3         Say Something (ver 3)              Rock  2010s
# 4           Cigarette Daydreams              Rock  2010s
# ...                         ...               ...    ...
# 3396          Moondance (ver 4)  Rhythm And Blues  1970s
# 3397                  Rich Girl  Rhythm And Blues  1970s
# 3398                 Sara Smile  Rhythm And Blues  1970s
# 3399             Lets Get It On  Rhythm And Blues  1970s
# 3400                 Move On Up  Rhythm And Blues  1970s
#
#                                                  chords  \
# 0     ['C', 'F', 'C', 'G/B', 'Am', 'F', 'C', 'F', 'C...
# 1     ['F#', 'Em', 'Am', 'Em', 'Am', 'G', 'Am', 'Em'...
# 2     ['G6sus2', 'Am', 'C', 'G6', 'G6sus2', 'Am', 'C...
# 3     ['Am', 'F', 'C', 'Gsus4', 'Am', 'F', 'C', 'Gsu...
# 4     ['D', 'Dmaj7', 'Em', 'G', 'A', 'D', 'Dmaj7', '...
# ...                                                 ...
# 3396                                                NaN
# 3397                                                NaN
# 3398                                                NaN
# 3399                                                NaN
# 3400                                                NaN
#
#                                       uuid
# 0     62d4ec07-9d59-4e00-a312-e98ce4f3b2fd
# 1     30af0a56-524d-49b7-ac65-be4caddbe097
# 2     672a1a12-3de2-4b68-bb17-55df130ce0e0
# 3     9edbfa0f-6d6d-44a4-b3d7-189d33010e15
# 4     eab426dd-9c57-4fad-b1b1-2b94601ff6ac
# ...                                    ...
# 3396                                   NaN
# 3397                                   NaN
# 3398                                   NaN
# 3399                                   NaN
# 3400                                   NaN
#
# [3401 rows x 6 columns]

# %%
extract(song_data_3,1,1)
# Out:
# Rock,2010s already extracted
# Folk,2010s already extracted
# Pop,2010s already extracted
# Country,2010s already extracted
# Electronic,2010s already extracted
# Rhythm And Blues,2010s already extracted
# Metal,2010s already extracted
# Contemporary R&b,2010s already extracted
# Religious Music,2010s already extracted
# Hip Hop,2010s already extracted
# Reggae,2010s already extracted
# Jazz,2010s already extracted
# Blues,2010s already extracted
# World Music,2010s already extracted
# Disco,2010s already extracted
# Comedy,2010s already extracted
# New Age,2010s already extracted
# Classical,2010s already extracted
# Experimental,2010s already extracted
# Darkwave,2010s already extracted
# Soundtrack,2010s already extracted
# Rock,2000s already extracted
# Folk,2000s already extracted
# Pop,2000s already extracted
# Country,2000s already extracted
# Electronic,2000s already extracted
# Rhythm And Blues,2000s already extracted
# Metal,2000s already extracted
# Contemporary R&b,2000s already extracted
# Religious Music,2000s already extracted
# Hip Hop,2000s already extracted
# Reggae,2000s already extracted
# Jazz,2000s already extracted
# Blues,2000s already extracted
# World Music,2000s already extracted
# Disco,2000s already extracted
# Comedy,2000s already extracted
# New Age,2000s already extracted
# Classical,2000s already extracted
# cookies banner not found. Ignored
# Extracted 40 of 147 (Experimental,2000s). 3401 in total
# Darkwave,2000s already extracted
# Soundtrack,2000s already extracted
# Rock,1990s already extracted
# Folk,1990s already extracted
# Pop,1990s already extracted
# Country,1990s already extracted
# Electronic,1990s already extracted
# Rhythm And Blues,1990s already extracted
# Metal,1990s already extracted
# Contemporary R&b,1990s already extracted
# Religious Music,1990s already extracted
# Hip Hop,1990s already extracted
# Reggae,1990s already extracted
# Jazz,1990s already extracted
# Blues,1990s already extracted
# World Music,1990s already extracted
# Disco,1990s already extracted
# Comedy,1990s already extracted
# New Age,1990s already extracted
# Classical,1990s already extracted
# Experimental,1990s already extracted
# Extracted 62 of 147 (Darkwave,1990s). 3401 in total
# Soundtrack,1990s already extracted
# Rock,1980s already extracted
# Folk,1980s already extracted
# Song 0. "Last Christmas" already extracted
# Song 1. "Hallelujah" already extracted
# Song 2. "Last Christmas (ver 4)" already extracted
# Song 3. "Take On Me" already extracted
# Song 4. "Last Christmas (ver 2)" already extracted
# Song 5. "Im Still Standing" already extracted
# Song 6. "Mad World (ver 2)" already extracted
# Song 7. "Time After Time" already extracted
# Song 8. "The Winner Takes It All" already extracted
# Song 9. "Englishman In New York" already extracted
# Song 10. "Last Christmas (ver 3)" already extracted
# Song 11. "Man In The Mirror" already extracted
# Song 12. "Time After Time (ver 3)" already extracted
# Song 13. "Slipping Through My Fingers" already extracted
# Song 14. "Hallelujah (ver 4)" already extracted
# Song 15. "Billie Jean (ver 2)" already extracted
# Song 16. "Im Still Standing (ver 3)" already extracted
# Song 17. "I Just Called To Say I Love You (ver 4)" already extracted
# Song 18. "Billie Jean (ver 3)" already extracted
# Song 19. "Take On Me (ver 4)" already extracted
# Song 20. "I Guess Thats Why They Call It The Blues (ver 2)" already extracted
# Song 21. "Beat It" already extracted
# Song 22. "True Colors (ver 2)" already extracted
# Song 23. "Girls Just Want To Have Fun" already extracted
# Song 24. "Hallelujah (ver 2)" already extracted
# Song 25. "Hello (ver 5)" already extracted
# Song 26. "Last Christmas (ver 5)" already extracted
# Song 27. "Islands In The Stream" already extracted
# Song 28. "Billie Jean" already extracted
# Song 29. "Englishman In New York (ver 2)" already extracted
# Song 30. "Proud Mary" already extracted
# Song 31. "Eternal Flame (ver 2)" already extracted
# Song 32. "Dance Me To The End Of Love" already extracted
# Song 33. "Wake Me Up Before You Go-Go" already extracted
# Song 34. "The Way You Make Me Feel (ver 2)" already extracted
# Song 35. "Faith (ver 2)" already extracted
# Song 36. "Stuck On You (ver 4)" already extracted
# Song 37. "True Colors" already extracted
# Song 38. "Eye In The Sky" already extracted
# Song 39. "Smooth Criminal" already extracted
# Song 40. "Faith (ver 3)" already extracted
# Song 41. "Like A Prayer" already extracted
# Song 42. "All Out Of Love (ver 2)" already extracted
# Song 43. "Wonderful Life" already extracted
# Song 44. "Listen To Your Heart" already extracted
# Song 45. "Its Still Rock And Roll To Me" already extracted
# Song 46. "Only The Good Die Young (ver 2)" already extracted
# Song 47. "Faith" already extracted
# Song 48. "Human Nature" already extracted
# Song 49. "Andante Andante" already extracted
# Extracted 50 of 147 (Pop,1980s). 3451 in total
# Song 0. "Wicked Game" already extracted
# Song 1. "Amarillo By Morning" already extracted
# Song 2. "The Dance" already extracted
# Song 3. "Wicked Game (ver 6)" already extracted
# Song 4. "9 To 5 (ver 3)" already extracted
# Song 5. "Will The Circle Be Unbroken" already extracted
# Song 6. "If Tomorrow Never Comes" already extracted
# Song 7. "Christmas In Dixie" already extracted
# Song 8. "Atlantic City" already extracted
# Song 9. "Forever And Ever Amen" already extracted
# Song 10. "Hello (ver 5)" already extracted
# Song 11. "Islands In The Stream" already extracted
# Song 12. "On The Road Again" already extracted
# Song 13. "Dixieland Delight (ver 2)" already extracted
# Song 14. "Stuck On You (ver 4)" already extracted
# Song 15. "Copperhead Road" already extracted
# Song 16. "A Country Boy Can Survive" already extracted
# Song 17. "Dont Close Your Eyes" already extracted
# Song 18. "On The Road Again (ver 5)" already extracted
# Song 19. "Luckenbach Texas (ver 2)" already extracted
# Song 20. "All Night Long" already extracted
# Song 21. "The Dance (ver 5)" already extracted
# Song 22. "When You Say Nothing At All" already extracted
# Song 23. "Althea" already extracted
# Song 24. "He Stopped Loving Her Today" already extracted
# Song 25. "Hello" already extracted
# Song 26. "Endless Love" already extracted
# Song 27. "9 To 5 (ver 2)" already extracted
# Song 28. "City Of New Orleans" already extracted
# Song 29. "Loser" already extracted
# Song 30. "I Told You So" already extracted
# Song 31. "Theres A New Kid In Town" already extracted
# Song 32. "Angel Flying Too Close To The Ground" already extracted
# Song 33. "The Chair (ver 2)" already extracted
# Song 34. "Wildflowers" already extracted
# Song 35. "Wicked Game (ver 3)" already extracted
# Song 36. "Fishin In The Dark" already extracted
# Song 37. "On The Road Again (ver 4)" already extracted
# Song 38. "Touch Of Grey (ver 4)" already extracted
# Song 39. "Diggin Up Bones" already extracted
# Song 40. "Chasin That Neon Rainbow (ver 2)" already extracted
# Song 41. "All My Rowdy Friends Have Settled Down" already extracted
# Song 42. "Storms Never Last" already extracted
# Song 43. "Deeper Than The Holler (ver 3)" already extracted
# Song 44. "Cassidy (ver 2)" already extracted
# Song 45. "Hello (ver 2)" already extracted
# Song 46. "Wicked Game (ver 2)" already extracted
# Song 47. "Dinosaur" already extracted
# Song 48. "God Bless The Usa (ver 3)" already extracted
# Song 49. "Amarillo By Morning (ver 5)" already extracted
# Extracted 50 of 147 (Country,1980s). 3501 in total
# Song 0. "Take On Me" already extracted
# Song 1. "Forever Young" already extracted
# Song 2. "Mad World (ver 2)" already extracted
# Song 3. "Sweet Dreams Are Made Of This (ver 3)" already extracted
# Song 4. "Forever Young (ver 4)" already extracted
# Song 5. "Take On Me (ver 4)" already extracted
# Song 6. "Holding Out For A Hero" already extracted
# Song 7. "99 Luftballons (ver 2)" already extracted
# Song 8. "Only You (ver 2)" already extracted
# Song 9. "Tainted Love (ver 2)" already extracted
# Song 10. "A Little Respect" already extracted
# Song 11. "Personal Jesus" already extracted
# Song 12. "Here Comes The Rain Again" already extracted
# Song 13. "Dont You Want Me (ver 2)" already extracted
# Song 14. "Head Over Heels" already extracted
# Song 15. "Like A Virgin" already extracted
# Song 16. "Everybody Wants To Rule The World (ver 2)" already extracted
# Song 17. "Its Raining Men (ver 2)" already extracted
# Song 18. "Shout (ver 2)" already extracted
# Song 19. "Irgendwie Irgendwo Irgendwann" already extracted
# Song 20. "Take My Breath Away" already extracted
# Song 21. "Hungry Like The Wolf" already extracted
# Song 22. "Tainted Love (ver 5)" already extracted
# Song 23. "Sweet Dreams Are Made Of This" already extracted
# Song 24. "I Ran" already extracted
# Song 25. "Blue Monday" already extracted
# Song 26. "Take My Breath Away (ver 3)" already extracted
# Song 27. "Sunglasses At Night" already extracted
# Song 28. "Ella Elle La" already extracted
# Song 29. "Save A Prayer" already extracted
# Song 30. "The Riddle" already extracted
# Song 31. "True Faith" already extracted
# Song 32. "Never Let Me Down Again" already extracted
# Song 33. "Its Raining Men" already extracted
# Song 34. "Shake The Disease" already extracted
# Song 35. "Just Cant Get Enough (ver 2)" already extracted
# Song 36. "Rio (ver 4)" already extracted
# Song 37. "Take On Me (ver 2)" already extracted
# Song 38. "Hunting High And Low" already extracted
# Song 39. "Dancing With Tears In My Eyes" already extracted
# Song 40. "Save A Prayer (ver 2)" already extracted
# Song 41. "Borderline" already extracted
# Song 42. "Its A Sin" already extracted
# Song 43. "Nobodys Diary (ver 2)" already extracted
# Song 44. "Dont You Want Me (ver 3)" already extracted
# Song 45. "Somebody" already extracted
# Song 46. "Der Kommissar" already extracted
# Song 47. "Mad World" already extracted
# Song 48. "The Sun Always Shines On Tv" already extracted
# Song 49. "The Chauffeur (ver 2)" already extracted
# Extracted 50 of 147 (Electronic,1980s). 3551 in total
# Song 0. "I Just Called To Say I Love You (ver 4)" already extracted
# Song 1. "Hello (ver 5)" already extracted
# Song 2. "Everybody Needs Somebody To Love" already extracted
# Song 3. "Proud Mary" already extracted
# Song 4. "Wake Me Up Before You Go-Go" already extracted
# Song 5. "Stuck On You (ver 4)" already extracted
# Song 6. "Unchain My Heart" already extracted
# Song 7. "Nothings Gonna Change My Love For You (ver 4)" already extracted
# Song 8. "All Night Long" already extracted
# Song 9. "Whats Love Got To Do With It (ver 2)" already extracted
# Song 10. "Sweet Home Chicago (ver 2)" already extracted
# Song 11. "Holding Back The Years" already extracted
# Song 12. "Hello" already extracted
# Song 13. "Smooth Operator" already extracted
# Song 14. "Maneater" already extracted
# Song 15. "Out Of Touch (ver 2)" already extracted
# Song 16. "Im So Excited (ver 2)" already extracted
# Song 17. "Every Time You Go Away (ver 2)" already extracted
# Song 18. "You Make My Dreams (ver 4)" already extracted
# Song 19. "That Spirit Of Christmas" already extracted
# Song 20. "I Cant Go For That No Can Do" already extracted
# Song 21. "Overjoyed (ver 5)" already extracted
# Song 22. "Je Te Promets" already extracted
# Song 23. "Minnie The Moocher" already extracted
# Song 24. "Maneater (ver 3)" already extracted
# Song 25. "Sexual Healing (ver 2)" already extracted
# Song 26. "You Make My Dreams (ver 2)" already extracted
# Song 27. "Hello (ver 2)" already extracted
# Song 28. "Up Where We Belong (ver 3)" already extracted
# Song 29. "If You Dont Know Me By Now (ver 2)" already extracted
# Song 30. "Quelque Chose De Tennessee (ver 2)" already extracted
# Song 31. "1999" already extracted
# Song 32. "On The Wings Of Love" already extracted
# Song 33. "Sweet Home Chicago" already extracted
# Song 34. "I Just Called To Say I Love You (ver 2)" already extracted
# Song 35. "Overjoyed" already extracted
# Song 36. "Part-Time Lover" already extracted
# Song 37. "Every Time You Go Away (ver 4)" already extracted
# Song 38. "Little Red Corvette (ver 2)" already extracted
# Song 39. "Nothings Gonna Change My Love For You (ver 3)" already extracted
# Song 40. "Happy Birthday" already extracted
# Song 41. "Private Dancer" already extracted
# Song 42. "Lenvie" already extracted
# Song 43. "When You Were Mine (ver 2)" already extracted
# Song 44. "Kiss On My List (ver 2)" already extracted
# Song 45. "Give It Up" already extracted
# Song 46. "You Can Leave Your Hat On" already extracted
# Song 47. "Lets Groove" already extracted
# Song 48. "Stuck On You" already extracted
# Song 49. "Freedom" already extracted
# Extracted 50 of 147 (Rhythm And Blues,1980s). 3601 in total
# Song 0. "Every Rose Has Its Thorn" already extracted
# Song 1. "Still Loving You (ver 4)" already extracted
# Song 2. "I Remember You (ver 2)" already extracted
# Song 3. "Fade To Black" already extracted
# Song 4. "Crazy Train (ver 3)" already extracted
# Song 5. "Still Loving You (ver 2)" already extracted
# Song 6. "Rock You Like A Hurricane" already extracted
# Song 7. "One" already extracted
# Song 8. "Were Not Gonna Take It" already extracted
# Song 9. "Every Rose Has Its Thorn (ver 3)" already extracted
# Song 10. "Master Of Puppets" already extracted
# Song 11. "When The Children Cry (ver 4)" already extracted
# Song 12. "Heaven" already extracted
# Song 13. "No One Like You" already extracted
# Song 14. "Still Loving You" already extracted
# Song 15. "Talk Dirty To Me" already extracted
# Song 16. "Wasted Years" already extracted
# Song 17. "Run To The Hills" already extracted
# Song 18. "Crazy Train" already extracted
# Song 19. "Still Loving You (ver 5)" already extracted
# Song 20. "Mother" already extracted
# Song 21. "18 And Life" already extracted
# Song 22. "Holy Diver" already extracted
# Song 23. "Youve Got Another Thing Comin (ver 2)" already extracted
# Song 24. "Breaking The Law" already extracted
# Song 25. "Breaking The Law (ver 2)" already extracted
# Song 26. "Every Rose Has Its Thorn (ver 2)" already extracted
# Song 27. "When The Smoke Is Going Down" already extracted
# Song 28. "Bringin On The Heartbreak" already extracted
# Song 29. "The Ballad Of Jayne (ver 2)" already extracted
# Song 30. "Cum On Feel The Noize (ver 3)" already extracted
# Song 31. "Fallen Angel" already extracted
# Song 32. "Heaven (ver 3)" already extracted
# Song 33. "Mr Crowley" already extracted
# Song 34. "Dont Know What You Got Till Its Gone" already extracted
# Song 35. "Still Loving You (ver 3)" already extracted
# Song 36. "Close My Eyes Forever" already extracted
# Song 37. "Goodbye To Romance (ver 2)" already extracted
# Song 38. "For Whom The Bell Tolls (ver 2)" already extracted
# Song 39. "The Trooper" already extracted
# Song 40. "Epic" already extracted
# Song 41. "Rainbow In The Dark" already extracted
# Song 42. "Heart Of Steel" already extracted
# Song 43. "Crazy Crazy Nights" already extracted
# Song 44. "Close My Eyes Forever (ver 2)" already extracted
# Song 45. "Heaven And Hell" already extracted
# Song 46. "Nothin But A Good Time" already extracted
# Song 47. "For Whom The Bell Tolls" already extracted
# Song 48. "2 Minutes To Midnight" already extracted
# Song 49. "18 And Life (ver 3)" already extracted
# Extracted 50 of 147 (Metal,1980s). 3651 in total
# Song 0. "Man In The Mirror" already extracted
# Song 1. "Billie Jean (ver 2)" already extracted
# Song 2. "Billie Jean (ver 3)" already extracted
# Song 3. "Beat It" already extracted
# Song 4. "Billie Jean" already extracted
# Song 5. "The Way You Make Me Feel (ver 2)" already extracted
# Song 6. "Human Nature" already extracted
# Song 7. "Thriller" already extracted
# Song 8. "Bad" already extracted
# Song 9. "Overjoyed (ver 5)" already extracted
# Song 10. "Greatest Love Of All" already extracted
# Song 11. "Man In The Mirror (ver 4)" already extracted
# Song 12. "Saving All My Love For You" already extracted
# Song 13. "Man In The Mirror (ver 2)" already extracted
# Song 14. "On The Wings Of Love" already extracted
# Song 15. "Pyt Pretty Young Thing (ver 3)" already extracted
# Song 16. "Overjoyed" already extracted
# Song 17. "Part-Time Lover" already extracted
# Song 18. "How Will I Know (ver 4)" already extracted
# Song 19. "Human Nature (ver 2)" already extracted
# Song 20. "Saving All My Love For You (ver 2)" already extracted
# Song 21. "Part-Time Lover (ver 2)" already extracted
# Song 22. "If We Hold On Together" already extracted
# Song 23. "Bad Album" already extracted
# Song 24. "Beat It (ver 2)" already extracted
# Song 25. "Greatest Love Of All (ver 3)" already extracted
# Song 26. "I Just Cant Stop Loving You (ver 2)" already extracted
# Song 27. "Suddenly" already extracted
# Song 28. "Free (ver 2)" already extracted
# Song 29. "The Girl Is Mine" already extracted
# Song 30. "The Beautiful Ones" already extracted
# Song 31. "I Just Cant Stop Loving You" already extracted
# Song 32. "The Lady In My Life" already extracted
# Song 33. "Through The Fire" already extracted
# Song 34. "Starfish And Coffee" already extracted
# Song 35. "Super Freak" already extracted
# Song 36. "The Way You Make Me Feel" already extracted
# Song 37. "Billie Jean (ver 8)" already extracted
# Song 38. "Overjoyed (ver 2)" already extracted
# Song 39. "Give It To Me Baby" already extracted
# Song 40. "Through The Fire (ver 2)" already extracted
# Song 41. "I Just Cant Stop Loving You (ver 6)" already extracted
# Song 42. "The Way You Make Me Feel (ver 4)" already extracted
# Song 43. "Pyt Pretty Young Thing" already extracted
# Song 44. "Thriller Album" already extracted
# Song 45. "Do Me Baby (ver 2)" already extracted
# Song 46. "Adore" already extracted
# Song 47. "You Give Good Love (ver 2)" already extracted
# Song 48. "Greatest Love Of All (ver 2)" already extracted
# Song 49. "Dare Me (ver 2)" already extracted
# Extracted 50 of 147 (Contemporary R&b,1980s). 3701 in total
# Song 0. "Oh Lord Youre Beautiful" already extracted
# Song 1. "Tennessee Christmas" already extracted
# Song 2. "Thy Word (ver 3)" already extracted
# Song 3. "I Will Be Here (ver 5)" already extracted
# Song 4. "There Is A Redeemer" already extracted
# Song 5. "Great Is The Lord" already extracted
# Song 6. "We Bow Down" already extracted
# Song 7. "Friends All In The Family Of God" already extracted
# Song 8. "I Will Call Upon The Lord" already extracted
# Song 9. "Thy Word (ver 2)" already extracted
# Song 10. "Friends" already extracted
# Song 11. "There Is A Redeemer (ver 2)" already extracted
# Song 12. "There Is A Redeemer (ver 3)" already extracted
# Song 13. "Oh Lord Youre Beautiful (ver 2)" already extracted
# Song 14. "Lead Me On" already extracted
# Song 15. "The Warrior Is A Child" already extracted
# Song 16. "Take Me In" already extracted
# Song 17. "Emmanuel" already extracted
# Song 18. "Emmanuel (ver 2)" already extracted
# Song 19. "The Love Of God" already extracted
# Song 20. "Thy Word (ver 4)" already extracted
# Song 21. "I Will Be Here" already extracted
# Song 22. "I Will Be Here (ver 2)" already extracted
# Song 23. "There Is A Redeemer (ver 4)" already extracted
# Song 24. "Romans Vii" already extracted
# Song 25. "Oh Lord Youre Beautiful (ver 3)" already extracted
# Song 26. "Oh Lord Youre Beautiful (ver 4)" already extracted
# Song 27. "Oh Lord Youre Beautiful (ver 5)" already extracted
# Song 28. "Oh Lord Youre Beautiful (ver 6)" already extracted
# Song 29. "Oh Lord Youre Beautiful (ver 7)" already extracted
# Song 30. "Oh Lord Youre Beautiful (ver 8)" already extracted
# Song 31. "Oh Lord Youre Beautiful (ver 9)" already extracted
# Song 32. "Verge Of A Miracle" already extracted
# Song 33. "Be With You" already extracted
# Song 34. "Screen Door" already extracted
# Song 35. "What Trouble Are Giants" already extracted
# Song 36. "We Bow Down (ver 2)" already extracted
# Song 37. "The Battle Belongs To The Lord" already extracted
# Song 38. "Hallowed Be Thy Name" already extracted
# Song 39. "Hallowed Be Thy Name (ver 2)" already extracted
# Song 40. "Until That Final Day" already extracted
# Song 41. "Hope To Carry On" already extracted
# Song 42. "First Family" already extracted
# Song 43. "Bound To Come Some Trouble" already extracted
# Song 44. "Somewhere" already extracted
# Song 45. "Lean On Me" already extracted
# Song 46. "Too Late" already extracted
# Song 47. "The Now And The Not Yet" already extracted
# Song 48. "Thy Word" already extracted
# Song 49. "Grace By Which I Stand" already extracted
# Extracted 50 of 147 (Religious Music,1980s). 3751 in total
# Song 0. "Just A Friend" already extracted
# Song 1. "Rappers Delight" already extracted
# Song 2. "Ice Ice Baby" already extracted
# Song 3. "Its Tricky" already extracted
# Extracted 4 of 147 (Hip Hop,1980s). 3755 in total
# Song 0. "Redemption Song (ver 2)" already extracted
# Song 1. "Redemption Song" already extracted
# Song 2. "Redemption Song (ver 3)" already extracted
# Song 3. "Red Red Wine" already extracted
# Song 4. "Could You Be Loved" already extracted
# Song 5. "Natural Mystic" already extracted
# Song 6. "Kingston Town" already extracted
# Song 7. "It Must Be Love (ver 5)" already extracted
# Song 8. "Kingston Town (ver 2)" already extracted
# Song 9. "Red Red Wine (ver 3)" already extracted
# Song 10. "Our House (ver 3)" already extracted
# Song 11. "Lively Up Yourself" already extracted
# Song 12. "Your House" already extracted
# Song 13. "Soul Rebel" already extracted
# Song 14. "Sinds 1 Dag Of 2 32 Jaar" already extracted
# Song 15. "Ghost Town" already extracted
# Song 16. "I Got You Babe" already extracted
# Song 17. "Gimme Hope Joanna" already extracted
# Song 18. "Bad Boys (ver 2)" already extracted
# Song 19. "It Must Be Love (ver 2)" already extracted
# Song 20. "Redemption Song (ver 6)" already extracted
# Song 21. "Redemption Song (ver 8)" already extracted
# Song 22. "Homely Girl" already extracted
# Song 23. "Many Rivers To Cross" already extracted
# Song 24. "Kaya" already extracted
# Song 25. "Natural Mystic (ver 2)" already extracted
# Song 26. "Bad Boys" already extracted
# Song 27. "Food For Thought" already extracted
# Song 28. "Forever Loving Jah" already extracted
# Song 29. "Zion Train" already extracted
# Song 30. "Kingston Town (ver 4)" already extracted
# Song 31. "Red Red Wine (ver 4)" already extracted
# Song 32. "Dont Break My Heart" already extracted
# Song 33. "Electric Avenue" already extracted
# Song 34. "House Of Fun" already extracted
# Song 35. "Roller Skates" already extracted
# Song 36. "Smoorverliefd" already extracted
# Song 37. "Pimpers Paradise" already extracted
# Song 38. "Reggae Fever" already extracted
# Song 39. "Coming In From The Cold" already extracted
# Song 40. "Coming In From The Cold (ver 2)" already extracted
# Song 41. "Keep On Moving" already extracted
# Song 42. "Johnny B Goode" already extracted
# Song 43. "Rally Round" already extracted
# Song 44. "Your House (ver 2)" already extracted
# Song 45. "Do You Feel My Love" already extracted
# Song 46. "Cherry Oh Baby" already extracted
# Song 47. "Rat In Mi Kitchen" already extracted
# Song 48. "Im Hurting Inside" already extracted
# Song 49. "Real Situation" already extracted
# Extracted 50 of 147 (Reggae,1980s). 3805 in total
# Song 0. "Dont Worry Be Happy (ver 3)" already extracted
# Song 1. "Nothings Gonna Change My Love For You (ver 4)" already extracted
# Song 2. "Dont Worry Be Happy (ver 2)" already extracted
# Song 3. "Nothings Gonna Change My Love For You (ver 3)" already extracted
# Song 4. "It Had To Be You (ver 2)" already extracted
# Song 5. "Dont Worry Be Happy (ver 4)" already extracted
# Song 6. "Nothings Gonna Change My Love For You" already extracted
# Song 7. "Give Me The Night" already extracted
# Song 8. "Dont Worry Be Happy" already extracted
# Song 9. "Nothings Gonna Change My Love For You (ver 2)" already extracted
# Song 10. "Broken Bicycles" already extracted
# Song 11. "I Beg Your Pardon Dear" already extracted
# Song 12. "Dont Worry Be Happy (ver 8)" already extracted
# Song 13. "Nothings Gonna Change My Love For You (ver 5)" already extracted
# Song 14. "Smiles And Smiles To Go" already extracted
# Song 15. "Dont Worry Be Happy (ver 5)" already extracted
# Song 16. "54 Duncan Terrace" already extracted
# Song 17. "Take Me Home" already extracted
# Song 18. "In Your Eyes (ver 2)" already extracted
# Song 19. "It Had To Be You" already extracted
# Song 20. "It Had To Be You (ver 3)" already extracted
# Song 21. "Oh No" already extracted
# Song 22. "Dont Worry Be Happy (ver 7)" already extracted
# Song 23. "Love Games" already extracted
# Song 24. "Looking Glass" already extracted
# Song 25. "Drifting And Dreaming" already extracted
# Song 26. "Stinkfoot" already extracted
# Song 27. "Broken Bicycles (ver 2)" already extracted
# Song 28. "Little Boy Blue" already extracted
# Song 29. "You Are The Love Of My Life" already extracted
# Song 30. "Out Of Sight Out Of Mind" already extracted
# Song 31. "The Chant Has Begun" already extracted
# Song 32. "La Is My Lady" already extracted
# Song 33. "In Your Eyes" already extracted
# Song 34. "It Had To Be You (ver 4)" already extracted
# Song 35. "Breezin" already extracted
# Song 36. "Tenderly" already extracted
# Song 37. "Three Views Of A Secret" already extracted
# Song 38. "Dont Worry Be Happy (ver 6)" already extracted
# Extracted 39 of 147 (Jazz,1980s). 3844 in total
# Song 0. "Josephine" already extracted
# Song 1. "On The Beach" already extracted
# Song 2. "Damn Your Eyes" already extracted
# Song 3. "I Can Hear Your Heartbeat (ver 2)" already extracted
# Song 4. "On The Beach (ver 2)" already extracted
# Song 5. "I Just Wanna Make Love To You" already extracted
# Song 6. "Stainsby Girls" already extracted
# Song 7. "Josephine (ver 2)" already extracted
# Song 8. "Lets Dance" already extracted
# Song 9. "On The Beach (ver 3)" already extracted
# Song 10. "Champagne And Reefer" already extracted
# Song 11. "Damn Your Eyes (ver 2)" already extracted
# Song 12. "Room To Move" already extracted
# Song 13. "Jumping At Shadows" already extracted
# Song 14. "I Just Wanna Make Love To You (ver 2)" already extracted
# Song 15. "Josephine (ver 4)" already extracted
# Song 16. "She Bop" already extracted
# Song 17. "I Can Hear Your Heartbeat" already extracted
# Song 18. "The Sky Is Crying" already extracted
# Song 19. "Change Of Heart" already extracted
# Song 20. "Change Of Heart (ver 2)" already extracted
# Song 21. "Baby Baby Baby" already extracted
# Song 22. "Hey Baby Right Away" already extracted
# Song 23. "Trouble Ive Had All My Days" already extracted
# Song 24. "Jumping At Shadows (ver 2)" already extracted
# Song 25. "Jumping At Shadows (ver 3)" already extracted
# Song 26. "Jumping At Shadows (ver 4)" already extracted
# Song 27. "Josephine (ver 3)" already extracted
# Song 28. "I Guess I Showed Her" already extracted
# Song 29. "Foul Play" already extracted
# Song 30. "Smoking Gun" already extracted
# Extracted 31 of 147 (Blues,1980s). 3875 in total
# Song 0. "Lambada" already extracted
# Song 1. "Un Amor" already extracted
# Song 2. "No Touch" already extracted
# Song 3. "Un Amor (ver 2)" already extracted
# Song 4. "Djobi Djoba (ver 2)" already extracted
# Song 5. "La Dona" already extracted
# Song 6. "Por Un Amor" already extracted
# Song 7. "Voce E Linda" already extracted
# Song 8. "Kahit Na Anong Mangyari" already extracted
# Song 9. "Calaverada" already extracted
# Song 10. "Ruptura" already extracted
# Song 11. "Princessa" already extracted
# Song 12. "Ciento" already extracted
# Song 13. "Solituda" already extracted
# Song 14. "Papa No Pega La Mama" already extracted
# Song 15. "Rogaciano El Huapanguero" already extracted
# Song 16. "El Sol Que Tú Eres" already extracted
# Song 17. "Vaca Profana" already extracted
# Song 18. "O Quereres" already extracted
# Song 19. "Dom De Iludir" already extracted
# Song 20. "Los Laureles" already extracted
# Song 21. "Panahon" already extracted
# Song 22. "Inday" already extracted
# Song 23. "Queixa" already extracted
# Song 24. "Trem Das Cores" already extracted
# Song 25. "Meu Bem, Meu Mal" already extracted
# Song 26. "Djobi Djoba" already extracted
# Song 27. "Valsa De Uma Cidade" already extracted
# Extracted 28 of 147 (World Music,1980s). 3903 in total
# Song 0. "Lay All Your Love On Me" already extracted
# Song 1. "Im So Excited (ver 2)" already extracted
# Song 2. "Youre My Heart Youre My Soul (ver 2)" already extracted
# Song 3. "Give It Up" already extracted
# Song 4. "Funkytown" already extracted
# Song 5. "Lay All Your Love On Me (ver 2)" already extracted
# Song 6. "Upside Down (ver 2)" already extracted
# Song 7. "Cheri Cheri Lady" already extracted
# Song 8. "Brother Louie" already extracted
# Song 9. "Im Coming Out" already extracted
# Song 10. "I Am What I Am" already extracted
# Song 11. "She Works Hard For The Money" already extracted
# Song 12. "Upside Down" already extracted
# Song 13. "Geronimos Cadillac" already extracted
# Song 14. "Youre My Heart Youre My Soul" already extracted
# Song 15. "You Can Win If You Want" already extracted
# Song 16. "Funkytown (ver 2)" already extracted
# Song 17. "Do You Wanna" already extracted
# Song 18. "This Time I Know Its For Real" already extracted
# Song 19. "Brother Louie (ver 2)" already extracted
# Song 20. "Im So Excited" already extracted
# Song 21. "Who Will Save The World" already extracted
# Song 22. "Me And I" already extracted
# Song 23. "Designer Music" already extracted
# Song 24. "My Old Piano" already extracted
# Song 25. "Heaven Will Know" already extracted
# Song 26. "Im Coming Out (ver 2)" already extracted
# Song 27. "Upside Down (ver 3)" already extracted
# Song 28. "The Night Is Yours The Night Is Mine" already extracted
# Song 29. "Love At First Sight" already extracted
# Song 30. "Love At First Sight (ver 2)" already extracted
# Song 31. "Diamonds Never Made A Lady" already extracted
# Song 32. "Theres Too Much Blue In Missing You" already extracted
# Song 33. "Breakaway" already extracted
# Song 34. "Cheri Cheri Lady (ver 2)" already extracted
# Song 35. "One In A Million" already extracted
# Song 36. "Bells Of Paris" already extracted
# Song 37. "Lucky Guy" already extracted
# Song 38. "Dont Worry" already extracted
# Song 39. "Im So Excited (ver 3)" already extracted
# Extracted 40 of 147 (Disco,1980s). 3943 in total
# Song 0. "Yoda" already extracted
# Song 1. "Melanie" already extracted
# Song 2. "I Love Rocky Road" already extracted
# Song 3. "Christmas At Ground Zero" already extracted
# Song 4. "One More Minute (ver 3)" already extracted
# Song 5. "Good Enough For Now" already extracted
# Song 6. "Stop Draggin My Car Around" already extracted
# Song 7. "I Think Im A Clone Now" already extracted
# Song 8. "My Bologna" already extracted
# Song 9. "Another One Rides The Bus" already extracted
# Song 10. "Ricky" already extracted
# Song 11. "Midnight Star" already extracted
# Song 12. "This Is The Life" already extracted
# Song 13. "Living With A Hernia" already extracted
# Song 14. "You Make Me" already extracted
# Song 15. "The Biggest Ball Of Twine In Minnesota" already extracted
# Song 16. "Generic Blues" already extracted
# Song 17. "Eat It" already extracted
# Song 18. "One More Minute" already extracted
# Song 19. "One More Minute (ver 2)" already extracted
# Song 20. "Dare To Be Stupid" already extracted
# Song 21. "I Lost On Jeopardy" already extracted
# Song 22. "Nature Trail To Hell" already extracted
# Song 23. "Nature Trail To Hell (ver 2)" already extracted
# Song 24. "Nature Trail To Hell (ver 3)" already extracted
# Song 25. "Happy Birthday" already extracted
# Song 26. "Gotta Boogie" already extracted
# Song 27. "Mr. Frump In The Iron Lung" already extracted
# Song 28. "Dont Wear Those Shoes" already extracted
# Song 29. "Spam" already extracted
# Song 30. "Buckingham Blues" already extracted
# Song 31. "The Checks In The Mail" already extracted
# Extracted 32 of 147 (Comedy,1980s). 3975 in total
# Song 0. "Orinoco Flow" already extracted
# Song 1. "Evening Falls" already extracted
# Song 2. "Exile" already extracted
# Song 3. "Exile (ver 2)" already extracted
# Song 4. "Na Laetha Geal Moige" already extracted
# Song 5. "Na Laetha Geal Moige (ver 2)" already extracted
# Song 6. "Cursum Perficio" already extracted
# Song 7. "On Your Shore" already extracted
# Song 8. "On Your Shore (ver 2)" already extracted
# Song 9. "Storms In Africa" already extracted
# Song 10. "Storms In Africa (ver 2)" already extracted
# Song 11. "River" already extracted
# Extracted 12 of 147 (New Age,1980s). 3987 in total
# Song 0. "Oh No" already extracted
# Extracted 1 of 147 (Classical,1980s). 3988 in total
# Song 0. "Eternal Legs" already extracted
# Extracted 1 of 147 (Experimental,1980s). 3989 in total
# Song 0. "The Honour Of Silence" already extracted
# Song 1. "The Honour Of Silence (ver 2)" already extracted
# Song 2. "Leper Lord" already extracted
# Song 3. "She Said Destroy" already extracted
# Song 4. "She Said Destroy (ver 2)" already extracted
# Extracted 5 of 147 (Darkwave,1980s). 3994 in total
# Extracted 84 of 147 (Soundtrack,1980s). 3994 in total
# Song 0. "Hotel California" already extracted
# Song 1. "Wish You Were Here" already extracted
# Song 2. "Imagine" already extracted
# Song 3. "Let It Be (ver 2)" already extracted
# Song 4. "Your Song" already extracted
# Song 5. "Knockin On Heavens Door (ver 2)" already extracted
# Song 6. "Bohemian Rhapsody (ver 5)" already extracted
# Song 7. "Have You Ever Seen The Rain" already extracted
# Song 8. "Love Of My Life" already extracted
# Song 9. "Let It Be" already extracted
# Song 10. "Father And Son" already extracted
# Song 11. "Sweet Caroline" already extracted
# Song 12. "Dont Stop Me Now (ver 3)" already extracted
# Song 13. "Heart Of Gold" already extracted
# Song 14. "Piano Man (ver 5)" already extracted
# Song 15. "Please Come Home For Christmas" already extracted
# Song 16. "Rocket Man" already extracted
# Song 17. "Bohemian Rhapsody" already extracted
# Song 18. "Wonderful Tonight (ver 2)" already extracted
# Song 19. "A Horse With No Name" already extracted
# Song 20. "Stairway To Heaven (ver 5)" already extracted
# Song 21. "Take It Easy (ver 2)" already extracted
# Song 22. "Crazy Little Thing Called Love" already extracted
# Song 23. "Hotel California (ver 4)" already extracted
# Song 24. "Somebody To Love" already extracted
# Song 25. "Dust In The Wind (ver 2)" already extracted
# Song 26. "How Deep Is Your Love (ver 8)" already extracted
# Song 27. "Across The Universe" already extracted
# Song 28. "Sweet Home Alabama" already extracted
# Song 29. "Simple Man (ver 3)" already extracted
# Song 30. "Starman (ver 2)" already extracted
# Song 31. "Wish You Were Here (ver 2)" already extracted
# Song 32. "Wild World" already extracted
# Song 33. "Sultans Of Swing (ver 2)" already extracted
# Song 34. "Highway To Hell" already extracted
# Song 35. "Tiny Dancer (ver 2)" already extracted
# Song 36. "My Sweet Lord" already extracted
# Song 37. "Comfortably Numb" already extracted
# Song 38. "Goodbye Yellow Brick Road" already extracted
# Song 39. "The Long And Winding Road" already extracted
# Song 40. "Me And Bobby Mcgee" already extracted
# Song 41. "Wild Horses" already extracted
# Song 42. "Fire And Rain (ver 3)" already extracted
# Song 43. "Imagine (ver 4)" already extracted
# Song 44. "Bridge Over Troubled Water (ver 2)" already extracted
# Song 45. "Heroes (ver 3)" already extracted
# Song 46. "Desperado" already extracted
# Song 47. "Roxanne (ver 3)" already extracted
# Song 48. "The Chain (ver 2)" already extracted
# Song 49. "Lyin Eyes" already extracted
# Extracted 50 of 147 (Rock,1970s). 4044 in total
# Song 0. "Take Me Home Country Roads (ver 10)" already extracted
# Song 1. "Imagine" already extracted
# Song 2. "Take Me Home Country Roads" already extracted
# Song 3. "Your Song" already extracted
# Song 4. "Knockin On Heavens Door (ver 2)" already extracted
# Song 5. "Jolene (ver 2)" already extracted
# Song 6. "Father And Son" already extracted
# Song 7. "Sweet Caroline" already extracted
# Song 8. "American Pie" already extracted
# Song 9. "Heart Of Gold" already extracted
# Song 10. "Piano Man (ver 5)" already extracted
# Song 11. "Rocket Man" already extracted
# Song 12. "River (ver 4)" already extracted
# Song 13. "Wild World" already extracted
# Song 14. "My Sweet Lord" already extracted
# Song 15. "Goodbye Yellow Brick Road" already extracted
# Song 16. "Fire And Rain (ver 3)" already extracted
# Song 17. "Imagine (ver 4)" already extracted
# Song 18. "Bridge Over Troubled Water (ver 2)" already extracted
# Song 19. "Youve Got A Friend" already extracted
# Song 20. "Your Song (ver 7)" already extracted
# Song 21. "Old Man (ver 10)" already extracted
# Song 22. "Rocket Man (ver 4)" already extracted
# Song 23. "Take Me Home Country Roads (ver 2)" already extracted
# Song 24. "Jealous Guy" already extracted
# Song 25. "Knockin On Heavens Door (ver 5)" already extracted
# Song 26. "Morning Has Broken" already extracted
# Song 27. "Wild World (ver 2)" already extracted
# Song 28. "Sweet Caroline (ver 4)" already extracted
# Song 29. "Maybe Im Amazed" already extracted
# Song 30. "Angel From Montgomery (ver 2)" already extracted
# Song 31. "Into The Mystic (ver 2)" already extracted
# Song 32. "Working Class Hero" already extracted
# Song 33. "Cats In The Cradle" already extracted
# Song 34. "Pancho And Lefty (ver 2)" already extracted
# Song 35. "Big Yellow Taxi" already extracted
# Song 36. "Sundown" already extracted
# Song 37. "A Spaceman Came Travelling" already extracted
# Song 38. "Time In A Bottle" already extracted
# Song 39. "Tangled Up In Blue" already extracted
# Song 40. "Chelsea Hotel No 2 (ver 2)" already extracted
# Song 41. "If You Could Read My Mind" already extracted
# Song 42. "Your Song (ver 3)" already extracted
# Song 43. "Take Me Home Country Roads (ver 3)" already extracted
# Song 44. "New York State Of Mind" already extracted
# Song 45. "Hurricane" already extracted
# Song 46. "Heart Of Gold (ver 4)" already extracted
# Song 47. "Old Man (ver 4)" already extracted
# Song 48. "Imagine (ver 6)" already extracted
# Song 49. "Youre So Vain (ver 3)" already extracted
# Extracted 50 of 147 (Folk,1970s). 4094 in total
# Song 0. "Sweet Caroline" already extracted
# Song 1. "How Deep Is Your Love (ver 8)" already extracted
# Song 2. "I Will Survive (ver 2)" already extracted
# Song 3. "Mamma Mia" already extracted
# Song 4. "The Gambler (ver 2)" already extracted
# Song 5. "Give A Little Bit (ver 2)" already extracted
# Song 6. "Mr Blue Sky" already extracted
# Song 7. "Sweet Caroline (ver 4)" already extracted
# Song 8. "Angel From Montgomery (ver 2)" already extracted
# Song 9. "Über Den Wolken" already extracted
# Song 10. "A Spaceman Came Travelling" already extracted
# Song 11. "Superstition" already extracted
# Song 12. "New York State Of Mind" already extracted
# Song 13. "How Deep Is Your Love" already extracted
# Song 14. "I Will Survive" already extracted
# Song 15. "Youre So Vain (ver 3)" already extracted
# Song 16. "Solsbury Hill (ver 2)" already extracted
# Song 17. "Dont Let The Sun Go Down On Me (ver 2)" already extracted
# Song 18. "Je Laime A Mourir (ver 3)" already extracted
# Song 19. "Burning Love" already extracted
# Song 20. "I Have A Dream" already extracted
# Song 21. "Top Of The World" already extracted
# Song 22. "Stayin Alive (ver 2)" already extracted
# Song 23. "Thank You For The Music (ver 2)" already extracted
# Song 24. "Youve Got A Friend (ver 2)" already extracted
# Song 25. "Merry Christmas Darling" already extracted
# Song 26. "Telephone Line" already extracted
# Song 27. "Sos" already extracted
# Song 28. "Sir Duke" already extracted
# Song 29. "How Deep Is Your Love (ver 3)" already extracted
# Song 30. "I Wont Last A Day Without You (ver 3)" already extracted
# Song 31. "Its Too Late (ver 3)" already extracted
# Song 32. "You Are So Beautiful" already extracted
# Song 33. "Chiquitita (ver 2)" already extracted
# Song 34. "How Deep Is Your Love (ver 4)" already extracted
# Song 35. "Mr Blue Sky (ver 2)" already extracted
# Song 36. "Mamma Mia (ver 2)" already extracted
# Song 37. "Im Not In Love" already extracted
# Song 38. "Dancing Queen" already extracted
# Song 39. "Rock With You (ver 2)" already extracted
# Song 40. "I Have A Dream (ver 2)" already extracted
# Song 41. "Year Of The Cat" already extracted
# Song 42. "Superstition (ver 4)" already extracted
# Song 43. "Solsbury Hill" already extracted
# Song 44. "The Gambler (ver 3)" already extracted
# Song 45. "Rhinestone Cowboy (ver 2)" already extracted
# Song 46. "Dancing Queen (ver 4)" already extracted
# Song 47. "Cracklin Rosie" already extracted
# Song 48. "Escape The Pina Colada Song" already extracted
# Song 49. "Sailing" already extracted
# Extracted 50 of 147 (Pop,1970s). 4144 in total
# Song 0. "Take Me Home Country Roads (ver 10)" already extracted
# Song 1. "Take Me Home Country Roads" already extracted
# Song 2. "Knockin On Heavens Door (ver 2)" already extracted
# Song 3. "Jolene (ver 2)" already extracted
# Song 4. "The Gambler (ver 2)" already extracted
# Song 5. "Take Me Home Country Roads (ver 2)" already extracted
# Song 6. "Always On My Mind" already extracted
# Song 7. "Knockin On Heavens Door (ver 5)" already extracted
# Song 8. "Sunday Morning Coming Down (ver 5)" already extracted
# Song 9. "Pancho And Lefty (ver 2)" already extracted
# Song 10. "Ghost Riders In The Sky (ver 7)" already extracted
# Song 11. "Take Me Home Country Roads (ver 3)" already extracted
# Song 12. "Listen To The Music (ver 4)" already extracted
# Song 13. "Rocky Mountain High" already extracted
# Song 14. "Help Me Make It Through The Night (ver 2)" already extracted
# Song 15. "Friend Of The Devil (ver 2)" already extracted
# Song 16. "I Will Always Love You (ver 4)" already extracted
# Song 17. "Blue Eyes Crying In The Rain" already extracted
# Song 18. "Angel From Montgomery (ver 2)" already extracted
# Song 19. "Margaritaville (ver 2)" already extracted
# Song 20. "Knockin On Heavens Door" already extracted
# Song 21. "Long Train Runnin (ver 2)" already extracted
# Song 22. "Beautiful Star Of Bethlehem" already extracted
# Song 23. "Take Me Home Country Roads (ver 8)" already extracted
# Song 24. "Coat Of Many Colors (ver 2)" already extracted
# Song 25. "Sunday Morning Coming Down (ver 3)" already extracted
# Song 26. "If We Make It Through December" already extracted
# Song 27. "Why Me Lord" already extracted
# Song 28. "Thank God Im A Country Boy (ver 3)" already extracted
# Song 29. "Scarlet Begonias" already extracted
# Song 30. "Long Train Runnin (ver 3)" already extracted
# Song 31. "Family Tradition" already extracted
# Song 32. "Man In Black" already extracted
# Song 33. "The Gambler (ver 3)" already extracted
# Song 34. "Rhinestone Cowboy (ver 2)" already extracted
# Song 35. "Mr Bojangles (ver 3)" already extracted
# Song 36. "Jolene" already extracted
# Song 37. "Me And Bobby Mcgee" already extracted
# Song 38. "Listen To The Music" already extracted
# Song 39. "Eyes Of The World (ver 2)" already extracted
# Song 40. "Shady Grove" already extracted
# Song 41. "For The Good Times" already extracted
# Song 42. "Pancho And Lefty (ver 3)" already extracted
# Song 43. "The Devil Went Down To Georgia" already extracted
# Song 44. "Christmas For Cowboys" already extracted
# Song 45. "Whiskey Bent And Hell Bound" already extracted
# Song 46. "Sunshine On My Shoulders" already extracted
# Song 47. "Here You Come Again" already extracted
# Song 48. "Blue Eyes Crying In The Rain (ver 2)" already extracted
# Song 49. "Sam Stone (ver 3)" already extracted
# Extracted 50 of 147 (Country,1970s). 4194 in total
# Song 0. "Video Killed The Radio Star (ver 2)" already extracted
# Song 1. "Video Killed The Radio Star (ver 4)" already extracted
# Song 2. "Mr Soul" already extracted
# Song 3. "Me" already extracted
# Song 4. "Autobahn" already extracted
# Song 5. "Video Killed The Radio Star" already extracted
# Song 6. "Mr Soul (ver 4)" already extracted
# Song 7. "Mr Soul (ver 5)" already extracted
# Song 8. "Someone Somewhere In Summertime" already extracted
# Song 9. "Being Boiled" already extracted
# Song 10. "Metal" already extracted
# Song 11. "Blind Youth" already extracted
# Song 12. "Video Killed The Radio Star (ver 3)" already extracted
# Song 13. "Kid Dynamo" already extracted
# Song 14. "Mr Soul (ver 2)" already extracted
# Song 15. "Mr Soul (ver 3)" already extracted
# Song 16. "Tracks" already extracted
# Song 17. "Airlane" already extracted
# Song 18. "Engineers" already extracted
# Song 19. "Complex" already extracted
# Song 20. "Conversation" already extracted
# Song 21. "Kometenmelodie 2" already extracted
# Song 22. "Cars" already extracted
# Song 23. "Films" already extracted
# Extracted 24 of 147 (Electronic,1970s). 4218 in total
# Song 0. "Aint No Sunshine" already extracted
# Song 1. "Lean On Me" already extracted
# Song 2. "September" already extracted
# Song 3. "Into The Mystic (ver 2)" already extracted
# Song 4. "Killing Me Softly With His Song" already extracted
# Song 5. "Superstition" already extracted
# Song 6. "Aint No Mountain High Enough" already extracted
# Song 7. "Easy (ver 2)" already extracted
# Song 8. "Lets Stay Together" already extracted
# Song 9. "Moondance" already extracted
# Song 10. "Rich Girl (ver 3)" already extracted
# Song 11. "Easy (ver 4)" already extracted
# Song 12. "Sir Duke" already extracted
# Song 13. "You Are So Beautiful" already extracted
# Song 14. "Superstition (ver 4)" already extracted
# Song 15. "Lovely Day (ver 5)" already extracted
# Song 16. "I Wish" already extracted
# Song 17. "Easy" already extracted
# Song 18. "Aint No Mountain High Enough (ver 2)" already extracted
# Song 19. "People Get Ready (ver 2)" already extracted
# Song 20. "You Are So Beautiful (ver 4)" already extracted
# Song 21. "Higher Ground (ver 2)" already extracted
# Song 22. "You Are The Sunshine Of My Life" already extracted
# Song 23. "Play That Funky Music" already extracted
# Extracted data from song 24. "The Wonder Of You (ver 5)"
# Extracted data from song 25. "Superstition (ver 2)"
# Extracted data from song 26. "Lets Get It On (ver 2)"
# Extracted data from song 27. "Young Americans"
# Extracted data from song 28. "Hot Stuff (ver 3)"
# Extracted data from song 29. "Give Love On Christmas Day"
# Extracted data from song 30. "Aint No Sunshine (ver 2)"
# Extracted data from song 31. "Signed Sealed Delivered Im Yours (ver 4)"
# Extracted data from song 32. "Use Me"
# Extracted data from song 33. "We Are Family"
# Extracted data from song 34. "Dont You Worry Bout A Thing (ver 3)"
# Extracted data from song 35. "Whats Going On (ver 4)"
# Extracted data from song 36. "Midnight Train To Georgia"
# Extracted data from song 37. "Abc (ver 2)"
# Extracted data from song 38. "Into The Mystic (ver 3)"
# Extracted data from song 39. "Love Really Hurts Without You (ver 2)"
# Extracted data from song 40. "Lovin You"
# Extracted data from song 41. "Lean On Me (ver 2)"
# Extracted data from song 42. "Never Can Say Goodbye"
# Extracted data from song 43. "Ben"
# Extracted data from song 44. "Wild Night"
# Extracted data from song 45. "Moondance (ver 4)"
# Extracted data from song 46. "Rich Girl"
# Extracted data from song 47. "Sara Smile"
# Extracted data from song 48. "Lets Get It On"
# Extracted data from song 49. "Move On Up"
# Extracted 50 of 147 (Rhythm And Blues,1970s). 4268 in total
# Extracted data from song 0. "Paranoid (ver 2)"
# Extracted data from song 1. "War Pigs"
# Extracted data from song 2. "Paranoid"
# Extracted data from song 3. "Changes"
# Extracted data from song 4. "Nib"
# Extracted data from song 5. "Snowblind"
# Extracted data from song 6. "Parisienne Walkways"
# Extracted data from song 7. "Before The Dawn"
# Extracted data from song 8. "Changes (ver 2)"
# Extracted data from song 9. "In Trance"
# Extracted data from song 10. "Rainbow Eyes (ver 2)"
# Extracted data from song 11. "In Trance (ver 2)"
# Extracted data from song 12. "Paranoid (ver 3)"
# Extracted data from song 13. "Nib (ver 2)"
# Extracted data from song 14. "Its Alright"
# Extracted data from song 15. "Epitaph"
# Extracted data from song 16. "Never Say Die"
# Extracted data from song 17. "Paranoid (ver 4)"
# Extracted data from song 18. "Born To Touch Your Feelings"
# Extracted data from song 19. "Beyond The Realms Of Death"
# Extracted data from song 20. "A National Acrobat"
# Extracted data from song 21. "Epitaph (ver 2)"
# Extracted data from song 22. "Divlje Jagode"
# Extracted data from song 23. "Frozen Rainbow"
# Extracted data from song 24. "Exciter"
# Extracted data from song 25. "Rainbow Eyes"
# Extracted data from song 26. "Electric Funeral"
# Extracted data from song 27. "Nib (ver 3)"
# Extracted data from song 28. "Is There Anybody There"
# Extracted data from song 29. "Dreamer Deceiver"
# Extracted data from song 30. "Victim Of Changes"
# Extracted 31 of 147 (Metal,1970s). 4299 in total
# Song 0. "Rock With You (ver 2)" already extracted
# Extracted data from song 1. "Rock With You"
# Extracted data from song 2. "Dont Stop Til You Get Enough"
# Extracted data from song 3. "I Wanna Be Your Lover"
# Extracted data from song 4. "Rock With You (ver 3)"
# Extracted data from song 5. "Shes Out Of My Life (ver 2)"
# Extracted data from song 6. "Its Gonna Be Lonely"
# Extracted data from song 7. "Shes Out Of My Life"
# Extracted data from song 8. "Why You Wanna Treat Me So Bad"
# Extracted data from song 9. "Rock With You (ver 4)"
# Extracted data from song 10. "Rock With You (ver 5)"
# Extracted data from song 11. "Shes Out Of My Life (ver 3)"
# ...
# Extracted data from song 45. "Big River (ver 2)"
# Extracted data from song 46. "Dont Take Your Guns To Town"
# Extracted data from song 47. "Maybellene"
# Extracted data from song 48. "Sleep Walk"
# Extracted data from song 49. "Big River (ver 4)"
# Extracted 50 of 147 (Rock,1950s). 5091 in total
# Extracted data from song 0. "This Land Is Your Land (ver 3)"
# Extracted data from song 1. "Big Rock Candy Mountain"
# Extracted data from song 2. "La Mauvaise Réputation"
# Extracted data from song 3. "Tom Dooley"
# Extracted data from song 4. "Freight Train (ver 2)"
# Extracted data from song 5. "Jamaica Farewell"
# Extracted data from song 6. "Freight Train"
# Extracted data from song 7. "Chanson Pour Lauvergnat"
# Extracted data from song 8. "This Land Is Your Land (ver 2)"
# Extracted data from song 9. "Jamaica Farewell (ver 2)"
# Extracted data from song 10. "Le Gorille (ver 2)"
# Extracted data from song 11. "Down In The Willow Garden"
# Extracted data from song 12. "Mta"
# Extracted data from song 13. "La Chasse Aux Papillons"
# Extracted data from song 14. "Dark As A Dungeon"
# Extracted data from song 15. "Chanson Pour Lauvergnat (ver 2)"
# Extracted data from song 16. "Skip To My Lou"
# Extracted data from song 17. "Scotch And Soda (ver 2)"
# Extracted data from song 18. "This Land Is Your Land"
# Extracted data from song 19. "Blow Ye Winds"
# Extracted data from song 20. "Scotch And Soda"
# Extracted data from song 21. "Sixteen Tons"
# Extracted data from song 22. "San Francisco Bay Blues"
# Extracted data from song 23. "Do Re Mi"
# Extracted data from song 24. "Island In The Sun (ver 3)"
# Extracted data from song 25. "Jesus Christ"
# Extracted data from song 26. "Big Rock Candy Mountain (ver 2)"
# Extracted data from song 27. "In The Good Old Summertime"
# Extracted data from song 28. "Beautiful Brown Eyes"
# Extracted data from song 29. "Banks Of Marble"
# Extracted data from song 30. "Scarlet Ribbons"
# Extracted data from song 31. "Celui Qui A Mal Tourné"
# Extracted data from song 32. "I Know An Old Lady Who Swallowed A Fly"
# Extracted data from song 33. "Lightning Express"
# Extracted data from song 34. "Scotch And Soda (ver 3)"
# Extracted data from song 35. "This Land Is Your Land (ver 4)"
# Extracted data from song 36. "Pretty Boy Floyd (ver 2)"
# Extracted data from song 37. "Pastures Of Plenty"
# Extracted data from song 38. "Tom Dooley (ver 3)"
# Extracted data from song 39. "Island In The Sun"
# Extracted data from song 40. "Man Smart Woman Smarter"
# Extracted data from song 41. "Jesus Christ (ver 2)"
# Extracted data from song 42. "Early In The Morning"
# Extracted data from song 43. "Across The Wide Missouri"
# Extracted data from song 44. "All My Sorrows"
# Extracted data from song 45. "Good News"
# Extracted data from song 46. "Molly Dee"
# Extracted data from song 47. "The Unfortunate Miss Bailey"
# Extracted data from song 48. "A Worried Man"
# Extracted data from song 49. "Raspberries Strawberries"
# Extracted 50 of 147 (Folk,1950s). 5141 in total
# Extracted data from song 0. "Have Yourself A Merry Little Christmas"
# Extracted data from song 1. "White Christmas"
# Extracted data from song 2. "Let It Snow"
# Song 3. "Blue Christmas (ver 3)" already extracted
# Extracted data from song 4. "Winter Wonderland (ver 2)"
# Extracted data from song 5. "Have Yourself A Merry Little Christmas (ver 3)"
# Extracted data from song 6. "White Christmas (ver 4)"
# Extracted data from song 7. "Sleigh Ride"
# Song 8. "Blue Christmas" already extracted
# Song 9. "Love Me Tender" already extracted
# Extracted data from song 10. "Marys Boychild Christmas Song (ver 2)"
# Extracted data from song 11. "Ne Me Quitte Pas"
# Extracted data from song 12. "Let It Snow (ver 2)"
# Song 13. "Heartbreak Hotel" already extracted
# Extracted data from song 14. "Have Yourself A Merry Little Christmas (ver 2)"
# Song 15. "Love Me Tender (ver 2)" already extracted
# Song 16. "Blue Suede Shoes" already extracted
# Extracted data from song 17. "Smile"
# Extracted data from song 18. "White Christmas (ver 7)"
# Song 19. "All Shook Up (ver 2)" already extracted
# Song 20. "Santa Claus Is Back In Town" already extracted
# Extracted data from song 21. "White Christmas (ver 2)"
# Extracted data from song 22. "Mack The Knife (ver 3)"
# Song 23. "Blue Christmas (ver 5)" already extracted
# Song 24. "Hound Dog (ver 2)" already extracted
# Extracted data from song 25. "Beyond The Sea"
# Song 26. "Hello Mary Lou (ver 3)" already extracted
# Song 27. "Blue Christmas (ver 2)" already extracted
# Extracted data from song 28. "My Funny Valentine"
# Extracted data from song 29. "Ive Got You Under My Skin"
# Extracted data from song 30. "Je Me Suis Fait Tout Petit (ver 2)"
# Song 31. "Hound Dog" already extracted
# Song 32. "La Mauvaise Réputation" already extracted
# Extracted data from song 33. "Everything Happens To Me"
# Extracted data from song 34. "Unforgettable"
# Song 35. "Dont Be Cruel (ver 4)" already extracted
# Extracted data from song 36. "Come Fly With Me"
# Extracted data from song 37. "The Great Pretender"
# Extracted data from song 38. "Quand On Na Que Lamour (ver 2)"
# Song 39. "Blue Suede Shoes (ver 2)" already extracted
# Song 40. "Blue Christmas (ver 4)" already extracted
# Extracted data from song 41. "Beyond The Sea (ver 4)"
# Song 42. "Hello Mary Lou (ver 5)" already extracted
# Extracted data from song 43. "All Of Me"
# Extracted data from song 44. "Thats Amore (ver 2)"
# Song 45. "White Christmas" already extracted
# Extracted data from song 46. "White Christmas (ver 3)"
# Extracted data from song 47. "Thats Amore"
# Extracted data from song 48. "Winter Wonderland"
# Extracted data from song 49. "Nature Boy"
# Extracted 50 of 147 (Pop,1950s). 5191 in total
# Song 0. "Folsom Prison Blues (ver 4)" already extracted
# Song 1. "I Walk The Line (ver 3)" already extracted
# Extracted data from song 2. "Big Iron"
# Song 3. "I Walk The Line" already extracted
# Song 4. "Folsom Prison Blues" already extracted
# Extracted data from song 5. "All I Have To Do Is Dream"
# Extracted data from song 6. "El Paso (ver 2)"
# Song 7. "I Still Miss Someone" already extracted
# Song 8. "Folsom Prison Blues (ver 2)" already extracted
# Extracted data from song 9. "Lovesick Blues"
# Extracted data from song 10. "Let It Be Me (ver 3)"
# Extracted data from song 11. "Big Iron (ver 3)"
# Extracted data from song 12. "Sixteen Tons (ver 3)"
# Extracted data from song 13. "Lost Highway"
# Extracted data from song 14. "Hey Good Lookin"
# Song 15. "Bye Bye Love (ver 2)" already extracted
# Song 16. "Wake Up Little Susie" already extracted
# Song 17. "Cry Cry Cry" already extracted
# Extracted data from song 18. "Cold Cold Heart"
# Song 19. "Great Balls Of Fire (ver 2)" already extracted
# Extracted data from song 20. "Hey Good Lookin (ver 2)"
# Extracted data from song 21. "All I Have To Do Is Dream (ver 10)"
# Song 22. "Give My Love To Rose" already extracted
# Extracted data from song 23. "All I Have To Do Is Dream (ver 7)"
# Song 24. "Bye Bye Love" already extracted
# Song 25. "Big River (ver 2)" already extracted
# Song 26. "Dont Take Your Guns To Town" already extracted
# Song 27. "Big River (ver 4)" already extracted
# Extracted data from song 28. "Give My Love To Rose (ver 2)"
# Extracted data from song 29. "Sixteen Tons (ver 2)"
# Extracted data from song 30. "Folsom Prison Blues (ver 7)"
# Extracted data from song 31. "Folsom Prison Blues (ver 12)"
# Extracted data from song 32. "Wake Up Little Susie (ver 2)"
# Extracted data from song 33. "Guess Things Happen That Way"
# Extracted data from song 34. "Get Rhythm"
# Extracted data from song 35. "Cool Water"
# Extracted data from song 36. "Theyre Hanging Me Tonight (ver 2)"
# Extracted data from song 37. "Folsom Prison Blues (ver 3)"
# Extracted data from song 38. "My Buckets Got A Hole In It"
# Extracted data from song 39. "When Will I Be Loved"
# Extracted data from song 40. "Oh Lonesome Me"
# Extracted data from song 41. "Its Only Make Believe (ver 2)"
# Extracted data from song 42. "I Got Stripes"
# Extracted data from song 43. "The Battle Of New Orleans (ver 2)"
# Extracted data from song 44. "Lovesick Blues (ver 3)"
# Extracted data from song 45. "Walking After Midnight (ver 3)"
# Extracted data from song 46. "Its Only Make Believe (ver 4)"
# Extracted data from song 47. "El Paso"
# Extracted data from song 48. "I Still Miss Someone (ver 2)"
# Extracted data from song 49. "Home Of The Blues"
# Extracted 50 of 147 (Country,1950s). 5241 in total
# Extracted 131 of 147 (Electronic,1950s). 5241 in total
# Song 0. "Love Me Tender" already extracted
# Song 1. "Heartbreak Hotel" already extracted
# Song 2. "Love Me Tender (ver 2)" already extracted
# Song 3. "Blue Suede Shoes" already extracted
# Song 4. "All Shook Up (ver 2)" already extracted
# Extracted data from song 5. "Only You"
# Song 6. "Hound Dog (ver 2)" already extracted
# Extracted data from song 7. "I Got A Woman (ver 2)"
# Song 8. "Hound Dog" already extracted
# Extracted data from song 9. "You Send Me"
# Song 10. "Dont Be Cruel (ver 4)" already extracted
# Song 11. "The Great Pretender" already extracted
# Song 12. "Blue Suede Shoes (ver 2)" already extracted
# Extracted data from song 13. "My Baby Just Cares For Me"
# Extracted data from song 14. "Hallelujah I Love Her So"
# Extracted data from song 15. "A Teenager In Love"
# Song 16. "Dont Be Cruel (ver 5)" already extracted
# Song 17. "Hound Dog (ver 3)" already extracted
# Extracted data from song 18. "Love Me"
# Extracted data from song 19. "Smoke Gets In Your Eyes (ver 2)"
# Extracted data from song 20. "One Night"
# Extracted data from song 21. "Twilight Time"
# Extracted data from song 22. "Black Is The Color Of My True Loves Hair"
# Extracted data from song 23. "Mystery Train"
# Extracted data from song 24. "I Got A Woman"
# Extracted data from song 25. "All Shook Up"
# Extracted data from song 26. "Only You (ver 2)"
# Extracted data from song 27. "Love Me Tender (ver 4)"
# Extracted data from song 28. "Love Me (ver 3)"
# Extracted data from song 29. "Lonely Avenue (ver 2)"
# Extracted data from song 30. "There Goes My Baby (ver 2)"
# Extracted data from song 31. "Bo Diddley"
# Extracted data from song 32. "Love Me Or Leave Me"
# Extracted data from song 33. "Dont Be Cruel"
# Extracted data from song 34. "Hound Dog (ver 5)"
# Extracted data from song 35. "Love Me (ver 4)"
# Extracted data from song 36. "Lonely Avenue"
# Extracted data from song 37. "I Got A Woman (ver 3)"
# Extracted data from song 38. "Hallelujah I Love Her So (ver 4)"
# Extracted data from song 39. "You Send Me (ver 2)"
# Extracted data from song 40. "Twilight Time (ver 2)"
# Extracted data from song 41. "My Prayer"
# Extracted data from song 42. "Dont Be Cruel (ver 3)"
# Extracted data from song 43. "Heartbreak Hotel (ver 2)"
# Extracted data from song 44. "All Shook Up (ver 3)"
# Extracted data from song 45. "Love Me Tender (ver 5)"
# Extracted data from song 46. "I Got A Woman (ver 3)"
# Extracted data from song 47. "One Night (ver 2)"
# Extracted data from song 48. "Love Me (ver 2)"
# Extracted data from song 49. "Three Cigarettes In An Ashtray"
# Extracted 50 of 147 (Rhythm And Blues,1950s). 5291 in total
# Extracted 133 of 147 (Metal,1950s). 5291 in total
# Song 0. "My Baby Just Cares For Me" already extracted
# Extracted data from song 1. "The Other Woman"
# Extracted data from song 2. "My Baby Just Cares For Me (ver 2)"
# Extracted data from song 3. "My Baby Just Cares For Me (ver 3)"
# Extracted 4 of 147 (Contemporary R&b,1950s). 5295 in total
# Extracted data from song 0. "I Believe"
# Extracted data from song 1. "Therell Be Peace In The Valley For Me"
# Extracted data from song 2. "Rock Island Line"
# Extracted data from song 3. "Good Morning Blues"
# Extracted data from song 4. "A Beautiful Life"
# Extracted data from song 5. "John Henry"
# Extracted data from song 6. "John Henry (ver 2)"
# Extracted 7 of 147 (Religious Music,1950s). 5302 in total
# Extracted 136 of 147 (Hip Hop,1950s). 5302 in total
# Extracted 137 of 147 (Reggae,1950s). 5302 in total
# Song 0. "White Christmas" already extracted
# Song 1. "Let It Snow" already extracted
# Song 2. "Winter Wonderland (ver 2)" already extracted
# Song 3. "White Christmas (ver 4)" already extracted
# Extracted data from song 4. "La Vie En Rose (ver 2)"
# Extracted data from song 5. "Dream A Little Dream Of Me"
# Extracted data from song 6. "I Dont Want To Set The World On Fire (ver 2)"
# Extracted data from song 7. "La Vie En Rose"
# Song 8. "Let It Snow (ver 2)" already extracted
# Extracted data from song 9. "Fever"
# Song 10. "Smile" already extracted
# Song 11. "White Christmas (ver 7)" already extracted
# Song 12. "White Christmas (ver 2)" already extracted
# Extracted data from song 13. "St James Infirmary"
# Song 14. "I Got A Woman (ver 2)" already extracted
# Song 15. "My Funny Valentine" already extracted
# Song 16. "Ive Got You Under My Skin" already extracted
# Song 17. "Je Me Suis Fait Tout Petit (ver 2)" already extracted
# Song 18. "Everything Happens To Me" already extracted
# Song 19. "Unforgettable" already extracted
# Song 20. "Come Fly With Me" already extracted
# Extracted data from song 21. "All Of Me (ver 2)"
# Song 22. "All Of Me" already extracted
# Extracted data from song 23. "When The Saints Go Marching In (ver 2)"
# Song 24. "My Baby Just Cares For Me" already extracted
# Song 25. "Hallelujah I Love Her So" already extracted
# Song 26. "White Christmas (ver 3)" already extracted
# Song 27. "Winter Wonderland" already extracted
# Extracted data from song 28. "Cry Me A River (ver 2)"
# Song 29. "Nature Boy" already extracted
# Extracted data from song 30. "Jingle Bells"
# Extracted data from song 31. "Cry Me A River"
# Extracted data from song 32. "Baby Its Cold Outside (ver 2)"
# Song 33. "Chanson Pour Lauvergnat" already extracted
# Extracted data from song 34. "Minor Swing"
# Extracted data from song 35. "In The Wee Small Hours Of The Morning"
# Extracted data from song 36. "You Make Me Feel So Young"
# Extracted data from song 37. "Dream A Little Dream Of Me (ver 2)"
# Extracted data from song 38. "Ill Be Seeing You"
# Extracted data from song 39. "One For My Baby"
# Extracted data from song 40. "Ive Got You Under My Skin (ver 5)"
# Extracted data from song 41. "Autumn Leaves"
# Extracted data from song 42. "Stormy Weather"
# Extracted data from song 43. "When I Fall In Love"
# Extracted data from song 44. "La Vie En Rose (ver 3)"
# Extracted data from song 45. "On The Sunny Side Of The Street (ver 3)"
# Extracted data from song 46. "I Dont Want To Set The World On Fire (ver 4)"
# Extracted data from song 47. "After Youve Gone"
# Extracted data from song 48. "Stardust"
# Extracted data from song 49. "They Cant Take That Away From Me"
# Extracted 50 of 147 (Jazz,1950s). 5352 in total
# Song 0. "Freight Train (ver 2)" already extracted
# Song 1. "Freight Train" already extracted
# Extracted data from song 2. "Key To The Highway (ver 2)"
# Extracted data from song 3. "Got My Mojo Working (ver 2)"
# Song 4. "Bo Diddley" already extracted
# Extracted data from song 5. "Im A Man"
# Song 6. "Rock Island Line" already extracted
# Song 7. "Good Morning Blues" already extracted
# Extracted data from song 8. "Tell Me What Kind Of Man Jesus Is"
# Extracted data from song 9. "Key To The Highway"
# Extracted data from song 10. "Ten Long Years"
# Extracted data from song 11. "Woke Up This Morning"
# Song 12. "John Henry" already extracted
# Song 13. "John Henry (ver 2)" already extracted
# Extracted data from song 14. "Got My Mojo Working"
# Extracted data from song 15. "Im In The Mood"
# Extracted data from song 16. "Pick A Bale Of Cotton"
# Extracted data from song 17. "Pick A Bale Of Cotton (ver 2)"
# Extracted 18 of 147 (Blues,1950s). 5370 in total
# Song 0. "Jamaica Farewell" already extracted
# Song 1. "Jamaica Farewell (ver 2)" already extracted
# Song 2. "Man Smart Woman Smarter" already extracted
# Extracted data from song 3. "Mama Look-A Boo-Boo"
# Extracted data from song 4. "Jamaica Farewell (ver 3)"
# Extracted 5 of 147 (World Music,1950s). 5375 in total
# Extracted 141 of 147 (Disco,1950s). 5375 in total
# Extracted 142 of 147 (Comedy,1950s). 5375 in total
# Extracted 143 of 147 (New Age,1950s). 5375 in total
# Extracted data from song 0. "The Water Is Wide"
# Extracted 1 of 147 (Classical,1950s). 5376 in total
# Extracted 145 of 147 (Experimental,1950s). 5376 in total
# Extracted 146 of 147 (Darkwave,1950s). 5376 in total
# Extracted 147 of 147 (Soundtrack,1950s). 5376 in total

# %%
len(song_data_3.df)
# Out:
# 5376

# %%
song_data_3.save(dataset_path)
