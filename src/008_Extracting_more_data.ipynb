# %% [markdown]
# # Extracting more data

# %%
import jl_io as io
from selenium import webdriver
from bs4 import BeautifulSoup
from functools import reduce
import time
import random
import os
import uuid
import pandas as pd 

class SongData:
    SEPARATOR = '^'
    
    def __init__(self, initial_data_path=None, df=None):
        self.df = pd.DataFrame(data=[], columns=['url','name','genre','decade','chords','uuid'])
        
        if initial_data_path is not None and os.path.isfile(initial_data_path):
            self.df = pd.read_csv(initial_data_path, sep=self.SEPARATOR)
        
        if df is not None:
            self.df = df
            
    def add_basic_data(self,basic_data):
        self.df = self.df.append(basic_data,ignore_index=True)

    def add_details(self,details):
        self.df.loc[self.df['url'] == details["url"], ["chords"]] = str(details["chords"])
        self.df.loc[self.df['url'] == details["url"], ["uuid"]] = details["uuid"]
        
    def has_basic_data(self,url):
        return (self.df['url'] == url).any()
    
    def has_chords(self,url):
        return ((self.df['url'] == url) & (self.df['chords'].notnull())).any()
        
    def get_chords(self,url):
        return eval( self.df[self.df['url'] == url]['chords'][0])
    
    def has_genre_and_decade(self, genre, decade):
        return ((self.df['genre'] == genre) & (self.df['decade'] == decade)).any()
    
    def save(self, path):
        self.df.to_csv(path,index=False,sep=self.SEPARATOR)

class ChordExtractor:

    def __init__(self, raw_html_output_directory):
        self.raw_html_output_directory = raw_html_output_directory
        self.driver = self.create_chrome_driver()
        self.first_time = True
        
        if not os.path.isdir(self.raw_html_output_directory):
            os.mkdir(self.raw_html_output_directory)
            
    def extract_song_data(self,url):
        chords_spans = self.get_chord_spans(url)
        
        chords = [span.decode_contents() for span in chords_spans]
        
        song_uuid = str(uuid.uuid4())
        with open(f"{self.raw_html_output_directory}/{song_uuid}.html", "w") as file: # De los datos,como del cerdo, se guarda todo.
            file.write(self.driver.page_source )
    
        info = {
            "url":url,
            "chords":chords,
            "uuid":song_uuid
        }
        
        return info
    
    def get_chord_spans(self,url):
        self.driver.get(url)
        
        if self.driver.page_source == '<html><head></head><body></body></html>':
            raise Exception('Denegation error')

        if self.first_time:
            self.click_on_accept_cookies()
            self.first_time = False

        soup = BeautifulSoup(self.driver.page_source, 'lxml')

        article = soup.findAll('article')[3];
        
        return article.findAll('span', {"style":"color: rgb(0, 0, 0);"})
    
    def click_on_accept_cookies(self):
        try:
            button = self.driver.find_element_by_xpath('//button[contains(text(), "thanks")]')

            button.click()
        except:
            print('cookies banner not found. Ignored')
            
    
    def create_chrome_driver(self):
        options = webdriver.ChromeOptions()
        options.add_argument('--ignore-certificate-errors')
        options.add_argument('--incognito')
        options.add_argument('--headless')
        
        driver = webdriver.Chrome("./chromedriver", options=options)
        return driver

class LinkExtractor:
    BASE_URL = "https://www.ultimate-guitar.com/explore?&type[]=Chords";
    
    def __init__(self):
        self.driver = self.create_chrome_driver()
        self.first_time = True
    
    def get_all_songs(self, genre, decade, first_page, last_page):
        links = self.get_all_filter_song_links(genre['pattern'],decade['pattern'], first_page, last_page)
        result = [ self.link_to_song_dict(link,genre,decade) for link in links]
        
        return result
    
    def link_to_song_dict(self,link, genre, decade):
        return {
            "name": link.contents[0],
            "url": link['href'],
            "genre": genre["name"],
            "decade": decade["name"]
        }
    
    def get_all_filter_song_links(self,genreFilter,decadeFilter, first_page, last_page):
        list_of_list = [self.get_links_single_page(genreFilter, decadeFilter, f'&page={page}')
                  for page in range(first_page,last_page + 1)]
        
        return reduce(lambda list1, list2: [*list1, *list2], list_of_list)
    
    def get_links_single_page(self,genreFilter,decadeFilter, pageFilter):
        self.driver.get(f'{self.BASE_URL}{genreFilter}{decadeFilter}{pageFilter}')
        
        if self.driver.page_source == '<html><head></head><body></body></html>':
            raise Exception('Denegation error')

        if self.first_time:
            self.click_on_accept_cookies()
            self.first_time = False

        soup = BeautifulSoup(self.driver.page_source, 'lxml')

        return soup.findAll('a', {"class":"_2KJtL _1mes3 kWOod"})
    
    def click_on_accept_cookies(self):
        try:
            button = self.driver.find_element_by_xpath('//button[contains(text(), "thanks")]')

            button.click()
        except:
            print('cookies banner not found. Ignored')
            
    
    def create_chrome_driver(self):
        options = webdriver.ChromeOptions()
        options.add_argument('--ignore-certificate-errors')
        options.add_argument('--incognito')
        options.add_argument('--headless')
        
        driver = webdriver.Chrome("./chromedriver", options=options)
        return driver

class ChordScraper:
    def __init__(self, linkExtractor, chordExtractor, genres, decades, song_data):
        self.linkExtractor = linkExtractor
        self.chordExtractor = chordExtractor
        self.genres = genres
        self.decades = decades
        self.song_data = song_data
        
        self.combinations = []

        for decade in self.decades:
            for genre in self.genres:
                    self.combinations.append( {"decade": decade, "genre": genre})
        
    def extract(self, first_page, last_page):      
        startIndex = 1
        
        return self.extract_from(startIndex, first_page, last_page)
    
    def extract_from(self, startIndexBase1,first_page, last_page):    
        for index, combination in enumerate(self.combinations[startIndexBase1 - 1:]):
            new_extracted_songs = []
            genre = combination["genre"]
            decade = combination["decade"]
            
            if song_data.has_genre_and_decade(genre["name"], decade["name"]):
                print(f'{genre["name"]},{decade["name"]} already extracted')
                continue
            
            song_basic_data_array = []          
            try:
                song_basic_data_array = self.linkExtractor.get_all_songs(genre,decade, first_page, last_page)
                      
                for basic_data in song_basic_data_array:
                    self.song_data.add_basic_data(basic_data)
                      
                new_extracted_songs = [self.extract_song_data(index,song) for index,song in enumerate(new_extracted_songs)]
            except Exception as e: 
                print(f'Error in ({genre["name"]},{decade["name"]})')
                raise e
            
            for index,song in enumerate(song_basic_data_array):
                try:
                    self.extract_song_data(index,song)
                except Exception as e: 
                    print(f'Error in "{song["name"]}"')
                    raise e
            
            number_of_songs = len(self.song_data.df)
            print(f'Extracted {index+startIndexBase1} of {len(self.combinations)} ({genre["name"]},{decade["name"]}). {number_of_songs} in total')  
        
    def extract_song_data(self,index,song): 
        if self.song_data.has_chords(song["url"]):
            print(f'Song {index}. "{song["name"]}" already extracted')  
            return
      
        song_details = self.chordExtractor.extract_song_data(song["url"])           
        self.song_data.add_details(song_details)
        print(f'Extracted data from song {index}. "{song["name"]}"')

# %% [markdown]
# ##  Extract

# %%
import jl_io as io

genres = io.from_file('../data/genres')
decades = io.from_file('../data/decades')

# %%
RAW_HTML_OUTPUT = '../data/raw_html'
CHORDS_DATASET_OUTPUT = "../data/chords2.csv"

# %%
song_data = SongData()

# %%
chord_extractor = ChordExtractor(RAW_HTML_OUTPUT)
link_extractor = LinkExtractor()
chord_scraper = ChordScraper(link_extractor,chord_extractor,genres,decades,song_data)

# %%
chord_scraper.extract(2,2)
# Out:
# Rock,2010s already extracted
# Folk,2010s already extracted
# Pop,2010s already extracted
# Country,2010s already extracted
# Electronic,2010s already extracted
# Rhythm And Blues,2010s already extracted
# Metal,2010s already extracted
# Contemporary R&b,2010s already extracted
# Religious Music,2010s already extracted
# Hip Hop,2010s already extracted
# Reggae,2010s already extracted
# Jazz,2010s already extracted
# Blues,2010s already extracted
# Extracted 14 of 147 (World Music,2010s). 3174 in total
# Disco,2010s already extracted
# Extracted 16 of 147 (Comedy,2010s). 3174 in total
# Extracted 17 of 147 (New Age,2010s). 3174 in total
# Extracted 18 of 147 (Classical,2010s). 3174 in total
# Extracted 19 of 147 (Experimental,2010s). 3174 in total
# Extracted 20 of 147 (Darkwave,2010s). 3174 in total
# Extracted 21 of 147 (Soundtrack,2010s). 3174 in total
# Rock,2000s already extracted
# Folk,2000s already extracted
# Pop,2000s already extracted
# Country,2000s already extracted
# Electronic,2000s already extracted
# Rhythm And Blues,2000s already extracted
# Metal,2000s already extracted
# Contemporary R&b,2000s already extracted
# Religious Music,2000s already extracted
# Hip Hop,2000s already extracted
# Reggae,2000s already extracted
# Jazz,2000s already extracted
# Blues,2000s already extracted
# World Music,2000s already extracted
# Extracted 36 of 147 (Disco,2000s). 3174 in total
# Extracted 37 of 147 (Comedy,2000s). 3174 in total
# Extracted 38 of 147 (New Age,2000s). 3174 in total
# Extracted 39 of 147 (Classical,2000s). 3174 in total
# Extracted 40 of 147 (Experimental,2000s). 3174 in total
# Extracted 41 of 147 (Darkwave,2000s). 3174 in total
# Extracted 42 of 147 (Soundtrack,2000s). 3174 in total
# Rock,1990s already extracted
# Folk,1990s already extracted
# Pop,1990s already extracted
# Country,1990s already extracted
# Electronic,1990s already extracted
# Rhythm And Blues,1990s already extracted
# Metal,1990s already extracted
# Contemporary R&b,1990s already extracted
# Religious Music,1990s already extracted
# Hip Hop,1990s already extracted
# Reggae,1990s already extracted
# Jazz,1990s already extracted
# Blues,1990s already extracted
# World Music,1990s already extracted
# Extracted 57 of 147 (Disco,1990s). 3174 in total
# Extracted 58 of 147 (Comedy,1990s). 3174 in total
# Extracted 59 of 147 (New Age,1990s). 3174 in total
# Extracted 60 of 147 (Classical,1990s). 3174 in total
# Extracted 61 of 147 (Experimental,1990s). 3174 in total
# Extracted 62 of 147 (Darkwave,1990s). 3174 in total
# Extracted 63 of 147 (Soundtrack,1990s). 3174 in total
# Rock,1980s already extracted
# Folk,1980s already extracted
# Pop,1980s already extracted
# Country,1980s already extracted
# Electronic,1980s already extracted
# Rhythm And Blues,1980s already extracted
# Metal,1980s already extracted
# Contemporary R&b,1980s already extracted
# Religious Music,1980s already extracted
# Extracted 73 of 147 (Hip Hop,1980s). 3174 in total
# Reggae,1980s already extracted
# Extracted 75 of 147 (Jazz,1980s). 3174 in total
# Extracted 76 of 147 (Blues,1980s). 3174 in total
# Extracted 77 of 147 (World Music,1980s). 3174 in total
# Extracted 78 of 147 (Disco,1980s). 3174 in total
# Extracted 79 of 147 (Comedy,1980s). 3174 in total
# Extracted 80 of 147 (New Age,1980s). 3174 in total
# Extracted 81 of 147 (Classical,1980s). 3174 in total
# Extracted 82 of 147 (Experimental,1980s). 3174 in total
# Extracted 83 of 147 (Darkwave,1980s). 3174 in total
# Extracted 84 of 147 (Soundtrack,1980s). 3174 in total
# Rock,1970s already extracted
# Folk,1970s already extracted
# Pop,1970s already extracted
# Country,1970s already extracted
# Extracted 89 of 147 (Electronic,1970s). 3174 in total
# Rhythm And Blues,1970s already extracted
# Extracted 91 of 147 (Metal,1970s). 3174 in total
# Extracted 92 of 147 (Contemporary R&b,1970s). 3174 in total
# Extracted 93 of 147 (Religious Music,1970s). 3174 in total
# Extracted 94 of 147 (Hip Hop,1970s). 3174 in total
# Reggae,1970s already extracted
# Jazz,1970s already extracted
# Blues,1970s already extracted
# Extracted 98 of 147 (World Music,1970s). 3174 in total
# Disco,1970s already extracted
# Extracted 100 of 147 (Comedy,1970s). 3174 in total
# Extracted 101 of 147 (New Age,1970s). 3174 in total
# Extracted 102 of 147 (Classical,1970s). 3174 in total
# Extracted 103 of 147 (Experimental,1970s). 3174 in total
# Extracted 104 of 147 (Darkwave,1970s). 3174 in total
# Extracted 105 of 147 (Soundtrack,1970s). 3174 in total
# Rock,1960s already extracted
# Folk,1960s already extracted
# Pop,1960s already extracted
# Country,1960s already extracted
# Extracted 110 of 147 (Electronic,1960s). 3174 in total
# Rhythm And Blues,1960s already extracted
# Extracted 112 of 147 (Metal,1960s). 3174 in total
# Extracted 113 of 147 (Contemporary R&b,1960s). 3174 in total
# Extracted 114 of 147 (Religious Music,1960s). 3174 in total
# Extracted 115 of 147 (Hip Hop,1960s). 3174 in total
# Extracted 116 of 147 (Reggae,1960s). 3174 in total
# Jazz,1960s already extracted
# Blues,1960s already extracted
# Extracted 119 of 147 (World Music,1960s). 3174 in total
# Extracted 120 of 147 (Disco,1960s). 3174 in total
# Extracted 121 of 147 (Comedy,1960s). 3174 in total
# Extracted 122 of 147 (New Age,1960s). 3174 in total
# Extracted 123 of 147 (Classical,1960s). 3174 in total
# Extracted 124 of 147 (Experimental,1960s). 3174 in total
# Extracted 125 of 147 (Darkwave,1960s). 3174 in total
# Extracted 126 of 147 (Soundtrack,1960s). 3174 in total
# Rock,1950s already extracted
# Folk,1950s already extracted
# Extracted data from song 0. "Unforgettable"
# Extracted data from song 1. "Santa Claus Is Back In Town (ver 2)"
# Extracted data from song 2. "The Great Pretender"
# Extracted data from song 3. "In The Wee Small Hours Of The Morning"
# Extracted data from song 4. "Baby Its Cold Outside (ver 2)"
# Extracted data from song 5. "Beyond The Sea (ver 4)"
# Extracted data from song 6. "Jingle Bells"
# Extracted data from song 7. "White Christmas (ver 6)"
# Song 8. "Hound Dog (ver 3)" already extracted
# Song 9. "Hello Mary Lou (ver 5)" already extracted
# Extracted data from song 10. "Stardust"
# Extracted data from song 11. "Ive Got You Under My Skin (ver 5)"
# Extracted data from song 12. "Chanson Pour Lauvergnat"
# Extracted data from song 13. "Impossible Dream"
# Song 14. "Travelin Man (ver 2)" already extracted
# Extracted data from song 15. "Autumn Leaves"
# Extracted data from song 16. "Nature Boy (ver 2)"
# Extracted data from song 17. "White Christmas (ver 5)"
# Extracted data from song 18. "White Christmas (ver 8)"
# Extracted data from song 19. "Thats Amore (ver 2)"
# Extracted data from song 20. "One For My Baby"
# Extracted data from song 21. "Someone To Watch Over Me"
# Extracted data from song 22. "Marys Boychild Christmas Song"
# Extracted data from song 23. "Mack The Knife (ver 6)"
# Extracted data from song 24. "The Happiest Christmas Tree"
# Extracted data from song 25. "Beyond The Sea (ver 2)"
# Extracted data from song 26. "Its Been A Long Long Time"
# Song 27. "One Night" already extracted
# Extracted data from song 28. "Winter Wonderland (ver 3)"
# Extracted data from song 29. "La Prière"
# Extracted data from song 30. "They Cant Take That Away From Me"
# Extracted data from song 31. "Young At Heart"
# Extracted data from song 32. "Witchcraft"
# Extracted data from song 33. "Autumn Leaves"
# Song 34. "All Shook Up" already extracted
# Song 35. "Love Me Tender (ver 4)" already extracted
# Song 36. "Love Me (ver 3)" already extracted
# Extracted data from song 37. "Le Gorille (ver 2)"
# Extracted data from song 38. "White Christmas (ver 10)"
# Extracted data from song 39. "Kiss Me Honey Honey Kiss Me"
# Extracted data from song 40. "Chanson Pour Lauvergnat (ver 2)"
# Extracted data from song 41. "Pretend"
# Song 42. "Heartbreak Hotel (ver 2)" already extracted
# Song 43. "I Got A Woman (ver 3)" already extracted
# Extracted data from song 44. "Il Nous Faut Regarder"
# Song 45. "Hound Dog (ver 5)" already extracted
# Song 46. "Love Me (ver 2)" already extracted
# Extracted data from song 47. "Travelin Man"
# Extracted data from song 48. "Hello Mary Lou (ver 2)"
# Extracted data from song 49. "Putain De Toi"
# Extracted 50 of 147 (Pop,1950s). 3224 in total
# Extracted data from song 0. "Lovesick Blues (ver 3)"
# Song 1. "Its Only Make Believe (ver 4)" already extracted
# Song 2. "Folsom Prison Blues (ver 3)" already extracted
# Extracted data from song 3. "Why Dont You Love Me"
# Song 4. "I Walk The Line (ver 4)" already extracted
# Extracted data from song 5. "Ramblin Man (ver 2)"
# Song 6. "Folsom Prison Blues (ver 5)" already extracted
# Extracted data from song 7. "I Got Stripes (ver 2)"
# Extracted data from song 8. "Sixteen Tons (ver 4)"
# Extracted data from song 9. "Baby Were Really In Love"
# Song 10. "Crazy Arms" already extracted
# Extracted data from song 11. "Howlin At The Moon"
# Extracted data from song 12. "Bird Dog (ver 3)"
# Extracted data from song 13. "Walking After Midnight"
# Extracted data from song 14. "Walking After Midnight (ver 3)"
# Extracted data from song 15. "Lonesome Whistle"
# Extracted data from song 16. "Cool Water"
# Extracted data from song 17. "Take These Chains From My Heart"
# Extracted data from song 18. "Big Iron (ver 4)"
# Song 19. "Folsom Prison Blues (ver 11)" already extracted
# Song 20. "Folsom Prison Blues (ver 12)" already extracted
# Extracted data from song 21. "Sixteen Tons"
# Extracted data from song 22. "Sixteen Tons (ver 5)"
# Extracted data from song 23. "The Battle Of New Orleans (ver 3)"
# Extracted data from song 24. "I Walk The Line (ver 8)"
# Extracted data from song 25. "Lets Have A Party (ver 2)"
# Extracted data from song 26. "Dark As A Dungeon"
# Extracted data from song 27. "Cold Cold Heart (ver 2)"
# Extracted data from song 28. "Lost Highway (ver 3)"
# Extracted data from song 29. "Let It Be Me"
# Extracted data from song 30. "Great Balls Of Fire"
# Extracted data from song 31. "The Masters Call (ver 2)"
# Extracted data from song 32. "Singing The Blues (ver 2)"
# Extracted data from song 33. "Utah Carol"
# Extracted data from song 34. "Train Of Love (ver 2)"
# Extracted data from song 35. "So Doggone Lonesome"
# Extracted data from song 36. "Big River"
# Extracted data from song 37. "Folsom Prison Blues (ver 8)"
# Extracted data from song 38. "Folsom Prison Blues (ver 10)"
# Extracted data from song 39. "Youre The Nearest Thing To Heaven"
# Extracted data from song 40. "My Grandfathers Clock"
# Extracted data from song 41. "I Walk The Line (ver 5)"
# Extracted data from song 42. "Three Cigarettes In An Ashtray"
# Extracted data from song 43. "Sixteen Tons"
# Extracted data from song 44. "Wake Up Little Susie (ver 2)"
# Extracted data from song 45. "Honky Tonk Man"
# Extracted data from song 46. "Hey Good Lookin (ver 3)"
# Extracted data from song 47. "Lovesick Blues (ver 2)"
# Extracted data from song 48. "My Buckets Got A Hole In It"
# Extracted data from song 49. "Devoted To You"
# Extracted 50 of 147 (Country,1950s). 3274 in total
# Extracted 131 of 147 (Electronic,1950s). 3274 in total
# Extracted data from song 0. "Smoke Gets In Your Eyes"
# Extracted data from song 1. "Twilight Time"
# Extracted data from song 2. "Im Walkin (ver 3)"
# Extracted data from song 3. "Dont Be Cruel"
# Extracted data from song 4. "All Shook Up (ver 3)"
# Extracted data from song 5. "Love Me Tender (ver 3)"
# Extracted data from song 6. "Blue Suede Shoes (ver 3)"
# Extracted data from song 7. "Thats All Right"
# Extracted data from song 8. "Where Or When (ver 2)"
# Extracted data from song 9. "Where Or When (ver 3)"
# Extracted data from song 10. "What Would I Do Without You"
# Extracted data from song 11. "I Got A Woman (ver 3)"
# Extracted data from song 12. "Three Cigarettes In An Ashtray (ver 2)"
# Extracted data from song 13. "There Goes My Baby (ver 3)"
# Extracted data from song 14. "The Big Beat"
# Extracted data from song 15. "Twilight Time (ver 2)"
# Extracted data from song 16. "Twilight Time (ver 4)"
# Extracted data from song 17. "My Baby Just Cares For Me (ver 3)"
# Extracted data from song 18. "My Prayer"
# Extracted data from song 19. "My Prayer (ver 2)"
# Extracted data from song 20. "I Wonder Why (ver 2)"
# Extracted data from song 21. "I Want To Walk You Home"
# Extracted data from song 22. "Crackin Up"
# Extracted data from song 23. "Im Walkin"
# Extracted data from song 24. "The Great Grandfather"
# Extracted data from song 25. "Stupid Cupid"
# Extracted data from song 26. "Please Tell Me Why"
# Extracted data from song 27. "Sick And Tired"
# Extracted data from song 28. "Bark Battle And Ball"
# Extracted data from song 29. "Dont Pity Me"
# Extracted data from song 30. "Dont Be Cruel (ver 3)"
# Extracted data from song 31. "I Got A Woman"
# Extracted data from song 32. "I Got A Woman (ver 2)"
# Extracted data from song 33. "Run Red Run"
# Extracted data from song 34. "Hound Dog (ver 4)"
# Extracted data from song 35. "The Gypsy"
# Extracted data from song 36. "I Got The Blues"
# Extracted data from song 37. "Im Sorry"
# Extracted data from song 38. "Im Sorry"
# Extracted data from song 39. "Little Mary"
# Extracted data from song 40. "Where Or When"
# Extracted data from song 41. "I Want You To Know"
# Extracted data from song 42. "Youll Never Never Know"
# Extracted data from song 43. "Mardi Gras In New Orleans"
# Extracted data from song 44. "Every Night About This Time"
# Extracted data from song 45. "Too Many Secrets"
# Extracted data from song 46. "Too Many Secrets (ver 2)"
# Extracted data from song 47. "Just For A Thrill"
# Extracted data from song 48. "Alexanders Ragtime Band"
# Extracted data from song 49. "Dedicated To The One I Love"
# Extracted 50 of 147 (Rhythm And Blues,1950s). 3324 in total
# Extracted 133 of 147 (Metal,1950s). 3324 in total
# Extracted 134 of 147 (Contemporary R&b,1950s). 3324 in total
# Extracted 135 of 147 (Religious Music,1950s). 3324 in total
# Extracted 136 of 147 (Hip Hop,1950s). 3324 in total
# Extracted 137 of 147 (Reggae,1950s). 3324 in total
# Song 0. "White Christmas (ver 5)" already extracted
# Song 1. "White Christmas (ver 8)" already extracted
# Extracted data from song 2. "Cry Me A River"
# Song 3. "One For My Baby" already extracted
# Song 4. "Someone To Watch Over Me" already extracted
# Extracted data from song 5. "A Kiss To Build A Dream On"
# Extracted data from song 6. "Summertime (ver 2)"
# Extracted data from song 7. "Im Beginning To See The Light"
# Extracted data from song 8. "The Lady Is A Tramp"
# Extracted data from song 9. "On The Sunny Side Of The Street (ver 3)"
# Song 10. "Winter Wonderland (ver 3)" already extracted
# Extracted data from song 11. "Hallelujah I Love Her So (ver 3)"
# Song 12. "La Prière" already extracted
# Song 13. "They Cant Take That Away From Me" already extracted
# Song 14. "Witchcraft" already extracted
# Extracted data from song 15. "Ill Be Seeing You (ver 2)"
# Song 16. "Autumn Leaves" already extracted
# Extracted data from song 17. "Hallelujah I Love Her So (ver 4)"
# Extracted data from song 18. "Ive Got The World On A String (ver 2)"
# Extracted data from song 19. "La Vie En Rose (ver 4)"
# Extracted data from song 20. "La Vie En Rose (ver 5)"
# Extracted data from song 21. "La Vie En Rose (ver 7)"
# Extracted data from song 22. "Basin Street Blues"
# Extracted data from song 23. "My Baby Just Cares For Me (ver 2)"
# Song 24. "White Christmas (ver 10)" already extracted
# Song 25. "Kiss Me Honey Honey Kiss Me" already extracted
# Song 26. "Chanson Pour Lauvergnat (ver 2)" already extracted
# Extracted data from song 27. "Strange Fruit"
# Extracted data from song 28. "I Dont Want To Set The World On Fire (ver 5)"
# Song 29. "Pretend" already extracted
# Song 30. "Putain De Toi" already extracted
# Extracted data from song 31. "My Funny Valentine (ver 2)"
# Extracted data from song 32. "I Only Have Eyes For You"
# Extracted data from song 33. "Ill Never Smile Again"
# Extracted data from song 34. "It Came Upon A Midnight Clear"
# Extracted data from song 35. "Ive Got You Under My Skin (ver 3)"
# Extracted data from song 36. "Do You Know What It Means To Miss New Orleans"
# Extracted data from song 37. "When The Saints Go Marching In"
# Extracted data from song 38. "Fever (ver 2)"
# Extracted data from song 39. "Crazy He Calls Me (ver 2)"
# Extracted data from song 40. "Mona Lisa"
# Extracted data from song 41. "Love Me Or Leave Me"
# Extracted data from song 42. "Black Is The Color Of My True Loves Hair"
# Extracted data from song 43. "God Bless The Child (ver 2)"
# Extracted data from song 44. "Je Me Suis Fait Tout Petit"
# Extracted data from song 45. "Dream A Little Dream Of Me (ver 5)"
# Extracted data from song 46. "I Dont Want To Set The World On Fire (ver 3)"
# Extracted data from song 47. "Summertime"
# Extracted data from song 48. "The Way You Look Tonight"
# Extracted data from song 49. "Hallelujah I Love Her So (ver 2)"
# Extracted 50 of 147 (Jazz,1950s). 3374 in total
# Extracted 139 of 147 (Blues,1950s). 3374 in total
# Extracted 140 of 147 (World Music,1950s). 3374 in total
# Extracted 141 of 147 (Disco,1950s). 3374 in total
# Extracted 142 of 147 (Comedy,1950s). 3374 in total
# Extracted 143 of 147 (New Age,1950s). 3374 in total
# Extracted 144 of 147 (Classical,1950s). 3374 in total
# Extracted 145 of 147 (Experimental,1950s). 3374 in total
# Extracted 146 of 147 (Darkwave,1950s). 3374 in total
# Extracted 147 of 147 (Soundtrack,1950s). 3374 in total

# %%
song_data.df
# Out:
#                                                     url  \
# 0     https://tabs.ultimate-guitar.com/tab/5_seconds...
# 1     https://tabs.ultimate-guitar.com/tab/keith-urb...
# 2     https://tabs.ultimate-guitar.com/tab/hozier/wo...
# 3     https://tabs.ultimate-guitar.com/tab/arctic_mo...
# 4     https://tabs.ultimate-guitar.com/tab/blackberr...
# ...                                                 ...
# 3369  https://tabs.ultimate-guitar.com/tab/ella-fitz...
# 3370  https://tabs.ultimate-guitar.com/tab/the_ink_s...
# 3371  https://tabs.ultimate-guitar.com/tab/ella-fitz...
# 3372  https://tabs.ultimate-guitar.com/tab/tony_benn...
# 3373  https://tabs.ultimate-guitar.com/tab/ray-charl...
#
#                                               name genre decade  \
# 0                                        Lie To Me  Rock  2010s
# 1                             Blue Aint Your Color  Rock  2010s
# 2                                        Work Song  Rock  2010s
# 3                                  Do I Wanna Know  Rock  2010s
# 4                           One Horse Town (ver 3)  Rock  2010s
# ...                                            ...   ...    ...
# 3369            Dream A Little Dream Of Me (ver 5)  Jazz  1950s
# 3370  I Dont Want To Set The World On Fire (ver 3)  Jazz  1950s
# 3371                                    Summertime  Jazz  1950s
# 3372                      The Way You Look Tonight  Jazz  1950s
# 3373              Hallelujah I Love Her So (ver 2)  Jazz  1950s
#
#                                                  chords  \
# 0     ['C', 'G', 'Am', 'F', 'C', 'G', 'Am', 'F', 'C'...
# 1     ['G', 'Am', 'C', 'D', 'G', 'G', 'Am', 'C', 'D'...
# 2     ['Bb', 'Cm', 'Bb', 'Cm', 'Bb', 'Cm', 'Bb', 'Cm...
# 3     ['Gm', 'Eb', 'Cm', 'Gm', 'Gm', 'Eb', 'Cm', 'Gm...
# 4     ['Am', 'C', 'Dm', 'F', 'C', 'G', 'Dm', 'F', 'C...
# ...                                                 ...
# 3369  ['Ebdim7', 'Fm7', 'Bb7', 'Eb', 'Ebdim7', 'C7',...
# 3370  ['B7', 'E', 'E/Ab', 'Gdim', 'Fm', 'E', 'E/Ab',...
# 3371  ['Amaj7', 'F#m', 'G#maj7', 'C#m', 'C#m', 'F#m'...
# 3372  ['Bbmaj9', 'G13', 'Cm7', 'F7', 'Bb', 'Gm11', '...
# 3373  ['A', 'A/C#', 'D', 'D#dim7', 'A', 'A/C#', 'D',...
#
#                                       uuid
# 0     dcee9fab-15b8-414e-aa07-a87b27f007e3
# 1     f86ca365-1710-4943-be4a-366708124d58
# 2     a4187f1b-3fb0-4277-8b33-4f9dc26116af
# 3     d75330a7-8e9a-409b-8b88-68cb5f357f7e
# 4     84075e00-a22c-47ee-9e21-2b2b09841e6e
# ...                                    ...
# 3369  9cefb6b0-f6c5-46e6-a4c5-78a0e71046ba
# 3370  37ca5e4a-92a6-4226-b829-e99f32217866
# 3371  8783061f-2296-45f5-a9ea-71a788f100c7
# 3372  f1806027-37c5-4921-a2f0-cea6e86bb756
# 3373  0ff680d0-d4de-4d21-9459-aa3f27846da0
#
# [3374 rows x 6 columns]

# %%
song_data.save('../data/chords_2.csv')

# %% [markdown]
# ## Cleaning

# %%
from jl_chord_cleaning import ChordDatasetCleaner
from jl_song_data import SongData

# %%
RAW_HTML_OUTPUT = '../data/raw_html'
song_data = SongData(initial_data_path='../data/chords_2.csv')

# %%
song_data.df
# Out:
#                                                     url  ...                                  uuid
# 0     https://tabs.ultimate-guitar.com/tab/5_seconds...  ...  dcee9fab-15b8-414e-aa07-a87b27f007e3
# 1     https://tabs.ultimate-guitar.com/tab/keith-urb...  ...  f86ca365-1710-4943-be4a-366708124d58
# 2     https://tabs.ultimate-guitar.com/tab/hozier/wo...  ...  a4187f1b-3fb0-4277-8b33-4f9dc26116af
# 3     https://tabs.ultimate-guitar.com/tab/arctic_mo...  ...  d75330a7-8e9a-409b-8b88-68cb5f357f7e
# 4     https://tabs.ultimate-guitar.com/tab/blackberr...  ...  84075e00-a22c-47ee-9e21-2b2b09841e6e
# ...                                                 ...  ...                                   ...
# 3369  https://tabs.ultimate-guitar.com/tab/ella-fitz...  ...  9cefb6b0-f6c5-46e6-a4c5-78a0e71046ba
# 3370  https://tabs.ultimate-guitar.com/tab/the_ink_s...  ...  37ca5e4a-92a6-4226-b829-e99f32217866
# 3371  https://tabs.ultimate-guitar.com/tab/ella-fitz...  ...  8783061f-2296-45f5-a9ea-71a788f100c7
# 3372  https://tabs.ultimate-guitar.com/tab/tony_benn...  ...  f1806027-37c5-4921-a2f0-cea6e86bb756
# 3373  https://tabs.ultimate-guitar.com/tab/ray-charl...  ...  0ff680d0-d4de-4d21-9459-aa3f27846da0
#
# [3374 rows x 6 columns]

# %%
cleaner = ChordDatasetCleaner()
clean_dataset = cleaner.clean_dataset(song_data.df, RAW_HTML_OUTPUT)
# Out:
# Re extracting chords for 121 songs
# https://tabs.ultimate-guitar.com/tab/1060259
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /Users