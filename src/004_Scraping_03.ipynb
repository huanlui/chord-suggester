# %% [markdown]
# # Extracting all the links

# %% [markdown]
# ## Let's wrap up the previous code

# %%
import jl_io as io

genres = io.from_file('../data/genres')
styles = io.from_file('../data/styles')
decades = io.from_file('../data/decades')

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
from functools import reduce

class SongExtractor:
    BASE_URL = "https://www.ultimate-guitar.com/explore?&type[]=Chords";
    MAX_NUM_PAGES = 20
    
    def __init__(self):
        pass
    
    def get_all_songs(self, genre, style, decade):
        links = self.get_all_filter_song_links(genre['pattern'], style['pattern'], decade['pattern'])
        result = [ self.link_to_song_dict(link,genre,style,decade) for link in links]
        
        return result
    
    def link_to_song_dict(self,link, genre, style, decade):
        return {
            "name": link.contents[0],
            "url": link['href'],
            "genre": genre["name"],
            "style": style["name"],
            "decade": decade["name"]
        }
    
    def get_all_filter_song_links(self,genreFilter,styleFilter,decadeFilter):
        list_of_list = [self.get_links_single_page(genreFilter, styleFilter, decadeFilter, f'&page={page}')
                  for page in range(1,self.MAX_NUM_PAGES+1)]
        
        return reduce(lambda list1, list2: [*list1, *list2], list_of_list)
    
    def get_links_single_page(self,genreFilter,styleFilter,decadeFilter, pageFilter):
        driver = self.create_chrome_driver();
        driver.get(f'{self.BASE_URL}{genreFilter}{styleFilter}{decadeFilter}')

        self.click_on_accept_cookies(driver)

        soup = BeautifulSoup(driver.page_source, 'lxml')

        return soup.findAll('a', {"class":"_2KJtL _1mes3 kWOod"})
    
    def click_on_accept_cookies(self, driver):
        button = driver.find_element_by_xpath('//button[contains(text(), "thanks")]')

        button.click()  
    
    def create_chrome_driver(self):
        options = webdriver.ChromeOptions()
        options.add_argument('--ignore-certificate-errors')
        options.add_argument('--incognito')
        options.add_argument('--headless')
        
        driver = webdriver.Chrome("./chromedriver", options=options)
        return driver

# %%
# %%time
extractor = SongExtractor()

songs = extractor.get_all_songs(genres[0], styles[0], decades[0])
# Out:
# CPU times: user 1.5 s, sys: 154 ms, total: 1.65 s
# Wall time: 1min 11s

# %%
len(songs)
# Out:
# 1000

# %%
songs[1:5]
# Out:
# [{'name': 'Radioactive',
#   'url': 'https://tabs.ultimate-guitar.com/tab/imagine-dragons/radioactive-chords-1171909',
#   'genre': 'Rock',
#   'style': 'Pop Rock',
#   'decade': '2010s'},
#  {'name': 'Say Something (ver\xa03)',
#   'url': 'https://tabs.ultimate-guitar.com/tab/a_great_big_world/say_something_chords_1443639',
#   'genre': 'Rock',
#   'style': 'Pop Rock',
#   'decade': '2010s'},
#  {'name': 'Counting Stars',
#   'url': 'https://tabs.ultimate-guitar.com/tab/onerepublic/counting-stars-chords-1233464',
#   'genre': 'Rock',
#   'style': 'Pop Rock',
#   'decade': '2010s'},
#  {'name': 'Million Reasons',
#   'url': 'https://tabs.ultimate-guitar.com/tab/lady-gaga/million-reasons-chords-1884102',
#   'genre': 'Rock',
#   'style': 'Pop Rock',
#   'decade': '2010s'}]

# %% [markdown]
# ## Calculate number of combinations

# %%
# %%time
combinations = []

for decade in decades:
    for genre in genres:
        for style in styles:
            combinations.append( (decade, genre, style))
# Out:
# CPU times: user 3.97 ms, sys: 35 µs, total: 4.01 ms
# Wall time: 3.99 ms

# %%
len(combinations)
# Out:
# 14700

# %%
combinations[0]
# Out:
# ({'code': '2010', 'name': '2010s', 'pattern': '&&decade[]=2010'},
#  {'code': '4', 'name': 'Rock', 'pattern': '&&genres[]=4'},
#  {'code': '24', 'name': 'Pop Rock', 'pattern': '&&subgenres[]=24'})

# %% [markdown]
# ## Try to improve performace

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
from functools import reduce

class ImprovedSongExtractor:
    BASE_URL = "https://www.ultimate-guitar.com/explore?&type[]=Chords";
    MAX_NUM_PAGES = 20
    
    def __init__(self):
        self.driver = self.create_chrome_driver()
        self.first_time = True
    
    def get_all_songs(self, genre, style, decade):
        links = self.get_all_filter_song_links(genre['pattern'], style['pattern'], decade['pattern'])
        result = [ self.link_to_song_dict(link,genre,style,decade) for link in links]
        
        return result
    
    def link_to_song_dict(self,link, genre, style, decade):
        return {
            "name": link.contents[0],
            "url": link['href'],
            "genre": genre["name"],
            "style": style["name"],
            "decade": decade["name"]
        }
    
    def get_all_filter_song_links(self,genreFilter,styleFilter,decadeFilter):
        list_of_list = [self.get_links_single_page(genreFilter, styleFilter, decadeFilter, f'&page={page}')
                  for page in range(1,self.MAX_NUM_PAGES+1)]
        
        return reduce(lambda list1, list2: [*list1, *list2], list_of_list)
    
    def get_links_single_page(self,genreFilter,styleFilter,decadeFilter, pageFilter):
        self.driver.get(f'{self.BASE_URL}{genreFilter}{styleFilter}{decadeFilter}')
        
        if self.driver.page_source == '<html><head></head><body></body></html>':
            raise Exception('Denegation error')

        if self.first_time:
            self.click_on_accept_cookies()
            self.first_time = False

        soup = BeautifulSoup(self.driver.page_source, 'lxml')

        return soup.findAll('a', {"class":"_2KJtL _1mes3 kWOod"})
    
    def click_on_accept_cookies(self):
        try:
            button = self.driver.find_element_by_xpath('//button[contains(text(), "thanks")]')

            button.click()
        except:
            print('cookies banner not found. Ignored')
            
    
    def create_chrome_driver(self):
        options = webdriver.ChromeOptions()
        options.add_argument('--ignore-certificate-errors')
        options.add_argument('--incognito')
        options.add_argument('--headless')
        
        driver = webdriver.Chrome("./chromedriver", options=options)
        return driver

# %%
# %%time
extractor = ImprovedSongExtractor()

songs = extractor.get_all_songs(genres[0], styles[0], decades[0])
# Out:
# CPU times: user 1.44 s, sys: 43.3 ms, total: 1.49 s
# Wall time: 17.1 s

# %% [markdown]
# ## Saving last combination index

# %% [markdown]
# If we get an error during the operation (unexpected error, service denegation etc.), we should be able to restart from the last point. Let's try to save the index inside combinations some way

# %%
number = 88

# %%
io.to_file(number,'../data/lastIndex.pickle')

# %%
io.from_file('../data/lastIndex.pickle')
# Out:
# 88

# %% [markdown]
# It works using `pickle`!

# %%
! rm '../data/lastIndex.pickle'

# %%
! ls ../data
# Out:
# decades genres  styles

# %% [markdown]
# ## AllCombinationsSongExtractor

# %%
import jl_io as io


class AllCombinationsSongExtractor:
    START_INDEX_FILE_PATH = '../data/nextIndex.pickle'
    def __init__(self, singleSongExtractor):
        self.extractor = singleSongExtractor
        
        self.genres = io.from_file('../data/genres')
        self.styles = io.from_file('../data/styles')
        self.decades = io.from_file('../data/decades')
        
        self.combinations = []

        for decade in self.decades:
            for genre in self.genres:
                for style in self.styles:
                    self.combinations.append( {"decade": decade, "genre": genre, "style": style })
        
    def extract(self, reset=False):      
        startIndex = 1
        
        if not reset:
            try:
                startIndex = io.from_file(self.START_INDEX_FILE_PATH)
            except:
                pass
        
        return self.extract_from(startIndex)
            
    def extract_from(self, startIndexBase1):
        songs = []
        
        for index, combination in enumerate(self.combinations[startIndexBase1 - 1:]):
            new_extracted_songs = []
            genre = combination["genre"]
            style = combination["style"]
            decade = combination["decade"]
            
            try:
                new_extracted_songs = self.extractor.get_all_songs(genre,style,decade)
            except Exception as e: 
                print(f'Error in ({genre["name"]},{style["name"]},{decade["name"]})')
                print(e)
                return songs
            
            base_1_index = index + startIndexBase1
            songs.extend(new_extracted_songs)
            
            number_of_songs = len(songs)
            print(f'Extracted {index+startIndexBase1} of {len(self.combinations)} ({genre["name"]},{style["name"]},{decade["name"]}). {number_of_songs} in total')
  
            io.to_file(index + startIndexBase1 , self.START_INDEX_FILE_PATH)
        
        return songs

# %%
all_combination_extractor = AllCombinationsSongExtractor(ImprovedSongExtractor)

# %%
all_songs = all_combination_extractor.extract()
# Out:
# Extracted 1 of 14700 (Rock,Pop Rock,2010s)
# Extracted 2 of 14700 (Rock,Singer-songwriter,2010s)
# Extracted 3 of 14700 (Rock,Alternative Rock,2010s)
# Extracted 4 of 14700 (Rock,Indie Rock,2010s)
# Extracted 5 of 14700 (Rock,Indie Pop,2010s)
# Extracted 6 of 14700 (Rock,Pop Punk,2010s)
# Extracted 7 of 14700 (Rock,Hard Rock,2010s)
# Extracted 8 of 14700 (Rock,Contemporary Folk,2010s)
# Extracted 9 of 14700 (Rock,Folk Rock,2010s)
# Extracted 10 of 14700 (Rock,Folk Pop,2010s)
# Extracted 11 of 14700 (Rock,Contemporary Country,2010s)
# Extracted 12 of 14700 (Rock,Country Pop,2010s)
# Extracted 13 of 14700 (Rock,Electropop,2010s)
# Extracted 14 of 14700 (Rock,Indie Folk,2010s)
# Extracted 15 of 14700 (Rock,Americana,2010s)
# Extracted 16 of 14700 (Rock,Punk Rock,2010s)
# Extracted 17 of 14700 (Rock,Power Pop,2010s)
# Extracted 18 of 14700 (Rock,Country Rock,2010s)
# Extracted 19 of 14700 (Rock,Dance-pop,2010s)
# Extracted 20 of 14700 (Rock,Blues Rock,2010s)
# Extracted 21 of 14700 (Rock,Alternative Country,2010s)
# Extracted 22 of 14700 (Rock,Adult Contemporary,2010s)
# Extracted 23 of 14700 (Rock,Synthpop,2010s)
# Extracted 24 of 14700 (Rock,Pop Soul,2010s)
# Extracted 25 of 14700 (Rock,Art Pop,2010s)
# Extracted 26 of 14700 (Rock,Art Rock,2010s)
# Extracted 27 of 14700 (Rock,Baroque Pop,2010s)
# Extracted 28 of 14700 (Rock,Post-grunge,2010s)
# Extracted 29 of 14700 (Rock,Teen Pop,2010s)
# Extracted 30 of 14700 (Rock,Soft Rock,2010s)
# Extracted 31 of 14700 (Rock,Progressive Rock,2010s)
# Extracted 32 of 14700 (Rock,Rock And Roll,2010s)
# Extracted 33 of 14700 (Rock,Aor,2010s)
# Extracted 34 of 14700 (Rock,Christian Rock,2010s)
# Extracted 35 of 14700 (Rock,Britpop,2010s)
# Extracted 36 of 14700 (Rock,New Wave,2010s)
# Extracted 37 of 14700 (Rock,Piano Rock,2010s)
# Extracted 38 of 14700 (Rock,Heartland Rock,2010s)
# Extracted 39 of 14700 (Rock,Soul,2010s)
# Extracted 40 of 14700 (Rock,Emo-pop,2010s)
# Extracted 41 of 14700 (Rock,Psychedelic Rock,2010s)
# Extracted 42 of 14700 (Rock,Worship Music,2010s)
# Extracted 43 of 14700 (Rock,Pop Rap,2010s)
# Extracted 44 of 14700 (Rock,Psychedelic Pop,2010s)
# Extracted 45 of 14700 (Rock,Blue-eyed Soul,2010s)
# Extracted 46 of 14700 (Rock,Southern Rock,2010s)
# Extracted 47 of 14700 (Rock,Contemporary Christian Music,2010s)
# Extracted 48 of 14700 (Rock,Alternative Metal,2010s)
# Extracted 49 of 14700 (Rock,Post-hardcore,2010s)
# Extracted 50 of 14700 (Rock,Roots Rock,2010s)
# Extracted 51 of 14700 (Rock,Heavy Metal,2010s)
# Extracted 52 of 14700 (Rock,Neo-psychedelia,2010s)
# Extracted 53 of 14700 (Rock,Outlaw Country,2010s)
# Extracted 54 of 14700 (Rock,Glam Rock,2010s)
# Extracted 55 of 14700 (Rock,Latin Pop,2010s)
# Extracted 56 of 14700 (Rock,Skate Punk,2010s)
# Extracted 57 of 14700 (Rock,Post-punk,2010s)
# Extracted 58 of 14700 (Rock,Vocal Jazz,2010s)
# Extracted 59 of 14700 (Rock,Lo-fi Indie,2010s)
# Extracted 60 of 14700 (Rock,Progressive Pop,2010s)
# Extracted 61 of 14700 (Rock,Indietronica,2010s)
# Extracted 62 of 14700 (Rock,Garage Rock Revival,2010s)
# Extracted 63 of 14700 (Rock,Dream Pop,2010s)
# Extracted 64 of 14700 (Rock,Grunge,2010s)
# Extracted 65 of 14700 (Rock,Post-punk Revival,2010s)
# Extracted 66 of 14700 (Rock,Nashville Sound,2010s)
# Extracted 67 of 14700 (Rock,Jangle Pop,2010s)
# Extracted 68 of 14700 (Rock,Power Metal,2010s)
# Extracted 69 of 14700 (Rock,Celtic Rock,2010s)
# Extracted 70 of 14700 (Rock,Experimental Rock,2010s)
# Extracted 71 of 14700 (Rock,Chamber Folk,2010s)
# Extracted 72 of 14700 (Rock,Chanson,2010s)
# Extracted 73 of 14700 (Rock,Sunshine Pop,2010s)
# Extracted 74 of 14700 (Rock,Merseybeat,2010s)
# Extracted 75 of 14700 (Rock,Sophisti-pop,2010s)
# Extracted 76 of 14700 (Rock,Traditional Pop,2010s)
# Extracted 77 of 14700 (Rock,Ska Punk,2010s)
# Extracted 78 of 14700 (Rock,Neo Soul,2010s)
# Extracted 79 of 14700 (Rock,Alternative R&b,2010s)
# Extracted 80 of 14700 (Rock,Rockabilly,2010s)
# Extracted 81 of 14700 (Rock,Bluegrass,2010s)
# Extracted 82 of 14700 (Rock,Melodic Hardcore,2010s)
# Extracted 83 of 14700 (Rock,Garage Rock,2010s)
# Extracted 84 of 14700 (Rock,Folk Punk,2010s)
# Extracted 85 of 14700 (Rock,Progressive Country,2010s)
# Extracted 86 of 14700 (Rock,Psychedelic Folk,2010s)
# Extracted 87 of 14700 (Rock,Bro-country,2010s)
# Extracted 88 of 14700 (Rock,Yacht Rock,2010s)
# Extracted 89 of 14700 (Rock,Pop Reggae,2010s)
# Extracted 90 of 14700 (Rock,Alternative Dance,2010s)
# Extracted 91 of 14700 (Rock,Progressive Bluegrass,2010s)
# Extracted 92 of 14700 (Rock,Ska,2010s)
# Extracted 93 of 14700 (Rock,Anti-folk,2010s)
# Extracted 94 of 14700 (Rock,Symphonic Metal,2010s)
# Extracted 95 of 14700 (Rock,Symphonic Prog,2010s)
# Extracted 96 of 14700 (Rock,Rap Rock,2010s)
# Extracted 97 of 14700 (Rock,Comedy Rock,2010s)
# Extracted 98 of 14700 (Rock,Funk,2010s)
# Extracted 99 of 14700 (Rock,Nu Metal,2010s)
# Extracted 100 of 14700 (Rock,Celtic Punk,2010s)
# Extracted 101 of 14700 (Folk,Pop Rock,2010s)
# Extracted 102 of 14700 (Folk,Singer-songwriter,2010s)
# Extracted 103 of 14700 (Folk,Alternative Rock,2010s)
# Extracted 104 of 14700 (Folk,Indie Rock,2010s)
# Extracted 105 of 14700 (Folk,Indie Pop,2010s)
# Extracted 106 of 14700 (Folk,Pop Punk,2010s)
# Extracted 107 of 14700 (Folk,Hard Rock,2010s)
# Extracted 108 of 14700 (Folk,Contemporary Folk,2010s)
# Extracted 109 of 14700 (Folk,Folk Rock,2010s)
# Extracted 110 of 14700 (Folk,Folk Pop,2010s)
# Extracted 111 of 14700 (Folk,Contemporary Country,2010s)
# Extracted 112 of 14700 (Folk,Country Pop,2010s)
# Extracted 113 of 14700 (Folk,Electropop,2010s)
# Extracted 114 of 14700 (Folk,Indie Folk,2010s)
# Extracted 115 of 14700 (Folk,Americana,2010s)
# Extracted 116 of 14700 (Folk,Punk Rock,2010s)
# Extracted 117 of 14700 (Folk,Power Pop,2010s)
# Extracted 118 of 14700 (Folk,Country Rock,2010s)
# Extracted 119 of 14700 (Folk,Dance-pop,2010s)
# Extracted 120 of 14700 (Folk,Blues Rock,2010s)
# Extracted 121 of 14700 (Folk,Alternative Country,2010s)
# Extracted 122 of 14700 (Folk,Adult Contemporary,2010s)
# Extracted 123 of 14700 (Folk,Synthpop,2010s)
# Extracted 124 of 14700 (Folk,Pop Soul,2010s)
# Extracted 125 of 14700 (Folk,Art Pop,2010s)
# Extracted 126 of 14700 (Folk,Art Rock,2010s)
# Extracted 127 of 14700 (Folk,Baroque Pop,2010s)
# Extracted 128 of 14700 (Folk,Post-grunge,2010s)
# Extracted 129 of 14700 (Folk,Teen Pop,2010s)
# Extracted 130 of 14700 (Folk,Soft Rock,2010s)
# Extracted 131 of 14700 (Folk,Progressive Rock,2010s)
# Extracted 132 of 14700 (Folk,Rock And Roll,2010s)
# Extracted 133 of 14700 (Folk,Aor,2010s)
# Extracted 134 of 14700 (Folk,Christian Rock,2010s)
# Extracted 135 of 14700 (Folk,Britpop,2010s)
# Extracted 136 of 14700 (Folk,New Wave,2010s)
# Extracted 137 of 14700 (Folk,Piano Rock,2010s)
# Extracted 138 of 14700 (Folk,Heartland Rock,2010s)
# Extracted 139 of 14700 (Folk,Soul,2010s)
# Extracted 140 of 14700 (Folk,Emo-pop,2010s)
# Extracted 141 of 14700 (Folk,Psychedelic Rock,2010s)
# Extracted 142 of 14700 (Folk,Worship Music,2010s)
# Extracted 143 of 14700 (Folk,Pop Rap,2010s)
# Extracted 144 of 14700 (Folk,Psychedelic Pop,2010s)
# Extracted 145 of 14700 (Folk,Blue-eyed Soul,2010s)
# Extracted 146 of 14700 (Folk,Southern Rock,2010s)
# Extracted 147 of 14700 (Folk,Contemporary Christian Music,2010s)
# Extracted 148 of 14700 (Folk,Alternative Metal,2010s)
# Extracted 149 of 14700 (Folk,Post-hardcore,2010s)
# Extracted 150 of 14700 (Folk,Roots Rock,2010s)
# Extracted 151 of 14700 (Folk,Heavy Metal,2010s)
# Extracted 152 of 14700 (Folk,Neo-psychedelia,2010s)
# Extracted 153 of 14700 (Folk,Outlaw Country,2010s)
# Extracted 154 of 14700 (Folk,Glam Rock,2010s)
# Extracted 155 of 14700 (Folk,Latin Pop,2010s)
# Extracted 156 of 14700 (Folk,Skate Punk,2010s)
# Extracted 157 of 14700 (Folk,Post-punk,2010s)
# Extracted 158 of 14700 (Folk,Vocal Jazz,2010s)
# Extracted 159 of 14700 (Folk,Lo-fi Indie,2010s)
# Extracted 160 of 14700 (Folk,Progressive Pop,2010s)
# Extracted 161 of 14700 (Folk,Indietronica,2010s)
# Extracted 162 of 14700 (Folk,Garage Rock Revival,2010s)
# Extracted 163 of 14700 (Folk,Dream Pop,2010s)
# Extracted 164 of 14700 (Folk,Grunge,2010s)
# Extracted 165 of 14700 (Folk,Post-punk Revival,2010s)
# Extracted 166 of 14700 (Folk,Nashville Sound,2010s)
# Extracted 167 of 14700 (Folk,Jangle Pop,2010s)
# Extracted 168 of 14700 (Folk,Power Metal,2010s)
# Extracted 169 of 14700 (Folk,Celtic Rock,2010s)
# Extracted 170 of 14700 (Folk,Experimental Rock,2010s)
# Extracted 171 of 14700 (Folk,Chamber Folk,2010s)
# Extracted 172 of 14700 (Folk,Chanson,2010s)
# Extracted 173 of 14700 (Folk,Sunshine Pop,2010s)
# Extracted 174 of 14700 (Folk,Merseybeat,2010s)
# Extracted 175 of 14700 (Folk,Sophisti-pop,2010s)
# Extracted 176 of 14700 (Folk,Traditional Pop,2010s)
# Extracted 177 of 14700 (Folk,Ska Punk,2010s)
# Extracted 178 of 14700 (Folk,Neo Soul,2010s)
# Extracted 179 of 14700 (Folk,Alternative R&b,2010s)
# Extracted 180 of 14700 (Folk,Rockabilly,2010s)
# Extracted 181 of 14700 (Folk,Bluegrass,2010s)
# Extracted 182 of 14700 (Folk,Melodic Hardcore,2010s)
# Extracted 183 of 14700 (Folk,Garage Rock,2010s)
# Extracted 184 of 14700 (Folk,Folk Punk,2010s)
# Extracted 185 of 14700 (Folk,Progressive Country,2010s)
# Extracted 186 of 14700 (Folk,Psychedelic Folk,2010s)
# Extracted 187 of 14700 (Folk,Bro-country,2010s)
# Extracted 188 of 14700 (Folk,Yacht Rock,2010s)
# Extracted 189 of 14700 (Folk,Pop Reggae,2010s)
# Extracted 190 of 14700 (Folk,Alternative Dance,2010s)
# Extracted 191 of 14700 (Folk,Progressive Bluegrass,2010s)
# Extracted 192 of 14700 (Folk,Ska,2010s)
# Extracted 193 of 14700 (Folk,Anti-folk,2010s)
# Extracted 194 of 14700 (Folk,Symphonic Metal,2010s)
# Extracted 195 of 14700 (Folk,Symphonic Prog,2010s)
# Extracted 196 of 14700 (Folk,Rap Rock,2010s)
# Extracted 197 of 14700 (Folk,Comedy Rock,2010s)
# Extracted 198 of 14700 (Folk,Funk,2010s)
# Extracted 199 of 14700 (Folk,Nu Metal,2010s)
# Extracted 200 of 14700 (Folk,Celtic Punk,2010s)
# Extracted 201 of 14700 (Pop,Pop Rock,2010s)
# Extracted 202 of 14700 (Pop,Singer-songwriter,2010s)
# Extracted 203 of 14700 (Pop,Alternative Rock,2010s)
# Extracted 204 of 14700 (Pop,Indie Rock,2010s)
# Extracted 205 of 14700 (Pop,Indie Pop,2010s)
# Extracted 206 of 14700 (Pop,Pop Punk,2010s)
# Extracted 207 of 14700 (Pop,Hard Rock,2010s)
# Extracted 208 of 14700 (Pop,Contemporary Folk,2010s)
# Extracted 209 of 14700 (Pop,Folk Rock,2010s)
# Extracted 210 of 14700 (Pop,Folk Pop,2010s)
# Extracted 211 of 14700 (Pop,Contemporary Country,2010s)
# Extracted 212 of 14700 (Pop,Country Pop,2010s)
# Extracted 213 of 14700 (Pop,Electropop,2010s)
# Extracted 214 of 14700 (Pop,Indie Folk,2010s)
# Extracted 215 of 14700 (Pop,Americana,2010s)
# Extracted 216 of 14700 (Pop,Punk Rock,2010s)
# Extracted 217 of 14700 (Pop,Power Pop,2010s)
# Extracted 218 of 14700 (Pop,Country Rock,2010s)
# Extracted 219 of 14700 (Pop,Dance-pop,2010s)
# Extracted 220 of 14700 (Pop,Blues Rock,2010s)
# Extracted 221 of 14700 (Pop,Alternative Country,2010s)
# Extracted 222 of 14700 (Pop,Adult Contemporary,2010s)
# Extracted 223 of 14700 (Pop,Synthpop,2010s)
# Extracted 224 of 14700 (Pop,Pop Soul,2010s)
# Extracted 225 of 14700 (Pop,Art Pop,2010s)
# Extracted 226 of 14700 (Pop,Art Rock,2010s)
# Extracted 227 of 14700 (Pop,Baroque Pop,2010s)
# Extracted 228 of 14700 (Pop,Post-grunge,2010s)
# Extracted 229 of 14700 (Pop,Teen Pop,2010s)
# Extracted 230 of 14700 (Pop,Soft Rock,2010s)
# Extracted 231 of 14700 (Pop,Progressive Rock,2010s)
# Extracted 232 of 14700 (Pop,Rock And Roll,2010s)
# Extracted 233 of 14700 (Pop,Aor,2010s)
# Extracted 234 of 14700 (Pop,Christian Rock,2010s)
# Extracted 235 of 14700 (Pop,Britpop,2010s)
# Extracted 236 of 14700 (Pop,New Wave,2010s)
# Extracted 237 of 14700 (Pop,Piano Rock,2010s)
# Extracted 238 of 14700 (Pop,Heartland Rock,2010s)
# Extracted 239 of 14700 (Pop,Soul,2010s)
# Extracted 240 of 14700 (Pop,Emo-pop,2010s)
# Extracted 241 of 14700 (Pop,Psychedelic Rock,2010s)
# Extracted 242 of 14700 (Pop,Worship Music,2010s)
# Extracted 243 of 14700 (Pop,Pop Rap,2010s)
# Extracted 244 of 14700 (Pop,Psychedelic Pop,2010s)
# Extracted 245 of 14700 (Pop,Blue-eyed Soul,2010s)
# Extracted 246 of 14700 (Pop,Southern Rock,2010s)
# Extracted 247 of 14700 (Pop,Contemporary Christian Music,2010s)
# Extracted 248 of 14700 (Pop,Alternative Metal,2010s)
# Extracted 249 of 14700 (Pop,Post-hardcore,2010s)
# Extracted 250 of 14700 (Pop,Roots Rock,2010s)
# Extracted 251 of 14700 (Pop,Heavy Metal,2010s)
# Extracted 252 of 14700 (Pop,Neo-psychedelia,2010s)
# Extracted 253 of 14700 (Pop,Outlaw Country,2010s)
# Extracted 254 of 14700 (Pop,Glam Rock,2010s)
# Extracted 255 of 14700 (Pop,Latin Pop,2010s)
# Extracted 256 of 14700 (Pop,Skate Punk,2010s)
# Extracted 257 of 14700 (Pop,Post-punk,2010s)
# Extracted 258 of 14700 (Pop,Vocal Jazz,2010s)
# Extracted 259 of 14700 (Pop,Lo-fi Indie,2010s)
# Extracted 260 of 14700 (Pop,Progressive Pop,2010s)
# Extracted 261 of 14700 (Pop,Indietronica,2010s)
# Extracted 262 of 14700 (Pop,Garage Rock Revival,2010s)
# Extracted 263 of 14700 (Pop,Dream Pop,2010s)
# Extracted 264 of 14700 (Pop,Grunge,2010s)
# Extracted 265 of 14700 (Pop,Post-punk Revival,2010s)
# Extracted 266 of 14700 (Pop,Nashville Sound,2010s)
# Extracted 267 of 14700 (Pop,Jangle Pop,2010s)
# Extracted 268 of 14700 (Pop,Power Metal,2010s)
# Extracted 269 of 14700 (Pop,Celtic Rock,2010s)
# Extracted 270 of 14700 (Pop,Experimental Rock,2010s)
# Extracted 271 of 14700 (Pop,Chamber Folk,2010s)
# Extracted 272 of 14700 (Pop,Chanson,2010s)
# Extracted 273 of 14700 (Pop,Sunshine Pop,2010s)
# Extracted 274 of 14700 (Pop,Merseybeat,2010s)
# Extracted 275 of 14700 (Pop,Sophisti-pop,2010s)
# Extracted 276 of 14700 (Pop,Traditional Pop,2010s)
# Extracted 277 of 14700 (Pop,Ska Punk,2010s)
# Extracted 278 of 14700 (Pop,Neo Soul,2010s)
# Extracted 279 of 14700 (Pop,Alternative R&b,2010s)
# Extracted 280 of 14700 (Pop,Rockabilly,2010s)
# Extracted 281 of 14700 (Pop,Bluegrass,2010s)
# Extracted 282 of 14700 (Pop,Melodic Hardcore,2010s)
# Extracted 283 of 14700 (Pop,Garage Rock,2010s)
# Extracted 284 of 14700 (Pop,Folk Punk,2010s)
# Extracted 285 of 14700 (Pop,Progressive Country,2010s)
# Extracted 286 of 14700 (Pop,Psychedelic Folk,2010s)
# Extracted 287 of 14700 (Pop,Bro-country,2010s)
# Extracted 288 of 14700 (Pop,Yacht Rock,2010s)
# Extracted 289 of 14700 (Pop,Pop Reggae,2010s)
# Extracted 290 of 14700 (Pop,Alternative Dance,2010s)
# Extracted 291 of 14700 (Pop,Progressive Bluegrass,2010s)
# Extracted 292 of 14700 (Pop,Ska,2010s)
# Extracted 293 of 14700 (Pop,Anti-folk,2010s)
# Extracted 294 of 14700 (Pop,Symphonic Metal,2010s)
# Extracted 295 of 14700 (Pop,Symphonic Prog,2010s)
# Extracted 296 of 14700 (Pop,Rap Rock,2010s)
# Extracted 297 of 14700 (Pop,Comedy Rock,2010s)
# Extracted 298 of 14700 (Pop,Funk,2010s)
# Extracted 299 of 14700 (Pop,Nu Metal,2010s)
# Extracted 300 of 14700 (Pop,Celtic Punk,2010s)
# Extracted 301 of 14700 (Country,Pop Rock,2010s)
# Extracted 302 of 14700 (Country,Singer-songwriter,2010s)
# Extracted 303 of 14700 (Country,Alternative Rock,2010s)
# Extracted 304 of 14700 (Country,Indie Rock,2010s)
# Extracted 305 of 14700 (Country,Indie Pop,2010s)
# Extracted 306 of 14700 (Country,Pop Punk,2010s)
# Extracted 307 of 14700 (Country,Hard Rock,2010s)
# Extracted 308 of 14700 (Country,Contemporary Folk,2010s)
# Extracted 309 of 14700 (Country,Folk Rock,2010s)
# Extracted 310 of 14700 (Country,Folk Pop,2010s)
# Extracted 311 of 14700 (Country,Contemporary Country,2010s)
# Extracted 312 of 14700 (Country,Country Pop,2010s)
# Extracted 313 of 14700 (Country,Electropop,2010s)
# Extracted 314 of 14700 (Country,Indie Folk,2010s)
# Extracted 315 of 14700 (Country,Americana,2010s)
# Extracted 316 of 14700 (Country,Punk Rock,2010s)
# Extracted 317 of 14700 (Country,Power Pop,2010s)
# Extracted 318 of 14700 (Country,Country Rock,2010s)
# Extracted 319 of 14700 (Country,Dance-pop,2010s)
# Extracted 320 of 14700 (Country,Blues Rock,2010s)
# Extracted 321 of 14700 (Country,Alternative Country,2010s)
# Extracted 322 of 14700 (Country,Adult Contemporary,2010s)
# Extracted 323 of 14700 (Country,Synthpop,2010s)
# Extracted 324 of 14700 (Country,Pop Soul,2010s)
# Extracted 325 of 14700 (Country,Art Pop,2010s)
# Extracted 326 of 14700 (Country,Art Rock,2010s)
# Extracted 327 of 14700 (Country,Baroque Pop,2010s)
# Extracted 328 of 14700 (Country,Post-grunge,2010s)
# Extracted 329 of 14700 (Country,Teen Pop,2010s)
# Extracted 330 of 14700 (Country,Soft Rock,2010s)
# Extracted 331 of 14700 (Country,Progressive Rock,2010s)
# Extracted 332 of 14700 (Country,Rock And Roll,2010s)
# Extracted 333 of 14700 (Country,Aor,2010s)
# Extracted 334 of 14700 (Country,Christian Rock,2010s)
# Extracted 335 of 14700 (Country,Britpop,2010s)
# Extracted 336 of 14700 (Country,New Wave,2010s)
# Extracted 337 of 14700 (Country,Piano Rock,2010s)
# Extracted 338 of 14700 (Country,Heartland Rock,2010s)
# Extracted 339 of 14700 (Country,Soul,2010s)
# Extracted 340 of 14700 (Country,Emo-pop,2010s)
# Extracted 341 of 14700 (Country,Psychedelic Rock,2010s)
# Extracted 342 of 14700 (Country,Worship Music,2010s)
# Extracted 343 of 14700 (Country,Pop Rap,2010s)
# Extracted 344 of 14700 (Country,Psychedelic Pop,2010s)
# Extracted 345 of 14700 (Country,Blue-eyed Soul,2010s)
# Extracted 346 of 14700 (Country,Southern Rock,2010s)
# Extracted 347 of 14700 (Country,Contemporary Christian Music,2010s)
# Extracted 348 of 14700 (Country,Alternative Metal,2010s)
# Extracted 349 of 14700 (Country,Post-hardcore,2010s)
# Extracted 350 of 14700 (Country,Roots Rock,2010s)
# Extracted 351 of 14700 (Country,Heavy Metal,2010s)
# Extracted 352 of 14700 (Country,Neo-psychedelia,2010s)
# Extracted 353 of 14700 (Country,Outlaw Country,2010s)
# Extracted 354 of 14700 (Country,Glam Rock,2010s)
# Extracted 355 of 14700 (Country,Latin Pop,2010s)
# Extracted 356 of 14700 (Country,Skate Punk,2010s)
# Extracted 357 of 14700 (Country,Post-punk,2010s)
# Extracted 358 of 14700 (Country,Vocal Jazz,2010s)
# Extracted 359 of 14700 (Country,Lo-fi Indie,2010s)
# Extracted 360 of 14700 (Country,Progressive Pop,2010s)
# Extracted 361 of 14700 (Country,Indietronica,2010s)
# Extracted 362 of 14700 (Country,Garage Rock Revival,2010s)
# Extracted 363 of 14700 (Country,Dream Pop,2010s)
# Extracted 364 of 14700 (Country,Grunge,2010s)
# Extracted 365 of 14700 (Country,Post-punk Revival,2010s)
# Extracted 366 of 14700 (Country,Nashville Sound,2010s)
# Extracted 367 of 14700 (Country,Jangle Pop,2010s)
# Extracted 368 of 14700 (Country,Power Metal,2010s)
# Extracted 369 of 14700 (Country,Celtic Rock,2010s)
# Extracted 370 of 14700 (Country,Experimental Rock,2010s)
# Extracted 371 of 14700 (Country,Chamber Folk,2010s)
# Extracted 372 of 14700 (Country,Chanson,2010s)
# Extracted 373 of 14700 (Country,Sunshine Pop,2010s)
# Extracted 374 of 14700 (Country,Merseybeat,2010s)
# Extracted 375 of 14700 (Country,Sophisti-pop,2010s)
# Extracted 376 of 14700 (Country,Traditional Pop,2010s)
# Extracted 377 of 14700 (Country,Ska Punk,2010s)
# Extracted 378 of 14700 (Country,Neo Soul,2010s)
# Extracted 379 of 14700 (Country,Alternative R&b,2010s)
# Extracted 380 of 14700 (Country,Rockabilly,2010s)
# Extracted 381 of 14700 (Country,Bluegrass,2010s)
# Extracted 382 of 14700 (Country,Melodic Hardcore,2010s)
# Extracted 383 of 14700 (Country,Garage Rock,2010s)
# Extracted 384 of 14700 (Country,Folk Punk,2010s)
# Extracted 385 of 14700 (Country,Progressive Country,2010s)
# Extracted 386 of 14700 (Country,Psychedelic Folk,2010s)
# Extracted 387 of 14700 (Country,Bro-country,2010s)
# Extracted 388 of 14700 (Country,Yacht Rock,2010s)
# Extracted 389 of 14700 (Country,Pop Reggae,2010s)
# Extracted 390 of 14700 (Country,Alternative Dance,2010s)
# Extracted 391 of 14700 (Country,Progressive Bluegrass,2010s)
# Extracted 392 of 14700 (Country,Ska,2010s)
# Extracted 393 of 14700 (Country,Anti-folk,2010s)
# Extracted 394 of 14700 (Country,Symphonic Metal,2010s)
# Extracted 395 of 14700 (Country,Symphonic Prog,2010s)
# Extracted 396 of 14700 (Country,Rap Rock,2010s)
# Extracted 397 of 14700 (Country,Comedy Rock,2010s)
# Extracted 398 of 14700 (Country,Funk,2010s)
# Extracted 399 of 14700 (Country,Nu Metal,2010s)
# Extracted 400 of 14700 (Country,Celtic Punk,2010s)
# Extracted 401 of 14700 (Electronic,Pop Rock,2010s)
# Extracted 402 of 14700 (Electronic,Singer-songwriter,2010s)
# Extracted 403 of 14700 (Electronic,Alternative Rock,2010s)
# Extracted 404 of 14700 (Electronic,Indie Rock,2010s)
# Extracted 405 of 14700 (Electronic,Indie Pop,2010s)
# Extracted 406 of 14700 (Electronic,Pop Punk,2010s)
# Extracted 407 of 14700 (Electronic,Hard Rock,2010s)
# Extracted 408 of 14700 (Electronic,Contemporary Folk,2010s)
# Extracted 409 of 14700 (Electronic,Folk Rock,2010s)
# Extracted 410 of 14700 (Electronic,Folk Pop,2010s)
# Extracted 411 of 14700 (Electronic,Contemporary Country,2010s)
# Extracted 412 of 14700 (Electronic,Country Pop,2010s)
# Extracted 413 of 14700 (Electronic,Electropop,2010s)
# Extracted 414 of 14700 (Electronic,Indie Folk,2010s)
# Extracted 415 of 14700 (Electronic,Americana,2010s)
# Extracted 416 of 14700 (Electronic,Punk Rock,2010s)
# Extracted 417 of 14700 (Electronic,Power Pop,2010s)
# Extracted 418 of 14700 (Electronic,Country Rock,2010s)
# Extracted 419 of 14700 (Electronic,Dance-pop,2010s)
# Extracted 420 of 14700 (Electronic,Blues Rock,2010s)
# Extracted 421 of 14700 (Electronic,Alternative Country,2010s)
# Extracted 422 of 14700 (Electronic,Adult Contemporary,2010s)
# Extracted 423 of 14700 (Electronic,Synthpop,2010s)
# Extracted 424 of 14700 (Electronic,Pop Soul,2010s)
# Extracted 425 of 14700 (Electronic,Art Pop,2010s)
# Extracted 426 of 14700 (Electronic,Art Rock,2010s)
# Extracted 427 of 14700 (Electronic,Baroque Pop,2010s)
# Extracted 428 of 14700 (Electronic,Post-grunge,2010s)
# Extracted 429 of 14700 (Electronic,Teen Pop,2010s)
# Extracted 430 of 14700 (Electronic,Soft Rock,2010s)
# Extracted 431 of 14700 (Electronic,Progressive Rock,2010s)
# Extracted 432 of 14700 (Electronic,Rock And Roll,2010s)
# Extracted 433 of 14700 (Electronic,Aor,2010s)
# Extracted 434 of 14700 (Electronic,Christian Rock,2010s)
# Extracted 435 of 14700 (Electronic,Britpop,2010s)
# Extracted 436 of 14700 (Electronic,New Wave,2010s)
# Extracted 437 of 14700 (Electronic,Piano Rock,2010s)
# Extracted 438 of 14700 (Electronic,Heartland Rock,2010s)
# Extracted 439 of 14700 (Electronic,Soul,2010s)
# Extracted 440 of 14700 (Electronic,Emo-pop,2010s)
# Extracted 441 of 14700 (Electronic,Psychedelic Rock,2010s)
# Extracted 442 of 14700 (Electronic,Worship Music,2010s)
# Extracted 443 of 14700 (Electronic,Pop Rap,2010s)
# Extracted 444 of 14700 (Electronic,Psychedelic Pop,2010s)
# Extracted 445 of 14700 (Electronic,Blue-eyed Soul,2010s)
# Extracted 446 of 14700 (Electronic,Southern Rock,2010s)
# Extracted 447 of 14700 (Electronic,Contemporary Christian Music,2010s)
# Extracted 448 of 14700 (Electronic,Alternative Metal,2010s)
# Extracted 449 of 14700 (Electronic,Post-hardcore,2010s)
# Extracted 450 of 14700 (Electronic,Roots Rock,2010s)
# Extracted 451 of 14700 (Electronic,Heavy Metal,2010s)
# Extracted 452 of 14700 (Electronic,Neo-psychedelia,2010s)
# Extracted 453 of 14700 (Electronic,Outlaw Country,2010s)
# Extracted 454 of 14700 (Electronic,Glam Rock,2010s)
# Extracted 455 of 14700 (Electronic,Latin Pop,2010s)
# Extracted 456 of 14700 (Electronic,Skate Punk,2010s)
# Extracted 457 of 14700 (Electronic,Post-punk,2010s)
# Extracted 458 of 14700 (Electronic,Vocal Jazz,2010s)
# Extracted 459 of 14700 (Electronic,Lo-fi Indie,2010s)
# Extracted 460 of 14700 (Electronic,Progressive Pop,2010s)
# Extracted 461 of 14700 (Electronic,Indietronica,2010s)
# Extracted 462 of 14700 (Electronic,Garage Rock Revival,2010s)
# Extracted 463 of 14700 (Electronic,Dream Pop,2010s)
# Extracted 464 of 14700 (Electronic,Grunge,2010s)
# Extracted 465 of 14700 (Electronic,Post-punk Revival,2010s)
# Extracted 466 of 14700 (Electronic,Nashville Sound,2010s)
# Extracted 467 of 14700 (Electronic,Jangle Pop,2010s)
# Extracted 468 of 14700 (Electronic,Power Metal,2010s)
# Extracted 469 of 14700 (Electronic,Celtic Rock,2010s)
# Extracted 470 of 14700 (Electronic,Experimental Rock,2010s)
# Extracted 471 of 14700 (Electronic,Chamber Folk,2010s)
# Extracted 472 of 14700 (Electronic,Chanson,2010s)
# Extracted 473 of 14700 (Electronic,Sunshine Pop,2010s)
# Extracted 474 of 14700 (Electronic,Merseybeat,2010s)
# Extracted 475 of 14700 (Electronic,Sophisti-pop,2010s)
# Extracted 476 of 14700 (Electronic,Traditional Pop,2010s)
# Extracted 477 of 14700 (Electronic,Ska Punk,2010s)
# Extracted 478 of 14700 (Electronic,Neo Soul,2010s)
# Extracted 479 of 14700 (Electronic,Alternative R&b,2010s)
# Extracted 480 of 14700 (Electronic,Rockabilly,2010s)
# Extracted 481 of 14700 (Electronic,Bluegrass,2010s)
# Extracted 482 of 14700 (Electronic,Melodic Hardcore,2010s)
# Extracted 483 of 14700 (Electronic,Garage Rock,2010s)
# Extracted 484 of 14700 (Electronic,Folk Punk,2010s)
# Extracted 485 of 14700 (Electronic,Progressive Country,2010s)
# Extracted 486 of 14700 (Electronic,Psychedelic Folk,2010s)
# Extracted 487 of 14700 (Electronic,Bro-country,2010s)
# Extracted 488 of 14700 (Electronic,Yacht Rock,2010s)
# Extracted 489 of 14700 (Electronic,Pop Reggae,2010s)
# Extracted 490 of 14700 (Electronic,Alternative Dance,2010s)
# Extracted 491 of 14700 (Electronic,Progressive Bluegrass,2010s)
# Extracted 492 of 14700 (Electronic,Ska,2010s)
# Extracted 493 of 14700 (Electronic,Anti-folk,2010s)
# Extracted 494 of 14700 (Electronic,Symphonic Metal,2010s)
# Extracted 495 of 14700 (Electronic,Symphonic Prog,2010s)
# Extracted 496 of 14700 (Electronic,Rap Rock,2010s)
# Extracted 497 of 14700 (Electronic,Comedy Rock,2010s)
# Extracted 498 of 14700 (Electronic,Funk,2010s)
# Extracted 499 of 14700 (Electronic,Nu Metal,2010s)
# Extracted 500 of 14700 (Electronic,Celtic Punk,2010s)
# Extracted 501 of 14700 (Rhythm And Blues,Pop Rock,2010s)
# Extracted 502 of 14700 (Rhythm And Blues,Singer-songwriter,2010s)
# Extracted 503 of 14700 (Rhythm And Blues,Alternative Rock,2010s)
# Extracted 504 of 14700 (Rhythm And Blues,Indie Rock,2010s)
# Extracted 505 of 14700 (Rhythm And Blues,Indie Pop,2010s)
# Extracted 506 of 14700 (Rhythm And Blues,Pop Punk,2010s)
# Extracted 507 of 14700 (Rhythm And Blues,Hard Rock,2010s)
# Extracted 508 of 14700 (Rhythm And Blues,Contemporary Folk,2010s)
# Extracted 509 of 14700 (Rhythm And Blues,Folk Rock,2010s)
# Extracted 510 of 14700 (Rhythm And Blues,Folk Pop,2010s)
# Extracted 511 of 14700 (Rhythm And Blues,Contemporary Country,2010s)
# Extracted 512 of 14700 (Rhythm And Blues,Country Pop,2010s)
# Extracted 513 of 14700 (Rhythm And Blues,Electropop,2010s)
# Extracted 514 of 14700 (Rhythm And Blues,Indie Folk,2010s)
# Extracted 515 of 14700 (Rhythm And Blues,Americana,2010s)
# Extracted 516 of 14700 (Rhythm And Blues,Punk Rock,2010s)
# Extracted 517 of 14700 (Rhythm And Blues,Power Pop,2010s)
# Extracted 518 of 14700 (Rhythm And Blues,Country Rock,2010s)
# Extracted 519 of 14700 (Rhythm And Blues,Dance-pop,2010s)
# Extracted 520 of 14700 (Rhythm And Blues,Blues Rock,2010s)
# Extracted 521 of 14700 (Rhythm And Blues,Alternative Country,2010s)
# Extracted 522 of 14700 (Rhythm And Blues,Adult Contemporary,2010s)
# Extracted 523 of 14700 (Rhythm And Blues,Synthpop,2010s)
# Extracted 524 of 14700 (Rhythm And Blues,Pop Soul,2010s)
# Extracted 525 of 14700 (Rhythm And Blues,Art Pop,2010s)
# Extracted 526 of 14700 (Rhythm And Blues,Art Rock,2010s)
# Extracted 527 of 14700 (Rhythm And Blues,Baroque Pop,2010s)
# Extracted 528 of 14700 (Rhythm And Blues,Post-grunge,2010s)
# Extracted 529 of 14700 (Rhythm And Blues,Teen Pop,2010s)
# Extracted 530 of 14700 (Rhythm And Blues,Soft Rock,2010s)
# Extracted 531 of 14700 (Rhythm And Blues,Progressive Rock,2010s)
# Extracted 532 of 14700 (Rhythm And Blues,Rock And Roll,2010s)
# Extracted 533 of 14700 (Rhythm And Blues,Aor,2010s)
# Extracted 534 of 14700 (Rhythm And Blues,Christian Rock,2010s)
# Extracted 535 of 14700 (Rhythm And Blues,Britpop,2010s)
# Extracted 536 of 14700 (Rhythm And Blues,New Wave,2010s)
# Extracted 537 of 14700 (Rhythm And Blues,Piano Rock,2010s)
# Extracted 538 of 14700 (Rhythm And Blues,Heartland Rock,2010s)
# Extracted 539 of 14700 (Rhythm And Blues,Soul,2010s)
# Extracted 540 of 14700 (Rhythm And Blues,Emo-pop,2010s)
# Extracted 541 of 14700 (Rhythm And Blues,Psychedelic Rock,2010s)
# Extracted 542 of 14700 (Rhythm And Blues,Worship Music,2010s)
# Extracted 543 of 14700 (Rhythm And Blues,Pop Rap,2010s)
# Extracted 544 of 14700 (Rhythm And Blues,Psychedelic Pop,2010s)
# Extracted 545 of 14700 (Rhythm And Blues,Blue-eyed Soul,2010s)
# Extracted 546 of 14700 (Rhythm And Blues,Southern Rock,2010s)
# Extracted 547 of 14700 (Rhythm And Blues,Contemporary Christian Music,2010s)
# Extracted 548 of 14700 (Rhythm And Blues,Alternative Metal,2010s)
# Extracted 549 of 14700 (Rhythm And Blues,Post-hardcore,2010s)
# Extracted 550 of 14700 (Rhythm And Blues,Roots Rock,2010s)
# Extracted 551 of 14700 (Rhythm And Blues,Heavy Metal,2010s)
# Extracted 552 of 14700 (Rhythm And Blues,Neo-psychedelia,2010s)
# Extracted 553 of 14700 (Rhythm And Blues,Outlaw Country,2010s)
# Extracted 554 of 14700 (Rhythm And Blues,Glam Rock,2010s)
# Extracted 555 of 14700 (Rhythm And Blues,Latin Pop,2010s)
# Extracted 556 of 14700 (Rhythm And Blues,Skate Punk,2010s)
# Extracted 557 of 14700 (Rhythm And Blues,Post-punk,2010s)
# Extracted 558 of 14700 (Rhythm And Blues,Vocal Jazz,2010s)
# Extracted 559 of 14700 (Rhythm And Blues,Lo-fi Indie,2010s)
# Extracted 560 of 14700 (Rhythm And Blues,Progressive Pop,2010s)
# Extracted 561 of 14700 (Rhythm And Blues,Indietronica,2010s)
# Extracted 562 of 14700 (Rhythm And Blues,Garage Rock Revival,2010s)
# Extracted 563 of 14700 (Rhythm And Blues,Dream Pop,2010s)
# Extracted 564 of 14700 (Rhythm And Blues,Grunge,2010s)
# Extracted 565 of 14700 (Rhythm And Blues,Post-punk Revival,2010s)
# Extracted 566 of 14700 (Rhythm And Blues,Nashville Sound,2010s)
# Extracted 567 of 14700 (Rhythm And Blues,Jangle Pop,2010s)
# Extracted 568 of 14700 (Rhythm And Blues,Power Metal,2010s)
# Extracted 569 of 14700 (Rhythm And Blues,Celtic Rock,2010s)
# Extracted 570 of 14700 (Rhythm And Blues,Experimental Rock,2010s)
# Extracted 571 of 14700 (Rhythm And Blues,Chamber Folk,2010s)
# Extracted 572 of 14700 (Rhythm And Blues,Chanson,2010s)
# Extracted 573 of 14700 (Rhythm And Blues,Sunshine Pop,2010s)
# Extracted 574 of 14700 (Rhythm And Blues,Merseybeat,2010s)
# Extracted 575 of 14700 (Rhythm And Blues,Sophisti-pop,2010s)
# Extracted 576 of 14700 (Rhythm And Blues,Traditional Pop,2010s)
# Extracted 577 of 14700 (Rhythm And Blues,Ska Punk,2010s)
# Extracted 578 of 14700 (Rhythm And Blues,Neo Soul,2010s)
# Extracted 579 of 14700 (Rhythm And Blues,Alternative R&b,2010s)
# Extracted 580 of 14700 (Rhythm And Blues,Rockabilly,2010s)
# Extracted 581 of 14700 (Rhythm And Blues,Bluegrass,2010s)
# Extracted 582 of 14700 (Rhythm And Blues,Melodic Hardcore,2010s)
# Extracted 583 of 14700 (Rhythm And Blues,Garage Rock,2010s)
# Extracted 584 of 14700 (Rhythm And Blues,Folk Punk,2010s)
# Extracted 585 of 14700 (Rhythm And Blues,Progressive Country,2010s)
# Extracted 586 of 14700 (Rhythm And Blues,Psychedelic Folk,2010s)
# Extracted 587 of 14700 (Rhythm And Blues,Bro-country,2010s)
# Extracted 588 of 14700 (Rhythm And Blues,Yacht Rock,2010s)
# Extracted 589 of 14700 (Rhythm And Blues,Pop Reggae,2010s)
# Extracted 590 of 14700 (Rhythm And Blues,Alternative Dance,2010s)
# Extracted 591 of 14700 (Rhythm And Blues,Progressive Bluegrass,2010s)
# Extracted 592 of 14700 (Rhythm And Blues,Ska,2010s)
# Extracted 593 of 14700 (Rhythm And Blues,Anti-folk,2010s)
# Extracted 594 of 14700 (Rhythm And Blues,Symphonic Metal,2010s)
# Extracted 595 of 14700 (Rhythm And Blues,Symphonic Prog,2010s)
# Extracted 596 of 14700 (Rhythm And Blues,Rap Rock,2010s)
# Extracted 597 of 14700 (Rhythm And Blues,Comedy Rock,2010s)
# Extracted 598 of 14700 (Rhythm And Blues,Funk,2010s)
# Extracted 599 of 14700 (Rhythm And Blues,Nu Metal,2010s)
# Extracted 600 of 14700 (Rhythm And Blues,Celtic Punk,2010s)
# Extracted 601 of 14700 (Metal,Pop Rock,2010s)
# Extracted 602 of 14700 (Metal,Singer-songwriter,2010s)
# Extracted 603 of 14700 (Metal,Alternative Rock,2010s)
# Extracted 604 of 14700 (Metal,Indie Rock,2010s)
# Extracted 605 of 14700 (Metal,Indie Pop,2010s)
# Extracted 606 of 14700 (Metal,Pop Punk,2010s)
# Extracted 607 of 14700 (Metal,Hard Rock,2010s)
# Extracted 608 of 14700 (Metal,Contemporary Folk,2010s)
# Extracted 609 of 14700 (Metal,Folk Rock,2010s)
# Extracted 610 of 14700 (Metal,Folk Pop,2010s)
# Extracted 611 of 14700 (Metal,Contemporary Country,2010s)
# Extracted 612 of 14700 (Metal,Country Pop,2010s)
# Extracted 613 of 14700 (Metal,Electropop,2010s)
# Extracted 614 of 14700 (Metal,Indie Folk,2010s)
# Extracted 615 of 14700 (Metal,Americana,2010s)
# Extracted 616 of 14700 (Metal,Punk Rock,2010s)
# Extracted 617 of 14700 (Metal,Power Pop,2010s)
# Extracted 618 of 14700 (Metal,Country Rock,2010s)
# Extracted 619 of 14700 (Metal,Dance-pop,2010s)
# Extracted 620 of 14700 (Metal,Blues Rock,2010s)
# Extracted 621 of 14700 (Metal,Alternative Country,2010s)
# Extracted 622 of 14700 (Metal,Adult Contemporary,2010s)
# Extracted 623 of 14700 (Metal,Synthpop,2010s)
# Extracted 624 of 14700 (Metal,Pop Soul,2010s)
# Extracted 625 of 14700 (Metal,Art Pop,2010s)
# Extracted 626 of 14700 (Metal,Art Rock,2010s)
# Extracted 627 of 14700 (Metal,Baroque Pop,2010s)
# Extracted 628 of 14700 (Metal,Post-grunge,2010s)
# Extracted 629 of 14700 (Metal,Teen Pop,2010s)
# Extracted 630 of 14700 (Metal,Soft Rock,2010s)
# Extracted 631 of 14700 (Metal,Progressive Rock,2010s)
# Extracted 632 of 14700 (Metal,Rock And Roll,2010s)
# Extracted 633 of 14700 (Metal,Aor,2010s)
# Extracted 634 of 14700 (Metal,Christian Rock,2010s)
# Extracted 635 of 14700 (Metal,Britpop,2010s)
# Extracted 636 of 14700 (Metal,New Wave,2010s)
# Extracted 637 of 14700 (Metal,Piano Rock,2010s)
# Extracted 638 of 14700 (Metal,Heartland Rock,2010s)
# Extracted 639 of 14700 (Metal,Soul,2010s)
# Extracted 640 of 14700 (Metal,Emo-pop,2010s)
# Extracted 641 of 14700 (Metal,Psychedelic Rock,2010s)
# Extracted 642 of 14700 (Metal,Worship Music,2010s)
# Extracted 643 of 14700 (Metal,Pop Rap,2010s)
# Extracted 644 of 14700 (Metal,Psychedelic Pop,2010s)
# Extracted 645 of 14700 (Metal,Blue-eyed Soul,2010s)
# Extracted 646 of 14700 (Metal,Southern Rock,2010s)
# Extracted 647 of 14700 (Metal,Contemporary Christian Music,2010s)
# Extracted 648 of 14700 (Metal,Alternative Metal,2010s)
# Extracted 649 of 14700 (Metal,Post-hardcore,2010s)
# Extracted 650 of 14700 (Metal,Roots Rock,2010s)
# Extracted 651 of 14700 (Metal,Heavy Metal,2010s)
# Extracted 652 of 14700 (Metal,Neo-psychedelia,2010s)
# Extracted 653 of 14700 (Metal,Outlaw Country,2010s)
# Extracted 654 of 14700 (Metal,Glam Rock,2010s)
# Extracted 655 of 14700 (Metal,Latin Pop,2010s)
# Extracted 656 of 14700 (Metal,Skate Punk,2010s)
# Extracted 657 of 14700 (Metal,Post-punk,2010s)
# Extracted 658 of 14700 (Metal,Vocal Jazz,2010s)
# Extracted 659 of 14700 (Metal,Lo-fi Indie,2010s)
# Extracted 660 of 14700 (Metal,Progressive Pop,2010s)
# Extracted 661 of 14700 (Metal,Indietronica,2010s)
# Extracted 662 of 14700 (Metal,Garage Rock Revival,2010s)
# Extracted 663 of 14700 (Metal,Dream Pop,2010s)
# Extracted 664 of 14700 (Metal,Grunge,2010s)
# Extracted 665 of 14700 (Metal,Post-punk Revival,2010s)
# Extracted 666 of 14700 (Metal,Nashville Sound,2010s)
# Extracted 667 of 14700 (Metal,Jangle Pop,2010s)
# Extracted 668 of 14700 (Metal,Power Metal,2010s)
# Extracted 669 of 14700 (Metal,Celtic Rock,2010s)
# Extracted 670 of 14700 (Metal,Experimental Rock,2010s)
# Extracted 671 of 14700 (Metal,Chamber Folk,2010s)
# Extracted 672 of 14700 (Metal,Chanson,2010s)
# Extracted 673 of 14700 (Metal,Sunshine Pop,2010s)
# Extracted 674 of 14700 (Metal,Merseybeat,2010s)
# Extracted 675 of 14700 (Metal,Sophisti-pop,2010s)
# Extracted 676 of 14700 (Metal,Traditional Pop,2010s)
# Extracted 677 of 14700 (Metal,Ska Punk,2010s)
# Extracted 678 of 14700 (Metal,Neo Soul,2010s)
# Extracted 679 of 14700 (Metal,Alternative R&b,2010s)
# Extracted 680 of 14700 (Metal,Rockabilly,2010s)
# Extracted 681 of 14700 (Metal,Bluegrass,2010s)
# Extracted 682 of 14700 (Metal,Melodic Hardcore,2010s)
# Extracted 683 of 14700 (Metal,Garage Rock,2010s)
# Extracted 684 of 14700 (Metal,Folk Punk,2010s)
# Extracted 685 of 14700 (Metal,Progressive Country,2010s)
# Extracted 686 of 14700 (Metal,Psychedelic Folk,2010s)
# Extracted 687 of 14700 (Metal,Bro-country,2010s)
# Extracted 688 of 14700 (Metal,Yacht Rock,2010s)
# Extracted 689 of 14700 (Metal,Pop Reggae,2010s)
# Extracted 690 of 14700 (Metal,Alternative Dance,2010s)
# Extracted 691 of 14700 (Metal,Progressive Bluegrass,2010s)
# Extracted 692 of 14700 (Metal,Ska,2010s)
# Extracted 693 of 14700 (Metal,Anti-folk,2010s)
# Extracted 694 of 14700 (Metal,Symphonic Metal,2010s)
# Extracted 695 of 14700 (Metal,Symphonic Prog,2010s)
# Extracted 696 of 14700 (Metal,Rap Rock,2010s)
# Extracted 697 of 14700 (Metal,Comedy Rock,2010s)
# Extracted 698 of 14700 (Metal,Funk,2010s)
# Extracted 699 of 14700 (Metal,Nu Metal,2010s)
# Extracted 700 of 14700 (Metal,Celtic Punk,2010s)
# Extracted 701 of 14700 (Contemporary R&b,Pop Rock,2010s)
# Extracted 702 of 14700 (Contemporary R&b,Singer-songwriter,2010s)
# Extracted 703 of 14700 (Contemporary R&b,Alternative Rock,2010s)
# Extracted 704 of 14700 (Contemporary R&b,Indie Rock,2010s)
# Extracted 705 of 14700 (Contemporary R&b,Indie Pop,2010s)
# Extracted 706 of 14700 (Contemporary R&b,Pop Punk,2010s)
# Extracted 707 of 14700 (Contemporary R&b,Hard Rock,2010s)
# Extracted 708 of 14700 (Contemporary R&b,Contemporary Folk,2010s)
# Extracted 709 of 14700 (Contemporary R&b,Folk Rock,2010s)
# Extracted 710 of 14700 (Contemporary R&b,Folk Pop,2010s)
# Extracted 711 of 14700 (Contemporary R&b,Contemporary Country,2010s)
# Extracted 712 of 14700 (Contemporary R&b,Country Pop,2010s)
# Extracted 713 of 14700 (Contemporary R&b,Electropop,2010s)
# Extracted 714 of 14700 (Contemporary R&b,Indie Folk,2010s)
# Extracted 715 of 14700 (Contemporary R&b,Americana,2010s)
# Extracted 716 of 14700 (Contemporary R&b,Punk Rock,2010s)
# Extracted 717 of 14700 (Contemporary R&b,Power Pop,2010s)
# Extracted 718 of 14700 (Contemporary R&b,Country Rock,2010s)
# Extracted 719 of 14700 (Contemporary R&b,Dance-pop,2010s)
# Extracted 720 of 14700 (Contemporary R&b,Blues Rock,2010s)
# Extracted 721 of 14700 (Contemporary R&b,Alternative Country,2010s)
# Extracted 722 of 14700 (Contemporary R&b,Adult Contemporary,2010s)
# Extracted 723 of 14700 (Contemporary R&b,Synthpop,2010s)
# Extracted 724 of 14700 (Contemporary R&b,Pop Soul,2010s)
# Extracted 725 of 14700 (Contemporary R&b,Art Pop,2010s)
# Extracted 726 of 14700 (Contemporary R&b,Art Rock,2010s)
# Extracted 727 of 14700 (Contemporary R&b,Baroque Pop,2010s)
# Extracted 728 of 14700 (Contemporary R&b,Post-grunge,2010s)
# Extracted 729 of 14700 (Contemporary R&b,Teen Pop,2010s)
# Extracted 730 of 14700 (Contemporary R&b,Soft Rock,2010s)
# Extracted 731 of 14700 (Contemporary R&b,Progressive Rock,2010s)
# Extracted 732 of 14700 (Contemporary R&b,Rock And Roll,2010s)
# Extracted 733 of 14700 (Contemporary R&b,Aor,2010s)
# Extracted 734 of 14700 (Contemporary R&b,Christian Rock,2010s)
# Extracted 735 of 14700 (Contemporary R&b,Britpop,2010s)
# Extracted 736 of 14700 (Contemporary R&b,New Wave,2010s)
# Extracted 737 of 14700 (Contemporary R&b,Piano Rock,2010s)
# Extracted 738 of 14700 (Contemporary R&b,Heartland Rock,2010s)
# Extracted 739 of 14700 (Contemporary R&b,Soul,2010s)
# Extracted 740 of 14700 (Contemporary R&b,Emo-pop,2010s)
# Extracted 741 of 14700 (Contemporary R&b,Psychedelic Rock,2010s)
# Extracted 742 of 14700 (Contemporary R&b,Worship Music,2010s)
# Extracted 743 of 14700 (Contemporary R&b,Pop Rap,2010s)
# Extracted 744 of 14700 (Contemporary R&b,Psychedelic Pop,2010s)
# Extracted 745 of 14700 (Contemporary R&b,Blue-eyed Soul,2010s)
# Extracted 746 of 14700 (Contemporary R&b,Southern Rock,2010s)
# Extracted 747 of 14700 (Contemporary R&b,Contemporary Christian Music,2010s)
# Extracted 748 of 14700 (Contemporary R&b,Alternative Metal,2010s)
# Extracted 749 of 14700 (Contemporary R&b,Post-hardcore,2010s)
# Extracted 750 of 14700 (Contemporary R&b,Roots Rock,2010s)
# Extracted 751 of 14700 (Contemporary R&b,Heavy Metal,2010s)
# Extracted 752 of 14700 (Contemporary R&b,Neo-psychedelia,2010s)
# Extracted 753 of 14700 (Contemporary R&b,Outlaw Country,2010s)
# Extracted 754 of 14700 (Contemporary R&b,Glam Rock,2010s)
# Extracted 755 of 14700 (Contemporary R&b,Latin Pop,2010s)
# Extracted 756 of 14700 (Contemporary R&b,Skate Punk,2010s)
# Extracted 757 of 14700 (Contemporary R&b,Post-punk,2010s)
# Extracted 758 of 14700 (Contemporary R&b,Vocal Jazz,2010s)
# Extracted 759 of 14700 (Contemporary R&b,Lo-fi Indie,2010s)
# Extracted 760 of 14700 (Contemporary R&b,Progressive Pop,2010s)
# Extracted 761 of 14700 (Contemporary R&b,Indietronica,2010s)
# Extracted 762 of 14700 (Contemporary R&b,Garage Rock Revival,2010s)
# Extracted 763 of 14700 (Contemporary R&b,Dream Pop,2010s)
# Extracted 764 of 14700 (Contemporary R&b,Grunge,2010s)
# Extracted 765 of 14700 (Contemporary R&b,Post-punk Revival,2010s)
# Extracted 766 of 14700 (Contemporary R&b,Nashville Sound,2010s)
# Extracted 767 of 14700 (Contemporary R&b,Jangle Pop,2010s)
# Extracted 768 of 14700 (Contemporary R&b,Power Metal,2010s)
# Extracted 769 of 14700 (Contemporary R&b,Celtic Rock,2010s)
# Extracted 770 of 14700 (Contemporary R&b,Experimental Rock,2010s)
# Extracted 771 of 14700 (Contemporary R&b,Chamber Folk,2010s)
# Extracted 772 of 14700 (Contemporary R&b,Chanson,2010s)
# Extracted 773 of 14700 (Contemporary R&b,Sunshine Pop,2010s)
# Extracted 774 of 14700 (Contemporary R&b,Merseybeat,2010s)
# Extracted 775 of 14700 (Contemporary R&b,Sophisti-pop,2010s)
# Extracted 776 of 14700 (Contemporary R&b,Traditional Pop,2010s)
# Extracted 777 of 14700 (Contemporary R&b,Ska Punk,2010s)
# Extracted 778 of 14700 (Contemporary R&b,Neo Soul,2010s)
# Extracted 779 of 14700 (Contemporary R&b,Alternative R&b,2010s)
# Extracted 780 of 14700 (Contemporary R&b,Rockabilly,2010s)
# Extracted 781 of 14700 (Contemporary R&b,Bluegrass,2010s)
# Extracted 782 of 14700 (Contemporary R&b,Melodic Hardcore,2010s)
# Extracted 783 of 14700 (Contemporary R&b,Garage Rock,2010s)
# Extracted 784 of 14700 (Contemporary R&b,Folk Punk,2010s)
# Extracted 785 of 14700 (Contemporary R&b,Progressive Country,2010s)
# Extracted 786 of 14700 (Contemporary R&b,Psychedelic Folk,2010s)
# Extracted 787 of 14700 (Contemporary R&b,Bro-country,2010s)
# Extracted 788 of 14700 (Contemporary R&b,Yacht Rock,2010s)
# Extracted 789 of 14700 (Contemporary R&b,Pop Reggae,2010s)
# Extracted 790 of 14700 (Contemporary R&b,Alternative Dance,2010s)
# Extracted 791 of 14700 (Contemporary R&b,Progressive Bluegrass,2010s)
# Extracted 792 of 14700 (Contemporary R&b,Ska,2010s)
# Extracted 793 of 14700 (Contemporary R&b,Anti-folk,2010s)
# Extracted 794 of 14700 (Contemporary R&b,Symphonic Metal,2010s)
# Extracted 795 of 14700 (Contemporary R&b,Symphonic Prog,2010s)
# Extracted 796 of 14700 (Contemporary R&b,Rap Rock,2010s)
# Extracted 797 of 14700 (Contemporary R&b,Comedy Rock,2010s)
# Extracted 798 of 14700 (Contemporary R&b,Funk,2010s)
# Extracted 799 of 14700 (Contemporary R&b,Nu Metal,2010s)
# Extracted 800 of 14700 (Contemporary R&b,Celtic Punk,2010s)
# Extracted 801 of 14700 (Religious Music,Pop Rock,2010s)
# Extracted 802 of 14700 (Religious Music,Singer-songwriter,2010s)
# Extracted 803 of 14700 (Religious Music,Alternative Rock,2010s)
# Extracted 804 of 14700 (Religious Music,Indie Rock,2010s)
# Extracted 805 of 14700 (Religious Music,Indie Pop,2010s)
# Extracted 806 of 14700 (Religious Music,Pop Punk,2010s)
# Extracted 807 of 14700 (Religious Music,Hard Rock,2010s)
# Extracted 808 of 14700 (Religious Music,Contemporary Folk,2010s)
# Extracted 809 of 14700 (Religious Music,Folk Rock,2010s)
# Extracted 810 of 14700 (Religious Music,Folk Pop,2010s)
# Extracted 811 of 14700 (Religious Music,Contemporary Country,2010s)
# Extracted 812 of 14700 (Religious Music,Country Pop,2010s)
# Extracted 813 of 14700 (Religious Music,Electropop,2010s)
# Extracted 814 of 14700 (Religious Music,Indie Folk,2010s)
# Extracted 815 of 14700 (Religious Music,Americana,2010s)
# Extracted 816 of 14700 (Religious Music,Punk Rock,2010s)
# Extracted 817 of 14700 (Religious Music,Power Pop,2010s)
# Extracted 818 of 14700 (Religious Music,Country Rock,2010s)
# Extracted 819 of 14700 (Religious Music,Dance-pop,2010s)
# Extracted 820 of 14700 (Religious Music,Blues Rock,2010s)
# Extracted 821 of 14700 (Religious Music,Alternative Country,2010s)
# Extracted 822 of 14700 (Religious Music,Adult Contemporary,2010s)
# Extracted 823 of 14700 (Religious Music,Synthpop,2010s)
# Extracted 824 of 14700 (Religious Music,Pop Soul,2010s)
# Extracted 825 of 14700 (Religious Music,Art Pop,2010s)
# Extracted 826 of 14700 (Religious Music,Art Rock,2010s)
# Extracted 827 of 14700 (Religious Music,Baroque Pop,2010s)
# Extracted 828 of 14700 (Religious Music,Post-grunge,2010s)
# Extracted 829 of 14700 (Religious Music,Teen Pop,2010s)
# Extracted 830 of 14700 (Religious Music,Soft Rock,2010s)
# Extracted 831 of 14700 (Religious Music,Progressive Rock,2010s)
# Extracted 832 of 14700 (Religious Music,Rock And Roll,2010s)
# Extracted 833 of 14700 (Religious Music,Aor,2010s)
# Extracted 834 of 14700 (Religious Music,Christian Rock,2010s)
# Extracted 835 of 14700 (Religious Music,Britpop,2010s)
# Extracted 836 of 14700 (Religious Music,New Wave,2010s)
# Extracted 837 of 14700 (Religious Music,Piano Rock,2010s)
# Extracted 838 of 14700 (Religious Music,Heartland Rock,2010s)
# Extracted 839 of 14700 (Religious Music,Soul,2010s)
# Extracted 840 of 14700 (Religious Music,Emo-pop,2010s)
# Extracted 841 of 14700 (Religious Music,Psychedelic Rock,2010s)
# Extracted 842 of 14700 (Religious Music,Worship Music,2010s)
# Extracted 843 of 14700 (Religious Music,Pop Rap,2010s)
# Extracted 844 of 14700 (Religious Music,Psychedelic Pop,2010s)
# Extracted 845 of 14700 (Religious Music,Blue-eyed Soul,2010s)
# Extracted 846 of 14700 (Religious Music,Southern Rock,2010s)
# Extracted 847 of 14700 (Religious Music,Contemporary Christian Music,2010s)
# Extracted 848 of 14700 (Religious Music,Alternative Metal,2010s)
# Extracted 849 of 14700 (Religious Music,Post-hardcore,2010s)
# Extracted 850 of 14700 (Religious Music,Roots Rock,2010s)
# Extracted 851 of 14700 (Religious Music,Heavy Metal,2010s)
# Extracted 852 of 14700 (Religious Music,Neo-psychedelia,2010s)
# Extracted 853 of 14700 (Religious Music,Outlaw Country,2010s)
# Extracted 854 of 14700 (Religious Music,Glam Rock,2010s)
# Extracted 855 of 14700 (Religious Music,Latin Pop,2010s)
# Extracted 856 of 14700 (Religious Music,Skate Punk,2010s)
# Extracted 857 of 14700 (Religious Music,Post-punk,2010s)
# Extracted 858 of 14700 (Religious Music,Vocal Jazz,2010s)
# Extracted 859 of 14700 (Religious Music,Lo-fi Indie,2010s)
# Extracted 860 of 14700 (Religious Music,Progressive Pop,2010s)
# Extracted 861 of 14700 (Religious Music,Indietronica,2010s)
# Extracted 862 of 14700 (Religious Music,Garage Rock Revival,2010s)
# Extracted 863 of 14700 (Religious Music,Dream Pop,2010s)
# Extracted 864 of 14700 (Religious Music,Grunge,2010s)
# Extracted 865 of 14700 (Religious Music,Post-punk Revival,2010s)
# Extracted 866 of 14700 (Religious Music,Nashville Sound,2010s)
# Extracted 867 of 14700 (Religious Music,Jangle Pop,2010s)
# Extracted 868 of 14700 (Religious Music,Power Metal,2010s)
# Extracted 869 of 14700 (Religious Music,Celtic Rock,2010s)
# Extracted 870 of 14700 (Religious Music,Experimental Rock,2010s)
# Extracted 871 of 14700 (Religious Music,Chamber Folk,2010s)
# Extracted 872 of 14700 (Religious Music,Chanson,2010s)
# Extracted 873 of 14700 (Religious Music,Sunshine Pop,2010s)
# Extracted 874 of 14700 (Religious Music,Merseybeat,2010s)
# Extracted 875 of 14700 (Religious Music,Sophisti-pop,2010s)
# Extracted 876 of 14700 (Religious Music,Traditional Pop,2010s)
# Extracted 877 of 14700 (Religious Music,Ska Punk,2010s)
# Extracted 878 of 14700 (Religious Music,Neo Soul,2010s)
# Extracted 879 of 14700 (Religious Music,Alternative R&b,2010s)
# Extracted 880 of 14700 (Religious Music,Rockabilly,2010s)
# Extracted 881 of 14700 (Religious Music,Bluegrass,2010s)
# Extracted 882 of 14700 (Religious Music,Melodic Hardcore,2010s)
# Extracted 883 of 14700 (Religious Music,Garage Rock,2010s)
# Extracted 884 of 14700 (Religious Music,Folk Punk,2010s)
# Extracted 885 of 14700 (Religious Music,Progressive Country,2010s)
# Extracted 886 of 14700 (Religious Music,Psychedelic Folk,2010s)
# Extracted 887 of 14700 (Religious Music,Bro-country,2010s)
# Extracted 888 of 14700 (Religious Music,Yacht Rock,2010s)
# Extracted 889 of 14700 (Religious Music,Pop Reggae,2010s)
# Extracted 890 of 14700 (Religious Music,Alternative Dance,2010s)
# Extracted 891 of 14700 (Religious Music,Progressive Bluegrass,2010s)
# Extracted 892 of 14700 (Religious Music,Ska,2010s)
# Extracted 893 of 14700 (Religious Music,Anti-folk,2010s)
# Extracted 894 of 14700 (Religious Music,Symphonic Metal,2010s)
# Extracted 895 of 14700 (Religious Music,Symphonic Prog,2010s)
# Extracted 896 of 14700 (Religious Music,Rap Rock,2010s)
# Extracted 897 of 14700 (Religious Music,Comedy Rock,2010s)
# Extracted 898 of 14700 (Religious Music,Funk,2010s)
# Extracted 899 of 14700 (Religious Music,Nu Metal,2010s)
# Extracted 900 of 14700 (Religious Music,Celtic Punk,2010s)
# Extracted 901 of 14700 (Hip Hop,Pop Rock,2010s)
# Extracted 902 of 14700 (Hip Hop,Singer-songwriter,2010s)
# Extracted 903 of 14700 (Hip Hop,Alternative Rock,2010s)
# Extracted 904 of 14700 (Hip Hop,Indie Rock,2010s)
# Extracted 905 of 14700 (Hip Hop,Indie Pop,2010s)
# Extracted 906 of 14700 (Hip Hop,Pop Punk,2010s)
# Extracted 907 of 14700 (Hip Hop,Hard Rock,2010s)
# Extracted 908 of 14700 (Hip Hop,Contemporary Folk,2010s)
# Extracted 909 of 14700 (Hip Hop,Folk Rock,2010s)
# Extracted 910 of 14700 (Hip Hop,Folk Pop,2010s)
# Extracted 911 of 14700 (Hip Hop,Contemporary Country,2010s)
# Extracted 912 of 14700 (Hip Hop,Country Pop,2010s)
# Extracted 913 of 14700 (Hip Hop,Electropop,2010s)
# Extracted 914 of 14700 (Hip Hop,Indie Folk,2010s)
# Extracted 915 of 14700 (Hip Hop,Americana,2010s)
# Extracted 916 of 14700 (Hip Hop,Punk Rock,2010s)
# Extracted 917 of 14700 (Hip Hop,Power Pop,2010s)
# Extracted 918 of 14700 (Hip Hop,Country Rock,2010s)
# Extracted 919 of 14700 (Hip Hop,Dance-pop,2010s)
# Extracted 920 of 14700 (Hip Hop,Blues Rock,2010s)
# Extracted 921 of 14700 (Hip Hop,Alternative Country,2010s)
# Extracted 922 of 14700 (Hip Hop,Adult Contemporary,2010s)
# Extracted 923 of 14700 (Hip Hop,Synthpop,2010s)
# Extracted 924 of 14700 (Hip Hop,Pop Soul,2010s)
# Extracted 925 of 14700 (Hip Hop,Art Pop,2010s)
# Extracted 926 of 14700 (Hip Hop,Art Rock,2010s)
# Extracted 927 of 14700 (Hip Hop,Baroque Pop,2010s)
# Extracted 928 of 14700 (Hip Hop,Post-grunge,2010s)
# Extracted 929 of 14700 (Hip Hop,Teen Pop,2010s)
# Extracted 930 of 14700 (Hip Hop,Soft Rock,2010s)
# Extracted 931 of 14700 (Hip Hop,Progressive Rock,2010s)
# Extracted 932 of 14700 (Hip Hop,Rock And Roll,2010s)
# Extracted 933 of 14700 (Hip Hop,Aor,2010s)
# Extracted 934 of 14700 (Hip Hop,Christian Rock,2010s)
# Extracted 935 of 14700 (Hip Hop,Britpop,2010s)
# Extracted 936 of 14700 (Hip Hop,New Wave,2010s)
# Extracted 937 of 14700 (Hip Hop,Piano Rock,2010s)
# Extracted 938 of 14700 (Hip Hop,Heartland Rock,2010s)
# Extracted 939 of 14700 (Hip Hop,Soul,2010s)
# Extracted 940 of 14700 (Hip Hop,Emo-pop,2010s)
# Extracted 941 of 14700 (Hip Hop,Psychedelic Rock,2010s)
# Extracted 942 of 14700 (Hip Hop,Worship Music,2010s)
# Extracted 943 of 14700 (Hip Hop,Pop Rap,2010s)
# Extracted 944 of 14700 (Hip Hop,Psychedelic Pop,2010s)
# Extracted 945 of 14700 (Hip Hop,Blue-eyed Soul,2010s)
# Extracted 946 of 14700 (Hip Hop,Southern Rock,2010s)
# Extracted 947 of 14700 (Hip Hop,Contemporary Christian Music,2010s)
# Extracted 948 of 14700 (Hip Hop,Alternative Metal,2010s)
# Extracted 949 of 14700 (Hip Hop,Post-hardcore,2010s)
# Extracted 950 of 14700 (Hip Hop,Roots Rock,2010s)
# Extracted 951 of 14700 (Hip Hop,Heavy Metal,2010s)
# Extracted 952 of 14700 (Hip Hop,Neo-psychedelia,2010s)
# Extracted 953 of 14700 (Hip Hop,Outlaw Country,2010s)
# Extracted 954 of 14700 (Hip Hop,Glam Rock,2010s)
# Extracted 955 of 14700 (Hip Hop,Latin Pop,2010s)
# Extracted 956 of 14700 (Hip Hop,Skate Punk,2010s)
# Extracted 957 of 14700 (Hip Hop,Post-punk,2010s)
# Extracted 958 of 14700 (Hip Hop,Vocal Jazz,2010s)
# Extracted 959 of 14700 (Hip Hop,Lo-fi Indie,2010s)
# Extracted 960 of 14700 (Hip Hop,Progressive Pop,2010s)
# Extracted 961 of 14700 (Hip Hop,Indietronica,2010s)
# Extracted 962 of 14700 (Hip Hop,Garage Rock Revival,2010s)
# Extracted 963 of 14700 (Hip Hop,Dream Pop,2010s)
# Extracted 964 of 14700 (Hip Hop,Grunge,2010s)
# Extracted 965 of 14700 (Hip Hop,Post-punk Revival,2010s)
# Extracted 966 of 14700 (Hip Hop,Nashville Sound,2010s)
# Extracted 967 of 14700 (Hip Hop,Jangle Pop,2010s)
# Extracted 968 of 14700 (Hip Hop,Power Metal,2010s)
# Extracted 969 of 14700 (Hip Hop,Celtic Rock,2010s)
# Extracted 970 of 14700 (Hip Hop,Experimental Rock,2010s)
# Extracted 971 of 14700 (Hip Hop,Chamber Folk,2010s)
# Extracted 972 of 14700 (Hip Hop,Chanson,2010s)
# Extracted 973 of 14700 (Hip Hop,Sunshine Pop,2010s)
# Extracted 974 of 14700 (Hip Hop,Merseybeat,2010s)
# Extracted 975 of 14700 (Hip Hop,Sophisti-pop,2010s)
# Extracted 976 of 14700 (Hip Hop,Traditional Pop,2010s)
# Extracted 977 of 14700 (Hip Hop,Ska Punk,2010s)
# Extracted 978 of 14700 (Hip Hop,Neo Soul,2010s)
# Extracted 979 of 14700 (Hip Hop,Alternative R&b,2010s)
# Extracted 980 of 14700 (Hip Hop,Rockabilly,2010s)
# Extracted 981 of 14700 (Hip Hop,Bluegrass,2010s)
# Extracted 982 of 14700 (Hip Hop,Melodic Hardcore,2010s)
# Extracted 983 of 14700 (Hip Hop,Garage Rock,2010s)
# Extracted 984 of 14700 (Hip Hop,Folk Punk,2010s)
# Extracted 985 of 14700 (Hip Hop,Progressive Country,2010s)
# Extracted 986 of 14700 (Hip Hop,Psychedelic Folk,2010s)
# Extracted 987 of 14700 (Hip Hop,Bro-country,2010s)
# Extracted 988 of 14700 (Hip Hop,Yacht Rock,2010s)
# Extracted 989 of 14700 (Hip Hop,Pop Reggae,2010s)
# Extracted 990 of 14700 (Hip Hop,Alternative Dance,2010s)
# Extracted 991 of 14700 (Hip Hop,Progressive Bluegrass,2010s)
# Extracted 992 of 14700 (Hip Hop,Ska,2010s)
# Extracted 993 of 14700 (Hip Hop,Anti-folk,2010s)
# Extracted 994 of 14700 (Hip Hop,Symphonic Metal,2010s)
# Extracted 995 of 14700 (Hip Hop,Symphonic Prog,2010s)
# Extracted 996 of 14700 (Hip Hop,Rap Rock,2010s)
# Extracted 997 of 14700 (Hip Hop,Comedy Rock,2010s)
# Extracted 998 of 14700 (Hip Hop,Funk,2010s)
# Extracted 999 of 14700 (Hip Hop,Nu Metal,2010s)
# Extracted 1000 of 14700 (Hip Hop,Celtic Punk,2010s)
# Extracted 1001 of 14700 (Reggae,Pop Rock,2010s)
# Extracted 1002 of 14700 (Reggae,Singer-songwriter,2010s)
# Extracted 1003 of 14700 (Reggae,Alternative Rock,2010s)
# Extracted 1004 of 14700 (Reggae,Indie Rock,2010s)
# Extracted 1005 of 14700 (Reggae,Indie Pop,2010s)
# Extracted 1006 of 14700 (Reggae,Pop Punk,2010s)
# Extracted 1007 of 14700 (Reggae,Hard Rock,2010s)
# Extracted 1008 of 14700 (Reggae,Contemporary Folk,2010s)
# Extracted 1009 of 14700 (Reggae,Folk Rock,2010s)
# Extracted 1010 of 14700 (Reggae,Folk Pop,2010s)
# Extracted 1011 of 14700 (Reggae,Contemporary Country,2010s)
# Extracted 1012 of 14700 (Reggae,Country Pop,2010s)
# Extracted 1013 of 14700 (Reggae,Electropop,2010s)
# Extracted 1014 of 14700 (Reggae,Indie Folk,2010s)
# Extracted 1015 of 14700 (Reggae,Americana,2010s)
# Extracted 1016 of 14700 (Reggae,Punk Rock,2010s)
# Extracted 1017 of 14700 (Reggae,Power Pop,2010s)
# Extracted 1018 of 14700 (Reggae,Country Rock,2010s)
# Extracted 1019 of 14700 (Reggae,Dance-pop,2010s)
# Extracted 1020 of 14700 (Reggae,Blues Rock,2010s)
# Extracted 1021 of 14700 (Reggae,Alternative Country,2010s)
# Extracted 1022 of 14700 (Reggae,Adult Contemporary,2010s)
# Extracted 1023 of 14700 (Reggae,Synthpop,2010s)
# Extracted 1024 of 14700 (Reggae,Pop Soul,2010s)
# Extracted 1025 of 14700 (Reggae,Art Pop,2010s)
# Extracted 1026 of 14700 (Reggae,Art Rock,2010s)
# Extracted 1027 of 14700 (Reggae,Baroque Pop,2010s)
# Extracted 1028 of 14700 (Reggae,Post-grunge,2010s)
# Extracted 1029 of 14700 (Reggae,Teen Pop,2010s)
# Extracted 1030 of 14700 (Reggae,Soft Rock,2010s)
# Extracted 1031 of 14700 (Reggae,Progressive Rock,2010s)
# Extracted 1032 of 14700 (Reggae,Rock And Roll,2010s)
# Extracted 1033 of 14700 (Reggae,Aor,2010s)
# Extracted 1034 of 14700 (Reggae,Christian Rock,2010s)
# Extracted 1035 of 14700 (Reggae,Britpop,2010s)
# Extracted 1036 of 14700 (Reggae,New Wave,2010s)
# Extracted 1037 of 14700 (Reggae,Piano Rock,2010s)
# Extracted 1038 of 14700 (Reggae,Heartland Rock,2010s)
# Extracted 1039 of 14700 (Reggae,Soul,2010s)
# Extracted 1040 of 14700 (Reggae,Emo-pop,2010s)
# Extracted 1041 of 14700 (Reggae,Psychedelic Rock,2010s)
# Extracted 1042 of 14700 (Reggae,Worship Music,2010s)
# Extracted 1043 of 14700 (Reggae,Pop Rap,2010s)
# Extracted 1044 of 14700 (Reggae,Psychedelic Pop,2010s)
# Extracted 1045 of 14700 (Reggae,Blue-eyed Soul,2010s)
# Extracted 1046 of 14700 (Reggae,Southern Rock,2010s)
# Extracted 1047 of 14700 (Reggae,Contemporary Christian Music,2010s)
# Extracted 1048 of 14700 (Reggae,Alternative Metal,2010s)
# Extracted 1049 of 14700 (Reggae,Post-hardcore,2010s)
# Extracted 1050 of 14700 (Reggae,Roots Rock,2010s)
# Extracted 1051 of 14700 (Reggae,Heavy Metal,2010s)
# Extracted 1052 of 14700 (Reggae,Neo-psychedelia,2010s)
# Extracted 1053 of 14700 (Reggae,Outlaw Country,2010s)
# Extracted 1054 of 14700 (Reggae,Glam Rock,2010s)
# Extracted 1055 of 14700 (Reggae,Latin Pop,2010s)
# Extracted 1056 of 14700 (Reggae,Skate Punk,2010s)
# Extracted 1057 of 14700 (Reggae,Post-punk,2010s)
# Extracted 1058 of 14700 (Reggae,Vocal Jazz,2010s)
# Extracted 1059 of 14700 (Reggae,Lo-fi Indie,2010s)
# Extracted 1060 of 14700 (Reggae,Progressive Pop,2010s)
# Extracted 1061 of 14700 (Reggae,Indietronica,2010s)
# Extracted 1062 of 14700 (Reggae,Garage Rock Revival,2010s)
# Extracted 1063 of 14700 (Reggae,Dream Pop,2010s)
# Extracted 1064 of 14700 (Reggae,Grunge,2010s)
# Extracted 1065 of 14700 (Reggae,Post-punk Revival,2010s)
# Extracted 1066 of 14700 (Reggae,Nashville Sound,2010s)
# Extracted 1067 of 14700 (Reggae,Jangle Pop,2010s)
# Extracted 1068 of 14700 (Reggae,Power Metal,2010s)
# Extracted 1069 of 14700 (Reggae,Celtic Rock,2010s)
# Extracted 1070 of 14700 (Reggae,Experimental Rock,2010s)
# Extracted 1071 of 14700 (Reggae,Chamber Folk,2010s)
# Extracted 1072 of 14700 (Reggae,Chanson,2010s)
# Extracted 1073 of 14700 (Reggae,Sunshine Pop,2010s)
# Extracted 1074 of 14700 (Reggae,Merseybeat,2010s)
# Extracted 1075 of 14700 (Reggae,Sophisti-pop,2010s)
# Extracted 1076 of 14700 (Reggae,Traditional Pop,2010s)
# Extracted 1077 of 14700 (Reggae,Ska Punk,2010s)
# Extracted 1078 of 14700 (Reggae,Neo Soul,2010s)
# Extracted 1079 of 14700 (Reggae,Alternative R&b,2010s)
# Extracted 1080 of 14700 (Reggae,Rockabilly,2010s)
# Extracted 1081 of 14700 (Reggae,Bluegrass,2010s)
# Extracted 1082 of 14700 (Reggae,Melodic Hardcore,2010s)
# Extracted 1083 of 14700 (Reggae,Garage Rock,2010s)
# Extracted 1084 of 14700 (Reggae,Folk Punk,2010s)
# Extracted 1085 of 14700 (Reggae,Progressive Country,2010s)
# Extracted 1086 of 14700 (Reggae,Psychedelic Folk,2010s)
# Extracted 1087 of 14700 (Reggae,Bro-country,2010s)
# Extracted 1088 of 14700 (Reggae,Yacht Rock,2010s)
# Extracted 1089 of 14700 (Reggae,Pop Reggae,2010s)
# Extracted 1090 of 14700 (Reggae,Alternative Dance,2010s)
# Extracted 1091 of 14700 (Reggae,Progressive Bluegrass,2010s)
# Extracted 1092 of 14700 (Reggae,Ska,2010s)
# Extracted 1093 of 14700 (Reggae,Anti-folk,2010s)
# Extracted 1094 of 14700 (Reggae,Symphonic Metal,2010s)
# Extracted 1095 of 14700 (Reggae,Symphonic Prog,2010s)
# Extracted 1096 of 14700 (Reggae,Rap Rock,2010s)
# Extracted 1097 of 14700 (Reggae,Comedy Rock,2010s)
# Extracted 1098 of 14700 (Reggae,Funk,2010s)
# Extracted 1099 of 14700 (Reggae,Nu Metal,2010s)
# Extracted 1100 of 14700 (Reggae,Celtic Punk,2010s)
# Extracted 1101 of 14700 (Jazz,Pop Rock,2010s)
# Extracted 1102 of 14700 (Jazz,Singer-songwriter,2010s)
# Extracted 1103 of 14700 (Jazz,Alternative Rock,2010s)
# Extracted 1104 of 14700 (Jazz,Indie Rock,2010s)
# Extracted 1105 of 14700 (Jazz,Indie Pop,2010s)
# Extracted 1106 of 14700 (Jazz,Pop Punk,2010s)
# Extracted 1107 of 14700 (Jazz,Hard Rock,2010s)
# Extracted 1108 of 14700 (Jazz,Contemporary Folk,2010s)
# Extracted 1109 of 14700 (Jazz,Folk Rock,2010s)
# Extracted 1110 of 14700 (Jazz,Folk Pop,2010s)
# Extracted 1111 of 14700 (Jazz,Contemporary Country,2010s)
# Extracted 1112 of 14700 (Jazz,Country Pop,2010s)
# Extracted 1113 of 14700 (Jazz,Electropop,2010s)
# Extracted 1114 of 14700 (Jazz,Indie Folk,2010s)
# Extracted 1115 of 14700 (Jazz,Americana,2010s)
# Extracted 1116 of 14700 (Jazz,Punk Rock,2010s)
# Extracted 1117 of 14700 (Jazz,Power Pop,2010s)
# Extracted 1118 of 14700 (Jazz,Country Rock,2010s)
# Extracted 1119 of 14700 (Jazz,Dance-pop,2010s)
# Extracted 1120 of 14700 (Jazz,Blues Rock,2010s)
# Extracted 1121 of 14700 (Jazz,Alternative Country,2010s)
# Extracted 1122 of 14700 (Jazz,Adult Contemporary,2010s)
# Extracted 1123 of 14700 (Jazz,Synthpop,2010s)
# Extracted 1124 of 14700 (Jazz,Pop Soul,2010s)
# Extracted 1125 of 14700 (Jazz,Art Pop,2010s)
# Extracted 1126 of 14700 (Jazz,Art Rock,2010s)
# Extracted 1127 of 14700 (Jazz,Baroque Pop,2010s)
# Extracted 1128 of 14700 (Jazz,Post-grunge,2010s)
# Extracted 1129 of 14700 (Jazz,Teen Pop,2010s)
# Extracted 1130 of 14700 (Jazz,Soft Rock,2010s)
# Extracted 1131 of 14700 (Jazz,Progressive Rock,2010s)
# Extracted 1132 of 14700 (Jazz,Rock And Roll,2010s)
# Extracted 1133 of 14700 (Jazz,Aor,2010s)
# Extracted 1134 of 14700 (Jazz,Christian Rock,2010s)
# Extracted 1135 of 14700 (Jazz,Britpop,2010s)
# Extracted 1136 of 14700 (Jazz,New Wave,2010s)
# Extracted 1137 of 14700 (Jazz,Piano Rock,2010s)
# Error in (Jazz,Heartland Rock,2010s)
# Message: disconnected: Unable to receive message from renderer
#   (Session info: headless chrome=78.0.3904.108)

# %%
len(all_songs)
# Out:
# 26793

# %%
all_songs[len(all_songs)-1]
# Out:
# {'name': 'The Safest Place',
#  'url': 'https://tabs.ultimate-guitar.com/tab/sade/the_safest_place_chords_967079',
#  'genre': 'Rhythm And Blues',
#  'style': 'Sophisti-pop',
#  'decade': '2010s'}

# %%
all_combination_extractor = AllCombinationsSongExtractor(ImprovedSongExtractor)
all_songs_2 = all_combination_extractor.extract_from(1138)
# Out:
# cookies banner not found. Ignored
# Extracted 1138 of 14700 (Jazz,Heartland Rock,2010s)
# Extracted 1139 of 14700 (Jazz,Soul,2010s)
# Extracted 1140 of 14700 (Jazz,Emo-pop,2010s)
# Extracted 1141 of 14700 (Jazz,Psychedelic Rock,2010s)
# Extracted 1142 of 14700 (Jazz,Worship Music,2010s)
# Extracted 1143 of 14700 (Jazz,Pop Rap,2010s)
# Extracted 1144 of 14700 (Jazz,Psychedelic Pop,2010s)
# Extracted 1145 of 14700 (Jazz,Blue-eyed Soul,2010s)
# Extracted 1146 of 14700 (Jazz,Southern Rock,2010s)
# Extracted 1147 of 14700 (Jazz,Contemporary Christian Music,2010s)
# Extracted 1148 of 14700 (Jazz,Alternative Metal,2010s)
# Extracted 1149 of 14700 (Jazz,Post-hardcore,2010s)
# Extracted 1150 of 14700 (Jazz,Roots Rock,2010s)
# Extracted 1151 of 14700 (Jazz,Heavy Metal,2010s)
# Extracted 1152 of 14700 (Jazz,Neo-psychedelia,2010s)
# Extracted 1153 of 14700 (Jazz,Outlaw Country,2010s)
# Extracted 1154 of 14700 (Jazz,Glam Rock,2010s)
# Extracted 1155 of 14700 (Jazz,Latin Pop,2010s)
# Extracted 1156 of 14700 (Jazz,Skate Punk,2010s)
# Extracted 1157 of 14700 (Jazz,Post-punk,2010s)
# Extracted 1158 of 14700 (Jazz,Vocal Jazz,2010s)
# Extracted 1159 of 14700 (Jazz,Lo-fi Indie,2010s)
# Extracted 1160 of 14700 (Jazz,Progressive Pop,2010s)
# Extracted 1161 of 14700 (Jazz,Indietronica,2010s)
# Extracted 1162 of 14700 (Jazz,Garage Rock Revival,2010s)
# Extracted 1163 of 14700 (Jazz,Dream Pop,2010s)
# Extracted 1164 of 14700 (Jazz,Grunge,2010s)
# Extracted 1165 of 14700 (Jazz,Post-punk Revival,2010s)
# Extracted 1166 of 14700 (Jazz,Nashville Sound,2010s)
# Extracted 1167 of 14700 (Jazz,Jangle Pop,2010s)
# Extracted 1168 of 14700 (Jazz,Power Metal,2010s)
# Extracted 1169 of 14700 (Jazz,Celtic Rock,2010s)
# Extracted 1170 of 14700 (Jazz,Experimental Rock,2010s)
# Extracted 1171 of 14700 (Jazz,Chamber Folk,2010s)
# Extracted 1172 of 14700 (Jazz,Chanson,2010s)
# Extracted 1173 of 14700 (Jazz,Sunshine Pop,2010s)
# Extracted 1174 of 14700 (Jazz,Merseybeat,2010s)
# Extracted 1175 of 14700 (Jazz,Sophisti-pop,2010s)
# Extracted 1176 of 14700 (Jazz,Traditional Pop,2010s)
# Extracted 1177 of 14700 (Jazz,Ska Punk,2010s)
# Extracted 1178 of 14700 (Jazz,Neo Soul,2010s)
# Extracted 1179 of 14700 (Jazz,Alternative R&b,2010s)
# Extracted 1180 of 14700 (Jazz,Rockabilly,2010s)
# Extracted 1181 of 14700 (Jazz,Bluegrass,2010s)
# Extracted 1182 of 14700 (Jazz,Melodic Hardcore,2010s)
# Extracted 1183 of 14700 (Jazz,Garage Rock,2010s)
# Extracted 1184 of 14700 (Jazz,Folk Punk,2010s)
# Extracted 1185 of 14700 (Jazz,Progressive Country,2010s)
# Extracted 1186 of 14700 (Jazz,Psychedelic Folk,2010s)
# Extracted 1187 of 14700 (Jazz,Bro-country,2010s)
# Extracted 1188 of 14700 (Jazz,Yacht Rock,2010s)
# Extracted 1189 of 14700 (Jazz,Pop Reggae,2010s)
# Extracted 1190 of 14700 (Jazz,Alternative Dance,2010s)
# Extracted 1191 of 14700 (Jazz,Progressive Bluegrass,2010s)
# Extracted 1192 of 14700 (Jazz,Ska,2010s)
# Extracted 1193 of 14700 (Jazz,Anti-folk,2010s)
# Extracted 1194 of 14700 (Jazz,Symphonic Metal,2010s)
# Extracted 1195 of 14700 (Jazz,Symphonic Prog,2010s)
# Extracted 1196 of 14700 (Jazz,Rap Rock,2010s)
# Extracted 1197 of 14700 (Jazz,Comedy Rock,2010s)
# Extracted 1198 of 14700 (Jazz,Funk,2010s)
# Extracted 1199 of 14700 (Jazz,Nu Metal,2010s)
# Extracted 1200 of 14700 (Jazz,Celtic Punk,2010s)
# Extracted 1201 of 14700 (Blues,Pop Rock,2010s)
# Extracted 1202 of 14700 (Blues,Singer-songwriter,2010s)
# Extracted 1203 of 14700 (Blues,Alternative Rock,2010s)
# Extracted 1204 of 14700 (Blues,Indie Rock,2010s)
# Extracted 1205 of 14700 (Blues,Indie Pop,2010s)
# Extracted 1206 of 14700 (Blues,Pop Punk,2010s)
# Extracted 1207 of 14700 (Blues,Hard Rock,2010s)
# Extracted 1208 of 14700 (Blues,Contemporary Folk,2010s)
# Extracted 1209 of 14700 (Blues,Folk Rock,2010s)
# Extracted 1210 of 14700 (Blues,Folk Pop,2010s)
# Extracted 1211 of 14700 (Blues,Contemporary Country,2010s)
# Extracted 1212 of 14700 (Blues,Country Pop,2010s)
# Extracted 1213 of 14700 (Blues,Electropop,2010s)
# Extracted 1214 of 14700 (Blues,Indie Folk,2010s)
# Extracted 1215 of 14700 (Blues,Americana,2010s)
# Extracted 1216 of 14700 (Blues,Punk Rock,2010s)
# Extracted 1217 of 14700 (Blues,Power Pop,2010s)
# Extracted 1218 of 14700 (Blues,Country Rock,2010s)
# Extracted 1219 of 14700 (Blues,Dance-pop,2010s)
# Extracted 1220 of 14700 (Blues,Blues Rock,2010s)
# Extracted 1221 of 14700 (Blues,Alternative Country,2010s)
# Extracted 1222 of 14700 (Blues,Adult Contemporary,2010s)
# Extracted 1223 of 14700 (Blues,Synthpop,2010s)
# Extracted 1224 of 14700 (Blues,Pop Soul,2010s)
# Extracted 1225 of 14700 (Blues,Art Pop,2010s)
# Extracted 1226 of 14700 (Blues,Art Rock,2010s)
# Extracted 1227 of 14700 (Blues,Baroque Pop,2010s)
# Extracted 1228 of 14700 (Blues,Post-grunge,2010s)
# Extracted 1229 of 14700 (Blues,Teen Pop,2010s)
# Extracted 1230 of 14700 (Blues,Soft Rock,2010s)
# Extracted 1231 of 14700 (Blues,Progressive Rock,2010s)
# Extracted 1232 of 14700 (Blues,Rock And Roll,2010s)
# Extracted 1233 of 14700 (Blues,Aor,2010s)
# Extracted 1234 of 14700 (Blues,Christian Rock,2010s)
# Extracted 1235 of 14700 (Blues,Britpop,2010s)
# Extracted 1236 of 14700 (Blues,New Wave,2010s)
# Extracted 1237 of 14700 (Blues,Piano Rock,2010s)
# Extracted 1238 of 14700 (Blues,Heartland Rock,2010s)
# Extracted 1239 of 14700 (Blues,Soul,2010s)
# Extracted 1240 of 14700 (Blues,Emo-pop,2010s)
# Extracted 1241 of 14700 (Blues,Psychedelic Rock,2010s)
# Extracted 1242 of 14700 (Blues,Worship Music,2010s)
# Extracted 1243 of 14700 (Blues,Pop Rap,2010s)
# Extracted 1244 of 14700 (Blues,Psychedelic Pop,2010s)
# Extracted 1245 of 14700 (Blues,Blue-eyed Soul,2010s)
# Extracted 1246 of 14700 (Blues,Southern Rock,2010s)
# Extracted 1247 of 14700 (Blues,Contemporary Christian Music,2010s)
# Extracted 1248 of 14700 (Blues,Alternative Metal,2010s)
# Extracted 1249 of 14700 (Blues,Post-hardcore,2010s)
# Extracted 1250 of 14700 (Blues,Roots Rock,2010s)
# Extracted 1251 of 14700 (Blues,Heavy Metal,2010s)
# Extracted 1252 of 14700 (Blues,Neo-psychedelia,2010s)
# Extracted 1253 of 14700 (Blues,Outlaw Country,2010s)
# Extracted 1254 of 14700 (Blues,Glam Rock,2010s)
# Extracted 1255 of 14700 (Blues,Latin Pop,2010s)
# Extracted 1256 of 14700 (Blues,Skate Punk,2010s)
# Extracted 1257 of 14700 (Blues,Post-punk,2010s)
# Extracted 1258 of 14700 (Blues,Vocal Jazz,2010s)
# Extracted 1259 of 14700 (Blues,Lo-fi Indie,2010s)
# Extracted 1260 of 14700 (Blues,Progressive Pop,2010s)
# Extracted 1261 of 14700 (Blues,Indietronica,2010s)
# Extracted 1262 of 14700 (Blues,Garage Rock Revival,2010s)
# Extracted 1263 of 14700 (Blues,Dream Pop,2010s)
# Extracted 1264 of 14700 (Blues,Grunge,2010s)
# Extracted 1265 of 14700 (Blues,Post-punk Revival,2010s)
# Extracted 1266 of 14700 (Blues,Nashville Sound,2010s)
# Extracted 1267 of 14700 (Blues,Jangle Pop,2010s)
# Extracted 1268 of 14700 (Blues,Power Metal,2010s)
# Extracted 1269 of 14700 (Blues,Celtic Rock,2010s)
# Extracted 1270 of 14700 (Blues,Experimental Rock,2010s)
# Extracted 1271 of 14700 (Blues,Chamber Folk,2010s)
# Extracted 1272 of 14700 (Blues,Chanson,2010s)
# Extracted 1273 of 14700 (Blues,Sunshine Pop,2010s)
# Extracted 1274 of 14700 (Blues,Merseybeat,2010s)
# Extracted 1275 of 14700 (Blues,Sophisti-pop,2010s)
# Extracted 1276 of 14700 (Blues,Traditional Pop,2010s)
# Extracted 1277 of 14700 (Blues,Ska Punk,2010s)
# Extracted 1278 of 14700 (Blues,Neo Soul,2010s)
# Extracted 1279 of 14700 (Blues,Alternative R&b,2010s)
# Extracted 1280 of 14700 (Blues,Rockabilly,2010s)
# Extracted 1281 of 14700 (Blues,Bluegrass,2010s)
# Extracted 1282 of 14700 (Blues,Melodic Hardcore,2010s)
# Extracted 1283 of 14700 (Blues,Garage Rock,2010s)
# Extracted 1284 of 14700 (Blues,Folk Punk,2010s)
# Extracted 1285 of 14700 (Blues,Progressive Country,2010s)
# Extracted 1286 of 14700 (Blues,Psychedelic Folk,2010s)
# Extracted 1287 of 14700 (Blues,Bro-country,2010s)
# Extracted 1288 of 14700 (Blues,Yacht Rock,2010s)
# Extracted 1289 of 14700 (Blues,Pop Reggae,2010s)
# Extracted 1290 of 14700 (Blues,Alternative Dance,2010s)
# Extracted 1291 of 14700 (Blues,Progressive Bluegrass,2010s)
# Extracted 1292 of 14700 (Blues,Ska,2010s)
# Extracted 1293 of 14700 (Blues,Anti-folk,2010s)
# Extracted 1294 of 14700 (Blues,Symphonic Metal,2010s)
# Extracted 1295 of 14700 (Blues,Symphonic Prog,2010s)
# Extracted 1296 of 14700 (Blues,Rap Rock,2010s)
# Extracted 1297 of 14700 (Blues,Comedy Rock,2010s)
# Extracted 1298 of 14700 (Blues,Funk,2010s)
# Extracted 1299 of 14700 (Blues,Nu Metal,2010s)
# Extracted 1300 of 14700 (Blues,Celtic Punk,2010s)
# Extracted 1301 of 14700 (World Music,Pop Rock,2010s)
# Extracted 1302 of 14700 (World Music,Singer-songwriter,2010s)
# Extracted 1303 of 14700 (World Music,Alternative Rock,2010s)
# Extracted 1304 of 14700 (World Music,Indie Rock,2010s)
# Extracted 1305 of 14700 (World Music,Indie Pop,2010s)
# Extracted 1306 of 14700 (World Music,Pop Punk,2010s)
# Extracted 1307 of 14700 (World Music,Hard Rock,2010s)
# Extracted 1308 of 14700 (World Music,Contemporary Folk,2010s)
# Extracted 1309 of 14700 (World Music,Folk Rock,2010s)
# Extracted 1310 of 14700 (World Music,Folk Pop,2010s)
# Extracted 1311 of 14700 (World Music,Contemporary Country,2010s)
# Extracted 1312 of 14700 (World Music,Country Pop,2010s)
# Extracted 1313 of 14700 (World Music,Electropop,2010s)
# Extracted 1314 of 14700 (World Music,Indie Folk,2010s)
# Extracted 1315 of 14700 (World Music,Americana,2010s)
# Extracted 1316 of 14700 (World Music,Punk Rock,2010s)
# Extracted 1317 of 14700 (World Music,Power Pop,2010s)
# Extracted 1318 of 14700 (World Music,Country Rock,2010s)
# Extracted 1319 of 14700 (World Music,Dance-pop,2010s)
# Extracted 1320 of 14700 (World Music,Blues Rock,2010s)
# Extracted 1321 of 14700 (World Music,Alternative Country,2010s)
# Extracted 1322 of 14700 (World Music,Adult Contemporary,2010s)
# Extracted 1323 of 14700 (World Music,Synthpop,2010s)
# Extracted 1324 of 14700 (World Music,Pop Soul,2010s)
# Extracted 1325 of 14700 (World Music,Art Pop,2010s)
# Extracted 1326 of 14700 (World Music,Art Rock,2010s)
# Extracted 1327 of 14700 (World Music,Baroque Pop,2010s)
# Extracted 1328 of 14700 (World Music,Post-grunge,2010s)
# Extracted 1329 of 14700 (World Music,Teen Pop,2010s)
# Extracted 1330 of 14700 (World Music,Soft Rock,2010s)
# Extracted 1331 of 14700 (World Music,Progressive Rock,2010s)
# Extracted 1332 of 14700 (World Music,Rock And Roll,2010s)
# Extracted 1333 of 14700 (World Music,Aor,2010s)
# Extracted 1334 of 14700 (World Music,Christian Rock,2010s)
# Extracted 1335 of 14700 (World Music,Britpop,2010s)
# Extracted 1336 of 14700 (World Music,New Wave,2010s)
# Extracted 1337 of 14700 (World Music,Piano Rock,2010s)
# Extracted 1338 of 14700 (World Music,Heartland Rock,2010s)
# Extracted 1339 of 14700 (World Music,Soul,2010s)
# Extracted 1340 of 14700 (World Music,Emo-pop,2010s)
# Extracted 1341 of 14700 (World Music,Psychedelic Rock,2010s)
# Extracted 1342 of 14700 (World Music,Worship Music,2010s)
# Extracted 1343 of 14700 (World Music,Pop Rap,2010s)
# Extracted 1344 of 14700 (World Music,Psychedelic Pop,2010s)
# Extracted 1345 of 14700 (World Music,Blue-eyed Soul,2010s)
# Extracted 1346 of 14700 (World Music,Southern Rock,2010s)
# Extracted 1347 of 14700 (World Music,Contemporary Christian Music,2010s)
# Extracted 1348 of 14700 (World Music,Alternative Metal,2010s)
# Extracted 1349 of 14700 (World Music,Post-hardcore,2010s)
# Extracted 1350 of 14700 (World Music,Roots Rock,2010s)
# Extracted 1351 of 14700 (World Music,Heavy Metal,2010s)
# Extracted 1352 of 14700 (World Music,Neo-psychedelia,2010s)
# Extracted 1353 of 14700 (World Music,Outlaw Country,2010s)
# Extracted 1354 of 14700 (World Music,Glam Rock,2010s)
# Extracted 1355 of 14700 (World Music,Latin Pop,2010s)
# Extracted 1356 of 14700 (World Music,Skate Punk,2010s)
# Extracted 1357 of 14700 (World Music,Post-punk,2010s)
# Extracted 1358 of 14700 (World Music,Vocal Jazz,2010s)
# Extracted 1359 of 14700 (World Music,Lo-fi Indie,2010s)
# Extracted 1360 of 14700 (World Music,Progressive Pop,2010s)
# Extracted 1361 of 14700 (World Music,Indietronica,2010s)
# Extracted 1362 of 14700 (World Music,Garage Rock Revival,2010s)
# Extracted 1363 of 14700 (World Music,Dream Pop,2010s)
# Extracted 1364 of 14700 (World Music,Grunge,2010s)
# Extracted 1365 of 14700 (World Music,Post-punk Revival,2010s)
# Extracted 1366 of 14700 (World Music,Nashville Sound,2010s)
# Extracted 1367 of 14700 (World Music,Jangle Pop,2010s)
# Extracted 1368 of 14700 (World Music,Power Metal,2010s)
# Extracted 1369 of 14700 (World Music,Celtic Rock,2010s)
# Extracted 1370 of 14700 (World Music,Experimental Rock,2010s)
# Extracted 1371 of 14700 (World Music,Chamber Folk,2010s)
# Extracted 1372 of 14700 (World Music,Chanson,2010s)
# Extracted 1373 of 14700 (World Music,Sunshine Pop,2010s)
# Extracted 1374 of 14700 (World Music,Merseybeat,2010s)
# Extracted 1375 of 14700 (World Music,Sophisti-pop,2010s)
# Extracted 1376 of 14700 (World Music,Traditional Pop,2010s)
# Extracted 1377 of 14700 (World Music,Ska Punk,2010s)
# Extracted 1378 of 14700 (World Music,Neo Soul,2010s)
# Extracted 1379 of 14700 (World Music,Alternative R&b,2010s)
# Extracted 1380 of 14700 (World Music,Rockabilly,2010s)
# Extracted 1381 of 14700 (World Music,Bluegrass,2010s)
# Extracted 1382 of 14700 (World Music,Melodic Hardcore,2010s)
# Extracted 1383 of 14700 (World Music,Garage Rock,2010s)
# Extracted 1384 of 14700 (World Music,Folk Punk,2010s)
# Extracted 1385 of 14700 (World Music,Progressive Country,2010s)
# Extracted 1386 of 14700 (World Music,Psychedelic Folk,2010s)
# Extracted 1387 of 14700 (World Music,Bro-country,2010s)
# Extracted 1388 of 14700 (World Music,Yacht Rock,2010s)
# Extracted 1389 of 14700 (World Music,Pop Reggae,2010s)
# Extracted 1390 of 14700 (World Music,Alternative Dance,2010s)
# Extracted 1391 of 14700 (World Music,Progressive Bluegrass,2010s)
# Extracted 1392 of 14700 (World Music,Ska,2010s)
# Extracted 1393 of 14700 (World Music,Anti-folk,2010s)
# Extracted 1394 of 14700 (World Music,Symphonic Metal,2010s)
# Extracted 1395 of 14700 (World Music,Symphonic Prog,2010s)
# Extracted 1396 of 14700 (World Music,Rap Rock,2010s)
# Extracted 1397 of 14700 (World Music,Comedy Rock,2010s)
# Extracted 1398 of 14700 (World Music,Funk,2010s)
# Extracted 1399 of 14700 (World Music,Nu Metal,2010s)
# Extracted 1400 of 14700 (World Music,Celtic Punk,2010s)
# Extracted 1401 of 14700 (Disco,Pop Rock,2010s)
# Extracted 1402 of 14700 (Disco,Singer-songwriter,2010s)
# Extracted 1403 of 14700 (Disco,Alternative Rock,2010s)
# Extracted 1404 of 14700 (Disco,Indie Rock,2010s)
# Extracted 1405 of 14700 (Disco,Indie Pop,2010s)
# Extracted 1406 of 14700 (Disco,Pop Punk,2010s)
# Extracted 1407 of 14700 (Disco,Hard Rock,2010s)
# Extracted 1408 of 14700 (Disco,Contemporary Folk,2010s)
# Extracted 1409 of 14700 (Disco,Folk Rock,2010s)
# Extracted 1410 of 14700 (Disco,Folk Pop,2010s)
# Extracted 1411 of 14700 (Disco,Contemporary Country,2010s)
# Extracted 1412 of 14700 (Disco,Country Pop,2010s)
# Extracted 1413 of 14700 (Disco,Electropop,2010s)
# Extracted 1414 of 14700 (Disco,Indie Folk,2010s)
# Extracted 1415 of 14700 (Disco,Americana,2010s)
# Extracted 1416 of 14700 (Disco,Punk Rock,2010s)
# Extracted 1417 of 14700 (Disco,Power Pop,2010s)
# Extracted 1418 of 14700 (Disco,Country Rock,2010s)
# Extracted 1419 of 14700 (Disco,Dance-pop,2010s)
# Extracted 1420 of 14700 (Disco,Blues Rock,2010s)
# Extracted 1421 of 14700 (Disco,Alternative Country,2010s)
# Extracted 1422 of 14700 (Disco,Adult Contemporary,2010s)
# Extracted 1423 of 14700 (Disco,Synthpop,2010s)
# Extracted 1424 of 14700 (Disco,Pop Soul,2010s)
# Extracted 1425 of 14700 (Disco,Art Pop,2010s)
# Extracted 1426 of 14700 (Disco,Art Rock,2010s)
# Extracted 1427 of 14700 (Disco,Baroque Pop,2010s)
# Extracted 1428 of 14700 (Disco,Post-grunge,2010s)
# Extracted 1429 of 14700 (Disco,Teen Pop,2010s)
# Extracted 1430 of 14700 (Disco,Soft Rock,2010s)
# Extracted 1431 of 14700 (Disco,Progressive Rock,2010s)
# Extracted 1432 of 14700 (Disco,Rock And Roll,2010s)
# Extracted 1433 of 14700 (Disco,Aor,2010s)
# Extracted 1434 of 14700 (Disco,Christian Rock,2010s)
# Extracted 1435 of 14700 (Disco,Britpop,2010s)
# Extracted 1436 of 14700 (Disco,New Wave,2010s)
# Extracted 1437 of 14700 (Disco,Piano Rock,2010s)
# Extracted 1438 of 14700 (Disco,Heartland Rock,2010s)
# Extracted 1439 of 14700 (Disco,Soul,2010s)
# Extracted 1440 of 14700 (Disco,Emo-pop,2010s)
# Extracted 1441 of 14700 (Disco,Psychedelic Rock,2010s)
# Extracted 1442 of 14700 (Disco,Worship Music,2010s)
# Extracted 1443 of 14700 (Disco,Pop Rap,2010s)
# Extracted 1444 of 14700 (Disco,Psychedelic Pop,2010s)
# Extracted 1445 of 14700 (Disco,Blue-eyed Soul,2010s)
# Extracted 1446 of 14700 (Disco,Southern Rock,2010s)
# Extracted 1447 of 14700 (Disco,Contemporary Christian Music,2010s)
# Extracted 1448 of 14700 (Disco,Alternative Metal,2010s)
# Extracted 1449 of 14700 (Disco,Post-hardcore,2010s)
# Extracted 1450 of 14700 (Disco,Roots Rock,2010s)
# Extracted 1451 of 14700 (Disco,Heavy Metal,2010s)
# Extracted 1452 of 14700 (Disco,Neo-psychedelia,2010s)
# Extracted 1453 of 14700 (Disco,Outlaw Country,2010s)
# Extracted 1454 of 14700 (Disco,Glam Rock,2010s)
# Extracted 1455 of 14700 (Disco,Latin Pop,2010s)
# Extracted 1456 of 14700 (Disco,Skate Punk,2010s)
# Extracted 1457 of 14700 (Disco,Post-punk,2010s)
# Extracted 1458 of 14700 (Disco,Vocal Jazz,2010s)
# Extracted 1459 of 14700 (Disco,Lo-fi Indie,2010s)
# Extracted 1460 of 14700 (Disco,Progressive Pop,2010s)
# Extracted 1461 of 14700 (Disco,Indietronica,2010s)
# Extracted 1462 of 14700 (Disco,Garage Rock Revival,2010s)
# Extracted 1463 of 14700 (Disco,Dream Pop,2010s)
# Extracted 1464 of 14700 (Disco,Grunge,2010s)
# Extracted 1465 of 14700 (Disco,Post-punk Revival,2010s)
# Extracted 1466 of 14700 (Disco,Nashville Sound,2010s)
# Extracted 1467 of 14700 (Disco,Jangle Pop,2010s)
# Extracted 1468 of 14700 (Disco,Power Metal,2010s)
# Extracted 1469 of 14700 (Disco,Celtic Rock,2010s)
# Extracted 1470 of 14700 (Disco,Experimental Rock,2010s)
# Extracted 1471 of 14700 (Disco,Chamber Folk,2010s)
# Extracted 1472 of 14700 (Disco,Chanson,2010s)
# Extracted 1473 of 14700 (Disco,Sunshine Pop,2010s)
# Extracted 1474 of 14700 (Disco,Merseybeat,2010s)
# Extracted 1475 of 14700 (Disco,Sophisti-pop,2010s)
# Extracted 1476 of 14700 (Disco,Traditional Pop,2010s)
# Extracted 1477 of 14700 (Disco,Ska Punk,2010s)
# Extracted 1478 of 14700 (Disco,Neo Soul,2010s)
# Extracted 1479 of 14700 (Disco,Alternative R&b,2010s)
# Extracted 1480 of 14700 (Disco,Rockabilly,2010s)
# Extracted 1481 of 14700 (Disco,Bluegrass,2010s)
# Extracted 1482 of 14700 (Disco,Melodic Hardcore,2010s)
# Extracted 1483 of 14700 (Disco,Garage Rock,2010s)
# Extracted 1484 of 14700 (Disco,Folk Punk,2010s)
# Extracted 1485 of 14700 (Disco,Progressive Country,2010s)
# Extracted 1486 of 14700 (Disco,Psychedelic Folk,2010s)
# Extracted 1487 of 14700 (Disco,Bro-country,2010s)
# Extracted 1488 of 14700 (Disco,Yacht Rock,2010s)
# Extracted 1489 of 14700 (Disco,Pop Reggae,2010s)
# Extracted 1490 of 14700 (Disco,Alternative Dance,2010s)
# Extracted 1491 of 14700 (Disco,Progressive Bluegrass,2010s)
# Extracted 1492 of 14700 (Disco,Ska,2010s)
# Extracted 1493 of 14700 (Disco,Anti-folk,2010s)
# Extracted 1494 of 14700 (Disco,Symphonic Metal,2010s)
# Extracted 1495 of 14700 (Disco,Symphonic Prog,2010s)
# Extracted 1496 of 14700 (Disco,Rap Rock,2010s)
# Extracted 1497 of 14700 (Disco,Comedy Rock,2010s)
# Extracted 1498 of 14700 (Disco,Funk,2010s)
# Extracted 1499 of 14700 (Disco,Nu Metal,2010s)
# Extracted 1500 of 14700 (Disco,Celtic Punk,2010s)
# Extracted 1501 of 14700 (Comedy,Pop Rock,2010s)
# Extracted 1502 of 14700 (Comedy,Singer-songwriter,2010s)
# Extracted 1503 of 14700 (Comedy,Alternative Rock,2010s)
# Extracted 1504 of 14700 (Comedy,Indie Rock,2010s)
# Extracted 1505 of 14700 (Comedy,Indie Pop,2010s)
# Extracted 1506 of 14700 (Comedy,Pop Punk,2010s)
# Extracted 1507 of 14700 (Comedy,Hard Rock,2010s)
# Extracted 1508 of 14700 (Comedy,Contemporary Folk,2010s)
# Extracted 1509 of 14700 (Comedy,Folk Rock,2010s)
# Extracted 1510 of 14700 (Comedy,Folk Pop,2010s)
# Extracted 1511 of 14700 (Comedy,Contemporary Country,2010s)
# Extracted 1512 of 14700 (Comedy,Country Pop,2010s)
# Extracted 1513 of 14700 (Comedy,Electropop,2010s)
# Extracted 1514 of 14700 (Comedy,Indie Folk,2010s)
# Extracted 1515 of 14700 (Comedy,Americana,2010s)
# Extracted 1516 of 14700 (Comedy,Punk Rock,2010s)
# Extracted 1517 of 14700 (Comedy,Power Pop,2010s)
# Extracted 1518 of 14700 (Comedy,Country Rock,2010s)
# Extracted 1519 of 14700 (Comedy,Dance-pop,2010s)
# Extracted 1520 of 14700 (Comedy,Blues Rock,2010s)
# Extracted 1521 of 14700 (Comedy,Alternative Country,2010s)
# Extracted 1522 of 14700 (Comedy,Adult Contemporary,2010s)
# Extracted 1523 of 14700 (Comedy,Synthpop,2010s)
# Extracted 1524 of 14700 (Comedy,Pop Soul,2010s)
# Extracted 1525 of 14700 (Comedy,Art Pop,2010s)
# Extracted 1526 of 14700 (Comedy,Art Rock,2010s)
# Extracted 1527 of 14700 (Comedy,Baroque Pop,2010s)
# Extracted 1528 of 14700 (Comedy,Post-grunge,2010s)
# Extracted 1529 of 14700 (Comedy,Teen Pop,2010s)
# Extracted 1530 of 14700 (Comedy,Soft Rock,2010s)
# Extracted 1531 of 14700 (Comedy,Progressive Rock,2010s)
# Extracted 1532 of 14700 (Comedy,Rock And Roll,2010s)
# Extracted 1533 of 14700 (Comedy,Aor,2010s)
# Extracted 1534 of 14700 (Comedy,Christian Rock,2010s)
# Extracted 1535 of 14700 (Comedy,Britpop,2010s)
# Extracted 1536 of 14700 (Comedy,New Wave,2010s)
# Extracted 1537 of 14700 (Comedy,Piano Rock,2010s)
# Extracted 1538 of 14700 (Comedy,Heartland Rock,2010s)
# Extracted 1539 of 14700 (Comedy,Soul,2010s)
# Extracted 1540 of 14700 (Comedy,Emo-pop,2010s)
# Extracted 1541 of 14700 (Comedy,Psychedelic Rock,2010s)
# Extracted 1542 of 14700 (Comedy,Worship Music,2010s)
# Extracted 1543 of 14700 (Comedy,Pop Rap,2010s)
# Extracted 1544 of 14700 (Comedy,Psychedelic Pop,2010s)
# Extracted 1545 of 14700 (Comedy,Blue-eyed Soul,2010s)
# Extracted 1546 of 14700 (Comedy,Southern Rock,2010s)
# Extracted 1547 of 14700 (Comedy,Contemporary Christian Music,2010s)
# Extracted 1548 of 14700 (Comedy,Alternative Metal,2010s)
# Extracted 1549 of 14700 (Comedy,Post-hardcore,2010s)
# Extracted 1550 of 14700 (Comedy,Roots Rock,2010s)
# Extracted 1551 of 14700 (Comedy,Heavy Metal,2010s)
# Extracted 1552 of 14700 (Comedy,Neo-psychedelia,2010s)
# Extracted 1553 of 14700 (Comedy,Outlaw Country,2010s)
# Extracted 1554 of 14700 (Comedy,Glam Rock,2010s)
# Extracted 1555 of 14700 (Comedy,Latin Pop,2010s)
# Extracted 1556 of 14700 (Comedy,Skate Punk,2010s)
# Extracted 1557 of 14700 (Comedy,Post-punk,2010s)
# Extracted 1558 of 14700 (Comedy,Vocal Jazz,2010s)
# Extracted 1559 of 14700 (Comedy,Lo-fi Indie,2010s)
# Extracted 1560 of 14700 (Comedy,Progressive Pop,2010s)
# Extracted 1561 of 14700 (Comedy,Indietronica,2010s)
# Extracted 1562 of 14700 (Comedy,Garage Rock Revival,2010s)
# Extracted 1563 of 14700 (Comedy,Dream Pop,2010s)
# Extracted 1564 of 14700 (Comedy,Grunge,2010s)
# Extracted 1565 of 14700 (Comedy,Post-punk Revival,2010s)
# Extracted 1566 of 14700 (Comedy,Nashville Sound,2010s)
# Extracted 1567 of 14700 (Comedy,Jangle Pop,2010s)
# Extracted 1568 of 14700 (Comedy,Power Metal,2010s)
# Extracted 1569 of 14700 (Comedy,Celtic Rock,2010s)
# Extracted 1570 of 14700 (Comedy,Experimental Rock,2010s)
# Extracted 1571 of 14700 (Comedy,Chamber Folk,2010s)
# Extracted 1572 of 14700 (Comedy,Chanson,2010s)
# Extracted 1573 of 14700 (Comedy,Sunshine Pop,2010s)
# Extracted 1574 of 14700 (Comedy,Merseybeat,2010s)
# Extracted 1575 of 14700 (Comedy,Sophisti-pop,2010s)
# Extracted 1576 of 14700 (Comedy,Traditional Pop,2010s)
# Extracted 1577 of 14700 (Comedy,Ska Punk,2010s)
# Extracted 1578 of 14700 (Comedy,Neo Soul,2010s)
# Extracted 1579 of 14700 (Comedy,Alternative R&b,2010s)
# Extracted 1580 of 14700 (Comedy,Rockabilly,2010s)
# Extracted 1581 of 14700 (Comedy,Bluegrass,2010s)
# Extracted 1582 of 14700 (Comedy,Melodic Hardcore,2010s)
# Extracted 1583 of 14700 (Comedy,Garage Rock,2010s)
# Extracted 1584 of 14700 (Comedy,Folk Punk,2010s)
# Extracted 1585 of 14700 (Comedy,Progressive Country,2010s)
# Extracted 1586 of 14700 (Comedy,Psychedelic Folk,2010s)
# Extracted 1587 of 14700 (Comedy,Bro-country,2010s)
# Extracted 1588 of 14700 (Comedy,Yacht Rock,2010s)
# Extracted 1589 of 14700 (Comedy,Pop Reggae,2010s)
# Extracted 1590 of 14700 (Comedy,Alternative Dance,2010s)
# Extracted 1591 of 14700 (Comedy,Progressive Bluegrass,2010s)
# Extracted 1592 of 14700 (Comedy,Ska,2010s)
# Extracted 1593 of 14700 (Comedy,Anti-folk,2010s)
# Extracted 1594 of 14700 (Comedy,Symphonic Metal,2010s)
# Extracted 1595 of 14700 (Comedy,Symphonic Prog,2010s)
# Extracted 1596 of 14700 (Comedy,Rap Rock,2010s)
# Extracted 1597 of 14700 (Comedy,Comedy Rock,2010s)
# Extracted 1598 of 14700 (Comedy,Funk,2010s)
# Extracted 1599 of 14700 (Comedy,Nu Metal,2010s)
# Extracted 1600 of 14700 (Comedy,Celtic Punk,2010s)
# Extracted 1601 of 14700 (New Age,Pop Rock,2010s)
# Extracted 1602 of 14700 (New Age,Singer-songwriter,2010s)
# Extracted 1603 of 14700 (New Age,Alternative Rock,2010s)
# Extracted 1604 of 14700 (New Age,Indie Rock,2010s)
# Extracted 1605 of 14700 (New Age,Indie Pop,2010s)
# Extracted 1606 of 14700 (New Age,Pop Punk,2010s)
# Extracted 1607 of 14700 (New Age,Hard Rock,2010s)
# Extracted 1608 of 14700 (New Age,Contemporary Folk,2010s)
# Extracted 1609 of 14700 (New Age,Folk Rock,2010s)
# Extracted 1610 of 14700 (New Age,Folk Pop,2010s)
# Extracted 1611 of 14700 (New Age,Contemporary Country,2010s)
# Extracted 1612 of 14700 (New Age,Country Pop,2010s)
# Extracted 1613 of 14700 (New Age,Electropop,2010s)
# Extracted 1614 of 14700 (New Age,Indie Folk,2010s)
# Extracted 1615 of 14700 (New Age,Americana,2010s)
# Extracted 1616 of 14700 (New Age,Punk Rock,2010s)
# Extracted 1617 of 14700 (New Age,Power Pop,2010s)
# Extracted 1618 of 14700 (New Age,Country Rock,2010s)
# Extracted 1619 of 14700 (New Age,Dance-pop,2010s)
# Extracted 1620 of 14700 (New Age,Blues Rock,2010s)
# Extracted 1621 of 14700 (New Age,Alternative Country,2010s)
# Extracted 1622 of 14700 (New Age,Adult Contemporary,2010s)
# Extracted 1623 of 14700 (New Age,Synthpop,2010s)
# Extracted 1624 of 14700 (New Age,Pop Soul,2010s)
# Extracted 1625 of 14700 (New Age,Art Pop,2010s)
# Extracted 1626 of 14700 (New Age,Art Rock,2010s)
# Extracted 1627 of 14700 (New Age,Baroque Pop,2010s)
# Extracted 1628 of 14700 (New Age,Post-grunge,2010s)
# Extracted 1629 of 14700 (New Age,Teen Pop,2010s)
# Extracted 1630 of 14700 (New Age,Soft Rock,2010s)
# Extracted 1631 of 14700 (New Age,Progressive Rock,2010s)
# Extracted 1632 of 14700 (New Age,Rock And Roll,2010s)
# Extracted 1633 of 14700 (New Age,Aor,2010s)
# Extracted 1634 of 14700 (New Age,Christian Rock,2010s)
# Extracted 1635 of 14700 (New Age,Britpop,2010s)
# Extracted 1636 of 14700 (New Age,New Wave,2010s)
# Extracted 1637 of 14700 (New Age,Piano Rock,2010s)
# Extracted 1638 of 14700 (New Age,Heartland Rock,2010s)
# Extracted 1639 of 14700 (New Age,Soul,2010s)
# Extracted 1640 of 14700 (New Age,Emo-pop,2010s)
# Extracted 1641 of 14700 (New Age,Psychedelic Rock,2010s)
# Extracted 1642 of 14700 (New Age,Worship Music,2010s)
# Extracted 1643 of 14700 (New Age,Pop Rap,2010s)
# Extracted 1644 of 14700 (New Age,Psychedelic Pop,2010s)
# Extracted 1645 of 14700 (New Age,Blue-eyed Soul,2010s)
# Extracted 1646 of 14700 (New Age,Southern Rock,2010s)
# Extracted 1647 of 14700 (New Age,Contemporary Christian Music,2010s)
# Extracted 1648 of 14700 (New Age,Alternative Metal,2010s)
# Extracted 1649 of 14700 (New Age,Post-hardcore,2010s)
# Extracted 1650 of 14700 (New Age,Roots Rock,2010s)
# Extracted 1651 of 14700 (New Age,Heavy Metal,2010s)
# Extracted 1652 of 14700 (New Age,Neo-psychedelia,2010s)
# Extracted 1653 of 14700 (New Age,Outlaw Country,2010s)
# Extracted 1654 of 14700 (New Age,Glam Rock,2010s)
# Extracted 1655 of 14700 (New Age,Latin Pop,2010s)
# Extracted 1656 of 14700 (New Age,Skate Punk,2010s)
# Extracted 1657 of 14700 (New Age,Post-punk,2010s)
# Extracted 1658 of 14700 (New Age,Vocal Jazz,2010s)
# Extracted 1659 of 14700 (New Age,Lo-fi Indie,2010s)
# Extracted 1660 of 14700 (New Age,Progressive Pop,2010s)
# Extracted 1661 of 14700 (New Age,Indietronica,2010s)
# Extracted 1662 of 14700 (New Age,Garage Rock Revival,2010s)
# Extracted 1663 of 14700 (New Age,Dream Pop,2010s)
# Extracted 1664 of 14700 (New Age,Grunge,2010s)
# Extracted 1665 of 14700 (New Age,Post-punk Revival,2010s)
# Extracted 1666 of 14700 (New Age,Nashville Sound,2010s)
# Extracted 1667 of 14700 (New Age,Jangle Pop,2010s)
# Extracted 1668 of 14700 (New Age,Power Metal,2010s)
# Extracted 1669 of 14700 (New Age,Celtic Rock,2010s)
# Extracted 1670 of 14700 (New Age,Experimental Rock,2010s)
# Extracted 1671 of 14700 (New Age,Chamber Folk,2010s)
# Extracted 1672 of 14700 (New Age,Chanson,2010s)
# Extracted 1673 of 14700 (New Age,Sunshine Pop,2010s)
# Extracted 1674 of 14700 (New Age,Merseybeat,2010s)
# Extracted 1675 of 14700 (New Age,Sophisti-pop,2010s)
# Extracted 1676 of 14700 (New Age,Traditional Pop,2010s)
# Extracted 1677 of 14700 (New Age,Ska Punk,2010s)
# Extracted 1678 of 14700 (New Age,Neo Soul,2010s)
# Extracted 1679 of 14700 (New Age,Alternative R&b,2010s)
# Extracted 1680 of 14700 (New Age,Rockabilly,2010s)
# Extracted 1681 of 14700 (New Age,Bluegrass,2010s)
# Extracted 1682 of 14700 (New Age,Melodic Hardcore,2010s)
# Extracted 1683 of 14700 (New Age,Garage Rock,2010s)
# Extracted 1684 of 14700 (New Age,Folk Punk,2010s)
# Extracted 1685 of 14700 (New Age,Progressive Country,2010s)
# Extracted 1686 of 14700 (New Age,Psychedelic Folk,2010s)
# Extracted 1687 of 14700 (New Age,Bro-country,2010s)
# Extracted 1688 of 14700 (New Age,Yacht Rock,2010s)
# Extracted 1689 of 14700 (New Age,Pop Reggae,2010s)
# Extracted 1690 of 14700 (New Age,Alternative Dance,2010s)
# Extracted 1691 of 14700 (New Age,Progressive Bluegrass,2010s)
# Extracted 1692 of 14700 (New Age,Ska,2010s)
# Extracted 1693 of 14700 (New Age,Anti-folk,2010s)
# Extracted 1694 of 14700 (New Age,Symphonic Metal,2010s)
# Extracted 1695 of 14700 (New Age,Symphonic Prog,2010s)
# Extracted 1696 of 14700 (New Age,Rap Rock,2010s)
# Extracted 1697 of 14700 (New Age,Comedy Rock,2010s)
# Extracted 1698 of 14700 (New Age,Funk,2010s)
# Extracted 1699 of 14700 (New Age,Nu Metal,2010s)
# Extracted 1700 of 14700 (New Age,Celtic Punk,2010s)
# Extracted 1701 of 14700 (Classical,Pop Rock,2010s)
# Extracted 1702 of 14700 (Classical,Singer-songwriter,2010s)
# Extracted 1703 of 14700 (Classical,Alternative Rock,2010s)
# Extracted 1704 of 14700 (Classical,Indie Rock,2010s)
# Extracted 1705 of 14700 (Classical,Indie Pop,2010s)
# Extracted 1706 of 14700 (Classical,Pop Punk,2010s)
# Extracted 1707 of 14700 (Classical,Hard Rock,2010s)
# Extracted 1708 of 14700 (Classical,Contemporary Folk,2010s)
# Extracted 1709 of 14700 (Classical,Folk Rock,2010s)
# Extracted 1710 of 14700 (Classical,Folk Pop,2010s)
# Extracted 1711 of 14700 (Classical,Contemporary Country,2010s)
# Extracted 1712 of 14700 (Classical,Country Pop,2010s)
# Extracted 1713 of 14700 (Classical,Electropop,2010s)
# Extracted 1714 of 14700 (Classical,Indie Folk,2010s)
# Extracted 1715 of 14700 (Classical,Americana,2010s)
# Extracted 1716 of 14700 (Classical,Punk Rock,2010s)
# Extracted 1717 of 14700 (Classical,Power Pop,2010s)
# Extracted 1718 of 14700 (Classical,Country Rock,2010s)
# Extracted 1719 of 14700 (Classical,Dance-pop,2010s)
# Extracted 1720 of 14700 (Classical,Blues Rock,2010s)
# Extracted 1721 of 14700 (Classical,Alternative Country,2010s)
# Extracted 1722 of 14700 (Classical,Adult Contemporary,2010s)
# Extracted 1723 of 14700 (Classical,Synthpop,2010s)
# Extracted 1724 of 14700 (Classical,Pop Soul,2010s)
# Extracted 1725 of 14700 (Classical,Art Pop,2010s)
# Extracted 1726 of 14700 (Classical,Art Rock,2010s)
# Extracted 1727 of 14700 (Classical,Baroque Pop,2010s)
# Extracted 1728 of 14700 (Classical,Post-grunge,2010s)
# Extracted 1729 of 14700 (Classical,Teen Pop,2010s)
# Extracted 1730 of 14700 (Classical,Soft Rock,2010s)
# Extracted 1731 of 14700 (Classical,Progressive Rock,2010s)
# Extracted 1732 of 14700 (Classical,Rock And Roll,2010s)
# Extracted 1733 of 14700 (Classical,Aor,2010s)
# Extracted 1734 of 14700 (Classical,Christian Rock,2010s)
# Extracted 1735 of 14700 (Classical,Britpop,2010s)
# Extracted 1736 of 14700 (Classical,New Wave,2010s)
# Extracted 1737 of 14700 (Classical,Piano Rock,2010s)
# Extracted 1738 of 14700 (Classical,Heartland Rock,2010s)
# Extracted 1739 of 14700 (Classical,Soul,2010s)
# Extracted 1740 of 14700 (Classical,Emo-pop,2010s)
# Extracted 1741 of 14700 (Classical,Psychedelic Rock,2010s)
# Extracted 1742 of 14700 (Classical,Worship Music,2010s)
# Extracted 1743 of 14700 (Classical,Pop Rap,2010s)
# Extracted 1744 of 14700 (Classical,Psychedelic Pop,2010s)
# Extracted 1745 of 14700 (Classical,Blue-eyed Soul,2010s)
# Extracted 1746 of 14700 (Classical,Southern Rock,2010s)
# Extracted 1747 of 14700 (Classical,Contemporary Christian Music,2010s)
# Extracted 1748 of 14700 (Classical,Alternative Metal,2010s)
# Extracted 1749 of 14700 (Classical,Post-hardcore,2010s)
# Extracted 1750 of 14700 (Classical,Roots Rock,2010s)
# Extracted 1751 of 14700 (Classical,Heavy Metal,2010s)
# Extracted 1752 of 14700 (Classical,Neo-psychedelia,2010s)
# Extracted 1753 of 14700 (Classical,Outlaw Country,2010s)
# Extracted 1754 of 14700 (Classical,Glam Rock,2010s)
# Extracted 1755 of 14700 (Classical,Latin Pop,2010s)
# Extracted 1756 of 14700 (Classical,Skate Punk,2010s)
# Extracted 1757 of 14700 (Classical,Post-punk,2010s)
# Extracted 1758 of 14700 (Classical,Vocal Jazz,2010s)
# Extracted 1759 of 14700 (Classical,Lo-fi Indie,2010s)
# Extracted 1760 of 14700 (Classical,Progressive Pop,2010s)
# Extracted 1761 of 14700 (Classical,Indietronica,2010s)
# Extracted 1762 of 14700 (Classical,Garage Rock Revival,2010s)
# Extracted 1763 of 14700 (Classical,Dream Pop,2010s)
# Extracted 1764 of 14700 (Classical,Grunge,2010s)
# Extracted 1765 of 14700 (Classical,Post-punk Revival,2010s)
# Extracted 1766 of 14700 (Classical,Nashville Sound,2010s)
# Extracted 1767 of 14700 (Classical,Jangle Pop,2010s)
# Extracted 1768 of 14700 (Classical,Power Metal,2010s)
# Extracted 1769 of 14700 (Classical,Celtic Rock,2010s)
# Extracted 1770 of 14700 (Classical,Experimental Rock,2010s)
# Extracted 1771 of 14700 (Classical,Chamber Folk,2010s)
# Extracted 1772 of 14700 (Classical,Chanson,2010s)
# Extracted 1773 of 14700 (Classical,Sunshine Pop,2010s)
# Extracted 1774 of 14700 (Classical,Merseybeat,2010s)
# Extracted 1775 of 14700 (Classical,Sophisti-pop,2010s)
# Extracted 1776 of 14700 (Classical,Traditional Pop,2010s)
# Extracted 1777 of 14700 (Classical,Ska Punk,2010s)
# Extracted 1778 of 14700 (Classical,Neo Soul,2010s)
# Extracted 1779 of 14700 (Classical,Alternative R&b,2010s)
# Extracted 1780 of 14700 (Classical,Rockabilly,2010s)
# Extracted 1781 of 14700 (Classical,Bluegrass,2010s)
# Extracted 1782 of 14700 (Classical,Melodic Hardcore,2010s)
# Extracted 1783 of 14700 (Classical,Garage Rock,2010s)
# Extracted 1784 of 14700 (Classical,Folk Punk,2010s)
# Extracted 1785 of 14700 (Classical,Progressive Country,2010s)
# Extracted 1786 of 14700 (Classical,Psychedelic Folk,2010s)
# Extracted 1787 of 14700 (Classical,Bro-country,2010s)
# Extracted 1788 of 14700 (Classical,Yacht Rock,2010s)
# Extracted 1789 of 14700 (Classical,Pop Reggae,2010s)
# Extracted 1790 of 14700 (Classical,Alternative Dance,2010s)
# Extracted 1791 of 14700 (Classical,Progressive Bluegrass,2010s)
# Extracted 1792 of 14700 (Classical,Ska,2010s)
# Extracted 1793 of 14700 (Classical,Anti-folk,2010s)
# Extracted 1794 of 14700 (Classical,Symphonic Metal,2010s)
# Extracted 1795 of 14700 (Classical,Symphonic Prog,2010s)
# Extracted 1796 of 14700 (Classical,Rap Rock,2010s)
# Extracted 1797 of 14700 (Classical,Comedy Rock,2010s)
# Extracted 1798 of 14700 (Classical,Funk,2010s)
# Extracted 1799 of 14700 (Classical,Nu Metal,2010s)
# Extracted 1800 of 14700 (Classical,Celtic Punk,2010s)
# Extracted 1801 of 14700 (Experimental,Pop Rock,2010s)
# Extracted 1802 of 14700 (Experimental,Singer-songwriter,2010s)
# Extracted 1803 of 14700 (Experimental,Alternative Rock,2010s)
# Extracted 1804 of 14700 (Experimental,Indie Rock,2010s)
# Extracted 1805 of 14700 (Experimental,Indie Pop,2010s)
# Extracted 1806 of 14700 (Experimental,Pop Punk,2010s)
# Extracted 1807 of 14700 (Experimental,Hard Rock,2010s)
# Extracted 1808 of 14700 (Experimental,Contemporary Folk,2010s)
# Extracted 1809 of 14700 (Experimental,Folk Rock,2010s)
# Extracted 1810 of 14700 (Experimental,Folk Pop,2010s)
# Extracted 1811 of 14700 (Experimental,Contemporary Country,2010s)
# Extracted 1812 of 14700 (Experimental,Country Pop,2010s)
# Extracted 1813 of 14700 (Experimental,Electropop,2010s)
# Extracted 1814 of 14700 (Experimental,Indie Folk,2010s)
# Extracted 1815 of 14700 (Experimental,Americana,2010s)
# Extracted 1816 of 14700 (Experimental,Punk Rock,2010s)
# Extracted 1817 of 14700 (Experimental,Power Pop,2010s)
# Extracted 1818 of 14700 (Experimental,Country Rock,2010s)
# Extracted 1819 of 14700 (Experimental,Dance-pop,2010s)
# Extracted 1820 of 14700 (Experimental,Blues Rock,2010s)
# Extracted 1821 of 14700 (Experimental,Alternative Country,2010s)
# Extracted 1822 of 14700 (Experimental,Adult Contemporary,2010s)
# Extracted 1823 of 14700 (Experimental,Synthpop,2010s)
# Extracted 1824 of 14700 (Experimental,Pop Soul,2010s)
# Extracted 1825 of 14700 (Experimental,Art Pop,2010s)
# Extracted 1826 of 14700 (Experimental,Art Rock,2010s)
# Extracted 1827 of 14700 (Experimental,Baroque Pop,2010s)
# Extracted 1828 of 14700 (Experimental,Post-grunge,2010s)
# Extracted 1829 of 14700 (Experimental,Teen Pop,2010s)
# Extracted 1830 of 14700 (Experimental,Soft Rock,2010s)
# Extracted 1831 of 14700 (Experimental,Progressive Rock,2010s)
# Extracted 1832 of 14700 (Experimental,Rock And Roll,2010s)
# Extracted 1833 of 14700 (Experimental,Aor,2010s)
# Extracted 1834 of 14700 (Experimental,Christian Rock,2010s)
# Extracted 1835 of 14700 (Experimental,Britpop,2010s)
# Extracted 1836 of 14700 (Experimental,New Wave,2010s)
# Extracted 1837 of 14700 (Experimental,Piano Rock,2010s)
# Extracted 1838 of 14700 (Experimental,Heartland Rock,2010s)
# Extracted 1839 of 14700 (Experimental,Soul,2010s)
# Extracted 1840 of 14700 (Experimental,Emo-pop,2010s)
# Extracted 1841 of 14700 (Experimental,Psychedelic Rock,2010s)
# Extracted 1842 of 14700 (Experimental,Worship Music,2010s)
# Extracted 1843 of 14700 (Experimental,Pop Rap,2010s)
# Extracted 1844 of 14700 (Experimental,Psychedelic Pop,2010s)
# Extracted 1845 of 14700 (Experimental,Blue-eyed Soul,2010s)
# Extracted 1846 of 14700 (Experimental,Southern Rock,2010s)
# Extracted 1847 of 14700 (Experimental,Contemporary Christian Music,2010s)
# Extracted 1848 of 14700 (Experimental,Alternative Metal,2010s)
# Extracted 1849 of 14700 (Experimental,Post-hardcore,2010s)
# Extracted 1850 of 14700 (Experimental,Roots Rock,2010s)
# Extracted 1851 of 14700 (Experimental,Heavy Metal,2010s)
# Extracted 1852 of 14700 (Experimental,Neo-psychedelia,2010s)
# Extracted 1853 of 14700 (Experimental,Outlaw Country,2010s)
# Extracted 1854 of 14700 (Experimental,Glam Rock,2010s)
# Extracted 1855 of 14700 (Experimental,Latin Pop,2010s)
# Extracted 1856 of 14700 (Experimental,Skate Punk,2010s)
# Extracted 1857 of 14700 (Experimental,Post-punk,2010s)
# Extracted 1858 of 14700 (Experimental,Vocal Jazz,2010s)
# Extracted 1859 of 14700 (Experimental,Lo-fi Indie,2010s)
# Extracted 1860 of 14700 (Experimental,Progressive Pop,2010s)
# Extracted 1861 of 14700 (Experimental,Indietronica,2010s)
# Extracted 1862 of 14700 (Experimental,Garage Rock Revival,2010s)
# Extracted 1863 of 14700 (Experimental,Dream Pop,2010s)
# Extracted 1864 of 14700 (Experimental,Grunge,2010s)
# Extracted 1865 of 14700 (Experimental,Post-punk Revival,2010s)
# Extracted 1866 of 14700 (Experimental,Nashville Sound,2010s)
# Extracted 1867 of 14700 (Experimental,Jangle Pop,2010s)
# Extracted 1868 of 14700 (Experimental,Power Metal,2010s)
# Extracted 1869 of 14700 (Experimental,Celtic Rock,2010s)
# Extracted 1870 of 14700 (Experimental,Experimental Rock,2010s)
# Extracted 1871 of 14700 (Experimental,Chamber Folk,2010s)
# Extracted 1872 of 14700 (Experimental,Chanson,2010s)
# Extracted 1873 of 14700 (Experimental,Sunshine Pop,2010s)
# Extracted 1874 of 14700 (Experimental,Merseybeat,2010s)
# Extracted 1875 of 14700 (Experimental,Sophisti-pop,2010s)
# Extracted 1876 of 14700 (Experimental,Traditional Pop,2010s)
# Extracted 1877 of 14700 (Experimental,Ska Punk,2010s)
# Extracted 1878 of 14700 (Experimental,Neo Soul,2010s)
# Extracted 1879 of 14700 (Experimental,Alternative R&b,2010s)
# Extracted 1880 of 14700 (Experimental,Rockabilly,2010s)
# Extracted 1881 of 14700 (Experimental,Bluegrass,2010s)
# Extracted 1882 of 14700 (Experimental,Melodic Hardcore,2010s)
# Extracted 1883 of 14700 (Experimental,Garage Rock,2010s)
# Extracted 1884 of 14700 (Experimental,Folk Punk,2010s)
# Extracted 1885 of 14700 (Experimental,Progressive Country,2010s)
# Extracted 1886 of 14700 (Experimental,Psychedelic Folk,2010s)
# Extracted 1887 of 14700 (Experimental,Bro-country,2010s)
# Extracted 1888 of 14700 (Experimental,Yacht Rock,2010s)
# Extracted 1889 of 14700 (Experimental,Pop Reggae,2010s)
# Extracted 1890 of 14700 (Experimental,Alternative Dance,2010s)
# Extracted 1891 of 14700 (Experimental,Progressive Bluegrass,2010s)
# Extracted 1892 of 14700 (Experimental,Ska,2010s)
# Extracted 1893 of 14700 (Experimental,Anti-folk,2010s)
# Extracted 1894 of 14700 (Experimental,Symphonic Metal,2010s)
# Extracted 1895 of 14700 (Experimental,Symphonic Prog,2010s)
# Extracted 1896 of 14700 (Experimental,Rap Rock,2010s)
# Extracted 1897 of 14700 (Experimental,Comedy Rock,2010s)
# Extracted 1898 of 14700 (Experimental,Funk,2010s)
# Extracted 1899 of 14700 (Experimental,Nu Metal,2010s)
# Extracted 1900 of 14700 (Experimental,Celtic Punk,2010s)
# Extracted 1901 of 14700 (Darkwave,Pop Rock,2010s)
# Extracted 1902 of 14700 (Darkwave,Singer-songwriter,2010s)
# Extracted 1903 of 14700 (Darkwave,Alternative Rock,2010s)
# Extracted 1904 of 14700 (Darkwave,Indie Rock,2010s)
# Extracted 1905 of 14700 (Darkwave,Indie Pop,2010s)
# Extracted 1906 of 14700 (Darkwave,Pop Punk,2010s)
# Extracted 1907 of 14700 (Darkwave,Hard Rock,2010s)
# Extracted 1908 of 14700 (Darkwave,Contemporary Folk,2010s)
# Extracted 1909 of 14700 (Darkwave,Folk Rock,2010s)
# Extracted 1910 of 14700 (Darkwave,Folk Pop,2010s)
# Extracted 1911 of 14700 (Darkwave,Contemporary Country,2010s)
# Extracted 1912 of 14700 (Darkwave,Country Pop,2010s)
# Extracted 1913 of 14700 (Darkwave,Electropop,2010s)
# Extracted 1914 of 14700 (Darkwave,Indie Folk,2010s)
# Extracted 1915 of 14700 (Darkwave,Americana,2010s)
# Extracted 1916 of 14700 (Darkwave,Punk Rock,2010s)
# Extracted 1917 of 14700 (Darkwave,Power Pop,2010s)
# Extracted 1918 of 14700 (Darkwave,Country Rock,2010s)
# Extracted 1919 of 14700 (Darkwave,Dance-pop,2010s)
# Extracted 1920 of 14700 (Darkwave,Blues Rock,2010s)
# Extracted 1921 of 14700 (Darkwave,Alternative Country,2010s)
# Extracted 1922 of 14700 (Darkwave,Adult Contemporary,2010s)
# Extracted 1923 of 14700 (Darkwave,Synthpop,2010s)
# Extracted 1924 of 14700 (Darkwave,Pop Soul,2010s)
# Extracted 1925 of 14700 (Darkwave,Art Pop,2010s)
# Extracted 1926 of 14700 (Darkwave,Art Rock,2010s)
# Extracted 1927 of 14700 (Darkwave,Baroque Pop,2010s)
# Extracted 1928 of 14700 (Darkwave,Post-grunge,2010s)
# Extracted 1929 of 14700 (Darkwave,Teen Pop,2010s)
# Extracted 1930 of 14700 (Darkwave,Soft Rock,2010s)
# Extracted 1931 of 14700 (Darkwave,Progressive Rock,2010s)
# Extracted 1932 of 14700 (Darkwave,Rock And Roll,2010s)
# Extracted 1933 of 14700 (Darkwave,Aor,2010s)
# Extracted 1934 of 14700 (Darkwave,Christian Rock,2010s)
# Extracted 1935 of 14700 (Darkwave,Britpop,2010s)
# Extracted 1936 of 14700 (Darkwave,New Wave,2010s)
# Extracted 1937 of 14700 (Darkwave,Piano Rock,2010s)
# Extracted 1938 of 14700 (Darkwave,Heartland Rock,2010s)
# Extracted 1939 of 14700 (Darkwave,Soul,2010s)
# Extracted 1940 of 14700 (Darkwave,Emo-pop,2010s)
# Extracted 1941 of 14700 (Darkwave,Psychedelic Rock,2010s)
# Extracted 1942 of 14700 (Darkwave,Worship Music,2010s)
# Extracted 1943 of 14700 (Darkwave,Pop Rap,2010s)
# Extracted 1944 of 14700 (Darkwave,Psychedelic Pop,2010s)
# Extracted 1945 of 14700 (Darkwave,Blue-eyed Soul,2010s)
# Extracted 1946 of 14700 (Darkwave,Southern Rock,2010s)
# Extracted 1947 of 14700 (Darkwave,Contemporary Christian Music,2010s)
# Extracted 1948 of 14700 (Darkwave,Alternative Metal,2010s)
# Extracted 1949 of 14700 (Darkwave,Post-hardcore,2010s)
# Extracted 1950 of 14700 (Darkwave,Roots Rock,2010s)
# Extracted 1951 of 14700 (Darkwave,Heavy Metal,2010s)
# Extracted 1952 of 14700 (Darkwave,Neo-psychedelia,2010s)
# Extracted 1953 of 14700 (Darkwave,Outlaw Country,2010s)
# Extracted 1954 of 14700 (Darkwave,Glam Rock,2010s)
# Extracted 1955 of 14700 (Darkwave,Latin Pop,2010s)
# Extracted 1956 of 14700 (Darkwave,Skate Punk,2010s)
# Extracted 1957 of 14700 (Darkwave,Post-punk,2010s)
# Extracted 1958 of 14700 (Darkwave,Vocal Jazz,2010s)
# Extracted 1959 of 14700 (Darkwave,Lo-fi Indie,2010s)
# Extracted 1960 of 14700 (Darkwave,Progressive Pop,2010s)
# Extracted 1961 of 14700 (Darkwave,Indietronica,2010s)
# Extracted 1962 of 14700 (Darkwave,Garage Rock Revival,2010s)
# Extracted 1963 of 14700 (Darkwave,Dream Pop,2010s)
# Extracted 1964 of 14700 (Darkwave,Grunge,2010s)
# Extracted 1965 of 14700 (Darkwave,Post-punk Revival,2010s)
# Extracted 1966 of 14700 (Darkwave,Nashville Sound,2010s)
# Extracted 1967 of 14700 (Darkwave,Jangle Pop,2010s)
# Extracted 1968 of 14700 (Darkwave,Power Metal,2010s)
# Extracted 1969 of 14700 (Darkwave,Celtic Rock,2010s)
# Extracted 1970 of 14700 (Darkwave,Experimental Rock,2010s)
# Extracted 1971 of 14700 (Darkwave,Chamber Folk,2010s)
# Extracted 1972 of 14700 (Darkwave,Chanson,2010s)
# Extracted 1973 of 14700 (Darkwave,Sunshine Pop,2010s)
# Extracted 1974 of 14700 (Darkwave,Merseybeat,2010s)
# Extracted 1975 of 14700 (Darkwave,Sophisti-pop,2010s)
# Extracted 1976 of 14700 (Darkwave,Traditional Pop,2010s)
# Extracted 1977 of 14700 (Darkwave,Ska Punk,2010s)
# Extracted 1978 of 14700 (Darkwave,Neo Soul,2010s)
# Extracted 1979 of 14700 (Darkwave,Alternative R&b,2010s)
# Extracted 1980 of 14700 (Darkwave,Rockabilly,2010s)
# Extracted 1981 of 14700 (Darkwave,Bluegrass,2010s)
# Extracted 1982 of 14700 (Darkwave,Melodic Hardcore,2010s)
# Extracted 1983 of 14700 (Darkwave,Garage Rock,2010s)
# Extracted 1984 of 14700 (Darkwave,Folk Punk,2010s)
# Extracted 1985 of 14700 (Darkwave,Progressive Country,2010s)
# Extracted 1986 of 14700 (Darkwave,Psychedelic Folk,2010s)
# Extracted 1987 of 14700 (Darkwave,Bro-country,2010s)
# Extracted 1988 of 14700 (Darkwave,Yacht Rock,2010s)
# Extracted 1989 of 14700 (Darkwave,Pop Reggae,2010s)
# Extracted 1990 of 14700 (Darkwave,Alternative Dance,2010s)
# Extracted 1991 of 14700 (Darkwave,Progressive Bluegrass,2010s)
# Extracted 1992 of 14700 (Darkwave,Ska,2010s)
# Extracted 1993 of 14700 (Darkwave,Anti-folk,2010s)
# Extracted 1994 of 14700 (Darkwave,Symphonic Metal,2010s)
# Extracted 1995 of 14700 (Darkwave,Symphonic Prog,2010s)
# Extracted 1996 of 14700 (Darkwave,Rap Rock,2010s)
# Extracted 1997 of 14700 (Darkwave,Comedy Rock,2010s)
# Extracted 1998 of 14700 (Darkwave,Funk,2010s)
# Extracted 1999 of 14700 (Darkwave,Nu Metal,2010s)
# Extracted 2000 of 14700 (Darkwave,Celtic Punk,2010s)
# Extracted 2001 of 14700 (Soundtrack,Pop Rock,2010s)
# Extracted 2002 of 14700 (Soundtrack,Singer-songwriter,2010s)
# Extracted 2003 of 14700 (Soundtrack,Alternative Rock,2010s)
# Extracted 2004 of 14700 (Soundtrack,Indie Rock,2010s)
# Extracted 2005 of 14700 (Soundtrack,Indie Pop,2010s)
# Extracted 2006 of 14700 (Soundtrack,Pop Punk,2010s)
# Extracted 2007 of 14700 (Soundtrack,Hard Rock,2010s)
# Extracted 2008 of 14700 (Soundtrack,Contemporary Folk,2010s)
# Extracted 2009 of 14700 (Soundtrack,Folk Rock,2010s)
# Extracted 2010 of 14700 (Soundtrack,Folk Pop,2010s)
# Extracted 2011 of 14700 (Soundtrack,Contemporary Country,2010s)
# Extracted 2012 of 14700 (Soundtrack,Country Pop,2010s)
# Extracted 2013 of 14700 (Soundtrack,Electropop,2010s)
# Extracted 2014 of 14700 (Soundtrack,Indie Folk,2010s)
# Extracted 2015 of 14700 (Soundtrack,Americana,2010s)
# Extracted 2016 of 14700 (Soundtrack,Punk Rock,2010s)
# Extracted 2017 of 14700 (Soundtrack,Power Pop,2010s)
# Extracted 2018 of 14700 (Soundtrack,Country Rock,2010s)
# Extracted 2019 of 14700 (Soundtrack,Dance-pop,2010s)
# Extracted 2020 of 14700 (Soundtrack,Blues Rock,2010s)
# Extracted 2021 of 14700 (Soundtrack,Alternative Country,2010s)
# Extracted 2022 of 14700 (Soundtrack,Adult Contemporary,2010s)
# Extracted 2023 of 14700 (Soundtrack,Synthpop,2010s)
# Extracted 2024 of 14700 (Soundtrack,Pop Soul,2010s)
# Extracted 2025 of 14700 (Soundtrack,Art Pop,2010s)
# Extracted 2026 of 14700 (Soundtrack,Art Rock,2010s)
# Extracted 2027 of 14700 (Soundtrack,Baroque Pop,2010s)
# Extracted 2028 of 14700 (Soundtrack,Post-grunge,2010s)
# Extracted 2029 of 14700 (Soundtrack,Teen Pop,2010s)
# Extracted 2030 of 14700 (Soundtrack,Soft Rock,2010s)
# Extracted 2031 of 14700 (Soundtrack,Progressive Rock,2010s)
# Extracted 2032 of 14700 (Soundtrack,Rock And Roll,2010s)
# Extracted 2033 of 14700 (Soundtrack,Aor,2010s)
# Extracted 2034 of 14700 (Soundtrack,Christian Rock,2010s)
# Extracted 2035 of 14700 (Soundtrack,Britpop,2010s)
# Extracted 2036 of 14700 (Soundtrack,New Wave,2010s)
# Extracted 2037 of 14700 (Soundtrack,Piano Rock,2010s)
# Extracted 2038 of 14700 (Soundtrack,Heartland Rock,2010s)
# ...
# Extracted 5675 of 14700 (Disco,Sophisti-pop,1990s)
# Extracted 5676 of 14700 (Disco,Traditional Pop,1990s)
# Extracted 5677 of 14700 (Disco,Ska Punk,1990s)
# Extracted 5678 of 14700 (Disco,Neo Soul,1990s)
# Extracted 5679 of 14700 (Disco,Alternative R&b,1990s)
# Extracted 5680 of 14700 (Disco,Rockabilly,1990s)
# Extracted 5681 of 14700 (Disco,Bluegrass,1990s)
# Extracted 5682 of 14700 (Disco,Melodic Hardcore,1990s)
# Extracted 5683 of 14700 (Disco,Garage Rock,1990s)
# Extracted 5684 of 14700 (Disco,Folk Punk,1990s)
# Extracted 5685 of 14700 (Disco,Progressive Country,1990s)
# Extracted 5686 of 14700 (Disco,Psychedelic Folk,1990s)
# Extracted 5687 of 14700 (Disco,Bro-country,1990s)
# Extracted 5688 of 14700 (Disco,Yacht Rock,1990s)
# Extracted 5689 of 14700 (Disco,Pop Reggae,1990s)
# Extracted 5690 of 14700 (Disco,Alternative Dance,1990s)
# Extracted 5691 of 14700 (Disco,Progressive Bluegrass,1990s)
# Extracted 5692 of 14700 (Disco,Ska,1990s)
# Extracted 5693 of 14700 (Disco,Anti-folk,1990s)
# Extracted 5694 of 14700 (Disco,Symphonic Metal,1990s)
# Extracted 5695 of 14700 (Disco,Symphonic Prog,1990s)
# Extracted 5696 of 14700 (Disco,Rap Rock,1990s)
# Extracted 5697 of 14700 (Disco,Comedy Rock,1990s)
# Extracted 5698 of 14700 (Disco,Funk,1990s)
# Extracted 5699 of 14700 (Disco,Nu Metal,1990s)
# Extracted 5700 of 14700 (Disco,Celtic Punk,1990s)
# Extracted 5701 of 14700 (Comedy,Pop Rock,1990s)
# Extracted 5702 of 14700 (Comedy,Singer-songwriter,1990s)
# Extracted 5703 of 14700 (Comedy,Alternative Rock,1990s)
# Extracted 5704 of 14700 (Comedy,Indie Rock,1990s)
# Extracted 5705 of 14700 (Comedy,Indie Pop,1990s)
# Extracted 5706 of 14700 (Comedy,Pop Punk,1990s)
# Extracted 5707 of 14700 (Comedy,Hard Rock,1990s)
# Extracted 5708 of 14700 (Comedy,Contemporary Folk,1990s)
# Extracted 5709 of 14700 (Comedy,Folk Rock,1990s)
# Extracted 5710 of 14700 (Comedy,Folk Pop,1990s)
# Extracted 5711 of 14700 (Comedy,Contemporary Country,1990s)
# Extracted 5712 of 14700 (Comedy,Country Pop,1990s)
# Extracted 5713 of 14700 (Comedy,Electropop,1990s)
# Extracted 5714 of 14700 (Comedy,Indie Folk,1990s)
# Extracted 5715 of 14700 (Comedy,Americana,1990s)
# Extracted 5716 of 14700 (Comedy,Punk Rock,1990s)
# Extracted 5717 of 14700 (Comedy,Power Pop,1990s)
# Extracted 5718 of 14700 (Comedy,Country Rock,1990s)
# Extracted 5719 of 14700 (Comedy,Dance-pop,1990s)
# Extracted 5720 of 14700 (Comedy,Blues Rock,1990s)
# Extracted 5721 of 14700 (Comedy,Alternative Country,1990s)
# Extracted 5722 of 14700 (Comedy,Adult Contemporary,1990s)
# Extracted 5723 of 14700 (Comedy,Synthpop,1990s)
# Extracted 5724 of 14700 (Comedy,Pop Soul,1990s)
# Extracted 5725 of 14700 (Comedy,Art Pop,1990s)
# Extracted 5726 of 14700 (Comedy,Art Rock,1990s)
# Extracted 5727 of 14700 (Comedy,Baroque Pop,1990s)
# Extracted 5728 of 14700 (Comedy,Post-grunge,1990s)
# Extracted 5729 of 14700 (Comedy,Teen Pop,1990s)
# Extracted 5730 of 14700 (Comedy,Soft Rock,1990s)
# Extracted 5731 of 14700 (Comedy,Progressive Rock,1990s)
# Extracted 5732 of 14700 (Comedy,Rock And Roll,1990s)
# Extracted 5733 of 14700 (Comedy,Aor,1990s)
# Extracted 5734 of 14700 (Comedy,Christian Rock,1990s)
# Extracted 5735 of 14700 (Comedy,Britpop,1990s)
# Extracted 5736 of 14700 (Comedy,New Wave,1990s)
# Extracted 5737 of 14700 (Comedy,Piano Rock,1990s)
# Extracted 5738 of 14700 (Comedy,Heartland Rock,1990s)
# Extracted 5739 of 14700 (Comedy,Soul,1990s)
# Extracted 5740 of 14700 (Comedy,Emo-pop,1990s)
# Extracted 5741 of 14700 (Comedy,Psychedelic Rock,1990s)
# Extracted 5742 of 14700 (Comedy,Worship Music,1990s)
# Extracted 5743 of 14700 (Comedy,Pop Rap,1990s)
# Extracted 5744 of 14700 (Comedy,Psychedelic Pop,1990s)
# Extracted 5745 of 14700 (Comedy,Blue-eyed Soul,1990s)
# Extracted 5746 of 14700 (Comedy,Southern Rock,1990s)
# Extracted 5747 of 14700 (Comedy,Contemporary Christian Music,1990s)
# Extracted 5748 of 14700 (Comedy,Alternative Metal,1990s)
# Extracted 5749 of 14700 (Comedy,Post-hardcore,1990s)
# Extracted 5750 of 14700 (Comedy,Roots Rock,1990s)
# Extracted 5751 of 14700 (Comedy,Heavy Metal,1990s)
# Extracted 5752 of 14700 (Comedy,Neo-psychedelia,1990s)
# Extracted 5753 of 14700 (Comedy,Outlaw Country,1990s)
# Extracted 5754 of 14700 (Comedy,Glam Rock,1990s)
# Extracted 5755 of 14700 (Comedy,Latin Pop,1990s)
# Extracted 5756 of 14700 (Comedy,Skate Punk,1990s)
# Extracted 5757 of 14700 (Comedy,Post-punk,1990s)
# Extracted 5758 of 14700 (Comedy,Vocal Jazz,1990s)
# Extracted 5759 of 14700 (Comedy,Lo-fi Indie,1990s)
# Extracted 5760 of 14700 (Comedy,Progressive Pop,1990s)
# Extracted 5761 of 14700 (Comedy,Indietronica,1990s)
# Extracted 5762 of 14700 (Comedy,Garage Rock Revival,1990s)
# Extracted 5763 of 14700 (Comedy,Dream Pop,1990s)
# Extracted 5764 of 14700 (Comedy,Grunge,1990s)
# Extracted 5765 of 14700 (Comedy,Post-punk Revival,1990s)
# Extracted 5766 of 14700 (Comedy,Nashville Sound,1990s)
# Extracted 5767 of 14700 (Comedy,Jangle Pop,1990s)
# Extracted 5768 of 14700 (Comedy,Power Metal,1990s)
# Extracted 5769 of 14700 (Comedy,Celtic Rock,1990s)
# Extracted 5770 of 14700 (Comedy,Experimental Rock,1990s)
# Extracted 5771 of 14700 (Comedy,Chamber Folk,1990s)
# Extracted 5772 of 14700 (Comedy,Chanson,1990s)
# Extracted 5773 of 14700 (Comedy,Sunshine Pop,1990s)
# Extracted 5774 of 14700 (Comedy,Merseybeat,1990s)
# Extracted 5775 of 14700 (Comedy,Sophisti-pop,1990s)
# Extracted 5776 of 14700 (Comedy,Traditional Pop,1990s)
# Extracted 5777 of 14700 (Comedy,Ska Punk,1990s)
# Extracted 5778 of 14700 (Comedy,Neo Soul,1990s)
# Extracted 5779 of 14700 (Comedy,Alternative R&b,1990s)
# Extracted 5780 of 14700 (Comedy,Rockabilly,1990s)
# Extracted 5781 of 14700 (Comedy,Bluegrass,1990s)
# Extracted 5782 of 14700 (Comedy,Melodic Hardcore,1990s)
# Extracted 5783 of 14700 (Comedy,Garage Rock,1990s)
# Extracted 5784 of 14700 (Comedy,Folk Punk,1990s)
# Extracted 5785 of 14700 (Comedy,Progressive Country,1990s)
# Extracted 5786 of 14700 (Comedy,Psychedelic Folk,1990s)
# Extracted 5787 of 14700 (Comedy,Bro-country,1990s)
# Extracted 5788 of 14700 (Comedy,Yacht Rock,1990s)
# Extracted 5789 of 14700 (Comedy,Pop Reggae,1990s)
# Extracted 5790 of 14700 (Comedy,Alternative Dance,1990s)
# Extracted 5791 of 14700 (Comedy,Progressive Bluegrass,1990s)
# Extracted 5792 of 14700 (Comedy,Ska,1990s)
# Extracted 5793 of 14700 (Comedy,Anti-folk,1990s)
# Extracted 5794 of 14700 (Comedy,Symphonic Metal,1990s)
# Extracted 5795 of 14700 (Comedy,Symphonic Prog,1990s)
# Extracted 5796 of 14700 (Comedy,Rap Rock,1990s)
# Extracted 5797 of 14700 (Comedy,Comedy Rock,1990s)
# Extracted 5798 of 14700 (Comedy,Funk,1990s)
# Extracted 5799 of 14700 (Comedy,Nu Metal,1990s)
# Extracted 5800 of 14700 (Comedy,Celtic Punk,1990s)
# Extracted 5801 of 14700 (New Age,Pop Rock,1990s)
# Extracted 5802 of 14700 (New Age,Singer-songwriter,1990s)
# Extracted 5803 of 14700 (New Age,Alternative Rock,1990s)
# Extracted 5804 of 14700 (New Age,Indie Rock,1990s)
# Extracted 5805 of 14700 (New Age,Indie Pop,1990s)
# Extracted 5806 of 14700 (New Age,Pop Punk,1990s)
# Extracted 5807 of 14700 (New Age,Hard Rock,1990s)
# Extracted 5808 of 14700 (New Age,Contemporary Folk,1990s)
# Extracted 5809 of 14700 (New Age,Folk Rock,1990s)
# Extracted 5810 of 14700 (New Age,Folk Pop,1990s)
# Extracted 5811 of 14700 (New Age,Contemporary Country,1990s)
# Extracted 5812 of 14700 (New Age,Country Pop,1990s)
# Extracted 5813 of 14700 (New Age,Electropop,1990s)
# Extracted 5814 of 14700 (New Age,Indie Folk,1990s)
# Extracted 5815 of 14700 (New Age,Americana,1990s)
# Extracted 5816 of 14700 (New Age,Punk Rock,1990s)
# Extracted 5817 of 14700 (New Age,Power Pop,1990s)
# Extracted 5818 of 14700 (New Age,Country Rock,1990s)
# Extracted 5819 of 14700 (New Age,Dance-pop,1990s)
# Extracted 5820 of 14700 (New Age,Blues Rock,1990s)
# Extracted 5821 of 14700 (New Age,Alternative Country,1990s)
# Extracted 5822 of 14700 (New Age,Adult Contemporary,1990s)
# Extracted 5823 of 14700 (New Age,Synthpop,1990s)
# Extracted 5824 of 14700 (New Age,Pop Soul,1990s)
# Extracted 5825 of 14700 (New Age,Art Pop,1990s)
# Extracted 5826 of 14700 (New Age,Art Rock,1990s)
# Extracted 5827 of 14700 (New Age,Baroque Pop,1990s)
# Extracted 5828 of 14700 (New Age,Post-grunge,1990s)
# Extracted 5829 of 14700 (New Age,Teen Pop,1990s)
# Extracted 5830 of 14700 (New Age,Soft Rock,1990s)
# Extracted 5831 of 14700 (New Age,Progressive Rock,1990s)
# Extracted 5832 of 14700 (New Age,Rock And Roll,1990s)
# Extracted 5833 of 14700 (New Age,Aor,1990s)
# Extracted 5834 of 14700 (New Age,Christian Rock,1990s)
# Extracted 5835 of 14700 (New Age,Britpop,1990s)
# Extracted 5836 of 14700 (New Age,New Wave,1990s)
# Extracted 5837 of 14700 (New Age,Piano Rock,1990s)
# Extracted 5838 of 14700 (New Age,Heartland Rock,1990s)
# Extracted 5839 of 14700 (New Age,Soul,1990s)
# Extracted 5840 of 14700 (New Age,Emo-pop,1990s)
# Extracted 5841 of 14700 (New Age,Psychedelic Rock,1990s)
# Extracted 5842 of 14700 (New Age,Worship Music,1990s)
# Extracted 5843 of 14700 (New Age,Pop Rap,1990s)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-ebecf5a01930> in <module>
#       1 all_combination_extractor = AllCombinationsSongExtractor()
# ----> 2 all_songs_2 = all_combination_extractor.extract_from(1138)
#
# <ipython-input-87-58864cacbfe6> in extract_from(self, startIndexBase1)
#      39
#      40             try:
# ---> 41                 new_extracted_songs = self.extractor.get_all_songs(genre,style,decade)
#      42             except Exception as e:
#      43                 print(f'Error in ({genre["name"]},{style["name"]},{decade["name"]})')
#
# <ipython-input-81-2b676e1f0e90> in get_all_songs(self, genre, style, decade)
#      13
#      14     def get_all_songs(self, genre, style, decade):
# ---> 15         links = self.get_all_filter_song_links(genre['pattern'], style['pattern'], decade['pattern'])
#      16         result = [ self.link_to_song_dict(link,genre,style,decade) for link in links]
#      17
#
# <ipython-input-81-2b676e1f0e90> in get_all_filter_song_links(self, genreFilter, styleFilter, decadeFilter)
#      29     def get_all_filter_song_links(self,genreFilter,styleFilter,decadeFilter):
#      30         list_of_list = [self.get_links_single_page(genreFilter, styleFilter, decadeFilter, f'&page={page}')
# ---> 31                   for page in range(1,self.MAX_NUM_PAGES+1)]
#      32
#      33         return reduce(lambda list1, list2: [*list1, *list2], list_of_list)
#
# <ipython-input-81-2b676e1f0e90> in <listcomp>(.0)
#      29     def get_all_filter_song_links(self,genreFilter,styleFilter,decadeFilter):
#      30         list_of_list = [self.get_links_single_page(genreFilter, styleFilter, decadeFilter, f'&page={page}')
# ---> 31                   for page in range(1,self.MAX_NUM_PAGES+1)]
#      32
#      33         return reduce(lambda list1, list2: [*list1, *list2], list_of_list)
#
# <ipython-input-81-2b676e1f0e90> in get_links_single_page(self, genreFilter, styleFilter, decadeFilter, pageFilter)
#      34
#      35     def get_links_single_page(self,genreFilter,styleFilter,decadeFilter, pageFilter):
# ---> 36         self.driver.get(f'{self.BASE_URL}{genreFilter}{styleFilter}{decadeFilter}')
#      37
#      38         if self.first_time:
#
# /opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# /opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# /opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# /opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     322             response = conn.urlopen(method, url, **kw)
#     323         else:
# --> 324             response = conn.urlopen(method, u.request_uri, **kw)
#     325
#     326         redirect_location = redirect and response.get_redirect_location()
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /opt/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1334         try:
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#    1338                 self.close()
#
# /opt/anaconda3/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# /opt/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# /opt/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
all_songs_2
# Out:
# []

# %% [markdown]
# ##  Sleep an amount of seconds to avoid service denegation

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
from functools import reduce
import time
import random

class RandomWaitSongExtractor:
    BASE_URL = "https://www.ultimate-guitar.com/explore?&type[]=Chords";
    MAX_NUM_PAGES = 20
    
    def __init__(self):
        random.seed()
 
        self.driver = self.create_chrome_driver()
        self.first_time = True
    
    def get_all_songs(self, genre, style, decade):
        links = self.get_all_filter_song_links(genre['pattern'], style['pattern'], decade['pattern'])
        result = [ self.link_to_song_dict(link,genre,style,decade) for link in links]
        
        return result
    
    def link_to_song_dict(self,link, genre, style, decade):
        return {
            "name": link.contents[0],
            "url": link['href'],
            "genre": genre["name"],
            "style": style["name"],
            "decade": decade["name"]
        }
    
    def get_all_filter_song_links(self,genreFilter,styleFilter,decadeFilter):
        list_of_list = [self.get_links_single_page(genreFilter, styleFilter, decadeFilter, f'&page={page}')
                  for page in range(1,self.MAX_NUM_PAGES+1)]
        
        return reduce(lambda list1, list2: [*list1, *list2], list_of_list)
    
    def get_links_single_page(self,genreFilter,styleFilter,decadeFilter, pageFilter):
        self.wait_randomly()
        
        self.driver.get(f'{self.BASE_URL}{genreFilter}{styleFilter}{decadeFilter}')
        
        if self.driver.page_source == '<html><head></head><body></body></html>':
            raise Exception('Denegation error')

        if self.first_time:
            self.click_on_accept_cookies()
            self.first_time = False

        soup = BeautifulSoup(self.driver.page_source, 'lxml')

        return soup.findAll('a', {"class":"_2KJtL _1mes3 kWOod"})
    
    def click_on_accept_cookies(self):
        try:
            button = self.driver.find_element_by_xpath('//button[contains(text(), "thanks")]')

            button.click()
        except:
            print('cookies banner not found. Ignored')
            
    
    def create_chrome_driver(self):
        options = webdriver.ChromeOptions()
        options.add_argument('--ignore-certificate-errors')
        options.add_argument('--incognito')
        options.add_argument('--headless')
        
        driver = webdriver.Chrome("./chromedriver", options=options)
        return driver
    
    def wait_randomly(self):
        n = random.random()
        time.sleep(n)

# %%
all_combination_extractor = AllCombinationsSongExtractor(RandomWaitSongExtractor())
all_songs = all_combination_extractor.extract_from(1)
# Out:
# Extracted 1 of 14700 (Rock,Pop Rock,2010s). 1000 in total
# Extracted 2 of 14700 (Rock,Singer-songwriter,2010s). 2000 in total
# Extracted 3 of 14700 (Rock,Alternative Rock,2010s). 3000 in total
# Extracted 4 of 14700 (Rock,Indie Rock,2010s). 4000 in total
# Extracted 5 of 14700 (Rock,Indie Pop,2010s). 5000 in total
# Extracted 6 of 14700 (Rock,Pop Punk,2010s). 6000 in total
# Extracted 7 of 14700 (Rock,Hard Rock,2010s). 7000 in total
# Extracted 8 of 14700 (Rock,Contemporary Folk,2010s). 8000 in total
# Extracted 9 of 14700 (Rock,Folk Rock,2010s). 9000 in total
# Extracted 10 of 14700 (Rock,Folk Pop,2010s). 10000 in total
# Extracted 11 of 14700 (Rock,Contemporary Country,2010s). 11000 in total
# Extracted 12 of 14700 (Rock,Country Pop,2010s). 12000 in total
# Extracted 13 of 14700 (Rock,Electropop,2010s). 13000 in total
# Extracted 14 of 14700 (Rock,Indie Folk,2010s). 14000 in total
# Extracted 15 of 14700 (Rock,Americana,2010s). 15000 in total
# Extracted 16 of 14700 (Rock,Punk Rock,2010s). 16000 in total
# Extracted 17 of 14700 (Rock,Power Pop,2010s). 17000 in total
# Extracted 18 of 14700 (Rock,Country Rock,2010s). 18000 in total
# Extracted 19 of 14700 (Rock,Dance-pop,2010s). 19000 in total
# Extracted 20 of 14700 (Rock,Blues Rock,2010s). 20000 in total
# Extracted 21 of 14700 (Rock,Alternative Country,2010s). 21000 in total
# Extracted 22 of 14700 (Rock,Adult Contemporary,2010s). 21660 in total
# Extracted 23 of 14700 (Rock,Synthpop,2010s). 22660 in total
# Extracted 24 of 14700 (Rock,Pop Soul,2010s). 23660 in total
# Extracted 25 of 14700 (Rock,Art Pop,2010s). 24660 in total
# Extracted 26 of 14700 (Rock,Art Rock,2010s). 25660 in total
# Extracted 27 of 14700 (Rock,Baroque Pop,2010s). 26660 in total
# Extracted 28 of 14700 (Rock,Post-grunge,2010s). 27660 in total
# Extracted 29 of 14700 (Rock,Teen Pop,2010s). 28660 in total
# Extracted 30 of 14700 (Rock,Soft Rock,2010s). 29660 in total
# Extracted 31 of 14700 (Rock,Progressive Rock,2010s). 30660 in total
# Extracted 32 of 14700 (Rock,Rock And Roll,2010s). 31100 in total
# Extracted 33 of 14700 (Rock,Aor,2010s). 31700 in total
# Extracted 34 of 14700 (Rock,Christian Rock,2010s). 32700 in total
# Extracted 35 of 14700 (Rock,Britpop,2010s). 33700 in total
# Extracted 36 of 14700 (Rock,New Wave,2010s). 34680 in total
# Extracted 37 of 14700 (Rock,Piano Rock,2010s). 35680 in total
# Extracted 38 of 14700 (Rock,Heartland Rock,2010s). 36680 in total
# Extracted 39 of 14700 (Rock,Soul,2010s). 37680 in total
# Extracted 40 of 14700 (Rock,Emo-pop,2010s). 38680 in total
# Extracted 41 of 14700 (Rock,Psychedelic Rock,2010s). 39680 in total
# Extracted 42 of 14700 (Rock,Worship Music,2010s). 40680 in total
# Extracted 43 of 14700 (Rock,Pop Rap,2010s). 41680 in total
# Extracted 44 of 14700 (Rock,Psychedelic Pop,2010s). 42680 in total
# Extracted 45 of 14700 (Rock,Blue-eyed Soul,2010s). 43360 in total
# Extracted 46 of 14700 (Rock,Southern Rock,2010s). 44360 in total
# Extracted 47 of 14700 (Rock,Contemporary Christian Music,2010s). 45360 in total
# Extracted 48 of 14700 (Rock,Alternative Metal,2010s). 46360 in total
# Extracted 49 of 14700 (Rock,Post-hardcore,2010s). 47360 in total
# Extracted 50 of 14700 (Rock,Roots Rock,2010s). 48360 in total
# Extracted 51 of 14700 (Rock,Heavy Metal,2010s). 48860 in total
# Extracted 52 of 14700 (Rock,Neo-psychedelia,2010s). 49860 in total
# Extracted 53 of 14700 (Rock,Outlaw Country,2010s). 49860 in total
# Error in (Rock,Glam Rock,2010s)
# Denegation error

# %%
len(all_songs)
# Out:
# 49860
